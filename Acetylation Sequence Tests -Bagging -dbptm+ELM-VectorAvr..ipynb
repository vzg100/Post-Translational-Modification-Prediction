# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=0)
    y.supervised_training("bagging")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("bagging")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 7, 11, 8, 7, 17, 7, 10, 3, 9, 10, 10, 15, -2.146153846153846, 91.16923076923078, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 263216
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.013174404015056462
# Specificity : 0.9991901572963713
# Accuracy: 0.9753054525560756
# ROC 0.506182280656
# TP 21 FP 52 TN 64158 FN 1573
#
#
#
# None
# Cross Validation: [ 0.97506269  0.97539663  0.97524467  0.97516868  0.97498594]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.10329807093963908
# Specificity : 0.9969896155545735
# Accuracy: 0.9241286591243468
# ROC 0.550143843247
# TP 332 FP 109 TN 36099 FN 2882
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 9, 9, 13, 3, 17, 7, 20, 9, 12, 3, 12, 17, -0.3076923076923076, 87.76923076923079, 0.0]
# Finished working with Data
# Training Data Points: 263216
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.01256281407035176
# Specificity : 0.9993459166510933
# Accuracy: 0.9754726156464653
# ROC 0.505954365361
# TP 20 FP 42 TN 64170 FN 1572
#
#
#
# None
# Cross Validation: [ 0.97494111  0.97532065  0.97513829  0.97530545  0.97506193]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.09925326695706285
# Specificity : 0.9970172337604949
# Accuracy: 0.9238242605651666
# ROC 0.548135250359
# TP 319 FP 108 TN 36100 FN 2895
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 15, 8, 7, 13, 7, 7, 1, 9, 20, 12, 20, 3, -0.3923076923076922, -28.492307692307698, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512739
# Test Data Points: 128185
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9749039254430321
# Specificity : 0.9979659531856302
# Accuracy: 0.9864024651870343
# ROC 0.986434939314
# TP 62660 FP 130 TN 63782 FN 1613
#
#
#
# None
# Cross Validation: [ 0.92755059  0.98638686  0.98797831  0.98982712  0.98933564]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.12196639701306783
# Specificity : 0.9961886875828546
# Accuracy: 0.9249150220688955
# ROC 0.559077542298
# TP 392 FP 138 TN 36070 FN 2822
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [6, 16, 13, 2, 18, 7, 7, 11, 20, 3, 11, 7, 17, -1.353846153846154, 113.55384615384617, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512867
# Test Data Points: 128217
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9751679313347431
# Specificity : 0.9983725843048274
# Accuracy: 0.9867334284845223
# ROC 0.98677025782
# TP 62715 FP 104 TN 63801 FN 1597
#
#
#
# None
# Cross Validation: [ 0.92457377  0.98889383  0.9891824   0.98994665  0.9882386 ]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.11263223397635345
# Specificity : 0.9959677419354839
# Accuracy: 0.9239510932981584
# ROC 0.554299987956
# TP 362 FP 146 TN 36062 FN 2852
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 12, 3, 9, 7, 3, 7, 5, 20, 11, 11, 11, 8, -0.7076923076923076, 34.81538461538462, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512528
# Test Data Points: 128133
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9736817545496966
# Specificity : 0.9985589649609198
# Accuracy: 0.9860769669015789
# ROC 0.986120359755
# TP 62598 FP 92 TN 63751 FN 1692
#
#
#
# None
# Cross Validation: [ 0.93929745  0.99765866  0.9982518   0.99752599  0.99795523]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.1179215930304916
# Specificity : 0.9961886875828546
# Accuracy: 0.924585256963117
# ROC 0.557055140307
# TP 379 FP 138 TN 36070 FN 2835
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 3, 3, 1, 3, 12, 7, 3, 11, 3, 16, 8, 5, 0.7307692307692307, 2.969230769230771, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512452
# Test Data Points: 128114
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9726550327204737
# Specificity : 0.9986235805674601
# Accuracy: 0.985614374697535
# ROC 0.985639306644
# TP 62425 FP 88 TN 63846 FN 1755
#
#
#
# None
# Cross Validation: [ 0.93870303  0.9977676   0.99758807  0.99758026  0.99807982]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.11512134411947729
# Specificity : 0.9963543968183827
# Accuracy: 0.924509157323322
# ROC 0.555737870469
# TP 370 FP 132 TN 36076 FN 2844
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 8, 1, 10, 13, 16, 7, 10, 7, 9, 19, 12, 20, -1.2538461538461538, 60.03846153846155, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4822954822954823
# Specificity : 0.650564617314931
# Accuracy: 0.5652846534653465
# ROC 0.566430049805
# TP 790 FP 557 TN 1037 FN 848
#
#
#
# None
# Cross Validation: [ 0.57549505  0.55940594  0.57425743  0.54764851  0.55108359]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.5214685749844431
# Specificity : 0.6484754750331418
# Accuracy: 0.6381208462279945
# ROC 0.584972025009
# TP 1676 FP 12728 TN 23480 FN 1538
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 19, 15, 4, 9, 19, 7, 7, 19, 5, 20, 15, 19, -1.4923076923076926, 63.730769230769226, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.47619047619047616
# Specificity : 0.6599749058971142
# Accuracy: 0.5668316831683168
# ROC 0.568082691044
# TP 780 FP 542 TN 1052 FN 858
#
#
#
# None
# Cross Validation: [ 0.57982673  0.5779703   0.5677599   0.5832302   0.56346749]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.514312383322962
# Specificity : 0.6596884666372073
# Accuracy: 0.6478362335751611
# ROC 0.58700042498
# TP 1653 FP 12322 TN 23886 FN 1561
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 5, 11, 1, 16, 8, 7, 3, 14, 8, 5, 14, 13, 0.3538461538461538, 5.915384615384618, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 251376
# Test Data Points: 62845
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.014879107253564786
# Specificity : 0.9997713613796707
# Accuracy: 0.9744927997454054
# ROC 0.507325234317
# TP 24 FP 14 TN 61218 FN 1589
#
#
#
# None
# Cross Validation: [ 0.97452462  0.97463601  0.97465152  0.97474699  0.97461929]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.11512134411947729
# Specificity : 0.9969343791427309
# Accuracy: 0.9250418548018873
# ROC 0.556027861631
# TP 370 FP 111 TN 36097 FN 2844
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 19, 3, 3, 17, 3, 7, 19, 15, 8, 17, 17, 3, -1.3461538461538463, 76.3923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 251390
# Test Data Points: 62848
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.011786600496277916
# Specificity : 0.9998203671043178
# Accuracy: 0.9744781059063137
# ROC 0.5058034838
# TP 19 FP 11 TN 61225 FN 1593
#
#
#
# None
# Cross Validation: [ 0.97444628  0.97468495  0.97473269  0.97468495  0.97446138]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.10952084629744867
# Specificity : 0.9967686699072028
# Accuracy: 0.924433057683527
# ROC 0.553144758102
# TP 352 FP 117 TN 36091 FN 2862
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 7, 17, 7, 2, 6, 7, 18, 14, 15, 18, 12, 18, -1.8384615384615386, 32.09230769230769, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.673992673992674
# Specificity : 0.7584692597239648
# Accuracy: 0.7156559405940595
# ROC 0.716230966858
# TP 1104 FP 385 TN 1209 FN 534
#
#
#
# None
# Cross Validation: [ 0.6717203   0.72710396  0.71472772  0.72493812  0.69814241]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.7355320472930927
# Specificity : 0.3307832523199293
# Accuracy: 0.36378164476688146
# ROC 0.533157649807
# TP 2364 FP 24231 TN 11977 FN 850
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 9, 2, 19, 4, 13, 7, 3, 17, 20, 8, 12, 20, -0.16923076923076924, -13.676923076923076, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6288156288156288
# Specificity : 0.7672521957340025
# Accuracy: 0.6970915841584159
# ROC 0.698033912275
# TP 1030 FP 371 TN 1223 FN 608
#
#
#
# None
# Cross Validation: [ 0.67419554  0.72277228  0.72215347  0.72060644  0.69504644]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.7212196639701307
# Specificity : 0.3360859478568272
# Accuracy: 0.36748516057023994
# ROC 0.528652805913
# TP 2318 FP 24039 TN 12169 FN 896
#
#
#
# None
