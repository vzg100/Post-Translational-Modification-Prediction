# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("bagging")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("bagging")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 9, 3, 13, 16, 10, 10, 17, 12, 7, 5, 20, 15, -0.36153846153846153, 40.338461538461544, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1467198104061187
# Specificity : 0.9457704371691825
# Accuracy: 0.7976882074624184
# ROC 0.546245123788
# TP 1362 FP 2213 TN 38595 FN 7921
#
#
#
# None
# Cross: Validation: [ 0.79906971  0.79834701  0.8010421   0.79992014  0.79774406]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.2810126582278481
# Specificity : 0.9309951525520388
# Accuracy: 0.8963422864084222
# ROC 0.60600390539
# TP 111 FP 484 TN 6530 FN 284
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 8, 4, 9, 11, 10, 11, 3, 2, 10, 10, 3, 0, -0.40000000000000013, 93.93333333333335, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.14621096309237824
# Specificity : 0.9466445166491584
# Accuracy: 0.8003034477251403
# ROC 0.546427739871
# TP 1339 FP 2184 TN 38749 FN 7819
#
#
#
# None
# Cross: Validation: [ 0.79926934  0.7981873   0.79794774  0.7995009   0.80129766]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.3139240506329114
# Specificity : 0.9311377245508982
# Accuracy: 0.8982318801457687
# ROC 0.622530887592
# TP 124 FP 483 TN 6531 FN 271
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 1, 17, 10, 3, 4, 10, 11, 1, 5, 4, 12, 13, 0.7846153846153846, 120.12307692307692, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331694
# Test Data Points: 82924
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8066858734731779
# Specificity : 0.929431887599267
# Accuracy: 0.867264000771791
# ROC 0.868058880536
# TP 33880 FP 2888 TN 38037 FN 8119
#
#
#
# None
# Cross: Validation: [ 0.5216521   0.90654093  0.93829215  0.93607322  0.93750829]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.30886075949367087
# Specificity : 0.9161676646706587
# Accuracy: 0.8837899851531921
# ROC 0.612514212082
# TP 122 FP 588 TN 6426 FN 273
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 12, 10, 20, 8, 10, 10, 11, 1, 20, 4, 4, 8, -0.4230769230769231, 71.3, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331670
# Test Data Points: 82918
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8016183764030279
# Specificity : 0.931260269269441
# Accuracy: 0.8653730191273307
# ROC 0.866439322836
# TP 33781 FP 2803 TN 37974 FN 8360
#
#
#
# None
# Cross: Validation: [ 0.52044767  0.9084276   0.93535704  0.93764849  0.93680427]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.3240506329113924
# Specificity : 0.9131736526946108
# Accuracy: 0.8817654204346066
# ROC 0.618612142803
# TP 128 FP 609 TN 6405 FN 267
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 2, 3, 11, 9, 16, 10, 11, 2, 7, 20, 10, 2, -0.8, 80.23076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305961
# Test Data Points: 76491
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.809293212036389
# Specificity : 0.9541775008585586
# Accuracy: 0.8865095239962871
# ROC 0.881735356447
# TP 28912 FP 1868 TN 38898 FN 6813
#
#
#
# None
# Cross: Validation: [ 0.56241176  0.93965224  0.95347104  0.95650412  0.95494836]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.24556962025316456
# Specificity : 0.9352723125178215
# Accuracy: 0.8985018221082467
# ROC 0.590420966385
# TP 97 FP 454 TN 6560 FN 298
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 10, 9, 10, 9, 15, 10, 17, 10, 9, 13, 20, 3, -1.1846153846153848, 131.92307692307693, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305630
# Test Data Points: 76408
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8068687665520933
# Specificity : 0.9543432565869874
# Accuracy: 0.8858365616165846
# ROC 0.88060601157
# TP 28639 FP 1868 TN 39046 FN 6855
#
#
#
# None
# Cross: Validation: [ 0.56252536  0.94081772  0.95479472  0.95560616  0.95399636]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.25063291139240507
# Specificity : 0.9358426005132592
# Accuracy: 0.899311647995681
# ROC 0.593237755953
# TP 99 FP 450 TN 6564 FN 296
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 17, 5, 10, 10, 5, 10, 1, 10, 10, 10, 0, 0, -0.7272727272727273, 91.25454545454546, 0.18181818181818182]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5975609756097561
# Specificity : 0.7090289982425307
# Accuracy: 0.6525579882939518
# ROC 0.653294986926
# TP 5586 FP 2649 TN 6455 FN 3762
#
#
#
# None
# Cross: Validation: [ 0.65608064  0.65662259  0.65667678  0.65691057  0.65799458]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.7341772151898734
# Specificity : 0.6100655831194753
# Accuracy: 0.6166824132811446
# ROC 0.672121399155
# TP 290 FP 2735 TN 4279 FN 105
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 3, 10, 18, 10, 20, 9, 10, 3, 19, 10, 0, 0, -0.6545454545454545, 61.61818181818182, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6004492939666238
# Specificity : 0.7122144112478032
# Accuracy: 0.6555928896596575
# ROC 0.656331852607
# TP 5613 FP 2620 TN 6484 FN 3735
#
#
#
# None
# Cross: Validation: [ 0.65510514  0.6534793   0.6595491   0.65669377  0.65463415]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.7063291139240506
# Specificity : 0.6062161391502708
# Accuracy: 0.6115535159940613
# ROC 0.656272626537
# TP 279 FP 2762 TN 4252 FN 116
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 7, 7, 17, 7, 20, 10, 13, 19, 11, 0, 0, 0, -1.9100000000000001, 41.6, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143752
# Test Data Points: 35939
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3072137946087526
# Specificity : 0.9272109351658201
# Accuracy: 0.7691365925596149
# ROC 0.617212364887
# TP 2815 FP 1949 TN 24827 FN 6348
#
#
#
# None
# Cross: Validation: [ 0.76883052  0.76465678  0.76671582  0.7682333   0.76787155]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.4860759493670886
# Specificity : 0.8622754491017964
# Accuracy: 0.8422189229315697
# ROC 0.674175699234
# TP 192 FP 966 TN 6048 FN 203
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 9, 13, 13, 17, 11, 10, 11, 10, 3, 3, 20, 4, 0.11538461538461536, 102.29230769230769, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143769
# Test Data Points: 35943
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.30156657963446476
# Specificity : 0.9258719300213076
# Accuracy: 0.7662131708538519
# ROC 0.613719254828
# TP 2772 FP 1983 TN 24768 FN 6420
#
#
#
# None
# Cross: Validation: [ 0.76893971  0.76952397  0.76796595  0.7658728   0.76970591]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.4582278481012658
# Specificity : 0.8659823210721415
# Accuracy: 0.8442434876501552
# ROC 0.662105084587
# TP 181 FP 940 TN 6074 FN 214
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 3, 10, 10, 20, 10, 18, 13, 3, 2, 10, 9, 0, 0.3999999999999999, 93.93333333333335, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5907145913564399
# Specificity : 0.6702548330404218
# Accuracy: 0.629958812052894
# ROC 0.630484712198
# TP 5522 FP 3002 TN 6102 FN 3826
#
#
#
# None
# Cross: Validation: [ 0.52866898  0.66236722  0.65629742  0.63604336  0.62612466]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.7189873417721518
# Specificity : 0.47191331622469346
# Accuracy: 0.4850857065730868
# ROC 0.595450328998
# TP 284 FP 3704 TN 3310 FN 111
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 10, 20, 17, 17, 4, 10, 12, 3, 11, 20, 11, 2, 0.02307692307692303, 116.72307692307692, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.582798459563543
# Specificity : 0.6711335676625659
# Accuracy: 0.626381964014741
# ROC 0.626966013613
# TP 5448 FP 2994 TN 6110 FN 3900
#
#
#
# None
# Cross: Validation: [ 0.53105354  0.65830262  0.65927813  0.64243902  0.6295393 ]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.7670886075949367
# Specificity : 0.4577986883376105
# Accuracy: 0.4742880280739641
# ROC 0.612443647966
# TP 303 FP 3803 TN 3211 FN 92
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("bagging")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("bagging")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 1, 2, 10, 3, 13, 15, 17, 7, 5, 3, 16, 11, -0.22307692307692306, -19.053846153846155, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.058823529411764705
# Specificity : 0.999168744804655
# Accuracy: 0.9548514851485148
# ROC 0.528996137108
# TP 7 FP 2 TN 2404 FN 112
#
#
#
# None
# Cross: Validation: [ 0.95368171  0.95366337  0.95524752  0.9540412   0.95721078]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9958027282266527
# Accuracy: 0.9947643979057592
# ROC 0.747901364113
# TP 1 FP 4 TN 949 FN 1
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 20, 10, 19, 9, 18, 15, 16, 18, 9, 17, 2, 17, -2.2153846153846155, 34.723076923076924, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.046296296296296294
# Specificity : 0.9987587918907737
# Accuracy: 0.958019801980198
# ROC 0.522527544094
# TP 5 FP 3 TN 2414 FN 103
#
#
#
# None
# Cross: Validation: [ 0.95249406  0.95524752  0.95485149  0.95562599  0.9548336 ]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.9979013641133263
# Accuracy: 0.9979057591623036
# ROC 0.998950682057
# TP 2 FP 2 TN 951 FN 0
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 10, 2, 1, 15, 13, 15, 20, 8, 3, 4, 9, 9, -0.2923076923076923, 30.261538461538464, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19360
# Test Data Points: 4840
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9472803347280335
# Specificity : 0.996734693877551
# Accuracy: 0.9723140495867768
# ROC 0.972007514303
# TP 2264 FP 8 TN 2442 FN 126
#
#
#
# None
# Cross: Validation: [ 0.85850031  0.97851684  0.97665289  0.97148171  0.97416822]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9979013641133263
# Accuracy: 0.9968586387434555
# ROC 0.748950682057
# TP 1 FP 2 TN 951 FN 1
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 12, 14, 1, 16, 15, 19, 15, 15, 15, 2, 8, -0.2846153846153846, 98.44615384615386, 0.3076923076923077]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19360
# Test Data Points: 4840
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9449081803005008
# Specificity : 0.9930441898527005
# Accuracy: 0.9692148760330579
# ROC 0.968976185077
# TP 2264 FP 17 TN 2427 FN 132
#
#
#
# None
# Cross: Validation: [ 0.84961785  0.9814088   0.97644628  0.97871461  0.96776193]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9958027282266527
# Accuracy: 0.9947643979057592
# ROC 0.747901364113
# TP 1 FP 4 TN 949 FN 1
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 7, 2, 13, 14, 19, 15, 17, 8, 13, 9, 13, 20, 0.10769230769230774, 67.93846153846155, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19232
# Test Data Points: 4809
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9458422174840085
# Specificity : 0.9906655844155844
# Accuracy: 0.9688084840923269
# ROC 0.96825390095
# TP 2218 FP 23 TN 2441 FN 127
#
#
#
# None
# Cross: Validation: [ 0.89207735  0.9808692   0.98835517  0.98627002  0.98668608]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9926547743966422
# Accuracy: 0.9916230366492147
# ROC 0.746327387198
# TP 1 FP 7 TN 946 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 11, 15, 1, 2, 17, 15, 12, 1, 10, 4, 12, 2, 0.4153846153846154, -1.3461538461538456, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19238
# Test Data Points: 4810
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9484492875104777
# Specificity : 0.990924092409241
# Accuracy: 0.9698544698544699
# ROC 0.96968668996
# TP 2263 FP 22 TN 2402 FN 123
#
#
#
# None
# Cross: Validation: [ 0.89189189  0.98794179  0.98419958  0.98606779  0.98689956]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.993704092339979
# Accuracy: 0.9926701570680628
# ROC 0.74685204617
# TP 1 FP 6 TN 947 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 13, 11, 16, 19, 13, 15, 12, 5, 1, 20, 8, 9, -0.18461538461538465, 9.500000000000002, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4406779661016949
# Specificity : 0.7394957983193278
# Accuracy: 0.5907172995780591
# ROC 0.590086882211
# TP 52 FP 31 TN 88 FN 66
#
#
#
# None
# Cross: Validation: [ 0.57983193  0.55932203  0.61864407  0.57627119  0.61440678]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.695697796432319
# Accuracy: 0.6963350785340314
# ROC 0.847848898216
# TP 2 FP 290 TN 663 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 7, 2, 9, 12, 13, 15, 18, 15, 12, 8, 17, 11, -0.9153846153846155, 42.261538461538464, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5084745762711864
# Specificity : 0.6722689075630253
# Accuracy: 0.5907172995780591
# ROC 0.590371741917
# TP 60 FP 39 TN 80 FN 58
#
#
#
# None
# Cross: Validation: [ 0.58823529  0.59745763  0.55084746  0.56779661  0.50847458]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.6673662119622246
# Accuracy: 0.6670157068062827
# ROC 0.583683105981
# TP 1 FP 317 TN 636 FN 1
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 9, 13, 7, 20, 19, 15, 1, 11, 3, 3, 16, 20, -0.32307692307692315, 5.1846153846153875, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9231
# Test Data Points: 2308
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06086956521739131
# Specificity : 0.9981760145918832
# Accuracy: 0.951473136915078
# ROC 0.529522789905
# TP 7 FP 4 TN 2189 FN 108
#
#
#
# None
# Cross: Validation: [ 0.94889563  0.95060659  0.94974003  0.95101864  0.95318596]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9968520461699895
# Accuracy: 0.9958115183246073
# ROC 0.748426023085
# TP 1 FP 3 TN 950 FN 1
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 10, 10, 8, 19, 11, 15, 1, 10, 12, 10, 8, 2, -0.9692307692307693, 76.7769230769231, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9221
# Test Data Points: 2306
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05217391304347826
# Specificity : 0.9981743496120493
# Accuracy: 0.9509973980919341
# ROC 0.525174131328
# TP 6 FP 4 TN 2187 FN 109
#
#
#
# None
# Cross: Validation: [ 0.9514521   0.95097614  0.95184382  0.9505423   0.94967462]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9958027282266527
# Accuracy: 0.9947643979057592
# ROC 0.747901364113
# TP 1 FP 4 TN 949 FN 1
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 19, 13, 10, 19, 8, 15, 13, 19, 11, 3, 1, 13, 0.23076923076923073, -3.1000000000000005, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5169491525423728
# Specificity : 0.7226890756302521
# Accuracy: 0.620253164556962
# ROC 0.619819114086
# TP 61 FP 33 TN 86 FN 57
#
#
#
# None
# Cross: Validation: [ 0.67647059  0.72457627  0.6059322   0.56779661  0.61440678]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4879328436516264
# Accuracy: 0.48900523560209425
# ROC 0.743966421826
# TP 2 FP 488 TN 465 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 1, 14, 17, 12, 3, 15, 19, 2, 14, 11, 7, 10, -0.15384615384615385, 76.06153846153848, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5254237288135594
# Specificity : 0.8067226890756303
# Accuracy: 0.6666666666666666
# ROC 0.666073208945
# TP 62 FP 23 TN 96 FN 56
#
#
#
# None
# Cross: Validation: [ 0.64285714  0.69915254  0.67372881  0.61016949  0.63559322]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.44700944386149005
# Accuracy: 0.4481675392670157
# ROC 0.723504721931
# TP 2 FP 527 TN 426 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("bagging")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("bagging")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 12, 13, 19, 1, 2, 20, 4, 10, 17, 5, 10, 18, -0.2692307692307692, 51.315384615384616, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.10415314730694354
# Specificity : 0.9570338543595822
# Accuracy: 0.7985043121645257
# ROC 0.530593500833
# TP 321 FP 580 TN 12919 FN 2761
#
#
#
# None
# Cross: Validation: [ 0.80810517  0.80394404  0.80416164  0.80669481  0.80675513]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.24812030075187969
# Specificity : 0.9594733593910718
# Accuracy: 0.9405286343612335
# ROC 0.603796830071
# TP 33 FP 197 TN 4664 FN 100
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 3, 18, 17, 10, 15, 20, 7, 2, 15, 10, 17, 17, -1.4153846153846152, 95.37692307692308, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.10962118672477372
# Specificity : 0.9577879099867628
# Accuracy: 0.8051987214281406
# ROC 0.533704548356
# TP 327 FP 574 TN 13024 FN 2656
#
#
#
# None
# Cross: Validation: [ 0.80412495  0.80539139  0.80349819  0.80482509  0.80422195]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.24812030075187969
# Specificity : 0.957416169512446
# Accuracy: 0.9385262314777734
# ROC 0.602768235132
# TP 33 FP 207 TN 4654 FN 100
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 17, 12, 11, 2, 3, 20, 1, 20, 20, 2, 10, 18, -0.3692307692307693, 25.8, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109789
# Test Data Points: 27448
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7961283822682786
# Specificity : 0.9487160566706021
# Accuracy: 0.8714660448848732
# ROC 0.872422219469
# TP 11063 FP 695 TN 12857 FN 2833
#
#
#
# None
# Cross: Validation: [ 0.51919994  0.91871903  0.94465698  0.9464058   0.94494845]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.3157894736842105
# Specificity : 0.9463073441678667
# Accuracy: 0.9295154185022027
# ROC 0.631048408926
# TP 42 FP 261 TN 4600 FN 91
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 11, 20, 19, 9, 20, 18, 13, 9, 9, 1, 1, -1.0153846153846156, 114.65384615384617, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109790
# Test Data Points: 27448
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8033094876797456
# Specificity : 0.9445954882798149
# Accuracy: 0.8733605362867969
# ROC 0.87395248798
# TP 11117 FP 754 TN 12855 FN 2722
#
#
#
# None
# Cross: Validation: [ 0.52125761  0.91686097  0.94491201  0.94593216  0.94454767]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.2932330827067669
# Specificity : 0.9426044023863402
# Accuracy: 0.9253103724469364
# ROC 0.617918742547
# TP 39 FP 279 TN 4582 FN 94
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 14, 9, 17, 2, 1, 20, 17, 5, 18, 12, 17, 1, -0.8846153846153848, 21.246153846153845, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102952
# Test Data Points: 25738
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8056918547595682
# Specificity : 0.9609918578830496
# Accuracy: 0.8872095733934261
# ROC 0.883341856321
# TP 9852 FP 527 TN 12983 FN 2376
#
#
#
# None
# Cross: Validation: [ 0.55938459  0.95015346  0.95279353  0.95593892  0.95523954]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.2857142857142857
# Specificity : 0.9514503188644312
# Accuracy: 0.9337204645574689
# ROC 0.618582302289
# TP 38 FP 236 TN 4625 FN 95
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 1, 13, 19, 12, 2, 20, 17, 19, 10, 2, 1, 17, -0.7076923076923076, 9.53846153846154, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102912
# Test Data Points: 25729
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8068153959303751
# Specificity : 0.9584939223243404
# Accuracy: 0.8863539197015041
# ROC 0.882654659127
# TP 9873 FP 560 TN 12932 FN 2364
#
#
#
# None
# Cross: Validation: [ 0.56131214  0.94694702  0.95860541  0.95491294  0.9529677 ]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.2556390977443609
# Specificity : 0.9551532606459576
# Accuracy: 0.9365238285943132
# ROC 0.605396179195
# TP 34 FP 218 TN 4643 FN 99
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 3, 17, 9, 3, 3, 20, 20, 4, 1, 9, 17, 15, -0.6923076923076924, 12.44615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5424342105263158
# Specificity : 0.6927731092436975
# Accuracy: 0.6167913549459684
# ROC 0.617603659885
# TP 1649 FP 914 TN 2061 FN 1391
#
#
#
# None
# Cross: Validation: [ 0.63098404  0.62134309  0.6232125   0.62454273  0.61356834]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.7518796992481203
# Specificity : 0.6274429129808682
# Accuracy: 0.6307569082899479
# ROC 0.689661306114
# TP 100 FP 1811 TN 3050 FN 33
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 13, 18, 9, 9, 10, 20, 13, 10, 12, 20, 18, 2, -0.2153846153846153, 31.03076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5542763157894737
# Specificity : 0.7018487394957983
# Accuracy: 0.627265170407315
# ROC 0.628062527643
# TP 1685 FP 887 TN 2088 FN 1355
#
#
#
# None
# Cross: Validation: [ 0.6143617   0.62400266  0.62587296  0.6341869   0.61772531]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.7218045112781954
# Specificity : 0.6377288623739972
# Accuracy: 0.6399679615538646
# ROC 0.679766686826
# TP 96 FP 1761 TN 3100 FN 37
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 8, 5, 11, 13, 5, 20, 3, 13, 7, 1, 10, 3, 1.1615384615384616, 30.261538461538464, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47222
# Test Data Points: 11806
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.22385008517887564
# Specificity : 0.934505692706572
# Accuracy: 0.757834999152973
# ROC 0.579177888943
# TP 657 FP 581 TN 8290 FN 2278
#
#
#
# None
# Cross: Validation: [ 0.75683916  0.75453159  0.75815332  0.75468022  0.75332486]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.47368421052631576
# Specificity : 0.9020777617774121
# Accuracy: 0.8906688025630757
# ROC 0.687880986152
# TP 63 FP 476 TN 4385 FN 70
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 15, 13, 17, 2, 1, 20, 3, 13, 4, 2, 3, 16, 0.6538461538461539, 12.192307692307693, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47252
# Test Data Points: 11814
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.23124147339699863
# Specificity : 0.9342490430083314
# Accuracy: 0.7597765363128491
# ROC 0.582745258203
# TP 678 FP 584 TN 8298 FN 2254
#
#
#
# None
# Cross: Validation: [ 0.75613679  0.748688    0.75586219  0.75569288  0.75694209]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.39849624060150374
# Specificity : 0.9047521086196256
# Accuracy: 0.8912695234281137
# ROC 0.651624174611
# TP 53 FP 463 TN 4398 FN 80
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 11, 1, 9, 3, 11, 20, 9, 1, 2, 1, 11, 19, -0.953846153846154, 54.53076923076924, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5648026315789474
# Specificity : 0.6756302521008404
# Accuracy: 0.6196176226101413
# ROC 0.62021644184
# TP 1717 FP 965 TN 2010 FN 1323
#
#
#
# None
# Cross: Validation: [ 0.54621011  0.64611037  0.62986365  0.60791487  0.60325906]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.6992481203007519
# Specificity : 0.4957827607488171
# Accuracy: 0.5012014417300761
# ROC 0.597515440525
# TP 93 FP 2451 TN 2410 FN 40
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 16, 10, 11, 13, 10, 20, 3, 10, 10, 11, 13, 18, 0.2153846153846153, 91.64615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5684210526315789
# Specificity : 0.6783193277310925
# Accuracy: 0.6227763923524522
# ROC 0.623370190181
# TP 1728 FP 957 TN 2018 FN 1312
#
#
#
# None
# Cross: Validation: [ 0.53141622  0.64810505  0.62853342  0.61456601  0.59328234]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.706766917293233
# Specificity : 0.4978399506274429
# Accuracy: 0.5034040849018823
# ROC 0.60230343396
# TP 94 FP 2441 TN 2420 FN 39
#
#
#
# None
