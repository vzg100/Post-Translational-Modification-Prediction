# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /usr/local/Cellar/python3/3.5.2_3/Frameworks/Python.framework/Versions/3.5/lib/python3.5/json/encoder.py:198: DeprecationWarning: Interpreting naive datetime as local 2017-10-21 15:44:55.792865. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print(i, "\n")
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.generate_pca()
    y.generate_tsne()
    del y
# Out:
# pass
#
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 5, 1, 10, 6, 20, 15, 19, 7, 2, 9, 13, 19, -1.023076923076923, 24.169230769230772, 0.23076923076923078]
# Finished working with Data
# ADASYN
#
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 8, 8, 17, 11, 8, 15, 13, 16, 9, 17, 10, 17, -2.56923076923077, 120.8, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# SMOTEENN
#
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 8, 12, 9, 16, 1, 15, 16, 4, 11, 14, 11, 11, -1.1384615384615384, 65.06153846153848, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# random_under_sample
#
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 12, 9, 1, 16, 2, 15, 9, 9, 19, 5, 17, 1, -1.423076923076923, 30.992307692307698, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# ncl
#
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 8, 4, 5, 20, 16, 15, 19, 17, 2, 16, 13, 2, -0.8153846153846153, 76.91538461538461, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# near_miss
#
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [6, 2, 11, 1, 11, 19, 15, 8, 7, 10, 10, 4, 1, -1.1538461538461537, 21.500000000000004, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data

# %%
y = Predictor()
y.load_data(file="Data/Training/clean_Y_filtered.csv")
y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function="pass", random_data=1)
y.generate_pca()
y.generate_tsne()
del y
# Out:
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 12, 3, 18, 7, 15, 15, 11, 11, 19, 5, 19, 11, -1.146153846153846, 52.607692307692325, 0.23076923076923078]
# Finished working with Data
# /usr/local/Cellar/python3/3.5.2_3/Frameworks/Python.framework/Versions/3.5/lib/python3.5/json/encoder.py:198: DeprecationWarning: Interpreting naive datetime as local 2017-10-21 15:45:01.872956. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
