# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 19, 9, 9, 1, 9, 10, 1, 2, 9, 9, 1, 11, -2.0538461538461537, 61.869230769230775, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0805140597539543
# Specificity : 0.9864103252250713
# Accuracy: 0.8217643888123615
# ROC 0.53346219249
# TP 733 FP 557 TN 40430 FN 8371
#
#
#
# None
# Cross: Validation: [ 0.8202707   0.82042682  0.82022719  0.81932521  0.8197245 ]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.06582278481012659
# Specificity : 0.982178500142572
# Accuracy: 0.9333243352679174
# ROC 0.524000642476
# TP 26 FP 125 TN 6889 FN 369
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 20, 15, 18, 18, 13, 10, 17, 17, 20, 9, 19, 5, -1.7461538461538462, 125.73846153846155, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08347007985997155
# Specificity : 0.9865689865689866
# Accuracy: 0.8217643888123615
# ROC 0.535019533214
# TP 763 FP 550 TN 40400 FN 8378
#
#
#
# None
# Cross: Validation: [ 0.81981155  0.81974806  0.82106566  0.81952486  0.82040327]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.06582278481012659
# Specificity : 0.982178500142572
# Accuracy: 0.9333243352679174
# ROC 0.524000642476
# TP 26 FP 125 TN 6889 FN 369
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 15, 7, 10, 10, 10, 10, 4, 9, 18, 19, 18, 7, -1.5307692307692307, 71.8923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331705
# Test Data Points: 82927
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6777185805346779
# Specificity : 0.9923440060660911
# Accuracy: 0.8328288735876131
# ROC 0.8350312933
# TP 28494 FP 313 TN 40570 FN 13550
#
#
#
# None
# Cross: Validation: [ 0.49278893  0.88129175  0.91866242  0.9225454   0.91926537]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.03291139240506329
# Specificity : 0.9920159680638723
# Accuracy: 0.9408827102173033
# ROC 0.512463680234
# TP 13 FP 56 TN 6958 FN 382
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 12, 15, 7, 10, 16, 10, 7, 5, 4, 7, 20, 7, -1.3076923076923077, 3.430769230769231, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331696
# Test Data Points: 82925
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6674413089874318
# Specificity : 0.9911912648754754
# Accuracy: 0.8265541151643051
# ROC 0.829316286931
# TP 28146 FP 359 TN 40396 FN 14024
#
#
#
# None
# Cross: Validation: [ 0.49280675  0.86831315  0.91441561  0.91914283  0.90883218]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.035443037974683546
# Specificity : 0.9894496720844026
# Accuracy: 0.9385882035362397
# ROC 0.51244635503
# TP 14 FP 74 TN 6940 FN 381
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 11, 3, 20, 7, 10, 10, 10, 7, 17, 19, 16, 17, -2.123076923076923, 61.72307692307693, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305944
# Test Data Points: 76486
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.762685816474796
# Specificity : 0.9365325077399381
# Accuracy: 0.8551891849488795
# ROC 0.849609162107
# TP 27295 FP 2583 TN 38115 FN 8493
#
#
#
# None
# Cross: Validation: [ 0.56620079  0.90624428  0.92261329  0.92395994  0.92555403]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.19746835443037974
# Specificity : 0.9177359566581124
# Accuracy: 0.879335942772304
# ROC 0.557602155544
# TP 78 FP 577 TN 6437 FN 317
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 20, 10, 10, 20, 19, 10, 18, 1, 5, 11, 12, 7, -0.8076923076923076, 54.71538461538463, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305888
# Test Data Points: 76473
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.778850458920976
# Specificity : 0.9300635785649409
# Accuracy: 0.8594013573418069
# ROC 0.854457018743
# TP 27833 FP 2849 TN 37888 FN 7903
#
#
#
# None
# Cross: Validation: [ 0.56737672  0.90367716  0.92007532  0.92456062  0.9240114 ]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.22531645569620254
# Specificity : 0.9151696606786427
# Accuracy: 0.8783911459036308
# ROC 0.570243058187
# TP 89 FP 595 TN 6419 FN 306
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 17, 17, 13, 9, 18, 10, 3, 3, 10, 1, 9, 3, -0.46153846153846173, 81.29230769230769, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7258237056054772
# Specificity : 0.6407073813708261
# Accuracy: 0.6838283112941687
# ROC 0.683265543488
# TP 6785 FP 3271 TN 5833 FN 2563
#
#
#
# None
# Cross: Validation: [ 0.68426187  0.68415348  0.68236506  0.68379404  0.67907859]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.810126582278481
# Specificity : 0.5960935272312518
# Accuracy: 0.6075043865568903
# ROC 0.703110054755
# TP 320 FP 2833 TN 4181 FN 75
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 10, 20, 1, 10, 11, 10, 3, 8, 2, 10, 11, 10, -0.18461538461538465, 125.00769230769231, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7241121095421481
# Specificity : 0.6422451669595782
# Accuracy: 0.6837199219596791
# ROC 0.683178638251
# TP 6769 FP 3257 TN 5847 FN 2579
#
#
#
# None
# Cross: Validation: [ 0.68924778  0.68334056  0.68312378  0.68542005  0.68531165]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.8075949367088607
# Specificity : 0.5846877673224978
# Accuracy: 0.5965717370765286
# ROC 0.696141352016
# TP 319 FP 2913 TN 4101 FN 76
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 8, 8, 5, 2, 8, 10, 1, 12, 15, 4, 18, 10, -0.6076923076923078, 80.04615384615386, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143747
# Test Data Points: 35937
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2829859216413838
# Specificity : 0.9536117128557556
# Accuracy: 0.7826195842724768
# ROC 0.618298817249
# TP 2593 FP 1242 TN 25532 FN 6570
#
#
#
# None
# Cross: Validation: [ 0.78276476  0.78100565  0.78172914  0.78058215  0.78570236]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.36455696202531646
# Specificity : 0.920302252637582
# Accuracy: 0.8906735051963828
# ROC 0.642429607331
# TP 144 FP 559 TN 6455 FN 251
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 10, 6, 5, 10, 10, 10, 11, 9, 15, 11, 8, 19, -1.5230769230769232, 139.96923076923076, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143832
# Test Data Points: 35959
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2816840277777778
# Specificity : 0.953333582619751
# Accuracy: 0.7811952501459997
# ROC 0.617508805199
# TP 2596 FP 1248 TN 25495 FN 6620
#
#
#
# None
# Cross: Validation: [ 0.78050001  0.78386496  0.78355905  0.77951442  0.78368607]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.3670886075949367
# Specificity : 0.9205873966353009
# Accuracy: 0.8910784181400999
# ROC 0.643838002115
# TP 145 FP 557 TN 6457 FN 250
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 19, 19, 10, 5, 10, 10, 19, 11, 9, 10, 1, 9, -1.5846153846153845, 61.24615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7001497646555412
# Specificity : 0.7289103690685413
# Accuracy: 0.7143399089529591
# ROC 0.714530066862
# TP 6545 FP 2468 TN 6636 FN 2803
#
#
#
# None
# Cross: Validation: [ 0.64161067  0.75178842  0.74512248  0.71945799  0.69934959]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.7772151898734178
# Specificity : 0.4294268605645851
# Accuracy: 0.4479686867323525
# ROC 0.603321025219
# TP 307 FP 4002 TN 3012 FN 88
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 15, 8, 18, 20, 10, 10, 5, 19, 14, 20, 11, 10, -1.1846153846153846, 66.90000000000002, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7041078305519898
# Specificity : 0.727043057996485
# Accuracy: 0.7154238022978539
# ROC 0.715575444274
# TP 6582 FP 2485 TN 6619 FN 2766
#
#
#
# None
# Cross: Validation: [ 0.64177325  0.75037936  0.74398439  0.71691057  0.70119241]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.8
# Specificity : 0.43213572854291415
# Accuracy: 0.4517478742070455
# ROC 0.616067864271
# TP 316 FP 3983 TN 3031 FN 79
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 20, 17, 17, 15, 15, 15, 10, 12, 7, 19, 13, 10, -0.7461538461538463, 57.73076923076924, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.018518518518518517
# Specificity : 0.9995862639635912
# Accuracy: 0.9576237623762376
# ROC 0.509052391241
# TP 2 FP 1 TN 2416 FN 106
#
#
#
# None
# Cross: Validation: [ 0.95407759  0.95405941  0.95485149  0.9544374   0.9548336 ]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 0 TN 953 FN 2
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 5, 5, 11, 19, 12, 15, 7, 10, 2, 10, 2, 17, 0.09230769230769245, 12.44615384615385, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05555555555555555
# Specificity : 1.0
# Accuracy: 0.9596039603960396
# ROC 0.527777777778
# TP 6 FP 0 TN 2417 FN 102
#
#
#
# None
# Cross: Validation: [ 0.95447348  0.9560396   0.95524752  0.9540412   0.95364501]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 0 TN 953 FN 2
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 15, 15, 5, 19, 10, 15, 2, 16, 5, 1, 13, 16, -0.5076923076923078, 49.70000000000001, 0.38461538461538464]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19348
# Test Data Points: 4838
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8589315525876461
# Specificity : 0.9995904995904996
# Accuracy: 0.9299297230260438
# ROC 0.929261026089
# TP 2058 FP 1 TN 2441 FN 338
#
#
#
# None
# Cross: Validation: [ 0.83877635  0.94047127  0.94646548  0.93382961  0.93424318]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 1 TN 952 FN 2
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 3, 11, 10, 13, 12, 15, 15, 10, 20, 3, 3, 9, 1.0692307692307692, 36.02307692307692, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19363
# Test Data Points: 4841
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8601079286010793
# Specificity : 0.9991776315789473
# Accuracy: 0.9299731460442058
# ROC 0.92964278009
# TP 2072 FP 2 TN 2430 FN 337
#
#
#
# None
# Cross: Validation: [ 0.84861627  0.9562074   0.94587895  0.9196281   0.94421488]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 0 TN 953 FN 2
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 3, 9, 3, 12, 7, 15, 3, 3, 2, 2, 1, 2, 0.9615384615384616, 0.4846153846153852, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19240
# Test Data Points: 4811
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9157540016849199
# Specificity : 0.9737382027082478
# Accuracy: 0.9451257534816047
# ROC 0.944746102197
# TP 2174 FP 64 TN 2373 FN 200
#
#
#
# None
# Cross: Validation: [ 0.85720224  0.97110788  0.97069216  0.9636099   0.96631316]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9695697796432319
# Accuracy: 0.9685863874345549
# ROC 0.734784889822
# TP 1 FP 29 TN 924 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 12, 8, 9, 20, 3, 15, 11, 10, 9, 16, 13, 2, -0.35384615384615387, 91.16923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19225
# Test Data Points: 4807
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.918816067653277
# Specificity : 0.957002457002457
# Accuracy: 0.9382151029748284
# ROC 0.937909262328
# TP 2173 FP 105 TN 2337 FN 192
#
#
#
# None
# Cross: Validation: [ 0.86207614  0.95631371  0.95818598  0.96129838  0.96670135]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9653725078698846
# Accuracy: 0.9643979057591623
# ROC 0.732686253935
# TP 1 FP 33 TN 920 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 3, 5, 12, 2, 3, 15, 19, 15, 9, 2, 17, 20, 0.2076923076923075, 21.646153846153847, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6271186440677966
# Specificity : 0.5546218487394958
# Accuracy: 0.5907172995780591
# ROC 0.590870246404
# TP 74 FP 53 TN 66 FN 44
#
#
#
# None
# Cross: Validation: [ 0.58403361  0.61864407  0.61016949  0.61864407  0.61440678]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6264428121720882
# Accuracy: 0.6272251308900524
# ROC 0.813221406086
# TP 2 FP 356 TN 597 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 8, 10, 9, 1, 10, 15, 12, 9, 10, 3, 7, 17, -0.8307692307692307, 91.20769230769233, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6271186440677966
# Specificity : 0.6134453781512605
# Accuracy: 0.620253164556962
# ROC 0.62028201111
# TP 74 FP 46 TN 73 FN 44
#
#
#
# None
# Cross: Validation: [ 0.62605042  0.62288136  0.62711864  0.63983051  0.58474576]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.5949632738719832
# Accuracy: 0.5958115183246073
# ROC 0.797481636936
# TP 2 FP 386 TN 567 FN 0
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 20, 17, 5, 20, 19, 15, 8, 3, 17, 12, 3, 8, -0.9307692307692309, 49.12307692307692, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9230
# Test Data Points: 2308
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.034782608695652174
# Specificity : 1.0
# Accuracy: 0.9519064124783362
# ROC 0.517391304348
# TP 4 FP 0 TN 2193 FN 111
#
#
#
# None
# Cross: Validation: [ 0.95019489  0.95017331  0.94971825  0.95058518  0.9514521 ]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 0 TN 953 FN 2
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 19, 11, 1, 2, 12, 15, 18, 3, 9, 18, 12, 3, -0.3076923076923077, -3.100000000000001, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9229
# Test Data Points: 2308
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.02608695652173913
# Specificity : 1.0
# Accuracy: 0.951473136915078
# ROC 0.513043478261
# TP 3 FP 0 TN 2193 FN 112
#
#
#
# None
# Cross: Validation: [ 0.95062798  0.94885132  0.95015171  0.95058518  0.95101864]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 0 TN 953 FN 2
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 20, 15, 1, 12, 16, 15, 15, 2, 12, 7, 19, 7, -0.8384615384615385, 55.461538461538474, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.711864406779661
# Specificity : 0.7647058823529411
# Accuracy: 0.7383966244725738
# ROC 0.738285144566
# TP 84 FP 28 TN 91 FN 34
#
#
#
# None
# Cross: Validation: [ 0.73529412  0.78389831  0.77542373  0.64830508  0.69915254]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.378803777544596
# Accuracy: 0.38010471204188484
# ROC 0.689401888772
# TP 2 FP 592 TN 361 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 17, 10, 10, 2, 16, 15, 1, 15, 19, 17, 8, 17, -2.138461538461539, 86.27692307692308, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7372881355932204
# Specificity : 0.7478991596638656
# Accuracy: 0.7426160337552743
# ROC 0.742593647629
# TP 87 FP 30 TN 89 FN 31
#
#
#
# None
# Cross: Validation: [ 0.7394958   0.77542373  0.75        0.64830508  0.70762712]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.36096537250786986
# Accuracy: 0.362303664921466
# ROC 0.680482686254
# TP 2 FP 609 TN 344 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 19, 5, 9, 1, 3, 20, 19, 5, 10, 19, 20, 5, -0.20000000000000004, -10.969230769230771, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.028874875539329572
# Specificity : 0.9952093160377359
# Accuracy: 0.8196128098425909
# ROC 0.512042095789
# TP 87 FP 65 TN 13503 FN 2926
#
#
#
# None
# Cross: Validation: [ 0.81980461  0.81890001  0.82098914  0.81905911  0.82056695]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.022556390977443608
# Specificity : 0.9956799012548858
# Accuracy: 0.9697637164597517
# ROC 0.509118146116
# TP 3 FP 21 TN 4840 FN 130
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 10, 18, 19, 19, 7, 20, 7, 7, 10, 9, 1, 19, -2.515384615384615, 32.330769230769235, 0.0]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.03048180924287119
# Specificity : 0.9937915742793791
# Accuracy: 0.81653700018093
# ROC 0.512136691761
# TP 93 FP 84 TN 13446 FN 2958
#
#
#
# None
# Cross: Validation: [ 0.81926185  0.82076951  0.81911942  0.82038601  0.82008444]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.045112781954887216
# Specificity : 0.9952684632791606
# Accuracy: 0.9699639567480978
# ROC 0.520190622617
# TP 6 FP 23 TN 4838 FN 127
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 18, 7, 10, 7, 17, 20, 20, 19, 2, 9, 8, 19, -2.3538461538461535, 75.62307692307692, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109776
# Test Data Points: 27445
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6645231213872832
# Specificity : 0.9994119808893789
# Accuracy: 0.8305337948624522
# ROC 0.831967551138
# TP 9197 FP 8 TN 13597 FN 4643
#
#
#
# None
# Cross: Validation: [ 0.49458918  0.88846784  0.92778021  0.92668707  0.92799621]
# Number of data points in benchmark 4994
# Benchmark Results
# Failed
# TP 0 FP 1 TN 4860 FN 133
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 17, 17, 2, 11, 2, 20, 10, 19, 10, 19, 10, 19, -1.8846153846153846, 137.63076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109772
# Test Data Points: 27443
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6712596997606788
# Specificity : 0.9988281822176651
# Accuracy: 0.8342382392595562
# ROC 0.835043940989
# TP 9256 FP 16 TN 13638 FN 4533
#
#
#
# None
# Cross: Validation: [ 0.4946072   0.89013992  0.9221295   0.92340208  0.92540631]
# Number of data points in benchmark 4994
# Benchmark Results
# Failed
# TP 0 FP 2 TN 4859 FN 133
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 7, 4, 3, 11, 8, 20, 11, 10, 16, 2, 12, 9, -0.2538461538461539, 72.22307692307695, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102925
# Test Data Points: 25732
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7703056054910933
# Specificity : 0.9482733066548096
# Accuracy: 0.8636328307166175
# ROC 0.859289456073
# TP 9427 FP 698 TN 12796 FN 2811
#
#
#
# None
# Cross: Validation: [ 0.54550754  0.9251127   0.93350433  0.93408729  0.93583615]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.22556390977443608
# Specificity : 0.9481588150586299
# Accuracy: 0.9289146976371646
# ROC 0.586861362417
# TP 30 FP 252 TN 4609 FN 103
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 11, 8, 20, 20, 4, 19, 16, 13, 3, 16, 11, 20, -0.43846153846153846, 85.26153846153848, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102903
# Test Data Points: 25726
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7639379259380902
# Specificity : 0.952166531335351
# Accuracy: 0.8630568296664852
# ROC 0.858052228637
# TP 9304 FP 648 TN 12899 FN 2875
#
#
#
# None
# Cross: Validation: [ 0.54677965  0.92933494  0.93492711  0.94153547  0.93123421]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.17293233082706766
# Specificity : 0.9477473770829048
# Accuracy: 0.9271125350420505
# ROC 0.560339853955
# TP 23 FP 254 TN 4607 FN 110
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 19, 15, 4, 18, 20, 20, 2, 17, 14, 3, 8, 4, -0.7153846153846153, 76.3923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6259868421052631
# Specificity : 0.6383193277310925
# Accuracy: 0.6320864505403159
# ROC 0.632153084918
# TP 1903 FP 1076 TN 1899 FN 1137
#
#
#
# None
# Cross: Validation: [ 0.6456117   0.63314495  0.63684736  0.64216827  0.63734619]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.8270676691729323
# Specificity : 0.6241514091750668
# Accuracy: 0.6295554665598718
# ROC 0.725609539174
# TP 110 FP 1827 TN 3034 FN 23
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 8, 2, 20, 13, 17, 20, 8, 5, 19, 20, 14, 20, -0.13076923076923083, 20.63846153846154, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6371710526315789
# Specificity : 0.641344537815126
# Accuracy: 0.6392352452202826
# ROC 0.639257795223
# TP 1937 FP 1067 TN 1908 FN 1103
#
#
#
# None
# Cross: Validation: [ 0.63829787  0.64361702  0.64582641  0.64166944  0.63634852]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.8045112781954887
# Specificity : 0.6340259205924706
# Accuracy: 0.6385662795354425
# ROC 0.719268599394
# TP 107 FP 1779 TN 3082 FN 26
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 8, 16, 11, 13, 15, 20, 11, 3, 20, 16, 16, 1, -0.7153846153846154, -7.4923076923076914, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47260
# Test Data Points: 11815
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1862611073137389
# Specificity : 0.9683878951513106
# Accuracy: 0.7746931866271689
# ROC 0.577324501233
# TP 545 FP 281 TN 8608 FN 2381
#
#
#
# None
# Cross: Validation: [ 0.76404875  0.76980366  0.76902243  0.76917217  0.77196546]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.23308270676691728
# Specificity : 0.9590619214153466
# Accuracy: 0.9397276732078494
# ROC 0.596072314091
# TP 31 FP 199 TN 4662 FN 102
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 15, 9, 20, 18, 3, 20, 5, 12, 1, 14, 12, 1, 0.2384615384615387, -17.5, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47286
# Test Data Points: 11822
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1802663024923182
# Specificity : 0.968851905993478
# Accuracy: 0.7734731855861953
# ROC 0.574559104243
# TP 528 FP 277 TN 8616 FN 2401
#
#
#
# None
# Cross: Validation: [ 0.76774084  0.76958214  0.77049319  0.76702479  0.76990102]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.24060150375939848
# Specificity : 0.9584447644517589
# Accuracy: 0.9393271926311574
# ROC 0.599523134106
# TP 32 FP 202 TN 4659 FN 101
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 7, 2, 12, 20, 4, 20, 17, 7, 12, 20, 13, 11, -0.2538461538461538, -14.792307692307693, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6549342105263158
# Specificity : 0.7284033613445379
# Accuracy: 0.6912718204488778
# ROC 0.691668785935
# TP 1991 FP 808 TN 2167 FN 1049
#
#
#
# None
# Cross: Validation: [ 0.65508644  0.73487367  0.71383439  0.68889258  0.66245427]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.7443609022556391
# Specificity : 0.44599876568607283
# Accuracy: 0.4539447336804165
# ROC 0.595179833971
# TP 99 FP 2693 TN 2168 FN 34
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 2, 2, 1, 1, 20, 1, 3, 1, 2, 1, 2, 0.9153846153846152, -7.400000000000001, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6641447368421053
# Specificity : 0.7321008403361344
# Accuracy: 0.6977556109725686
# ROC 0.698122788589
# TP 2019 FP 797 TN 2178 FN 1021
#
#
#
# None
# Cross: Validation: [ 0.65159574  0.72556516  0.7121716   0.68806119  0.6715996 ]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.6992481203007519
# Specificity : 0.44579304669821024
# Accuracy: 0.4525430516619944
# ROC 0.572520583499
# TP 93 FP 2694 TN 2167 FN 40
#
#
#
# None
