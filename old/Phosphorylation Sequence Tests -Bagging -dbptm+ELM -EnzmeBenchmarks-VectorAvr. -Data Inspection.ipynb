# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /usr/local/Cellar/python3/3.5.2_3/Frameworks/Python.framework/Versions/3.5/lib/python3.5/json/encoder.py:198: DeprecationWarning: Interpreting naive datetime as local 2017-10-19 20:16:38.822317. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
benchmarks = ["Data/Training/phos_CDK1.csv", "Data/Training/phos_CK2.csv", "Data/Training/phos_MAPK1.csv", "Data/Training/phos_PKA.csv", "Data/Training/phos_PKC.csv"]
for j in benchmarks:
    for i in par:
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(j)
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training("bagging")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file=j)
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training("bagging")
        del x
# Out:
# y pass   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 8, 2, 12, 18, 20, 2, 8, 1, 14, 1, 3, 7, -0.16923076923076924, -3.8307692307692314, 0.0]
# Finished working with Data
# Training Data Points: 2403
# Test Data Points: 601
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.17391304347826086
# Specificity : 0.9844290657439446
# Accuracy: 0.9534109816971714
# ROC 0.579171054611
# TP 4 FP 9 TN 569 FN 19
#
#
#
# None
# Cross Validation: [ 0.95681063  0.96179402  0.96833333  0.965       0.96666667]
# x pass   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 8, 2, 7, 10, 7, 1, 19, 8, 17, 7, 2, -1.5923076923076922, 2.7, 0.0]
# Finished working with Data
# Training Data Points: 2403
# Test Data Points: 601
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2777777777777778
# Specificity : 0.9897084048027445
# Accuracy: 0.9683860232945092
# ROC 0.63374309129
# TP 5 FP 6 TN 577 FN 13
#
#
#
# None
# Cross Validation: [ 0.95681063  0.97009967  0.96166667  0.95        0.96166667]
# y ADASYN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 17, 12, 4, 9, 10, 4, 3, 7, 10, 9, 9, 9, -1.0384615384615385, 69.47692307692309, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4613
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9744463373083475
# Specificity : 0.9805996472663139
# Accuracy: 0.9774696707105719
# ROC 0.977522992287
# TP 572 FP 11 TN 556 FN 15
#
#
#
# None
# Cross Validation: [ 0.89081456  0.96013865  0.97484822  0.94882914  0.9358196 ]
# x ADASYN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 19, 9, 5, 5, 20, 10, 1, 15, 13, 11, 10, 17, -0.8076923076923077, 30.11538461538462, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4613
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9740932642487047
# Specificity : 0.991304347826087
# Accuracy: 0.9826689774696707
# ROC 0.982698806037
# TP 564 FP 5 TN 570 FN 15
#
#
#
# None
# Cross Validation: [ 0.90467938  0.97400347  0.97484822  0.96270598  0.96010408]
# y SMOTEENN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 8, 13, 18, 7, 10, 3, 3, 7, 13, 13, 18, 19, 0.02307692307692313, 14.384615384615381, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4633
# Test Data Points: 1159
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9782608695652174
# Specificity : 0.9590017825311943
# Accuracy: 0.9689387402933564
# ROC 0.968631326048
# TP 585 FP 23 TN 538 FN 13
#
#
#
# None
# Cross Validation: [ 0.93787748  0.98015531  0.97236615  0.9775475   0.98100173]
# x SMOTEENN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 10, 2, 5, 8, 20, 8, 7, 11, 3, 7, 10, 20, -0.8999999999999999, -8.9, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4635
# Test Data Points: 1159
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.975
# Specificity : 0.9695885509838998
# Accuracy: 0.9723899913718723
# ROC 0.972294275492
# TP 585 FP 17 TN 542 FN 15
#
#
#
# None
# Cross Validation: [ 0.94051724  0.98793103  0.98013817  0.98100173  0.96891192]
# y random_under_sample   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 9, 9, 7, 1, 10, 11, 3, 18, 2, 2, 11, 15, -1.2769230769230768, 76.3923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8888888888888888
# Specificity : 0.92
# Accuracy: 0.9069767441860465
# ROC 0.904444444444
# TP 16 FP 2 TN 23 FN 2
#
#
#
# None
# Cross Validation: [ 0.93181818  0.90909091  1.          0.85714286  0.95238095]
# x random_under_sample   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 4, 1, 11, 18, 10, 12, 4, 10, 20, 15, 1, 10, -0.030769230769230806, 34.28461538461538, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8333333333333334
# Specificity : 0.96
# Accuracy: 0.9069767441860465
# ROC 0.896666666667
# TP 15 FP 1 TN 24 FN 3
#
#
#
# None
# Cross Validation: [ 0.93181818  0.88636364  0.92857143  0.88095238  0.97619048]
# y ncl   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 12, 11, 8, 11, 10, 3, 20, 13, 11, 9, 19, 3, -0.30769230769230776, 94.46153846153848, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2260
# Test Data Points: 566
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4
# Specificity : 0.9945553539019963
# Accuracy: 0.9787985865724381
# ROC 0.697277676951
# TP 6 FP 3 TN 548 FN 9
#
#
#
# None
# Cross Validation: [ 0.97173145  0.95583039  0.96283186  0.96283186  0.95212766]
# x ncl   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 14, 11, 9, 2, 10, 3, 10, 10, 11, 10, 13, 11, 0.02307692307692303, 123.70769230769231, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2260
# Test Data Points: 566
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4
# Specificity : 0.9818511796733213
# Accuracy: 0.9664310954063604
# ROC 0.690925589837
# TP 6 FP 10 TN 541 FN 9
#
#
#
# None
# Cross Validation: [ 0.9540636   0.95936396  0.96106195  0.95929204  0.96099291]
# y near_miss   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 9, 9, 12, 8, 10, 3, 17, 9, 9, 2, 9, 7, -1.9153846153846152, 108.00000000000001, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7777777777777778
# Specificity : 0.88
# Accuracy: 0.8372093023255814
# ROC 0.828888888889
# TP 14 FP 3 TN 22 FN 4
#
#
#
# None
# Cross Validation: [ 0.88636364  0.93181818  0.92857143  0.92857143  0.88095238]
# x near_miss   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 9, 17, 17, 17, 10, 11, 1, 11, 2, 11, 1, 10, -1.8461538461538465, 207.95384615384614, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7222222222222222
# Specificity : 0.88
# Accuracy: 0.813953488372093
# ROC 0.801111111111
# TP 13 FP 3 TN 22 FN 5
#
#
#
# None
# Cross Validation: [ 0.88636364  0.88636364  0.95238095  0.80952381  0.88095238]
# y pass   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 12, 9, 16, 16, 20, 3, 4, 20, 20, 16, 7, 4, -0.21538461538461548, 32.176923076923075, 0.0]
# Finished working with Data
# Training Data Points: 1812
# Test Data Points: 453
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.15789473684210525
# Specificity : 1.0
# Accuracy: 0.9646799116997793
# ROC 0.578947368421
# TP 3 FP 0 TN 434 FN 16
#
#
#
# None
# Cross Validation: [ 0.95814978  0.95594714  0.9580574   0.95353982  0.96017699]
# x pass   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 1, 10, 2, 4, 10, 8, 10, 3, 3, 7, 20, 20, 0.16923076923076924, 85.11538461538463, 0.0]
# Finished working with Data
# Training Data Points: 1812
# Test Data Points: 453
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05263157894736842
# Specificity : 0.9930875576036866
# Accuracy: 0.9536423841059603
# ROC 0.522859568276
# TP 1 FP 3 TN 431 FN 18
#
#
#
# None
# Cross Validation: [ 0.95814978  0.95374449  0.95584989  0.95132743  0.9579646 ]
# y ADASYN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 12, 13, 18, 9, 15, 9, 5, 8, 20, 17, 14, 11, -0.8923076923076922, 18.24615384615385, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3460
# Test Data Points: 865
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9685393258426966
# Specificity : 0.9833333333333333
# Accuracy: 0.9757225433526011
# ROC 0.975936329588
# TP 431 FP 7 TN 413 FN 14
#
#
#
# None
# Cross Validation: [ 0.83949192  0.95612009  0.94566474  0.96412037  0.95833333]
# x ADASYN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 2, 17, 2, 9, 20, 9, 9, 3, 13, 17, 9, 17, -1.6, 49.12307692307692, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3460
# Test Data Points: 865
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.947136563876652
# Specificity : 0.9902676399026764
# Accuracy: 0.9676300578034682
# ROC 0.96870210189
# TP 430 FP 4 TN 407 FN 24
#
#
#
# None
# Cross Validation: [ 0.8556582   0.95612009  0.95375723  0.9375      0.93402778]
# y SMOTEENN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 15, 2, 5, 10, 13, 7, 1, 11, 10, 15, 1, 0.09230769230769233, 31.68461538461539, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3466
# Test Data Points: 867
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9679633867276888
# Specificity : 0.9558139534883721
# Accuracy: 0.9619377162629758
# ROC 0.961888670108
# TP 423 FP 19 TN 411 FN 14
#
#
#
# None
# Cross Validation: [ 0.93194925  0.96885813  0.97693195  0.97459584  0.97228637]
# x SMOTEENN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 1, 8, 3, 3, 20, 10, 10, 18, 15, 19, 19, 19, -0.8538461538461538, 42.261538461538464, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3467
# Test Data Points: 867
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9748283752860412
# Specificity : 0.9697674418604652
# Accuracy: 0.972318339100346
# ROC 0.972297908573
# TP 426 FP 13 TN 417 FN 11
#
#
#
# None
# Cross Validation: [ 0.9343318   0.97577855  0.97808535  0.97690531  0.97690531]
# y random_under_sample   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 12, 14, 3, 7, 10, 13, 13, 3, 3, 18, 10, 1, 1.576923076923077, 32.330769230769235, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7272727272727273
# Specificity : 0.8823529411764706
# Accuracy: 0.7948717948717948
# ROC 0.804812834225
# TP 16 FP 2 TN 15 FN 6
#
#
#
# None
# Cross Validation: [ 0.6         0.85        0.73684211  0.92105263  0.73684211]
# x random_under_sample   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 19, 9, 9, 1, 10, 3, 15, 12, 3, 7, 1, 19, -0.47692307692307695, 30.738461538461536, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6363636363636364
# Specificity : 0.8235294117647058
# Accuracy: 0.717948717948718
# ROC 0.729946524064
# TP 14 FP 3 TN 14 FN 8
#
#
#
# None
# Cross Validation: [ 0.7         0.7         0.71052632  0.76315789  0.73684211]
# y ncl   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 12, 1, 1, 13, 15, 20, 12, 3, 8, 20, 7, 2, 0.2846153846153846, 17.676923076923078, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1699
# Test Data Points: 425
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05555555555555555
# Specificity : 1.0
# Accuracy: 0.96
# ROC 0.527777777778
# TP 1 FP 0 TN 407 FN 17
#
#
#
# None
# Cross Validation: [ 0.95305164  0.95774648  0.9504717   0.9504717   0.95754717]
# x ncl   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 7, 1, 7, 7, 20, 8, 4, 2, 9, 12, 3, 11, -0.6076923076923075, 14.67692307692308, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1703
# Test Data Points: 426
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 407 FN 19
#
#
#
# None
# Cross Validation: [ 0.95081967  0.95316159  0.95529412  0.95764706  0.94823529]
# y near_miss   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 3, 3, 3, 8, 10, 13, 8, 19, 17, 3, 1, 10, 0.0846153846153846, 77.12307692307692, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7272727272727273
# Specificity : 0.8823529411764706
# Accuracy: 0.7948717948717948
# ROC 0.804812834225
# TP 16 FP 2 TN 15 FN 6
#
#
#
# None
# Cross Validation: [ 0.725       0.75        0.68421053  0.81578947  0.60526316]
# x near_miss   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 5, 12, 19, 3, 20, 3, 16, 19, 8, 12, 16, 3, 0.3538461538461538, -8.130769230769232, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7272727272727273
# Specificity : 0.7647058823529411
# Accuracy: 0.7435897435897436
# ROC 0.745989304813
# TP 16 FP 4 TN 13 FN 6
#
#
#
# None
# Cross Validation: [ 0.775       0.675       0.60526316  0.68421053  0.71052632]
# y pass   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 12, 10, 13, 3, 10, 11, 7, 9, 12, 10, 3, 19, 0.33076923076923076, 57.846153846153854, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 929
# Test Data Points: 233
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.21428571428571427
# Specificity : 0.9817351598173516
# Accuracy: 0.9356223175965666
# ROC 0.598010437052
# TP 3 FP 4 TN 215 FN 11
#
#
#
# None
# Cross Validation: [ 0.93562232  0.92703863  0.94827586  0.94827586  0.91810345]
# x pass   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 17, 7, 17, 1, 10, 8, 11, 11, 19, 4, 2, 10, -1.8923076923076927, 75.91538461538462, 0.0]
# Finished working with Data
# Training Data Points: 929
# Test Data Points: 233
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4
# Specificity : 0.9865470852017937
# Accuracy: 0.9613733905579399
# ROC 0.693273542601
# TP 4 FP 3 TN 220 FN 6
#
#
#
# None
# Cross Validation: [ 0.92703863  0.94420601  0.93965517  0.93965517  0.95258621]
# y ADASYN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 7, 3, 7, 17, 10, 5, 10, 3, 19, 13, 7, 10, -0.8230769230769232, 66.73076923076924, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9783549783549783
# Specificity : 0.957345971563981
# Accuracy: 0.9683257918552036
# ROC 0.967850474959
# TP 226 FP 9 TN 202 FN 5
#
#
#
# None
# Cross Validation: [ 0.83031674  0.95464853  0.87301587  0.91609977  0.93877551]
# x ADASYN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 10, 1, 20, 2, 20, 11, 10, 2, 3, 13, 20, 20, 0.3923076923076923, 17.51538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9696969696969697
# Specificity : 0.976303317535545
# Accuracy: 0.9728506787330317
# ROC 0.973000143616
# TP 224 FP 5 TN 206 FN 7
#
#
#
# None
# Cross Validation: [ 0.86199095  0.89795918  0.9478458   0.92743764  0.94331066]
# y SMOTEENN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 3, 20, 19, 17, 20, 10, 17, 2, 11, 10, 20, 15, -0.9000000000000002, 47.876923076923084, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9688888888888889
# Specificity : 0.9861751152073732
# Accuracy: 0.9773755656108597
# ROC 0.977532002048
# TP 218 FP 3 TN 214 FN 7
#
#
#
# None
# Cross Validation: [ 0.92986425  0.97505669  0.97052154  0.97505669  0.95011338]
# x SMOTEENN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 7, 17, 7, 14, 10, 8, 20, 8, 14, 11, 17, 7, -2.253846153846154, 46.53846153846155, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1766
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9649122807017544
# Specificity : 0.9345794392523364
# Accuracy: 0.9502262443438914
# ROC 0.949745859977
# TP 220 FP 14 TN 200 FN 8
#
#
#
# None
# Cross Validation: [ 0.92081448  0.96153846  0.97511312  0.96825397  0.96371882]
# y random_under_sample   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 7, 6, 7, 8, 10, 12, 17, 3, 13, 10, 3, 14, -0.2615384615384618, 61.215384615384615, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7692307692307693
# Specificity : 0.8
# Accuracy: 0.782608695652174
# ROC 0.784615384615
# TP 10 FP 2 TN 8 FN 3
#
#
#
# None
# Cross Validation: [ 0.875       0.83333333  0.86363636  0.77272727  0.90909091]
# x random_under_sample   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 12, 1, 17, 10, 10, 2, 10, 10, 3, 18, 18, 7, -0.7384615384615384, 84.34615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6153846153846154
# Specificity : 0.9
# Accuracy: 0.7391304347826086
# ROC 0.757692307692
# TP 8 FP 1 TN 9 FN 5
#
#
#
# None
# Cross Validation: [ 0.83333333  0.95833333  0.86363636  0.86363636  0.81818182]
# y ncl   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 3, 13, 19, 17, 20, 10, 17, 18, 17, 14, 8, 16, -1.1846153846153844, 36.75384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 845
# Test Data Points: 212
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2222222222222222
# Specificity : 0.9901477832512315
# Accuracy: 0.9575471698113207
# ROC 0.606185002737
# TP 2 FP 2 TN 201 FN 7
#
#
#
# None
# Cross Validation: [ 0.93396226  0.93867925  0.93838863  0.93838863  0.91469194]
# x ncl   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 2, 2, 11, 2, 10, 2, 10, 12, 10, 10, 2, 10, 0.5307692307692309, 53.67692307692308, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 845
# Test Data Points: 212
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2222222222222222
# Specificity : 0.9950738916256158
# Accuracy: 0.9622641509433962
# ROC 0.608648056924
# TP 2 FP 1 TN 202 FN 7
#
#
#
# None
# Cross Validation: [ 0.94339623  0.93396226  0.94312796  0.93838863  0.95260664]
# y near_miss   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 16, 4, 12, 10, 20, 20, 3, 16, 12, 19, 10, 17, 0.06923076923076919, 27.300000000000004, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6923076923076923
# Specificity : 0.9
# Accuracy: 0.782608695652174
# ROC 0.796153846154
# TP 9 FP 1 TN 9 FN 4
#
#
#
# None
# Cross Validation: [ 0.75        0.79166667  0.86363636  0.77272727  0.81818182]
# x near_miss   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 11, 8, 8, 2, 10, 1, 7, 1, 8, 1, 16, 10, -1.4153846153846155, 40.61538461538461, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7692307692307693
# Specificity : 0.9
# Accuracy: 0.8260869565217391
# ROC 0.834615384615
# TP 10 FP 1 TN 9 FN 3
#
#
#
# None
# Cross Validation: [ 0.875       0.75        0.81818182  0.72727273  0.81818182]
# y pass   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 5, 8, 2, 10, 14, 9, 20, 5, 14, 12, 1, 0.8692307692307691, 31.46923076923077, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 4080
# Test Data Points: 1021
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.18181818181818182
# Specificity : 0.9949392712550608
# Accuracy: 0.9686581782566112
# ROC 0.588378726537
# TP 6 FP 5 TN 983 FN 27
#
#
#
# None
# Cross Validation: [ 0.96865818  0.96666667  0.96764706  0.96764706  0.9745098 ]
# x pass   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 1, 17, 7, 18, 20, 17, 12, 17, 3, 12, 5, 17, -0.5384615384615384, 2.7, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 4080
# Test Data Points: 1021
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2926829268292683
# Specificity : 0.9918367346938776
# Accuracy: 0.9637610186092067
# ROC 0.642259830762
# TP 12 FP 8 TN 972 FN 29
#
#
#
# None
# Cross Validation: [ 0.96180215  0.96862745  0.96764706  0.97058824  0.96666667]
# y ADASYN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 10, 9, 18, 9, 20, 10, 7, 7, 18, 9, 9, 12, -1.7461538461538462, 49.12307692307692, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7857
# Test Data Points: 1965
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9762396694214877
# Specificity : 0.9809428284854563
# Accuracy: 0.9786259541984733
# ROC 0.978591248953
# TP 945 FP 19 TN 978 FN 23
#
#
#
# None
# Cross Validation: [ 0.84020356  0.93587786  0.96792261  0.93380855  0.95162933]
# x ADASYN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 12, 8, 9, 11, 20, 20, 1, 18, 6, 17, 1, 4, -1.076923076923077, 11.292307692307695, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7857
# Test Data Points: 1965
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9618556701030928
# Specificity : 0.9829145728643216
# Accuracy: 0.9725190839694656
# ROC 0.972385121484
# TP 933 FP 17 TN 978 FN 37
#
#
#
# None
# Cross Validation: [ 0.83053435  0.91857506  0.93635438  0.92718941  0.96741344]
# y SMOTEENN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 18, 20, 18, 1, 10, 6, 16, 13, 18, 17, 20, 2, -0.8384615384615384, 31.592307692307696, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7855
# Test Data Points: 1964
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9594059405940594
# Specificity : 0.9779874213836478
# Accuracy: 0.9684317718940937
# ROC 0.968696680989
# TP 969 FP 21 TN 933 FN 41
#
#
#
# None
# Cross Validation: [ 0.95824847  0.97199593  0.98014257  0.97046843  0.96790627]
# x SMOTEENN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 19, 13, 12, 14, 20, 16, 10, 10, 15, 8, 9, 1, -0.2076923076923076, 57.407692307692315, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7855
# Test Data Points: 1964
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9742574257425742
# Specificity : 0.9664570230607966
# Accuracy: 0.9704684317718941
# ROC 0.970357224402
# TP 984 FP 32 TN 922 FN 26
#
#
#
# None
# Cross Validation: [ 0.94857434  0.96894094  0.97199593  0.97505092  0.97860418]
# y random_under_sample   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 2, 10, 11, 9, 20, 2, 11, 20, 2, 11, 2, 20, -0.015384615384615398, 100.84615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8787878787878788
# Specificity : 0.8863636363636364
# Accuracy: 0.8831168831168831
# ROC 0.882575757576
# TP 29 FP 5 TN 39 FN 4
#
#
#
# None
# Cross Validation: [ 0.87179487  0.82894737  0.85526316  0.88157895  0.85526316]
# x random_under_sample   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 4, 1, 2, 19, 10, 5, 19, 18, 13, 7, 7, 7, -1.0538461538461539, 81.54615384615386, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7575757575757576
# Specificity : 0.9545454545454546
# Accuracy: 0.8701298701298701
# ROC 0.856060606061
# TP 25 FP 2 TN 42 FN 8
#
#
#
# None
# Cross Validation: [ 0.80769231  0.84210526  0.84210526  0.81578947  0.78947368]
# y ncl   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 17, 20, 11, 12, 20, 1, 18, 16, 1, 12, 11, 20, -0.9538461538461536, 11.292307692307695, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3864
# Test Data Points: 966
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.34782608695652173
# Specificity : 0.9956521739130435
# Accuracy: 0.9648033126293996
# ROC 0.671739130435
# TP 16 FP 4 TN 916 FN 30
#
#
#
# None
# Cross Validation: [ 0.97001034  0.96583851  0.9689441   0.9699793   0.96476684]
# x ncl   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 4, 7, 6, 7, 20, 12, 10, 20, 13, 5, 3, 12, 1.1307692307692307, 9.230769230769232, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3868
# Test Data Points: 967
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.34782608695652173
# Specificity : 0.995656894679696
# Accuracy: 0.9648397104446742
# ROC 0.671741490818
# TP 16 FP 4 TN 917 FN 30
#
#
#
# None
# Cross Validation: [ 0.96280992  0.97724922  0.96794209  0.96794209  0.9689441 ]
# y near_miss   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 15, 13, 13, 9, 10, 15, 3, 3, 3, 2, 2, 10, 0.9846153846153847, 57.846153846153854, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7878787878787878
# Specificity : 0.9090909090909091
# Accuracy: 0.8571428571428571
# ROC 0.848484848485
# TP 26 FP 4 TN 40 FN 7
#
#
#
# None
# Cross Validation: [ 0.79487179  0.81578947  0.78947368  0.78947368  0.75      ]
# x near_miss   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 7, 17, 12, 19, 10, 11, 4, 3, 18, 17, 16, 1, -1.5769230769230766, 72.39999999999999, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5757575757575758
# Specificity : 0.8863636363636364
# Accuracy: 0.7532467532467533
# ROC 0.731060606061
# TP 19 FP 5 TN 39 FN 14
#
#
#
# None
# Cross Validation: [ 0.79487179  0.82894737  0.68421053  0.75        0.82894737]
# y pass   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 18, 7, 11, 3, 15, 5, 2, 19, 17, 3, 15, 19, -1.1076923076923078, 27.53076923076923, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 2469
# Test Data Points: 618
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 597 FN 20
#
#
#
# None
# Cross Validation: [ 0.96116505  0.96440129  0.96272285  0.96272285  0.96272285]
# x pass   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 12, 17, 3, 1, 10, 10, 9, 10, 3, 11, 14, 20, 0.030769230769230778, 87.76923076923077, 0.0]
# Finished working with Data
# Training Data Points: 2469
# Test Data Points: 618
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.038461538461538464
# Specificity : 0.9966216216216216
# Accuracy: 0.9563106796116505
# ROC 0.517541580042
# TP 1 FP 2 TN 590 FN 25
#
#
#
# None
# Cross Validation: [ 0.96278317  0.96116505  0.96758509  0.96758509  0.96272285]
# y ADASYN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 8, 4, 1, 13, 15, 2, 12, 4, 13, 9, 7, 4, 0.3538461538461538, 94.60769230769232, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4776
# Test Data Points: 1194
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9723577235772358
# Specificity : 0.9758203799654577
# Accuracy: 0.974036850921273
# ROC 0.974089051771
# TP 598 FP 14 TN 565 FN 17
#
#
#
# None
# Cross Validation: [ 0.86778243  0.88619247  0.93886097  0.92372171  0.91198659]
# x ADASYN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 7, 16, 16, 19, 10, 10, 2, 3, 1, 12, 15, 10, -0.30000000000000004, 30.84615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4776
# Test Data Points: 1194
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9693053311793215
# Specificity : 0.9826086956521739
# Accuracy: 0.97571189279732
# ROC 0.975957013416
# TP 600 FP 10 TN 565 FN 19
#
#
#
# None
# Cross Validation: [ 0.84686192  0.89205021  0.91792295  0.94719195  0.90947192]
# y SMOTEENN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 17, 1, 12, 7, 15, 18, 8, 2, 20, 11, 18, 5, -0.7615384615384614, -16.876923076923077, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4769
# Test Data Points: 1193
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9838187702265372
# Specificity : 0.9808695652173913
# Accuracy: 0.9823973176865046
# ROC 0.982344167722
# TP 608 FP 11 TN 564 FN 10
#
#
#
# None
# Cross Validation: [ 0.93629505  0.98407376  0.98154362  0.97902685  0.97483221]
# x SMOTEENN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 7, 5, 11, 17, 20, 3, 10, 10, 19, 2, 7, 10, -0.5846153846153846, 26.530769230769234, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4769
# Test Data Points: 1193
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9660194174757282
# Specificity : 0.9791304347826087
# Accuracy: 0.972338642078793
# ROC 0.972574926129
# TP 597 FP 12 TN 563 FN 21
#
#
#
# None
# Cross Validation: [ 0.93629505  0.98491199  0.98657718  0.98154362  0.98154362]
# y random_under_sample   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 17, 19, 7, 16, 10, 1, 20, 9, 10, 8, 2, 7, -1.723076923076923, 40.61538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7777777777777778
# Specificity : 0.7083333333333334
# Accuracy: 0.7380952380952381
# ROC 0.743055555556
# TP 14 FP 7 TN 17 FN 4
#
#
#
# None
# Cross Validation: [ 0.69047619  0.69047619  0.64285714  0.61904762  0.69047619]
# x random_under_sample   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 3, 11, 12, 19, 20, 17, 17, 7, 2, 5, 7, 20, -0.8538461538461537, 48.23846153846155, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4444444444444444
# Specificity : 0.7916666666666666
# Accuracy: 0.6428571428571429
# ROC 0.618055555556
# TP 8 FP 5 TN 19 FN 10
#
#
#
# None
# Cross Validation: [ 0.57142857  0.61904762  0.66666667  0.78571429  0.76190476]
# y ncl   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 5, 10, 10, 7, 15, 12, 11, 7, 15, 2, 11, 3, -0.2615384615384615, 71.8923076923077, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2308
# Test Data Points: 577
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0625
# Specificity : 0.9964349376114082
# Accuracy: 0.9705372616984402
# ROC 0.529467468806
# TP 1 FP 2 TN 559 FN 15
#
#
#
# None
# Cross Validation: [ 0.95493934  0.96360485  0.96013865  0.96360485  0.96360485]
# x ncl   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 20, 19, 13, 12, 20, 12, 8, 12, 3, 11, 8, 14, 0.976923076923077, 14.200000000000005, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2308
# Test Data Points: 577
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 3 TN 558 FN 16
#
#
#
# None
# Cross Validation: [ 0.95493934  0.96360485  0.96187175  0.95840555  0.96360485]
# y near_miss   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 20, 4, 9, 17, 10, 13, 2, 3, 14, 18, 1, 13, 0.3076923076923076, 24.938461538461535, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7777777777777778
# Specificity : 0.8333333333333334
# Accuracy: 0.8095238095238095
# ROC 0.805555555556
# TP 14 FP 4 TN 20 FN 4
#
#
#
# None
# Cross Validation: [ 0.71428571  0.76190476  0.69047619  0.61904762  0.69047619]
# x near_miss   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 7, 10, 12, 18, 20, 13, 20, 10, 5, 14, 1, 20, -0.10769230769230768, -3.8307692307692314, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7222222222222222
# Specificity : 0.7916666666666666
# Accuracy: 0.7619047619047619
# ROC 0.756944444444
# TP 13 FP 5 TN 19 FN 5
#
#
#
# None
# Cross Validation: [ 0.71428571  0.80952381  0.71428571  0.66666667  0.5952381 ]

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
benchmarks = ["Data/Training/phos_CDK1.csv", "Data/Training/phos_CK2.csv", "Data/Training/phos_MAPK1.csv", "Data/Training/phos_PKA.csv", "Data/Training/phos_PKC.csv"]
for j in benchmarks:
    for i in par:
        try:
            print("y", i, " ", j)
            y = Predictor()
            y.load_data(j)
            y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
            y.supervised_training("bagging")
            del y
            print("x", i, " ", j)
            x = Predictor()
            x.load_data(file=j)
            x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
            x.supervised_training("bagging")
            del x
        except:
            print("NotValidBenchmark")
# Out:
# y pass   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 2, 8, 8, 17, 10, 20, 8, 3, 18, 7, 7, 17, -2.323076923076923, 95.33846153846154, 0.0]
# Finished working with Data
# Training Data Points: 2403
# Test Data Points: 601
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2857142857142857
# Specificity : 0.993103448275862
# Accuracy: 0.9683860232945092
# ROC 0.639408866995
# TP 6 FP 4 TN 576 FN 15
#
#
#
# None
# Cross Validation: [ 0.96511628  0.96345515  0.96166667  0.95333333  0.96333333]
# x pass   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 19, 2, 11, 6, 10, 11, 7, 2, 17, 12, 20, 11, -1.1384615384615386, 49.099999999999994, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 2403
# Test Data Points: 601
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.21052631578947367
# Specificity : 0.979381443298969
# Accuracy: 0.9550748752079867
# ROC 0.594953879544
# TP 4 FP 12 TN 570 FN 15
#
#
#
# None
# Cross Validation: [ 0.96677741  0.95016611  0.95833333  0.97333333  0.96166667]
# y ADASYN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 17, 3, 15, 18, 20, 9, 10, 8, 10, 5, 17, 7, -1.2461538461538462, 80.94615384615385, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4613
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9724612736660929
# Specificity : 0.9738219895287958
# Accuracy: 0.9731369150779896
# ROC 0.973141631597
# TP 565 FP 15 TN 558 FN 16
#
#
#
# None
# Cross Validation: [ 0.89168111  0.96360485  0.95923677  0.97831743  0.97831743]
# x ADASYN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 7, 9, 16, 2, 10, 1, 10, 1, 2, 8, 10, 9, -1.5923076923076924, 45.51538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4613
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9775086505190311
# Specificity : 0.9670138888888888
# Accuracy: 0.9722703639514731
# ROC 0.972261269704
# TP 565 FP 19 TN 557 FN 13
#
#
#
# None
# Cross Validation: [ 0.8864818   0.9610052   0.9679098   0.96270598  0.97311362]
# y SMOTEENN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 19, 3, 5, 17, 20, 14, 12, 2, 2, 13, 11, 17, 0.8538461538461541, -4.584615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4634
# Test Data Points: 1159
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9833333333333333
# Specificity : 0.9463327370304114
# Accuracy: 0.9654874892148404
# ROC 0.964833035182
# TP 590 FP 30 TN 529 FN 10
#
#
#
# None
# Cross Validation: [ 0.94137931  0.97152718  0.9775475   0.9775475   0.97927461]
# x SMOTEENN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 2, 1, 3, 13, 10, 20, 3, 7, 7, 7, 20, 18, -0.5692307692307692, -8.861538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4632
# Test Data Points: 1159
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9749163879598662
# Specificity : 0.9732620320855615
# Accuracy: 0.9741156169111302
# ROC 0.974089210023
# TP 583 FP 15 TN 546 FN 15
#
#
#
# None
# Cross Validation: [ 0.94477998  0.97842968  0.96632124  0.98186528  0.97061366]
# y random_under_sample   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 9, 1, 9, 9, 10, 17, 13, 10, 3, 11, 3, 11, -0.3307692307692308, 87.76923076923079, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8888888888888888
# Specificity : 0.96
# Accuracy: 0.9302325581395349
# ROC 0.924444444444
# TP 16 FP 1 TN 24 FN 2
#
#
#
# None
# Cross Validation: [ 0.93181818  0.97727273  0.95238095  0.88095238  0.95238095]
# x random_under_sample   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 17, 1, 13, 18, 20, 3, 9, 17, 10, 7, 12, 9, -1.2538461538461538, 16.907692307692304, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 1.0
# Specificity : 0.88
# Accuracy: 0.9302325581395349
# ROC 0.94
# TP 18 FP 3 TN 22 FN 0
#
#
#
# None
# Cross Validation: [ 0.84090909  0.86363636  0.95238095  0.9047619   0.92857143]
# y ncl   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 18, 7, 1, 12, 10, 11, 9, 11, 13, 16, 3, 7, -1.0307692307692309, 85.86153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2260
# Test Data Points: 566
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4
# Specificity : 0.9836660617059891
# Accuracy: 0.9681978798586572
# ROC 0.691833030853
# TP 6 FP 9 TN 542 FN 9
#
#
#
# None
# Cross Validation: [ 0.9664311   0.95053004  0.96460177  0.96106195  0.96808511]
# x ncl   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 3, 3, 9, 8, 20, 2, 12, 9, 3, 9, 7, 17, -0.30000000000000004, 49.12307692307692, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2260
# Test Data Points: 566
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.26666666666666666
# Specificity : 0.9872958257713249
# Accuracy: 0.9681978798586572
# ROC 0.626981246219
# TP 4 FP 7 TN 544 FN 11
#
#
#
# None
# Cross Validation: [ 0.95759717  0.96113074  0.95575221  0.96637168  0.95567376]
# y near_miss   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 12, 11, 8, 11, 10, 3, 20, 13, 11, 9, 19, 3, -0.30769230769230776, 94.46153846153848, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7777777777777778
# Specificity : 0.88
# Accuracy: 0.8372093023255814
# ROC 0.828888888889
# TP 14 FP 3 TN 22 FN 4
#
#
#
# None
# Cross Validation: [ 0.93181818  0.90909091  0.9047619   0.9047619   0.85714286]
# x near_miss   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 10, 10, 5, 1, 20, 13, 3, 17, 7, 14, 10, 17, -0.2692307692307693, 61.961538461538474, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9444444444444444
# Specificity : 0.88
# Accuracy: 0.9069767441860465
# ROC 0.912222222222
# TP 17 FP 3 TN 22 FN 1
#
#
#
# None
# Cross Validation: [ 0.90909091  0.88636364  0.95238095  0.92857143  0.80952381]
# y pass   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 18, 7, 1, 17, 10, 1, 11, 3, 11, 11, 12, 11, -0.9461538461538461, 107.44615384615386, 0.0]
# Finished working with Data
# Training Data Points: 1812
# Test Data Points: 453
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08333333333333333
# Specificity : 0.9931972789115646
# Accuracy: 0.9690949227373068
# ROC 0.538265306122
# TP 1 FP 3 TN 438 FN 11
#
#
#
# None
# Cross Validation: [ 0.95374449  0.95594714  0.94701987  0.95575221  0.9579646 ]
# x pass   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 12, 15, 11, 5, 10, 10, 3, 8, 14, 5, 2, 10, 0.4538461538461538, 61.83076923076924, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 1812
# Test Data Points: 453
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 427 FN 25
#
#
#
# None
# Cross Validation: [ 0.96035242  0.95594714  0.9580574   0.95575221  0.96017699]
# y ADASYN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 13, 8, 17, 1, 15, 19, 10, 19, 11, 12, 7, 2, -0.6692307692307691, 41.8, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3460
# Test Data Points: 865
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9620535714285714
# Specificity : 0.9760191846522782
# Accuracy: 0.96878612716763
# ROC 0.96903637804
# TP 431 FP 10 TN 407 FN 17
#
#
#
# None
# Cross Validation: [ 0.8256351   0.93764434  0.93410405  0.96296296  0.93055556]
# x ADASYN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 8, 12, 3, 16, 10, 5, 20, 2, 12, 14, 8, 19, 0.04615384615384613, 6.6461538461538465, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3460
# Test Data Points: 865
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9622222222222222
# Specificity : 0.9710843373493976
# Accuracy: 0.9664739884393063
# ROC 0.966653279786
# TP 433 FP 12 TN 403 FN 17
#
#
#
# None
# Cross Validation: [ 0.83949192  0.94919169  0.96647399  0.93518519  0.95833333]
# y SMOTEENN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 2, 3, 11, 12, 10, 1, 4, 19, 7, 11, 12, 5, 0.7461538461538461, 41.34615384615385, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3466
# Test Data Points: 867
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9610983981693364
# Specificity : 0.9534883720930233
# Accuracy: 0.9573241061130334
# ROC 0.957293385131
# TP 420 FP 20 TN 410 FN 17
#
#
#
# None
# Cross Validation: [ 0.94348328  0.97347174  0.97462514  0.97459584  0.98498845]
# x SMOTEENN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 20, 7, 11, 7, 10, 10, 4, 8, 13, 19, 18, 2, -1.423076923076923, 12.44615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3466
# Test Data Points: 867
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.977116704805492
# Specificity : 0.9465116279069767
# Accuracy: 0.9619377162629758
# ROC 0.961814166356
# TP 427 FP 23 TN 407 FN 10
#
#
#
# None
# Cross Validation: [ 0.94348328  0.97808535  0.98385236  0.96766744  0.97459584]
# y random_under_sample   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 7, 8, 14, 7, 20, 16, 11, 16, 5, 12, 13, 11, -0.9307692307692308, 9.20769230769231, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5454545454545454
# Specificity : 0.9411764705882353
# Accuracy: 0.717948717948718
# ROC 0.743315508021
# TP 12 FP 1 TN 16 FN 10
#
#
#
# None
# Cross Validation: [ 0.55        0.775       0.63157895  0.78947368  0.84210526]
# x random_under_sample   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 7, 13, 1, 5, 15, 9, 17, 5, 7, 3, 13, 10, -0.33846153846153854, 3.8853846153846145, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7272727272727273
# Specificity : 0.7647058823529411
# Accuracy: 0.7435897435897436
# ROC 0.745989304813
# TP 16 FP 4 TN 13 FN 6
#
#
#
# None
# Cross Validation: [ 0.75        0.625       0.65789474  0.81578947  0.73684211]
# y ncl   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 17, 3, 12, 9, 20, 3, 8, 2, 19, 10, 1, 3, -0.2615384615384616, 67.66923076923078, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1700
# Test Data Points: 425
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 406 FN 18
#
#
#
# None
# Cross Validation: [ 0.95070423  0.95539906  0.95529412  0.95754717  0.9504717 ]
# x ncl   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 9, 3, 3, 11, 20, 11, 11, 3, 10, 11, 10, 17, -0.19230769230769246, 102.29230769230772, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1702
# Test Data Points: 426
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 408 FN 18
#
#
#
# None
# Cross Validation: [ 0.95784543  0.95539906  0.95764706  0.95058824  0.95058824]
# y near_miss   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 7, 9, 7, 2, 10, 3, 11, 1, 13, 7, 7, 2, -1.0384615384615385, 10.984615384615388, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5
# Specificity : 0.8823529411764706
# Accuracy: 0.6666666666666666
# ROC 0.691176470588
# TP 11 FP 2 TN 15 FN 11
#
#
#
# None
# Cross Validation: [ 0.75        0.7         0.73684211  0.68421053  0.78947368]
# x near_miss   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 12, 20, 18, 12, 20, 9, 9, 5, 11, 10, 12, 20, -0.030769230769230778, 47.6, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7727272727272727
# Specificity : 0.6470588235294118
# Accuracy: 0.717948717948718
# ROC 0.709893048128
# TP 17 FP 6 TN 11 FN 5
#
#
#
# None
# Cross Validation: [ 0.7         0.825       0.57894737  0.81578947  0.60526316]
# y pass   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 11, 9, 16, 11, 10, 10, 9, 9, 2, 11, 10, 17, -2.0846153846153848, 143.36923076923077, 0.0]
# Finished working with Data
# Training Data Points: 929
# Test Data Points: 233
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.09090909090909091
# Specificity : 0.9774774774774775
# Accuracy: 0.9356223175965666
# ROC 0.534193284193
# TP 1 FP 5 TN 217 FN 10
#
#
#
# None
# Cross Validation: [ 0.93133047  0.94420601  0.95258621  0.9612069   0.94827586]
# x pass   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 9, 3, 11, 17, 10, 20, 5, 18, 15, 17, 11, 1, -1.4846153846153847, 88.42307692307693, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 929
# Test Data Points: 233
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.16666666666666666
# Specificity : 0.973568281938326
# Accuracy: 0.9527896995708155
# ROC 0.570117474302
# TP 1 FP 6 TN 221 FN 5
#
#
#
# None
# Cross Validation: [ 0.94420601  0.92274678  0.94396552  0.93965517  0.94396552]
# y ADASYN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 12, 4, 7, 4, 10, 2, 9, 19, 13, 9, 7, 12, -0.07692307692307686, 110.1923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.948051948051948
# Specificity : 0.9715639810426541
# Accuracy: 0.9592760180995475
# ROC 0.959807964547
# TP 219 FP 6 TN 205 FN 12
#
#
#
# None
# Cross Validation: [ 0.84841629  0.90702948  0.9138322   0.88435374  0.87981859]
# x ADASYN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 18, 2, 17, 3, 10, 17, 10, 10, 2, 3, 2, 10, 0.11538461538461536, 72.66153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9733333333333334
# Specificity : 0.9585253456221198
# Accuracy: 0.9660633484162896
# ROC 0.965929339478
# TP 219 FP 9 TN 208 FN 6
#
#
#
# None
# Cross Validation: [ 0.88235294  0.93877551  0.8707483   0.93424036  0.95464853]
# y SMOTEENN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 9, 3, 11, 3, 10, 11, 10, 3, 3, 1, 1, 11, 0.6384615384615384, 82.15384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1767
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9736842105263158
# Specificity : 0.9626168224299065
# Accuracy: 0.9683257918552036
# ROC 0.968150516478
# TP 222 FP 8 TN 206 FN 6
#
#
#
# None
# Cross Validation: [ 0.92533937  0.96153846  0.97511312  0.96832579  0.96825397]
# x SMOTEENN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 4, 7, 8, 19, 10, 12, 8, 14, 9, 17, 7, 11, -1.5769230769230769, 45.446153846153855, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1765
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9385964912280702
# Specificity : 0.9626168224299065
# Accuracy: 0.9502262443438914
# ROC 0.950606656829
# TP 214 FP 8 TN 206 FN 14
#
#
#
# None
# Cross Validation: [ 0.92986425  0.97963801  0.96825397  0.96825397  0.96145125]
# y random_under_sample   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 3, 17, 11, 9, 20, 11, 17, 11, 12, 19, 13, 1, -0.4000000000000001, 64.50000000000001, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 1.0
# Specificity : 1.0
# Accuracy: 1.0
# ROC 1.0
# TP 13 FP 0 TN 10 FN 0
#
#
#
# None
# Cross Validation: [ 0.875       0.66666667  0.81818182  0.86363636  0.90909091]
# x random_under_sample   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 11, 5, 15, 11, 20, 3, 17, 3, 3, 16, 7, 15, -0.33076923076923087, 91.6469230769231, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7692307692307693
# Specificity : 0.9
# Accuracy: 0.8260869565217391
# ROC 0.834615384615
# TP 10 FP 1 TN 9 FN 3
#
#
#
# None
# Cross Validation: [ 0.91666667  0.83333333  0.86363636  0.90909091  0.90909091]
# y ncl   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 9, 19, 9, 7, 10, 2, 3, 8, 20, 9, 13, 2, -0.5538461538461539, 78.75384615384617, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 845
# Test Data Points: 212
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3333333333333333
# Specificity : 0.9852216748768473
# Accuracy: 0.9575471698113207
# ROC 0.659277504105
# TP 3 FP 3 TN 200 FN 6
#
#
#
# None
# Cross Validation: [ 0.94339623  0.93867925  0.9478673   0.93838863  0.94312796]
# x ncl   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 9, 3, 3, 11, 20, 12, 17, 3, 3, 9, 10, 3, 0.6000000000000001, 53.67692307692308, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 845
# Test Data Points: 212
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 201 FN 9
#
#
#
# None
# Cross Validation: [ 0.93867925  0.95283019  0.9478673   0.93838863  0.94312796]
# y near_miss   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 11, 2, 2, 11, 10, 17, 18, 11, 14, 14, 3, 14, 0.03846153846153853, 118.5846153846154, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8461538461538461
# Specificity : 0.9
# Accuracy: 0.8695652173913043
# ROC 0.873076923077
# TP 11 FP 1 TN 9 FN 2
#
#
#
# None
# Cross Validation: [ 0.79166667  0.875       0.72727273  0.72727273  0.81818182]
# x near_miss   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 3, 7, 2, 1, 10, 3, 9, 12, 12, 5, 13, 17, 1.2153846153846155, 2.7, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7692307692307693
# Specificity : 0.9
# Accuracy: 0.8260869565217391
# ROC 0.834615384615
# TP 10 FP 1 TN 9 FN 3
#
#
#
# None
# Cross Validation: [ 0.83333333  0.66666667  0.86363636  0.68181818  0.81818182]
# y pass   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 3, 3, 2, 14, 10, 15, 1, 7, 3, 14, 19, 11, 0.8615384615384616, 53.06923076923077, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 4080
# Test Data Points: 1021
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2826086956521739
# Specificity : 0.9928205128205129
# Accuracy: 0.960822722820764
# ROC 0.637714604236
# TP 13 FP 7 TN 968 FN 33
#
#
#
# None
# Cross Validation: [ 0.96571988  0.97254902  0.96960784  0.96470588  0.9745098 ]
# x pass   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 4, 17, 10, 12, 10, 17, 12, 5, 7, 5, 13, 19, 0.4769230769230769, 40.48461538461538, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 4080
# Test Data Points: 1021
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.40625
# Specificity : 0.9949443882709808
# Accuracy: 0.9764936336924583
# ROC 0.700597194135
# TP 13 FP 5 TN 984 FN 19
#
#
#
# None
# Cross Validation: [ 0.97061704  0.96960784  0.9754902   0.96568627  0.96470588]
# y ADASYN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 19, 18, 18, 12, 20, 10, 18, 11, 10, 9, 5, 20, -1.4307692307692308, 44.93076923076924, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7857
# Test Data Points: 1965
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9855670103092784
# Specificity : 0.9829145728643216
# Accuracy: 0.9842239185750636
# ROC 0.984240791587
# TP 956 FP 17 TN 978 FN 14
#
#
#
# None
# Cross Validation: [ 0.88804071  0.94503817  0.95621181  0.9200611   0.93177189]
# x ADASYN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 3, 18, 17, 20, 20, 2, 18, 20, 17, 17, 7, 2, -1.2538461538461538, 46.761538461538464, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7857
# Test Data Points: 1965
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9724489795918367
# Specificity : 0.9776649746192894
# Accuracy: 0.9750636132315522
# ROC 0.975056977106
# TP 953 FP 22 TN 963 FN 27
#
#
#
# None
# Cross Validation: [ 0.85496183  0.956743    0.94704684  0.93686354  0.95519348]
# y SMOTEENN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 11, 8, 8, 12, 10, 2, 11, 11, 10, 10, 10, 14, -0.2076923076923077, 147.03076923076924, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7855
# Test Data Points: 1964
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9752475247524752
# Specificity : 0.9685534591194969
# Accuracy: 0.9719959266802444
# ROC 0.971900491936
# TP 985 FP 30 TN 924 FN 25
#
#
#
# None
# Cross Validation: [ 0.94704684  0.97556008  0.97912424  0.98167006  0.98013245]
# x SMOTEENN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 2, 16, 9, 17, 10, 3, 10, 2, 15, 1, 1, 1, -0.730769230769231, 63.769230769230774, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7854
# Test Data Points: 1964
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.973293768545994
# Specificity : 0.9769150052465897
# Accuracy: 0.975050916496945
# ROC 0.975104386896
# TP 984 FP 22 TN 931 FN 27
#
#
#
# None
# Cross Validation: [ 0.94806517  0.97505092  0.97861507  0.97147224  0.98166072]
# y random_under_sample   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 10, 2, 3, 14, 10, 20, 13, 17, 10, 18, 14, 3, 0.8923076923076921, 55.63076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7272727272727273
# Specificity : 0.9318181818181818
# Accuracy: 0.8441558441558441
# ROC 0.829545454545
# TP 24 FP 3 TN 41 FN 9
#
#
#
# None
# Cross Validation: [ 0.85897436  0.88157895  0.86842105  0.84210526  0.88157895]
# x random_under_sample   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 1, 9, 8, 7, 20, 7, 9, 1, 9, 1, 10, 8, -2.423076923076923, 27.261538461538468, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8181818181818182
# Specificity : 0.9090909090909091
# Accuracy: 0.8701298701298701
# ROC 0.863636363636
# TP 27 FP 4 TN 40 FN 6
#
#
#
# None
# Cross Validation: [ 0.92307692  0.86842105  0.82894737  0.88157895  0.89473684]
# y ncl   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 17, 8, 1, 5, 10, 15, 19, 15, 12, 5, 19, 6, -1.0076923076923079, 51.753846153846155, 0.38461538461538464]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3867
# Test Data Points: 967
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.45652173913043476
# Specificity : 0.993485342019544
# Accuracy: 0.96794208893485
# ROC 0.725003540575
# TP 21 FP 6 TN 915 FN 25
#
#
#
# None
# Cross Validation: [ 0.96694215  0.96794209  0.96897622  0.96480331  0.9679089 ]
# x ncl   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 13, 1, 15, 2, 10, 2, 3, 12, 10, 3, 3, 18, 1.4461538461538461, 20.915384615384614, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3869
# Test Data Points: 968
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.37777777777777777
# Specificity : 0.9934994582881906
# Accuracy: 0.9648760330578512
# ROC 0.685638618033
# TP 17 FP 6 TN 917 FN 28
#
#
#
# None
# Cross Validation: [ 0.95975232  0.97828335  0.96690796  0.96483971  0.96690796]
# y near_miss   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 7, 9, 7, 13, 10, 7, 9, 19, 3, 7, 8, 17, -2.146153846153846, 29.169230769230772, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7272727272727273
# Specificity : 0.8863636363636364
# Accuracy: 0.8181818181818182
# ROC 0.806818181818
# TP 24 FP 5 TN 39 FN 9
#
#
#
# None
# Cross Validation: [ 0.84615385  0.76315789  0.76315789  0.78947368  0.78947368]
# x near_miss   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 19, 2, 11, 12, 20, 10, 20, 7, 2, 17, 10, 1, -0.40769230769230774, 66.13076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6666666666666666
# Specificity : 0.9090909090909091
# Accuracy: 0.8051948051948052
# ROC 0.787878787879
# TP 22 FP 4 TN 40 FN 11
#
#
#
# None
# Cross Validation: [ 0.84615385  0.86842105  0.81578947  0.78947368  0.84210526]
# y pass   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 12, 14, 5, 13, 20, 11, 10, 5, 11, 12, 19, 20, 0.6846153846153847, 30.553846153846155, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 2469
# Test Data Points: 618
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 5 TN 590 FN 23
#
#
#
# None
# Cross Validation: [ 0.96440129  0.96440129  0.96272285  0.96272285  0.9643436 ]
# x pass   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 2, 15, 14, 3, 10, 12, 10, 19, 5, 19, 18, 2, 0.2384615384615385, 21.207692307692312, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 2469
# Test Data Points: 618
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 594 FN 23
#
#
#
# None
# Cross Validation: [ 0.96601942  0.96601942  0.96272285  0.96758509  0.95948136]
# y ADASYN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 11, 8, 2, 8, 20, 13, 20, 3, 2, 11, 4, 8, -0.3692307692307693, 25.04615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4776
# Test Data Points: 1194
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9659090909090909
# Specificity : 0.9809688581314879
# Accuracy: 0.9731993299832495
# ROC 0.97343897452
# TP 595 FP 11 TN 567 FN 21
#
#
#
# None
# Cross Validation: [ 0.86945607  0.89121339  0.93718593  0.88432523  0.95725063]
# x ADASYN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 12, 18, 13, 3, 20, 20, 20, 9, 9, 1, 15, 17, -0.3461538461538459, 78.20000000000002, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4776
# Test Data Points: 1194
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9724919093851133
# Specificity : 0.9600694444444444
# Accuracy: 0.966499162479062
# ROC 0.966280676915
# TP 601 FP 23 TN 553 FN 17
#
#
#
# None
# Cross Validation: [ 0.76569038  0.90376569  0.91541039  0.94216262  0.92623638]
# y SMOTEENN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 17, 1, 6, 9, 20, 2, 13, 17, 8, 2, 3, 4, -3.416070845000482e-17, 27.00769230769231, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4771
# Test Data Points: 1193
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9664
# Specificity : 0.9964788732394366
# Accuracy: 0.980720871751886
# ROC 0.98143943662
# TP 604 FP 2 TN 566 FN 21
#
#
#
# None
# Cross Validation: [ 0.93299832  0.9840871   0.98154362  0.99077181  0.98993289]
# x SMOTEENN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 10, 3, 10, 2, 10, 10, 10, 20, 1, 10, 19, 11, -0.6846153846153846, 66.13076923076925, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4770
# Test Data Points: 1193
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9664
# Specificity : 0.9735915492957746
# Accuracy: 0.9698239731768651
# ROC 0.969995774648
# TP 604 FP 15 TN 553 FN 21
#
#
#
# None
# Cross Validation: [ 0.94221106  0.98323554  0.98322148  0.97902685  0.98322148]
# y random_under_sample   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 2, 5, 2, 16, 20, 10, 8, 12, 3, 12, 19, 7, 0.10769230769230775, 2.638461538461541, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5555555555555556
# Specificity : 0.6666666666666666
# Accuracy: 0.6190476190476191
# ROC 0.611111111111
# TP 10 FP 8 TN 16 FN 8
#
#
#
# None
# Cross Validation: [ 0.73809524  0.69047619  0.5952381   0.78571429  0.66666667]
# x random_under_sample   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 2, 10, 20, 2, 10, 2, 10, 2, 2, 12, 10, 2, 0.5076923076923077, 9.230769230769232, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6111111111111112
# Specificity : 0.4166666666666667
# Accuracy: 0.5
# ROC 0.513888888889
# TP 11 FP 14 TN 10 FN 7
#
#
#
# None
# Cross Validation: [ 0.61904762  0.64285714  0.76190476  0.57142857  0.73809524]
# y ncl   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 2, 18, 4, 5, 20, 14, 10, 16, 20, 11, 3, 17, 0.1769230769230767, 18.24615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2308
# Test Data Points: 577
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 561 FN 16
#
#
#
# None
# Cross Validation: [ 0.96013865  0.96360485  0.96707106  0.95667244  0.96533795]
# x ncl   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 15, 1, 13, 3, 15, 3, 3, 3, 9, 2, 15, 11, 1.2538461538461538, 14.676923076923076, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2308
# Test Data Points: 577
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 7 TN 554 FN 16
#
#
#
# None
# Cross Validation: [ 0.96187175  0.96533795  0.96360485  0.95840555  0.96013865]
# y near_miss   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 7, 12, 17, 8, 15, 19, 10, 13, 8, 7, 3, 3, -0.9307692307692306, 56.43076923076924, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6666666666666666
# Specificity : 0.7916666666666666
# Accuracy: 0.7380952380952381
# ROC 0.729166666667
# TP 12 FP 5 TN 19 FN 6
#
#
#
# None
# Cross Validation: [ 0.69047619  0.66666667  0.76190476  0.69047619  0.73809524]
# x near_miss   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 20, 20, 8, 20, 14, 1, 2, 6, 9, 4, 7, -0.3923076923076923, -3.100000000000001, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6666666666666666
# Specificity : 0.8333333333333334
# Accuracy: 0.7619047619047619
# ROC 0.75
# TP 12 FP 4 TN 20 FN 6
#
#
#
# None
# Cross Validation: [ 0.73809524  0.73809524  0.71428571  0.71428571  0.66666667]

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
benchmarks = ["Data/Training/phos_CDK1.csv", "Data/Training/phos_CK2.csv", "Data/Training/phos_MAPK1.csv", "Data/Training/phos_PKA.csv", "Data/Training/phos_PKC.csv"]
for j in benchmarks:
    for i in par:
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(j)
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training("bagging")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file=j)
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training("bagging")
        del x
# Out:
# y pass   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 9, 3, 9, 8, 10, 7, 8, 2, 2, 1, 1, 3, -0.9076923076923075, 110.60000000000001, 0.0]
# Finished working with Data
# Training Data Points: 2403
# Test Data Points: 601
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.13043478260869565
# Specificity : 0.9913494809688581
# Accuracy: 0.9584026622296173
# ROC 0.560892131789
# TP 3 FP 5 TN 573 FN 20
#
#
#
# None
# Cross Validation: [ 0.96179402  0.96013289  0.96833333  0.96666667  0.95333333]
# x pass   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 8, 17, 13, 17, 20, 1, 10, 2, 3, 12, 8, 17, -0.3307692307692308, 27.77692307692308, 0.0]
# Finished working with Data
# Training Data Points: 2403
# Test Data Points: 601
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3181818181818182
# Specificity : 0.9844559585492227
# Accuracy: 0.9600665557404326
# ROC 0.651318888366
# TP 7 FP 9 TN 570 FN 15
#
#
#
# None
# Cross Validation: [ 0.9551495   0.96179402  0.95833333  0.96833333  0.96166667]
# y ADASYN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 8, 3, 16, 19, 20, 18, 4, 9, 3, 20, 19, 3, -0.5384615384615385, -13.892307692307693, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4613
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9844020797227037
# Specificity : 0.9809358752166378
# Accuracy: 0.9826689774696707
# ROC 0.98266897747
# TP 568 FP 11 TN 566 FN 9
#
#
#
# None
# Cross Validation: [ 0.89254766  0.96880416  0.9687771   0.97745013  0.96097138]
# x ADASYN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 12, 19, 18, 2, 10, 3, 2, 17, 3, 19, 3, 9, -0.27692307692307694, -2.3307692307692305, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4613
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9739130434782609
# Specificity : 0.9792746113989638
# Accuracy: 0.9766031195840554
# ROC 0.976593827439
# TP 560 FP 12 TN 567 FN 15
#
#
#
# None
# Cross Validation: [ 0.87781629  0.94714038  0.9687771   0.96357329  0.97571552]
# y SMOTEENN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 9, 20, 8, 18, 20, 1, 19, 17, 3, 3, 17, 9, -1.8923076923076922, -0.615384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4634
# Test Data Points: 1159
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9716666666666667
# Specificity : 0.9660107334525939
# Accuracy: 0.9689387402933564
# ROC 0.96883870006
# TP 583 FP 19 TN 540 FN 17
#
#
#
# None
# Cross Validation: [ 0.94913793  0.97497843  0.97322971  0.97409326  0.98272884]
# x SMOTEENN   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 5, 10, 10, 8, 10, 9, 2, 10, 1, 10, 18, 9, -1.3307692307692311, 81.67692307692309, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4632
# Test Data Points: 1159
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9749163879598662
# Specificity : 0.964349376114082
# Accuracy: 0.9698015530629853
# ROC 0.969632882037
# TP 583 FP 20 TN 541 FN 15
#
#
#
# None
# Cross Validation: [ 0.93960311  0.97152718  0.9835924   0.98272884  0.97493518]
# y random_under_sample   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 12, 3, 5, 7, 10, 18, 9, 16, 10, 19, 8, 3, -0.9230769230769231, -14.661538461538461, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8888888888888888
# Specificity : 0.96
# Accuracy: 0.9302325581395349
# ROC 0.924444444444
# TP 16 FP 1 TN 24 FN 2
#
#
#
# None
# Cross Validation: [ 0.95454545  0.95454545  0.95238095  0.95238095  0.9047619 ]
# x random_under_sample   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 8, 17, 12, 2, 10, 9, 18, 3, 17, 8, 9, 3, -1.3538461538461537, 86.6769230769231, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 1.0
# Specificity : 1.0
# Accuracy: 1.0
# ROC 1.0
# TP 18 FP 0 TN 25 FN 0
#
#
#
# None
# Cross Validation: [ 0.93181818  0.97727273  0.92857143  0.92857143  0.9047619 ]
# y ncl   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 15, 13, 19, 16, 20, 18, 17, 20, 20, 10, 6, 13, -0.9307692307692306, 1.3615384615384627, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2260
# Test Data Points: 566
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2
# Specificity : 0.9945553539019963
# Accuracy: 0.9734982332155477
# ROC 0.597277676951
# TP 3 FP 3 TN 548 FN 12
#
#
#
# None
# Cross Validation: [ 0.95936396  0.94876325  0.96460177  0.96106195  0.95921986]
# x ncl   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 18, 17, 17, 1, 10, 12, 10, 10, 12, 10, 11, 7, -0.6692307692307693, 95.37692307692308, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2260
# Test Data Points: 566
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4
# Specificity : 0.9891107078039928
# Accuracy: 0.9734982332155477
# ROC 0.694555353902
# TP 6 FP 6 TN 545 FN 9
#
#
#
# None
# Cross Validation: [ 0.95583039  0.96113074  0.95752212  0.96637168  0.95921986]
# y near_miss   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 20, 3, 20, 13, 20, 12, 5, 20, 18, 11, 11, 8, 0.3923076923076924, 25.084615384615386, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8888888888888888
# Specificity : 0.84
# Accuracy: 0.8604651162790697
# ROC 0.864444444444
# TP 16 FP 4 TN 21 FN 2
#
#
#
# None
# Cross Validation: [ 0.93181818  0.93181818  0.88095238  0.88095238  0.88095238]
# x near_miss   Data/Training/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 8, 8, 16, 15, 20, 18, 7, 13, 17, 2, 3, 17, -1.2076923076923076, 66.25384615384617, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 171
# Test Data Points: 43
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8333333333333334
# Specificity : 0.88
# Accuracy: 0.8604651162790697
# ROC 0.856666666667
# TP 15 FP 3 TN 22 FN 3
#
#
#
# None
# Cross Validation: [ 0.88636364  0.90909091  0.92857143  0.88095238  0.85714286]
# y pass   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 7, 8, 9, 9, 10, 9, 10, 11, 12, 9, 17, 11, -2.307692307692308, 193.4, 0.0]
# Finished working with Data
# Training Data Points: 1812
# Test Data Points: 453
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05263157894736842
# Specificity : 0.9976958525345622
# Accuracy: 0.9580573951434879
# ROC 0.525163715741
# TP 1 FP 1 TN 433 FN 18
#
#
#
# None
# Cross Validation: [ 0.95374449  0.95814978  0.95584989  0.95575221  0.95575221]
# x pass   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 3, 19, 6, 7, 15, 3, 1, 17, 15, 15, 4, 10, -0.35384615384615387, 80.52307692307693, 0.3076923076923077]
# Finished working with Data
# Training Data Points: 1812
# Test Data Points: 453
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.047619047619047616
# Specificity : 0.9930555555555556
# Accuracy: 0.9492273730684326
# ROC 0.520337301587
# TP 1 FP 3 TN 429 FN 20
#
#
#
# None
# Cross Validation: [ 0.95374449  0.95154185  0.95584989  0.95353982  0.96681416]
# y ADASYN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 3, 10, 9, 5, 15, 15, 12, 17, 3, 9, 15, 15, 0.12307692307692324, 82.92384615384617, 0.38461538461538464]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3460
# Test Data Points: 865
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9467849223946785
# Specificity : 0.9758454106280193
# Accuracy: 0.9606936416184971
# ROC 0.961315166511
# TP 427 FP 10 TN 404 FN 24
#
#
#
# None
# Cross Validation: [ 0.88452656  0.95265589  0.9583815   0.9525463   0.97800926]
# x ADASYN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 12, 2, 1, 4, 10, 12, 1, 1, 9, 17, 17, 13, 0.13076923076923072, 84.25384615384615, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3460
# Test Data Points: 865
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9733924611973392
# Specificity : 0.9782608695652174
# Accuracy: 0.9757225433526011
# ROC 0.975826665381
# TP 439 FP 9 TN 405 FN 12
#
#
#
# None
# Cross Validation: [ 0.84526559  0.96766744  0.93757225  0.93402778  0.96643519]
# y SMOTEENN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 18, 11, 19, 1, 20, 7, 7, 5, 17, 3, 9, 1, -1.7538461538461534, -5.315384615384616, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3466
# Test Data Points: 867
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9702517162471396
# Specificity : 0.9627906976744186
# Accuracy: 0.9665513264129181
# ROC 0.966521206961
# TP 424 FP 16 TN 414 FN 13
#
#
#
# None
# Cross Validation: [ 0.92618224  0.97462514  0.96078431  0.97690531  0.97228637]
# x SMOTEENN   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 17, 9, 1, 19, 20, 12, 8, 3, 3, 14, 17, 1, -0.19230769230769235, -8.861538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3467
# Test Data Points: 867
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.977116704805492
# Specificity : 0.958139534883721
# Accuracy: 0.9677047289504037
# ROC 0.967628119845
# TP 427 FP 18 TN 412 FN 10
#
#
#
# None
# Cross Validation: [ 0.94009217  0.98039216  0.97923875  0.97344111  0.96766744]
# y random_under_sample   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 1, 1, 2, 1, 10, 3, 1, 2, 1, 1, 2, 5, 0.6461538461538461, 18.115384615384613, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5
# Specificity : 0.7058823529411765
# Accuracy: 0.5897435897435898
# ROC 0.602941176471
# TP 11 FP 5 TN 12 FN 11
#
#
#
# None
# Cross Validation: [ 0.75        0.675       0.73684211  0.81578947  0.68421053]
# x random_under_sample   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 3, 2, 12, 18, 20, 20, 12, 2, 12, 2, 4, 1, 1.6076923076923078, 17.51538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6818181818181818
# Specificity : 0.9411764705882353
# Accuracy: 0.7948717948717948
# ROC 0.811497326203
# TP 15 FP 1 TN 16 FN 7
#
#
#
# None
# Cross Validation: [ 0.675       0.775       0.68421053  0.89473684  0.57894737]
# y ncl   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 17, 3, 7, 17, 10, 16, 13, 17, 17, 15, 12, 10, -1.2230769230769232, 133.63846153846154, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1701
# Test Data Points: 426
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 407 FN 18
#
#
#
# None
# Cross Validation: [ 0.95305164  0.95539906  0.95529412  0.95764706  0.95294118]
# x ncl   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 7, 16, 13, 7, 20, 18, 11, 9, 9, 3, 17, 9, -2.076923076923077, 75.9846153846154, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1700
# Test Data Points: 425
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05555555555555555
# Specificity : 0.995085995085995
# Accuracy: 0.9552941176470588
# ROC 0.525320775321
# TP 1 FP 2 TN 405 FN 17
#
#
#
# None
# Cross Validation: [ 0.95305164  0.94366197  0.95764706  0.95283019  0.95518868]
# y near_miss   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 13, 20, 11, 19, 10, 1, 13, 9, 20, 11, 20, 4, -0.46923076923076923, 60.33076923076924, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5909090909090909
# Specificity : 0.7647058823529411
# Accuracy: 0.6666666666666666
# ROC 0.677807486631
# TP 13 FP 4 TN 13 FN 9
#
#
#
# None
# Cross Validation: [ 0.725       0.6         0.65789474  0.81578947  0.78947368]
# x near_miss   Data/Training/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 1, 4, 3, 2, 10, 12, 15, 20, 19, 19, 9, 9, -0.27692307692307705, 21.97692307692308, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 155
# Test Data Points: 39
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6818181818181818
# Specificity : 0.7647058823529411
# Accuracy: 0.717948717948718
# ROC 0.723262032086
# TP 15 FP 4 TN 13 FN 7
#
#
#
# None
# Cross Validation: [ 0.675       0.7         0.76315789  0.68421053  0.71052632]
# y pass   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 15, 1, 12, 3, 20, 14, 1, 10, 14, 7, 12, 5, 0.7153846153846154, 55.04615384615385, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 929
# Test Data Points: 233
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2
# Specificity : 0.9865470852017937
# Accuracy: 0.9527896995708155
# ROC 0.593273542601
# TP 2 FP 3 TN 220 FN 8
#
#
#
# None
# Cross Validation: [ 0.94420601  0.94420601  0.94827586  0.95258621  0.94827586]
# x pass   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 6, 2, 1, 15, 10, 12, 19, 17, 3, 15, 9, 3, 0.09230769230769233, -13.807692307692308, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 929
# Test Data Points: 233
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 223 FN 10
#
#
#
# None
# Cross Validation: [ 0.93991416  0.93991416  0.95689655  0.95258621  0.93965517]
# y ADASYN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 9, 16, 5, 9, 20, 6, 11, 10, 16, 3, 11, 13, -0.4615384615384617, 13.523076923076928, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.925764192139738
# Specificity : 0.9624413145539906
# Accuracy: 0.9434389140271493
# ROC 0.944102753347
# TP 212 FP 8 TN 205 FN 17
#
#
#
# None
# Cross Validation: [ 0.80995475  0.94557823  0.90929705  0.92517007  0.92517007]
# x ADASYN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 3, 16, 2, 7, 10, 13, 13, 16, 17, 19, 3, 7, -0.4538461538461539, 12.192307692307693, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9432314410480349
# Specificity : 0.971830985915493
# Accuracy: 0.9570135746606335
# ROC 0.957531213482
# TP 216 FP 6 TN 207 FN 13
#
#
#
# None
# Cross Validation: [ 0.83484163  0.92063492  0.95238095  0.92970522  0.93650794]
# y SMOTEENN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 10, 3, 11, 11, 10, 8, 2, 2, 2, 7, 8, 19, -0.8, 101.49230769230769, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1765
# Test Data Points: 442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9649122807017544
# Specificity : 0.9672897196261683
# Accuracy: 0.9660633484162896
# ROC 0.966101000164
# TP 220 FP 7 TN 207 FN 8
#
#
#
# None
# Cross Validation: [ 0.9321267   0.97737557  0.95464853  0.95918367  0.96371882]
# x SMOTEENN   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 10, 3, 2, 11, 20, 11, 12, 10, 2, 12, 3, 9, 0.953846153846154, 38.861538461538466, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1764
# Test Data Points: 441
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9780701754385965
# Specificity : 0.9389671361502347
# Accuracy: 0.9591836734693877
# ROC 0.958518655794
# TP 223 FP 13 TN 200 FN 5
#
#
#
# None
# Cross Validation: [ 0.92743764  0.97505669  0.96598639  0.9569161   0.98412698]
# y random_under_sample   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 8, 18, 8, 8, 20, 8, 8, 8, 8, 13, 3, 13, -1.4923076923076926, 86.52307692307694, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9230769230769231
# Specificity : 0.9
# Accuracy: 0.9130434782608695
# ROC 0.911538461538
# TP 12 FP 1 TN 9 FN 1
#
#
#
# None
# Cross Validation: [ 0.83333333  0.75        0.77272727  1.          0.72727273]
# x random_under_sample   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 5, 3, 3, 3, 20, 13, 12, 5, 14, 8, 13, 3, 2.7769230769230764, 11.715384615384616, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8461538461538461
# Specificity : 0.9
# Accuracy: 0.8695652173913043
# ROC 0.873076923077
# TP 11 FP 1 TN 9 FN 2
#
#
#
# None
# Cross Validation: [ 0.875       0.875       1.          0.90909091  0.86363636]
# y ncl   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 12, 8, 12, 9, 10, 20, 4, 2, 10, 9, 10, 7, -0.09230769230769215, 57.36923076923078, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 845
# Test Data Points: 212
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1111111111111111
# Specificity : 0.9852216748768473
# Accuracy: 0.9481132075471698
# ROC 0.548166392994
# TP 1 FP 3 TN 200 FN 8
#
#
#
# None
# Cross Validation: [ 0.91981132  0.93867925  0.94312796  0.93838863  0.95260664]
# x ncl   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 13, 16, 19, 19, 20, 2, 1, 1, 9, 9, 1, 9, -1.284615384615385, 23.6, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 845
# Test Data Points: 212
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1111111111111111
# Specificity : 0.9802955665024631
# Accuracy: 0.9433962264150944
# ROC 0.545703338807
# TP 1 FP 4 TN 199 FN 8
#
#
#
# None
# Cross Validation: [ 0.94339623  0.93396226  0.95260664  0.95734597  0.9478673 ]
# y near_miss   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 19, 10, 1, 1, 10, 2, 3, 9, 9, 19, 19, 9, -1.6384615384615384, 88.24615384615386, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7692307692307693
# Specificity : 0.9
# Accuracy: 0.8260869565217391
# ROC 0.834615384615
# TP 10 FP 1 TN 9 FN 3
#
#
#
# None
# Cross Validation: [ 0.79166667  0.83333333  0.81818182  0.63636364  0.72727273]
# x near_miss   Data/Training/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 18, 11, 18, 11, 10, 10, 20, 11, 3, 10, 18, 20, -1.5230769230769232, 37.392307692307696, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 91
# Test Data Points: 23
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7692307692307693
# Specificity : 0.9
# Accuracy: 0.8260869565217391
# ROC 0.834615384615
# TP 10 FP 1 TN 9 FN 3
#
#
#
# None
# Cross Validation: [ 0.79166667  0.83333333  0.81818182  0.77272727  0.77272727]
# y pass   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 11, 9, 3, 1, 10, 17, 8, 19, 12, 9, 2, 3, -0.9384615384615385, 81.86153846153847, 0.0]
# Finished working with Data
# Training Data Points: 4080
# Test Data Points: 1021
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.25
# Specificity : 0.9969666329625885
# Accuracy: 0.9735553379040157
# ROC 0.623483316481
# TP 8 FP 3 TN 986 FN 24
#
#
#
# None
# Cross Validation: [ 0.97061704  0.96176471  0.96568627  0.96568627  0.96862745]
# x pass   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 2, 1, 3, 17, 10, 5, 5, 9, 10, 2, 10, 9, -0.4, 87.47692307692309, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 4080
# Test Data Points: 1021
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2727272727272727
# Specificity : 0.9907881269191402
# Accuracy: 0.9598432908912831
# ROC 0.631757699823
# TP 12 FP 9 TN 968 FN 32
#
#
#
# None
# Cross Validation: [ 0.96767875  0.96764706  0.96764706  0.96764706  0.97058824]
# y ADASYN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 20, 17, 10, 3, 20, 7, 16, 3, 17, 19, 2, 1, -1.2538461538461536, 46.284615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7857
# Test Data Points: 1965
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.977482088024565
# Specificity : 0.979757085020243
# Accuracy: 0.9786259541984733
# ROC 0.978619586522
# TP 955 FP 20 TN 968 FN 22
#
#
#
# None
# Cross Validation: [ 0.89312977  0.93638677  0.93839104  0.94246436  0.92617108]
# x ADASYN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 6, 15, 4, 10, 20, 9, 13, 1, 20, 17, 18, 3, -0.5000000000000001, 118.91538461538462, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7857
# Test Data Points: 1965
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9815195071868583
# Specificity : 0.9778002018163471
# Accuracy: 0.9796437659033079
# ROC 0.979659854502
# TP 956 FP 22 TN 969 FN 18
#
#
#
# None
# Cross Validation: [ 0.9043257   0.93435115  0.95672098  0.94704684  0.91089613]
# y SMOTEENN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 7, 2, 16, 6, 20, 11, 5, 9, 1, 8, 7, 12, -1.0461538461538462, -2.7923076923076904, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7855
# Test Data Points: 1964
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9653465346534653
# Specificity : 0.9706498951781971
# Accuracy: 0.9679226069246436
# ROC 0.967998214916
# TP 975 FP 28 TN 926 FN 35
#
#
#
# None
# Cross Validation: [ 0.94857434  0.97861507  0.97148676  0.9811609   0.97300051]
# x SMOTEENN   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 8, 15, 3, 18, 10, 8, 18, 8, 2, 1, 15, 9, -1.1538461538461537, 0.11538461538461771, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 7854
# Test Data Points: 1964
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9584569732937686
# Specificity : 0.9716684155299056
# Accuracy: 0.964867617107943
# ROC 0.965062694412
# TP 969 FP 27 TN 926 FN 42
#
#
#
# None
# Cross Validation: [ 0.95162933  0.9709776   0.98167006  0.97656648  0.97096281]
# y random_under_sample   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 10, 2, 20, 2, 10, 1, 19, 6, 18, 20, 20, 13, -0.16153846153846158, 12.192307692307693, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7575757575757576
# Specificity : 0.9090909090909091
# Accuracy: 0.8441558441558441
# ROC 0.833333333333
# TP 25 FP 4 TN 40 FN 8
#
#
#
# None
# Cross Validation: [ 0.85897436  0.88157895  0.88157895  0.84210526  0.88157895]
# x random_under_sample   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 13, 3, 18, 18, 10, 17, 10, 10, 10, 10, 2, 10, -0.5307692307692308, 117.10769230769232, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6666666666666666
# Specificity : 0.9318181818181818
# Accuracy: 0.8181818181818182
# ROC 0.799242424242
# TP 22 FP 3 TN 41 FN 11
#
#
#
# None
# Cross Validation: [ 0.83333333  0.82894737  0.78947368  0.81578947  0.82894737]
# y ncl   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 19, 18, 11, 5, 10, 5, 8, 10, 19, 12, 15, 10, -1.0000000000000002, 49.830769230769235, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3865
# Test Data Points: 967
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.43478260869565216
# Specificity : 0.991313789359392
# Accuracy: 0.9648397104446742
# ROC 0.713048199028
# TP 20 FP 8 TN 913 FN 26
#
#
#
# None
# Cross Validation: [ 0.96694215  0.97204969  0.97204969  0.96583851  0.97101449]
# x ncl   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 9, 9, 8, 19, 10, 19, 19, 2, 9, 9, 9, 19, -2.476923076923077, 143.72307692307695, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 3865
# Test Data Points: 967
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3695652173913043
# Specificity : 0.990228013029316
# Accuracy: 0.9607032057911065
# ROC 0.67989661521
# TP 17 FP 9 TN 912 FN 29
#
#
#
# None
# Cross Validation: [ 0.96177686  0.97308489  0.97101449  0.9699793   0.97204969]
# y near_miss   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 7, 2, 19, 13, 20, 12, 7, 12, 13, 19, 12, 11, 0.21538461538461526, 2.2384615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7272727272727273
# Specificity : 0.8863636363636364
# Accuracy: 0.8181818181818182
# ROC 0.806818181818
# TP 24 FP 5 TN 39 FN 9
#
#
#
# None
# Cross Validation: [ 0.84615385  0.76315789  0.76315789  0.84210526  0.77631579]
# x near_miss   Data/Training/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 15, 14, 14, 7, 20, 11, 10, 3, 10, 10, 7, 2, 0.0999999999999999, 38.861538461538466, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305
# Test Data Points: 77
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7575757575757576
# Specificity : 0.8636363636363636
# Accuracy: 0.8181818181818182
# ROC 0.810606060606
# TP 25 FP 6 TN 38 FN 8
#
#
#
# None
# Cross Validation: [ 0.79487179  0.78947368  0.78947368  0.76315789  0.85526316]
# y pass   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 13, 8, 9, 8, 10, 5, 12, 13, 17, 2, 3, 1, 0.6076923076923078, 72.66153846153847, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 2469
# Test Data Points: 618
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 594 FN 24
#
#
#
# None
# Cross Validation: [ 0.96601942  0.96440129  0.96272285  0.96596434  0.96272285]
# x pass   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 2, 1, 7, 2, 20, 7, 12, 1, 7, 19, 9, 3, -0.9615384615384612, -16.892307692307693, 0.0]
# Finished working with Data
# Training Data Points: 2469
# Test Data Points: 618
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 597 FN 20
#
#
#
# None
# Cross Validation: [ 0.96440129  0.96440129  0.95948136  0.9643436   0.96596434]
# y ADASYN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 3, 9, 3, 18, 15, 10, 5, 19, 7, 18, 2, 19, -0.6538461538461539, 5.661538461538462, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4776
# Test Data Points: 1194
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9644012944983819
# Specificity : 0.9756944444444444
# Accuracy: 0.9698492462311558
# ROC 0.970047869471
# TP 596 FP 14 TN 562 FN 22
#
#
#
# None
# Cross Validation: [ 0.86276151  0.91213389  0.90368509  0.96144174  0.8977368 ]
# x ADASYN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 7, 6, 5, 9, 10, 10, 1, 13, 16, 12, 2, 2, 0.3153846153846154, 41.823076923076925, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4776
# Test Data Points: 1194
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9723127035830619
# Specificity : 0.9844827586206897
# Accuracy: 0.9782244556113903
# ROC 0.978397731102
# TP 597 FP 9 TN 571 FN 17
#
#
#
# None
# Cross Validation: [ 0.87531381  0.91799163  0.94639866  0.9086337   0.92539816]
# y SMOTEENN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 3, 7, 12, 3, 10, 15, 3, 1, 18, 16, 4, 18, -0.2, -10.361538461538462, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4769
# Test Data Points: 1193
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9660194174757282
# Specificity : 0.9686956521739131
# Accuracy: 0.9673093042749371
# ROC 0.967357534825
# TP 597 FP 18 TN 557 FN 21
#
#
#
# None
# Cross Validation: [ 0.94467728  0.97988265  0.98322148  0.98322148  0.98489933]
# x SMOTEENN   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 15, 3, 15, 19, 10, 19, 17, 1, 3, 10, 20, 3, -0.27692307692307705, 29.93076923076923, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 4769
# Test Data Points: 1193
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9692556634304207
# Specificity : 0.9860869565217392
# Accuracy: 0.9773679798826488
# ROC 0.977671309976
# TP 599 FP 8 TN 567 FN 19
#
#
#
# None
# Cross Validation: [ 0.93126572  0.9782062   0.98154362  0.9807047   0.9840604 ]
# y random_under_sample   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 13, 8, 9, 8, 10, 5, 12, 13, 17, 2, 3, 1, 0.6076923076923078, 72.66153846153847, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5
# Specificity : 0.75
# Accuracy: 0.6428571428571429
# ROC 0.625
# TP 9 FP 6 TN 18 FN 9
#
#
#
# None
# Cross Validation: [ 0.54761905  0.76190476  0.71428571  0.66666667  0.61904762]
# x random_under_sample   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 19, 11, 19, 16, 15, 9, 20, 19, 15, 20, 20, 1, -1.8923076923076922, 18.369230769230768, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6111111111111112
# Specificity : 0.4583333333333333
# Accuracy: 0.5238095238095238
# ROC 0.534722222222
# TP 11 FP 13 TN 11 FN 7
#
#
#
# None
# Cross Validation: [ 0.66666667  0.69047619  0.66666667  0.57142857  0.76190476]
# y ncl   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 5, 19, 2, 3, 15, 19, 9, 19, 12, 12, 7, 9, -0.23846153846153847, 49.53846153846155, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2308
# Test Data Points: 577
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 4 TN 557 FN 16
#
#
#
# None
# Cross Validation: [ 0.95840555  0.96187175  0.96187175  0.96360485  0.96187175]
# x ncl   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 18, 3, 9, 13, 20, 15, 12, 8, 17, 18, 15, 19, -1.0153846153846156, 45.223076923076924, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2308
# Test Data Points: 577
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 561 FN 16
#
#
#
# None
# Cross Validation: [ 0.96360485  0.96360485  0.96013865  0.96187175  0.96013865]
# y near_miss   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 9, 15, 13, 7, 10, 12, 7, 1, 1, 11, 12, 12, -0.16923076923076932, 33.07692307692308, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4444444444444444
# Specificity : 0.8333333333333334
# Accuracy: 0.6666666666666666
# ROC 0.638888888889
# TP 8 FP 4 TN 20 FN 10
#
#
#
# None
# Cross Validation: [ 0.64285714  0.61904762  0.71428571  0.5952381   0.73809524]
# x near_miss   Data/Training/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 17, 13, 6, 9, 10, 11, 3, 3, 3, 2, 2, 7, 0.030769230769230625, 82.92307692307692, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 168
# Test Data Points: 42
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4444444444444444
# Specificity : 0.7916666666666666
# Accuracy: 0.6428571428571429
# ROC 0.618055555556
# TP 8 FP 5 TN 19 FN 10
#
#
#
# None
# Cross Validation: [ 0.61904762  0.78571429  0.76190476  0.66666667  0.73809524]
