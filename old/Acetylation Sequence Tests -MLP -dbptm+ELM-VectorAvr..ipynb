# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 7, 11, 19, 18, 10, 7, 9, 9, 18, 19, 10, 17, -2.9076923076923076, 52.338461538461544, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 263216
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 64178 FN 1626
#
#
#
# None
# Cross Validation: [ 0.9754274   0.97541183  0.97541183  0.97539663  0.97541146]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.0006222775357809583
# Specificity : 1.0
# Accuracy: 0.9185226523261123
# ROC 0.500311138768
# TP 2 FP 0 TN 36208 FN 3212
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 11, 19, 18, 11, 3, 7, 20, 10, 13, 11, 13, 7, -0.9076923076923076, -16.27692307692308, 0.0]
# Finished working with Data
# Training Data Points: 263216
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 64181 FN 1622
#
#
#
# None
# Cross Validation: [ 0.97539701  0.97536624  0.97541183  0.97544222  0.97544185]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 10, 17, 17, 20, 7, 7, 7, 17, 12, 17, 14, 18, -2.215384615384615, 108.00000000000001, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512777
# Test Data Points: 128195
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7025770229708083
# Specificity : 0.9311694002754476
# Accuracy: 0.8165139045984633
# ROC 0.816873211623
# TP 45175 FP 4398 TN 59498 FN 19124
#
#
#
# None
# Cross Validation: [ 0.79578926  0.83665382  0.82804967  0.81476512  0.83586595]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.08369632856253889
# Specificity : 0.9211776403004861
# Accuracy: 0.8528993962761909
# ROC 0.502436984432
# TP 269 FP 2854 TN 33354 FN 2945
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 5, 19, 9, 2, 3, 7, 9, 15, 9, 9, 2, 13, -0.9153846153846156, 31.469230769230773, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512777
# Test Data Points: 128195
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.730778792964137
# Specificity : 0.9449082849042122
# Accuracy: 0.8374117555286867
# ROC 0.837843538934
# TP 47030 FP 3517 TN 60322 FN 17326
#
#
#
# None
# Cross Validation: [ 0.78305095  0.8203036   0.82861132  0.83130256  0.82221477]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.07591785936527691
# Specificity : 0.9389637649138312
# Accuracy: 0.8686012886205672
# ROC 0.50744081214
# TP 244 FP 2210 TN 33998 FN 2970
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 12, 13, 11, 7, 7, 7, 20, 6, 19, 7, 12, 2, -0.26153846153846155, -17.60769230769231, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512521
# Test Data Points: 128131
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6136724712625775
# Specificity : 0.8059253234056531
# Accuracy: 0.7095940873012776
# ROC 0.709798897334
# TP 39399 FP 12407 TN 51522 FN 24803
#
#
#
# None
# Cross Validation: [ 0.70969001  0.7187778   0.70320768  0.73026614  0.72263326]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.2700684505289359
# Specificity : 0.8179407865665046
# Accuracy: 0.7732738065039826
# ROC 0.544004618548
# TP 868 FP 6592 TN 29616 FN 2346
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 12, 20, 7, 2, 2, 7, 17, 13, 18, 12, 20, 11, -0.23846153846153845, 21.246153846153845, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 512512
# Test Data Points: 128129
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6650489224575147
# Specificity : 0.7760117411941044
# Accuracy: 0.7205160424259925
# ROC 0.720530331826
# TP 42617 FP 14346 TN 49702 FN 21464
#
#
#
# None
# Cross Validation: [ 0.69515098  0.71519106  0.72659372  0.71334915  0.71544861]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.28189172370877413
# Specificity : 0.789576889085285
# Accuracy: 0.7481862919182183
# ROC 0.535734306397
# TP 906 FP 7619 TN 28589 FN 2308
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 5, 7, 18, 11, 11, 7, 18, 12, 8, 8, 16, 9, -1.6076923076923075, 25.084615384615386, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.23870573870573872
# Specificity : 0.8155583437892095
# Accuracy: 0.5232054455445545
# ROC 0.527132041247
# TP 391 FP 294 TN 1300 FN 1247
#
#
#
# None
# Cross Validation: [ 0.51701733  0.53681931  0.52691832  0.5362005   0.52693498]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.24984443061605477
# Specificity : 0.8210892620415378
# Accuracy: 0.7745167672873015
# ROC 0.535466846329
# TP 803 FP 6478 TN 29730 FN 2411
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 17, 3, 12, 7, 9, 7, 17, 9, 5, 9, 12, 7, -1.5153846153846153, 29.876923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.442002442002442
# Specificity : 0.6311166875784191
# Accuracy: 0.5352722772277227
# ROC 0.53655956479
# TP 724 FP 588 TN 1006 FN 914
#
#
#
# None
# Cross Validation: [ 0.52568069  0.55259901  0.53867574  0.52413366  0.53157895]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.4626633478531425
# Specificity : 0.6145326999558108
# Accuracy: 0.6021510831515398
# ROC 0.538598023904
# TP 1487 FP 13957 TN 22251 FN 1727
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 1, 16, 10, 1, 3, 7, 11, 3, 10, 1, 9, 20, -0.30000000000000004, -15.430769230769231, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 251361
# Test Data Points: 62841
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 61226 FN 1613
#
#
#
# None
# Cross Validation: [ 0.97426839  0.9742843   0.97423657  0.97425207  0.97428349]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 2 TN 36206 FN 3214
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 12, 2, 16, 9, 16, 7, 9, 7, 7, 15, 9, 4, -1.9923076923076921, 2.784615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 251376
# Test Data Points: 62845
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 61232 FN 1613
#
#
#
# None
# Cross Validation: [ 0.97419047  0.97427003  0.97422188  0.97425371  0.97430104]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 18, 12, 7, 20, 3, 7, 5, 9, 3, 3, 2, 7, 3.416070845000482e-17, 0.48461538461538456, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8284493284493285
# Specificity : 0.6706398996235885
# Accuracy: 0.7506188118811881
# ROC 0.749544614036
# TP 1357 FP 525 TN 1069 FN 281
#
#
#
# None
# Cross Validation: [ 0.72555693  0.76701733  0.76732673  0.75030941  0.7380805 ]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.8456751711263223
# Specificity : 0.14540985417587274
# Accuracy: 0.20250114149459691
# ROC 0.495542512651
# TP 2718 FP 30943 TN 5265 FN 496
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 13, 13, 5, 7, 1, 7, 13, 3, 7, 19, 7, 9, -0.5692307692307692, -20.16923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8156288156288156
# Specificity : 0.6951066499372648
# Accuracy: 0.7561881188118812
# ROC 0.755367732783
# TP 1336 FP 486 TN 1108 FN 302
#
#
#
# None
# Cross Validation: [ 0.74071782  0.75154703  0.75030941  0.75        0.74643963]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.827317983820784
# Specificity : 0.16126270437472381
# Accuracy: 0.21556491299274516
# ROC 0.494290344098
# TP 2659 FP 30369 TN 5839 FN 555
#
#
#
# None
