# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
from scipy.stats import randint
from scipy.stats import uniform
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier



forest = {"max_depth": [3, None],
              "min_samples_leaf": randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"],
              "max_depth":randint(1,1000),
              "warm_start":[True ,False]
         }
mlp = {
    "activation":["identity", "logistic", "tanh", "relu"], 
    "solver":["lbfgs", "sgd", "adam"], 
    "learning_rate":["constant", "invscaling", "adaptive"], 
    "hidden_layer_sizes":randint(1,99), 
    "alpha":uniform(0.000001, .001), 
    "power_t":uniform(0.1, .9), 
    "momentum":uniform(0.0, 1.0)
}
svc = {
    "kernel":["rbf", "linear", "sigmoid"],
    "probability":[True, False],
    "shrinking":[True, False], 
    "C":uniform(0.1, 1.0)  
}
bagging = {
    "n_estimators":randint(1,50), 
    "base_estimator":[None, RandomForestClassifier, XGBClassifier], 
    "bootstrap":[True, False], 
    "bootstrap_features":[True, False]
}
xgb = {
    
}

# %% [markdown]
# Serine Phosphorylation Test No Gridsearch

# %%
classy = ["xgb", "mlp_adam", "forest", "svc", "bagging"]
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
best_score = 0
best_params = []
for j in classy:
    for i in par:
        print("y",j, i)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training(j)
        y.benchmark("Data/Benchmarks/phos.csv", "S")
        if y.benchmark_mcc > best_score:
            best_score = y.benchmark_mcc
            best_params = ["y", i, j]
        del y
        print("x",j , i)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training(j)
        x.benchmark("Data/Benchmarks/phos.csv", "S")
        if x.benchmark_mcc > best_score:
            best_score = x.benchmark_mcc
            best_params = ["x", i, j]
        del x
print("Best Score")
print(best_score)
print(best_params)
# Out:
# y xgb pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 7, 10, 3, 5, 10, 10, 18, 1, 1, 12, 12, 0, 0.6833333333333332, 15.900000000000006, 0.08333333333333333]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08822891827444179
# Specificity : 0.9855132754190628
# Accuracy: 0.8202471501866603
# ROC 0.536871096847
# Matthews Correlation Coeff:  0.173064615634
# TP 814 FP 592 TN 40273 FN 8412
#
#
#
# None
# Cross Validation: 0.168728854293
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0076968620485494375
# Specificity : 0.981620999088248
# Accuracy: 0.9316943622429623
# ROC 0.494658930568
# Matthews Correlation Coeff:  -0.0178011852199
# TP 26 FP 1149 TN 61368 FN 3352
#
#
#
# None
# x xgb pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 12, 12, 20, 10, 1, 10, 10, 12, 3, 9, 20, 12, 0.7230769230769231, 17.51538461538462, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08604269293924466
# Specificity : 0.9866686199824202
# Accuracy: 0.8224231897945739
# ROC 0.536355656461
# Matthews Correlation Coeff:  0.174516109298
# TP 786 FP 546 TN 40410 FN 8349
#
#
#
# None
# Cross Validation: 0.167874214246
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.006216696269982238
# Specificity : 0.9829646336196555
# Accuracy: 0.9328932392442523
# ROC 0.494590664945
# Matthews Correlation Coeff:  -0.0187400261564
# TP 21 FP 1065 TN 61452 FN 3357
#
#
#
# None
# y xgb ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 17, 3, 13, 10, 2, 10, 3, 5, 3, 17, 5, 3, 1.0, 24.04615384615385, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331776
# Test Data Points: 82945
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6666824892011203
# Specificity : 0.9909828232584352
# Accuracy: 0.8262463077943215
# ROC 0.82883265623
# Matthews Correlation Coeff:  0.69256615483
# TP 28090 FP 368 TN 40443 FN 14044
#
#
#
# None
# Cross Validation: 0.67287631824
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.004736530491415038
# Specificity : 0.993329814290513
# Accuracy: 0.9426511874952576
# ROC 0.499033172391
# Matthews Correlation Coeff:  -0.005277999487
# TP 16 FP 417 TN 62100 FN 3362
#
#
#
# None
# x xgb ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 19, 2, 3, 13, 9, 10, 3, 14, 17, 19, 7, 19, -0.38461538461538464, 44.78461538461538, 0.0]
# Balancing Data

# %% [markdown]
# Threonine Phosphorylation No Grid search

# %%
classy = ["xgb", "mlp_adam", "forest", "svc", "bagging"]
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
best_score = 0
best_params = []
for j in classy:
    for i in par:
        print("y",j, i)
        y = Predictor()
        y.load_data(file="Data/Training/clean_t_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training(j)
        y.benchmark("Data/Benchmarks/phos.csv", "T")
        if y.benchmark_mcc > best_score:
            best_score = y.benchmark_mcc
            best_params = ["y", i, j]
        del y
        print("x",j , i)
        x = Predictor()
        x.load_data(file="Data/Training/clean_t_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training(j)
        x.benchmark("Data/Benchmarks/phos.csv", "T")
        if x.benchmark_mcc > best_score:
            best_score = x.benchmark_mcc
            best_params = ["x", i, j]
        del x
print("Best Score")
print(best_score)
print(best_params)

# %% [markdown]
# Tyrosine Phopshorylation No Grid Search

# %%
classy = ["xgb", "mlp_adam", "forest", "svc", "bagging"]
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
best_score = 0
best_params = []
for j in classy:
    for i in par:
        print("y",j, i)
        y = Predictor()
        y.load_data(file="Data/Training/clean_Y_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
        y.supervised_training(j)
        y.benchmark("Data/Benchmarks/phos.csv", "Y")
        if y.benchmark_mcc > best_score:
            best_score = y.benchmark_mcc
            best_params = ["y", i, j]
        del y
        print("x",j , i)
        x = Predictor()
        x.load_data(file="Data/Training/clean_Y_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
        x.supervised_training(j)
        x.benchmark("Data/Benchmarks/phos.csv", "Y")
        if x.benchmark_mcc > best_score:
            best_score = x.benchmark_mcc
            best_params = ["x", i, j]
        del x
print("Best Score")
print(best_score)
print(best_params)

# %% [markdown]
# Lysine Acetylation No Grid Search

# %%
classy = ["xgb", "mlp_adam", "forest", "svc", "bagging"]
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
best_score = 0
best_params = []
for j in classy:
    for i in par:
        print("y",j, i)
        y = Predictor()
        y.load_data(file="Data/Training/k_acetylation.csv")
        y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=0)
        y.supervised_training(j)
        y.benchmark("Data/Benchmarks/acet.csv", "K")
        if y.benchmark_mcc > best_score:
            best_score = y.benchmark_mcc
            best_params = ["y", i, j]
        del y
        print("x",j , i)
        x = Predictor()
        x.load_data(file="Data/Training/k_acetylation.csv")
        x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
        x.supervised_training(j)
        x.benchmark("Data/Benchmarks/acet.csv", "K")
        if x.benchmark_mcc > best_score:
            best_score = x.benchmark_mcc
            best_params = ["x", i, j]
        del x
print("Best Score")
print(best_score)
print(best_params)

# %% [markdown]
# Lysine Methylation No Grid Search

# %%
classy = ["xgb", "mlp_adam", "forest", "svc", "bagging"]
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
best_score = 0
best_params = []
for j in classy:
    for i in par:
        print("y",j, i)
        y = Predictor()
        y.load_data(file="Data/Training/k_methylation.csv")
        y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=0)
        y.supervised_training(j)
        y.benchmark("Data/Benchmarks/methylation.csv", "K")
        if y.benchmark_mcc > best_score:
            best_score = y.benchmark_mcc
            best_params = ["y", i, j]
        del y
        print("x",j , i)
        x = Predictor()
        x.load_data(file="Data/Training/k_methylation.csv")
        x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
        x.supervised_training(j)
        x.benchmark("Data/Benchmarks/methylation.csv", "K")
        if x.benchmark_mcc > best_score:
            best_score = x.benchmark_mcc
            best_params = ["x", i, j]
        del x
print("Best Score")
print(best_score)
print(best_params)
