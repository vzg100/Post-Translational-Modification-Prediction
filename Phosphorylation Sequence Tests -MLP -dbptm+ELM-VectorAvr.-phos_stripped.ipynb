# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 10, 10, 8, 11, 15, 10, 19, 10, 9, 9, 0, 0, -1.6636363636363638, 126.27272727272728, 0.09090909090909091]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05815229317533465
# Specificity : 0.9870659150255021
# Accuracy: 0.818051146912619
# ROC 0.5226091041
# TP 530 FP 530 TN 40447 FN 8584
#
#
#
# None
# Cross: Validation: [ 0.8161982   0.81451758  0.81567547  0.81694949  0.81527251]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.06835443037974684
# Specificity : 0.9877388080980896
# Accuracy: 0.9387231745174788
# ROC 0.528046619239
# TP 27 FP 86 TN 6928 FN 368
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 10, 10, 17, 10, 17, 10, 17, 10, 11, 10, 0, 0, -1.881818181818182, 273.92727272727274, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0221909504221693
# Specificity : 0.9958387388931046
# Accuracy: 0.8162743806272584
# ROC 0.509014844658
# TP 205 FP 170 TN 40683 FN 9033
#
#
#
# None
# Cross: Validation: [ 0.8161982   0.81603482  0.81583518  0.81573168  0.81605111]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.02531645569620253
# Specificity : 0.9942971200456231
# Accuracy: 0.9426373329734107
# ROC 0.509806787871
# TP 10 FP 40 TN 6974 FN 385
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 9, 13, 13, 17, 10, 10, 20, 1, 9, 15, 12, 12, 0.09230769230769233, 75.14615384615387, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331729
# Test Data Points: 82933
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6701155986870273
# Specificity : 0.8900002445525911
# Accuracy: 0.7785320680549359
# ROC 0.78005792162
# TP 28173 FP 4498 TN 36393 FN 13869
#
#
#
# None
# Cross: Validation: [ 0.50817518  0.81363044  0.82340954  0.83867506  0.83250133]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.3468354430379747
# Specificity : 0.8897918448816653
# Accuracy: 0.8608449183425564
# ROC 0.61831364396
# TP 137 FP 773 TN 6241 FN 258
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 13, 7, 12, 6, 5, 10, 19, 15, 5, 18, 13, 10, 0.015384615384615382, 23.43846153846154, 0.3076923076923077]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331705
# Test Data Points: 82927
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6900925771674719
# Specificity : 0.8503960105602816
# Accuracy: 0.7691704752372569
# ROC 0.770244293864
# TP 28997 FP 6120 TN 34788 FN 13022
#
#
#
# None
# Cross: Validation: [ 0.52370731  0.80768396  0.83658925  0.82261293  0.84826231]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.4379746835443038
# Specificity : 0.8377530652979754
# Accuracy: 0.8164394655149143
# ROC 0.637863874421
# TP 173 FP 1138 TN 5876 FN 222
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 11, 7, 11, 3, 2, 10, 19, 4, 19, 20, 7, 19, -1.3153846153846156, 6.6846153846153875, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305792
# Test Data Points: 76448
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7201992778975063
# Specificity : 0.7223900390481102
# Accuracy: 0.7213661573880285
# ROC 0.721294658473
# TP 25732 FP 11304 TN 29415 FN 9997
#
#
#
# None
# Cross: Validation: [ 0.62841895  0.70960653  0.71716722  0.71006436  0.72662106]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.5341772151898734
# Specificity : 0.6633875106928999
# Accuracy: 0.6564988527466594
# ROC 0.598782362941
# TP 211 FP 2361 TN 4653 FN 184
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 1, 3, 10, 19, 9, 9, 19, 10, 10, 0, 0, -0.9454545454545457, 101.04545454545456, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 232086
# Test Data Points: 58022
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9308773820604517
# Specificity : 0.49819725517562224
# Accuracy: 0.802643824756127
# ROC 0.714537318618
# TP 38004 FP 8629 TN 8567 FN 2822
#
#
#
# None
# Cross: Validation: [ 0.7638178   0.80822791  0.80841419  0.81554954  0.80264042]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.9164556962025316
# Specificity : 0.28785286569717705
# Accuracy: 0.321365906330139
# ROC 0.60215428095
# TP 362 FP 4995 TN 2019 FN 33
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 13, 1, 11, 11, 2, 10, 10, 1, 11, 20, 3, 5, 0.32307692307692304, 53.67692307692308, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.561617458279846
# Specificity : 0.6971660808435852
# Accuracy: 0.6284955560372859
# ROC 0.629391769562
# TP 5250 FP 2757 TN 6347 FN 4098
#
#
#
# None
# Cross: Validation: [ 0.64540429  0.64041838  0.63537828  0.58710027  0.64357724]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.5974683544303797
# Specificity : 0.6608212147134302
# Accuracy: 0.6574436496153327
# ROC 0.629144784572
# TP 236 FP 2379 TN 4635 FN 159
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 8, 12, 4, 18, 3, 15, 10, 10, 3, 17, 18, 8, -0.8923076923076925, 54.938461538461546, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.785836542575952
# Specificity : 0.5019771528998243
# Accuracy: 0.645783654888359
# ROC 0.643906847738
# TP 7346 FP 4534 TN 4570 FN 2002
#
#
#
# None
# Cross: Validation: [ 0.64551268  0.63060915  0.65055279  0.64596206  0.59257453]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.8202531645569621
# Specificity : 0.43199315654405473
# Accuracy: 0.4526926710757187
# ROC 0.626123160551
# TP 324 FP 3984 TN 3030 FN 71
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 11, 17, 11, 10, 10, 1, 20, 3, 2, 10, 0, 0, -0.6272727272727274, 58.263636363636365, 0.09090909090909091]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143692
# Test Data Points: 35923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3859363112705141
# Specificity : 0.8858992590374972
# Accuracy: 0.7578431645463909
# ROC 0.635917785154
# TP 3551 FP 3049 TN 23673 FN 5650
#
#
#
# None
# Cross: Validation: [ 0.7548714   0.76917938  0.76619436  0.75975725  0.74942932]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.44050632911392407
# Specificity : 0.8334759053321927
# Accuracy: 0.8125253070589823
# ROC 0.636991117223
# TP 174 FP 1168 TN 5846 FN 221
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 2, 2, 7, 2, 3, 10, 11, 9, 19, 17, 10, 17, -1.3692307692307693, 114.03076923076922, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143688
# Test Data Points: 35922
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.15798081116441343
# Specificity : 0.9727850467289719
# Accuracy: 0.7647402705862703
# ROC 0.565382928947
# TP 1449 FP 728 TN 26022 FN 7723
#
#
#
# None
# Cross: Validation: [ 0.7622693   0.76728002  0.76176159  0.76484508  0.7671557 ]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.1620253164556962
# Specificity : 0.950242372398061
# Accuracy: 0.9082197327574572
# ROC 0.556133844427
# TP 64 FP 349 TN 6665 FN 331
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 10, 2, 10, 16, 17, 10, 9, 7, 10, 9, 3, 10, -1.5769230769230769, 72.66153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4968977321352161
# Specificity : 0.8157952548330404
# Accuracy: 0.654238022978539
# ROC 0.656346493484
# TP 4645 FP 1677 TN 7427 FN 4703
#
#
#
# None
# Cross: Validation: [ 0.61207457  0.67721656  0.65640581  0.66617886  0.65799458]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.4962025316455696
# Specificity : 0.5171086398631308
# Accuracy: 0.5159940612768255
# ROC 0.506655585754
# TP 196 FP 3387 TN 3627 FN 199
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 5, 19, 19, 11, 11, 10, 2, 7, 2, 2, 13, 19, -0.49999999999999994, 48.353846153846156, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.34745400085579803
# Specificity : 0.9078427065026362
# Accuracy: 0.6239432039887275
# ROC 0.627648353679
# TP 3248 FP 839 TN 8265 FN 6100
#
#
#
# None
# Cross: Validation: [ 0.63564925  0.6656189   0.71217212  0.67783198  0.67327913]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.34430379746835443
# Specificity : 0.626746506986028
# Accuracy: 0.6116884869753003
# ROC 0.485525152227
# TP 136 FP 2618 TN 4396 FN 259
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 7, 7, 10, 12, 13, 15, 2, 12, 19, 19, 10, 5, -0.2846153846153847, 48.91538461538462, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 2410 FN 115
#
#
#
# None
# Cross: Validation: [ 0.95288994  0.95247525  0.95287129  0.95324881  0.95206022]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 1.0
# Accuracy: 0.9989528795811519
# ROC 0.75
# TP 1 FP 0 TN 953 FN 1
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 1, 5, 20, 1, 3, 15, 14, 9, 10, 8, 4, 1, -0.2692307692307692, 32.330769230769235, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 2386 FN 139
#
#
#
# None
# Cross: Validation: [ 0.95288994  0.95326733  0.95168317  0.95364501  0.95324881]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 1.0
# Accuracy: 0.9989528795811519
# ROC 0.75
# TP 1 FP 0 TN 953 FN 1
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 2, 8, 17, 3, 1, 15, 12, 10, 12, 12, 9, 20, 0.6153846153846153, 2.7, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19360
# Test Data Points: 4840
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7597672485453034
# Specificity : 0.8385373870172556
# Accuracy: 0.7993801652892562
# ROC 0.799152317781
# TP 1828 FP 393 TN 2041 FN 578
#
#
#
# None
# Cross: Validation: [ 0.64552778  0.67155546  0.66363636  0.6656334   0.67885927]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8593913955928646
# Accuracy: 0.8596858638743455
# ROC 0.929695697796
# TP 2 FP 134 TN 819 FN 0
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 12, 9, 10, 1, 9, 15, 13, 10, 10, 1, 16, 1, -0.1461538461538462, 18.55384615384616, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19356
# Test Data Points: 4840
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8542178542178542
# Specificity : 0.7468723936613845
# Accuracy: 0.8010330578512397
# ROC 0.80054512394
# TP 2086 FP 607 TN 1791 FN 356
#
#
#
# None
# Cross: Validation: [ 0.66880165  0.69359504  0.65433884  0.63435304  0.6713518 ]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.7639034627492131
# Accuracy: 0.7643979057591623
# ROC 0.881951731375
# TP 2 FP 225 TN 728 FN 0
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 19, 12, 5, 20, 5, 15, 12, 7, 9, 18, 3, 8, -0.4307692307692308, 81.47769230769231, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19236
# Test Data Points: 4809
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6780936454849499
# Specificity : 0.8779478692594125
# Accuracy: 0.7785402370555209
# ROC 0.778020757372
# TP 1622 FP 295 TN 2122 FN 770
#
#
#
# None
# Cross: Validation: [ 0.7962578   0.84345114  0.81181119  0.83194676  0.82175541]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.8761804826862539
# Accuracy: 0.875392670157068
# ROC 0.688090241343
# TP 1 FP 118 TN 835 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 12, 15, 4, 19, 13, 15, 1, 7, 16, 8, 7, 8, -1.1307692307692307, 42.35384615384615, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19226
# Test Data Points: 4807
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9103594080338266
# Specificity : 0.6457821457821458
# Accuracy: 0.7759517370501352
# ROC 0.778070776908
# TP 2153 FP 865 TN 1577 FN 212
#
#
#
# None
# Cross: Validation: [ 0.81547743  0.76138964  0.83295195  0.82334582  0.80878069]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.6673662119622246
# Accuracy: 0.6670157068062827
# ROC 0.583683105981
# TP 1 FP 317 TN 636 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 9, 19, 2, 1, 20, 15, 15, 14, 12, 7, 5, 8, -0.6461538461538463, 32.36153846153846, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6440677966101694
# Specificity : 0.453781512605042
# Accuracy: 0.5485232067510548
# ROC 0.548924654608
# TP 76 FP 65 TN 54 FN 42
#
#
#
# None
# Cross: Validation: [ 0.53361345  0.58898305  0.54237288  0.49576271  0.50423729]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4018887722980063
# Accuracy: 0.4031413612565445
# ROC 0.700944386149
# TP 2 FP 570 TN 383 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 15, 15, 13, 3, 10, 15, 9, 9, 2, 3, 3, 2, 0.8923076923076922, 52.815384615384616, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6271186440677966
# Specificity : 0.3865546218487395
# Accuracy: 0.5063291139240507
# ROC 0.506836632958
# TP 74 FP 73 TN 46 FN 44
#
#
#
# None
# Cross: Validation: [ 0.54621849  0.54237288  0.53389831  0.51694915  0.52542373]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4228751311647429
# Accuracy: 0.42408376963350786
# ROC 0.711437565582
# TP 2 FP 550 TN 403 FN 0
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 10, 9, 15, 10, 4, 15, 10, 20, 19, 10, 17, 16, -1.5153846153846153, 86.70769230769233, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9227
# Test Data Points: 2307
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 2192 FN 115
#
#
#
# None
# Cross: Validation: [ 0.94844021  0.94885132  0.94885132  0.94796184  0.94882914]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 0 TN 953 FN 2
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 5, 12, 7, 5, 2, 15, 12, 2, 9, 17, 9, 19, -0.06153846153846159, 21.830769230769235, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9226
# Test Data Points: 2307
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 3 TN 2189 FN 115
#
#
#
# None
# Cross: Validation: [ 0.94887348  0.94885132  0.94796184  0.94926279  0.94926279]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 1.0
# Accuracy: 0.9989528795811519
# ROC 0.75
# TP 1 FP 0 TN 953 FN 1
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 9, 18, 8, 7, 15, 10, 16, 20, 8, 15, 10, 0, -1.8500000000000003, -15.966666666666667, 0.16666666666666666]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.652542372881356
# Specificity : 0.680672268907563
# Accuracy: 0.6666666666666666
# ROC 0.666607320894
# TP 77 FP 38 TN 81 FN 41
#
#
#
# None
# Cross: Validation: [ 0.58823529  0.63983051  0.66949153  0.54237288  0.61016949]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.3473242392444911
# Accuracy: 0.34764397905759165
# ROC 0.423662119622
# TP 1 FP 622 TN 331 FN 1
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 19, 10, 10, 1, 1, 15, 18, 3, 10, 19, 13, 13, -0.23076923076923078, 41.823076923076925, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4406779661016949
# Specificity : 0.9159663865546218
# Accuracy: 0.679324894514768
# ROC 0.678322176328
# TP 52 FP 10 TN 109 FN 66
#
#
#
# None
# Cross: Validation: [ 0.64705882  0.65254237  0.60169492  0.5720339   0.60169492]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.5813221406086044
# Accuracy: 0.581151832460733
# ROC 0.540661070304
# TP 1 FP 399 TN 554 FN 1
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 5, 19, 20, 20, 11, 20, 1, 17, 13, 12, 18, 17, -0.4461538461538461, -5.9, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 3 TN 13533 FN 3045
#
#
#
# None
# Cross: Validation: [ 0.81841756  0.81419612  0.81785283  0.81266586  0.81743064]
# Number of data points in benchmark 4994
# Benchmark Results
# Failed
# TP 0 FP 1 TN 4860 FN 133
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 5, 12, 16, 2, 11, 20, 7, 19, 1, 13, 7, 12, -0.24615384615384617, -7.107692307692307, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 13557 FN 3022
#
#
#
# None
# Cross: Validation: [ 0.81799542  0.81841756  0.81827503  0.81863691  0.81773221]
# Number of data points in benchmark 4994
# Benchmark Results
# Failed
# TP 0 FP 0 TN 4861 FN 133
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 1, 7, 17, 13, 18, 20, 3, 2, 3, 10, 5, 20, 0.46153846153846145, 21.246153846153845, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109780
# Test Data Points: 27446
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5920223431681466
# Specificity : 0.9119566829847203
# Accuracy: 0.7491802084092399
# ROC 0.751989513076
# TP 8267 FP 1187 TN 12295 FN 5697
#
#
#
# None
# Cross: Validation: [ 0.51238796  0.77002113  0.77715431  0.80171252  0.77743769]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.17293233082706766
# Specificity : 0.9168895289035178
# Accuracy: 0.8970764917901481
# ROC 0.544910929865
# TP 23 FP 404 TN 4457 FN 110
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 13, 1, 2, 10, 19, 20, 4, 9, 20, 10, 8, 2, 0.023076923076922926, 5.953846153846156, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109784
# Test Data Points: 27446
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6598727025674033
# Specificity : 0.8078437198247047
# Accuracy: 0.7324564599577352
# ROC 0.733858211196
# TP 9227 FP 2587 TN 10876 FN 4756
#
#
#
# None
# Cross: Validation: [ 0.52960251  0.75603891  0.80361437  0.79038076  0.79872472]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.38345864661654133
# Specificity : 0.8290475210861963
# Accuracy: 0.8171806167400881
# ROC 0.606253083851
# TP 51 FP 831 TN 4030 FN 82
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 12, 3, 2, 7, 11, 20, 11, 4, 8, 20, 11, 4, 0.13846153846153852, -13.96923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102928
# Test Data Points: 25733
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7710004912395612
# Specificity : 0.5849545084695613
# Accuracy: 0.6732600163214549
# ROC 0.677977499855
# TP 9417 FP 5611 TN 7908 FN 2797
#
#
#
# None
# Cross: Validation: [ 0.61096646  0.69747017  0.68237992  0.68820923  0.69577552]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.5864661654135338
# Specificity : 0.5430981279572105
# Accuracy: 0.5442531037244693
# ROC 0.564782146685
# TP 78 FP 2221 TN 2640 FN 55
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 1, 12, 10, 15, 14, 20, 1, 18, 10, 10, 9, 14, -0.5307692307692307, 78.14615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102880
# Test Data Points: 25721
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6858428805237315
# Specificity : 0.6717280201466558
# Accuracy: 0.6784339644648342
# ROC 0.678785450335
# TP 8381 FP 4432 TN 9069 FN 3839
#
#
#
# None
# Cross: Validation: [ 0.61719995  0.69550173  0.68775272  0.69136858  0.68443563]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.46616541353383456
# Specificity : 0.6506891586093396
# Accuracy: 0.6457749299158991
# ROC 0.558427286072
# TP 62 FP 1698 TN 3163 FN 71
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 17, 17, 20, 12, 12, 20, 11, 12, 13, 3, 20, 7, 0.0307692307692309, 101.46923076923078, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5654605263157895
# Specificity : 0.6315966386554622
# Accuracy: 0.598171238570241
# ROC 0.598528582486
# TP 1719 FP 1096 TN 1879 FN 1321
#
#
#
# None
# Cross: Validation: [ 0.59923537  0.59408245  0.59112072  0.5576987   0.5678417 ]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.5488721804511278
# Specificity : 0.6266200370294178
# Accuracy: 0.6245494593512214
# ROC 0.58774610874
# TP 73 FP 1815 TN 3046 FN 60
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 20, 17, 11, 9, 3, 20, 17, 14, 20, 2, 5, 3, 0.023076923076923064, 62.492307692307705, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7546052631578948
# Specificity : 0.44201680672268906
# Accuracy: 0.6
# ROC 0.59831103494
# TP 2294 FP 1660 TN 1315 FN 746
#
#
#
# None
# Cross: Validation: [ 0.60771277  0.5731383   0.58862654  0.60159628  0.54223479]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.7593984962406015
# Specificity : 0.42048961119111294
# Accuracy: 0.42951541850220265
# ROC 0.589944053716
# TP 101 FP 2817 TN 2044 FN 32
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 2, 13, 1, 20, 17, 20, 1, 2, 13, 17, 13, 3, 1.0384615384615385, 4.453846153846156, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47200
# Test Data Points: 11800
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.16541609822646658
# Specificity : 0.9551195308976094
# Accuracy: 0.7588983050847458
# ROC 0.560267814562
# TP 485 FP 398 TN 8470 FN 2447
#
#
#
# None
# Cross: Validation: [ 0.75103805  0.74637743  0.75220339  0.70378846  0.7510806 ]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.20300751879699247
# Specificity : 0.9378728656655009
# Accuracy: 0.9183019623548258
# ROC 0.570440192231
# TP 27 FP 302 TN 4559 FN 106
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 10, 10, 3, 5, 18, 20, 13, 14, 4, 10, 1, 9, 0.676923076923077, 70.5923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47209
# Test Data Points: 11803
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.19222903885480572
# Specificity : 0.9376479873717443
# Accuracy: 0.7523510971786834
# ROC 0.564938513113
# TP 564 FP 553 TN 8316 FN 2370
#
#
#
# None
# Cross: Validation: [ 0.7548081   0.75192748  0.74741569  0.75122861  0.72750381]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.23308270676691728
# Specificity : 0.9158609339642049
# Accuracy: 0.8976772126551862
# ROC 0.574471820366
# TP 31 FP 409 TN 4452 FN 102
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 3, 3, 2, 12, 5, 20, 16, 12, 12, 12, 2, 12, 2.123076923076923, 9.230769230769232, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5947368421052631
# Specificity : 0.7482352941176471
# Accuracy: 0.6706566916043225
# ROC 0.671486068111
# TP 1808 FP 749 TN 2226 FN 1232
#
#
#
# None
# Cross: Validation: [ 0.63513963  0.67586436  0.66478217  0.64599268  0.64050549]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.5263157894736842
# Specificity : 0.46903929232668173
# Accuracy: 0.47056467761313575
# ROC 0.4976775409
# TP 70 FP 2581 TN 2280 FN 63
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 10, 10, 10, 1, 18, 20, 2, 3, 16, 12, 2, 12, 0.37692307692307686, 25.8, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4644736842105263
# Specificity : 0.8285714285714286
# Accuracy: 0.6445552784704904
# ROC 0.646522556391
# TP 1412 FP 510 TN 2465 FN 1628
#
#
#
# None
# Cross: Validation: [ 0.61552527  0.68733378  0.66195544  0.66361822  0.63036249]
# Number of data points in benchmark 4994
# Benchmark Results
# Sensitivity: 0.46616541353383456
# Specificity : 0.5550298292532401
# Accuracy: 0.552663195835002
# ROC 0.510597621394
# TP 62 FP 2163 TN 2698 FN 71
#
#
#
# None
