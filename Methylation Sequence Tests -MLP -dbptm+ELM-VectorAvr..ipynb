# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_methylation.csv")
    y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/methylation.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_methylation.csv")
    x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/methylation.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 17, 10, 2, 13, 5, 7, 1, 14, 17, 2, 5, 12, 0.8076923076923077, 24.938461538461535, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 21290
# Test Data Points: 5323
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 5229 FN 94
#
#
#
# None
# Cross Validation: [ 0.98083787  0.98083787  0.98083787  0.98065001  0.98101861]
# Number of data points in benchmark 2612
# Benchmark Results
# Failed
# TP 0 FP 0 TN 2480 FN 132
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 7, 7, 2, 7, 7, 7, 2, 10, 10, 10, 19, 10, -1.6, 53.67692307692308, 0.0]
# Finished working with Data
# Training Data Points: 21290
# Test Data Points: 5323
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 5218 FN 105
#
#
#
# None
# Cross Validation: [ 0.98083787  0.98065001  0.98083787  0.98083787  0.98101861]
# Number of data points in benchmark 2612
# Benchmark Results
# Failed
# TP 0 FP 0 TN 2480 FN 132
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 17, 9, 12, 15, 1, 7, 9, 11, 6, 9, 14, 9, -1.5846153846153845, 36.76923076923077, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 41577
# Test Data Points: 10395
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.854863813229572
# Specificity : 0.8709800190294957
# Accuracy: 0.863011063011063
# ROC 0.86292191613
# TP 4394 FP 678 TN 4577 FN 746
#
#
#
# None
# Cross Validation: [ 0.64877345  0.65791246  0.61875902  0.68250914  0.66371596]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.21212121212121213
# Specificity : 0.85
# Accuracy: 0.8177641653905053
# ROC 0.531060606061
# TP 28 FP 372 TN 2108 FN 104
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 10, 15, 9, 12, 5, 7, 18, 19, 1, 11, 9, 13, -1.0769230769230769, 20.053846153846155, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 41577
# Test Data Points: 10395
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9018845929667768
# Specificity : 0.8719512195121951
# Accuracy: 0.8867724867724868
# ROC 0.886917906239
# TP 4642 FP 672 TN 4576 FN 505
#
#
#
# None
# Cross Validation: [ 0.64781145  0.64290524  0.64290524  0.61458534  0.68796305]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.23484848484848486
# Specificity : 0.8657258064516129
# Accuracy: 0.833843797856049
# ROC 0.55028714565
# TP 31 FP 333 TN 2147 FN 101
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 17, 20, 1, 20, 10, 7, 8, 18, 11, 9, 3, 3, -1.4923076923076921, 50.58461538461538, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 41756
# Test Data Points: 10439
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8734008019858698
# Specificity : 0.8754325259515571
# Accuracy: 0.8744132579749018
# ROC 0.874416663969
# TP 4574 FP 648 TN 4554 FN 663
#
#
#
# None
# Cross Validation: [ 0.86733716  0.86722866  0.87853243  0.85429639  0.87143131]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.22727272727272727
# Specificity : 0.8842741935483871
# Accuracy: 0.8510719754977029
# ROC 0.555773460411
# TP 30 FP 287 TN 2193 FN 102
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 3, 2, 17, 16, 9, 7, 10, 17, 8, 9, 3, 2, -1.5153846153846156, 68.4923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 41756
# Test Data Points: 10440
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9260456273764258
# Specificity : 0.8164092664092664
# Accuracy: 0.8716475095785441
# ROC 0.871227446893
# TP 4871 FP 951 TN 4229 FN 389
#
#
#
# None
# Cross Validation: [ 0.87222222  0.86925287  0.84280103  0.86310949  0.89701092]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.25
# Specificity : 0.8262096774193548
# Accuracy: 0.7970903522205207
# ROC 0.53810483871
# TP 33 FP 431 TN 2049 FN 99
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 12, 1, 1, 12, 20, 7, 20, 13, 20, 3, 12, 7, 1.1076923076923078, 3.446153846153846, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 814
# Test Data Points: 204
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.49
# Specificity : 0.41346153846153844
# Accuracy: 0.45098039215686275
# ROC 0.451730769231
# TP 49 FP 61 TN 43 FN 51
#
#
#
# None
# Cross Validation: [ 0.45098039  0.45098039  0.5245098   0.41176471  0.4950495 ]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.4393939393939394
# Specificity : 0.4745967741935484
# Accuracy: 0.4728177641653905
# ROC 0.456995356794
# TP 58 FP 1303 TN 1177 FN 74
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 20, 20, 15, 10, 7, 7, 7, 13, 13, 19, 5, 3, -0.5076923076923076, -3.1000000000000005, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 814
# Test Data Points: 204
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.31
# Specificity : 0.7019230769230769
# Accuracy: 0.5098039215686274
# ROC 0.505961538462
# TP 31 FP 31 TN 73 FN 69
#
#
#
# None
# Cross Validation: [ 0.51470588  0.51960784  0.45588235  0.43627451  0.47029703]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.2878787878787879
# Specificity : 0.7048387096774194
# Accuracy: 0.6837672281776417
# ROC 0.496358748778
# TP 38 FP 732 TN 1748 FN 94
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 19, 8, 7, 1, 10, 7, 5, 10, 5, 7, 19, 3, -1.4076923076923076, 5.953846153846157, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 20570
# Test Data Points: 5143
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 5051 FN 92
#
#
#
# None
# Cross Validation: [ 0.98016722  0.98016722  0.98016722  0.98016722  0.98035402]
# Number of data points in benchmark 2612
# Benchmark Results
# Failed
# TP 0 FP 0 TN 2480 FN 132
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 2, 5, 9, 8, 1, 7, 13, 3, 11, 20, 11, 9, -0.12307692307692301, 53.984615384615395, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 20570
# Test Data Points: 5143
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 5051 FN 92
#
#
#
# None
# Cross Validation: [ 0.98016722  0.98016722  0.98016722  0.98016722  0.9801595 ]
# Number of data points in benchmark 2612
# Benchmark Results
# Failed
# TP 0 FP 0 TN 2480 FN 132
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 10, 12, 13, 8, 7, 2, 12, 17, 16, 5, 3, 0.6923076923076923, 16.06923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 814
# Test Data Points: 204
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.73
# Specificity : 0.4230769230769231
# Accuracy: 0.5735294117647058
# ROC 0.576538461538
# TP 73 FP 60 TN 44 FN 27
#
#
#
# None
# Cross Validation: [ 0.67647059  0.65196078  0.67156863  0.65686275  0.63861386]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.8863636363636364
# Specificity : 0.1596774193548387
# Accuracy: 0.19640122511485453
# ROC 0.523020527859
# TP 117 FP 2084 TN 396 FN 15
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 3, 8, 13, 18, 3, 7, 18, 15, 19, 20, 7, 7, -1.4692307692307693, 34.43076923076923, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 814
# Test Data Points: 204
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.53
# Specificity : 0.7788461538461539
# Accuracy: 0.6568627450980392
# ROC 0.654423076923
# TP 53 FP 23 TN 81 FN 47
#
#
#
# None
# Cross Validation: [ 0.61764706  0.67647059  0.67156863  0.60784314  0.69306931]
# Number of data points in benchmark 2612
# Benchmark Results
# Sensitivity: 0.5984848484848485
# Specificity : 0.4028225806451613
# Accuracy: 0.4127105666156202
# ROC 0.500653714565
# TP 79 FP 1481 TN 999 FN 53
#
#
#
# None
