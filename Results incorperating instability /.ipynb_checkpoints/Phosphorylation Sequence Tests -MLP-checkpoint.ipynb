# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 162268
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.003105590062111801
# Specificity : 0.9996611700926135
# Accuracy: 0.9818635607321131
# ROC 0.501383380077
# TP 1 FP 6 TN 17702 FN 321
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 1 TN 62516 FN 3378
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 342566
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 5 TN 17728 FN 297
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9999520130524497
# Accuracy: 0.948706275134684
# ROC 0.500124023104
# TP 1 FP 3 TN 62514 FN 3377
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 318213
# Test Data Points: 35358
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8530308161192008
# Specificity : 0.8742063492063492
# Accuracy: 0.8635952259743198
# ROC 0.863618582663
# TP 15114 FP 2219 TN 15421 FN 2604
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.14268798105387803
# Specificity : 0.9062654957851465
# Accuracy: 0.8671219364139919
# ROC 0.52447673842
# TP 482 FP 5860 TN 56657 FN 2896
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 498511
# Test Data Points: 35358
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.795483061480552
# Specificity : 0.9506844703770198
# Accuracy: 0.8737202330448555
# ROC 0.873083765929
# TP 13948 FP 879 TN 16945 FN 3586
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.08555358200118414
# Specificity : 0.9566197994145592
# Accuracy: 0.9119660065255331
# ROC 0.521086690708
# TP 289 FP 2712 TN 59805 FN 3089
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 282937
# Test Data Points: 31438
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8646098208735944
# Specificity : 0.7847318244669238
# Accuracy: 0.82969654558178
# ROC 0.82467082267
# TP 15301 FP 2958 TN 10783 FN 2396
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.29425695677915925
# Specificity : 0.7687988867028168
# Accuracy: 0.7444722664845588
# ROC 0.531527921741
# TP 994 FP 14454 TN 48063 FN 2384
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 463222
# Test Data Points: 31436
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8950144631614769
# Specificity : 0.7776892430278884
# Accuracy: 0.8434915383636595
# ROC 0.836351853095
# TP 15780 FP 3069 TN 10736 FN 1851
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.2803433984606276
# Specificity : 0.7630084616984181
# Accuracy: 0.7382654222626907
# ROC 0.52167593008
# TP 947 FP 14816 TN 47701 FN 2431
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5941558441558441
# Specificity : 0.6430769230769231
# Accuracy: 0.6192733017377567
# ROC 0.618616383616
# TP 183 FP 116 TN 209 FN 125
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.5840734162226169
# Specificity : 0.6652910408368924
# Accuracy: 0.6611275514075423
# ROC 0.62468222853
# TP 1973 FP 20925 TN 41592 FN 1405
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5504587155963303
# Specificity : 0.6078431372549019
# Accuracy: 0.5781990521327014
# ROC 0.579150926426
# TP 180 FP 120 TN 186 FN 147
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.5432208407341622
# Specificity : 0.6756082345601996
# Accuracy: 0.6688216101373398
# ROC 0.609414537647
# TP 1835 FP 20280 TN 42237 FN 1543
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 157482
# Test Data Points: 17499
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17179 FN 320
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 337780
# Test Data Points: 17499
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 17187 FN 310
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7027027027027027
# Specificity : 0.87
# Accuracy: 0.7819905213270142
# ROC 0.786351351351
# TP 234 FP 39 TN 261 FN 99
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.7089994079336885
# Specificity : 0.33565270246492956
# Accuracy: 0.3547917140905987
# ROC 0.522326055199
# TP 2395 FP 41533 TN 20984 FN 983
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7907692307692308
# Specificity : 0.7857142857142857
# Accuracy: 0.7883096366508688
# ROC 0.788241758242
# TP 257 FP 66 TN 242 FN 68
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.8433984606275903
# Specificity : 0.19285954220452037
# Accuracy: 0.22620836178769255
# ROC 0.518129001416
# TP 2849 FP 50460 TN 12057 FN 529
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 11334
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1205 FN 55
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 23928
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1204 FN 56
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 2 TN 23512 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21796
# Test Data Points: 2422
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9263157894736842
# Specificity : 0.8213984835720304
# Accuracy: 0.8748967795210569
# ROC 0.873857136523
# TP 1144 FP 212 TN 975 FN 91
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.827421961384707
# Accuracy: 0.8277223519422627
# ROC 0.913710980692
# TP 41 FP 4058 TN 19456 FN 0
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 34390
# Test Data Points: 2422
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.910874897792314
# Specificity : 0.8632193494578816
# Accuracy: 0.8872832369942196
# ROC 0.887047123625
# TP 1114 FP 164 TN 1035 FN 109
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8703750956876755
# Accuracy: 0.8706007217151348
# ROC 0.935187547844
# TP 41 FP 3048 TN 20466 FN 0
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16866
# Test Data Points: 1875
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9585062240663901
# Specificity : 0.8686567164179104
# Accuracy: 0.9264
# ROC 0.913581470242
# TP 1155 FP 88 TN 582 FN 50
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8170451645828017
# Accuracy: 0.8173211632349819
# ROC 0.89632746034
# TP 40 FP 4302 TN 19212 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 29469
# Test Data Points: 1875
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9590301003344481
# Specificity : 0.8910162002945509
# Accuracy: 0.9344
# ROC 0.925023150314
# TP 1147 FP 74 TN 605 FN 49
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8354171982648635
# Accuracy: 0.8356612184249629
# ROC 0.905513477181
# TP 40 FP 3870 TN 19644 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.43636363636363634
# Specificity : 0.7241379310344828
# Accuracy: 0.584070796460177
# ROC 0.580250783699
# TP 24 FP 16 TN 42 FN 31
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.6664965552436846
# Accuracy: 0.6670345998726385
# ROC 0.821053155671
# TP 40 FP 7842 TN 15672 FN 1
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4603174603174603
# Specificity : 0.76
# Accuracy: 0.5929203539823009
# ROC 0.610158730159
# TP 29 FP 12 TN 38 FN 34
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 6716 TN 16798 FN 41
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 10397
# Test Data Points: 1156
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1105 FN 51
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 22991
# Test Data Points: 1156
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.017241379310344827
# Specificity : 0.9899817850637522
# Accuracy: 0.9411764705882353
# ROC 0.503611582187
# TP 1 FP 11 TN 1087 FN 57
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 200 TN 23314 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.52
# Specificity : 0.8253968253968254
# Accuracy: 0.6902654867256637
# ROC 0.672698412698
# TP 26 FP 11 TN 52 FN 24
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 8190 TN 15324 FN 41
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4166666666666667
# Specificity : 0.7924528301886793
# Accuracy: 0.5929203539823009
# ROC 0.604559748428
# TP 25 FP 11 TN 42 FN 35
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.558986135919027
# Accuracy: 0.5597113139460836
# ROC 0.767297946008
# TP 40 FP 10370 TN 13144 FN 1
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58739
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6379 FN 148
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 124005
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 3 TN 6401 FN 123
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 41 TN 46456 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 114857
# Test Data Points: 12762
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8495229156890349
# Specificity : 0.885539331135186
# Accuracy: 0.8674972574831531
# ROC 0.867531123412
# TP 5431 FP 729 TN 5640 FN 962
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.18329278183292783
# Specificity : 0.9088328279243822
# Accuracy: 0.8900900900900901
# ROC 0.546062804879
# TP 226 FP 4239 TN 42258 FN 1007
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 180123
# Test Data Points: 12762
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.872209026128266
# Specificity : 0.888009927097875
# Accuracy: 0.8801911926030402
# ROC 0.880109476613
# TP 5508 FP 722 TN 5725 FN 807
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.21492295214922952
# Specificity : 0.9090909090909091
# Accuracy: 0.891158600460926
# ROC 0.56200693062
# TP 265 FP 4227 TN 42270 FN 968
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 98069
# Test Data Points: 10897
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8466635115948887
# Specificity : 0.8922773146116718
# Accuracy: 0.865742865008718
# ROC 0.869470413103
# TP 5367 FP 491 TN 4067 FN 972
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.12327656123276562
# Specificity : 0.8865518205475622
# Accuracy: 0.8668342761366017
# ROC 0.50491419089
# TP 152 FP 5275 TN 41222 FN 1081
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 163338
# Test Data Points: 10897
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9821679962458939
# Specificity : 0.7606571936056838
# Accuracy: 0.8906120950720382
# ROC 0.871412594926
# TP 6279 FP 1078 TN 3426 FN 114
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.37307380373073806
# Specificity : 0.7456825171516442
# Accuracy: 0.736056987219778
# ROC 0.559378160441
# TP 460 FP 11825 TN 34672 FN 773
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3684210526315789
# Specificity : 0.8
# Accuracy: 0.5827814569536424
# ROC 0.584210526316
# TP 56 FP 30 TN 120 FN 96
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.3957826439578264
# Specificity : 0.7573606899369851
# Accuracy: 0.7480201131363922
# ROC 0.576571666947
# TP 488 FP 11282 TN 35215 FN 745
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5821917808219178
# Specificity : 0.6153846153846154
# Accuracy: 0.5993377483443708
# ROC 0.598788198103
# TP 85 FP 60 TN 96 FN 61
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.5020275750202757
# Specificity : 0.6955932640815536
# Accuracy: 0.6905929184998952
# ROC 0.598810419551
# TP 619 FP 14154 TN 32343 FN 614
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 56178
# Test Data Points: 6243
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6089 FN 154
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 1 TN 46496 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 121444
# Test Data Points: 6243
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6074 FN 169
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6438356164383562
# Specificity : 0.9166666666666666
# Accuracy: 0.7847682119205298
# ROC 0.780251141553
# TP 94 FP 13 TN 143 FN 52
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6123276561232766
# Specificity : 0.28666365571972385
# Accuracy: 0.2950764718206579
# ROC 0.449495655922
# TP 755 FP 33168 TN 13329 FN 478
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7315436241610739
# Specificity : 0.7516339869281046
# Accuracy: 0.7417218543046358
# ROC 0.741588805545
# TP 109 FP 38 TN 115 FN 40
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.8167072181670721
# Specificity : 0.2267458115577349
# Accuracy: 0.24198617221873037
# ROC 0.521726514862
# TP 1007 FP 35954 TN 10543 FN 226
#
#
#
# None
