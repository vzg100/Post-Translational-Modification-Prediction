# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 10, 3, 10, 10, 19, 10, 9, 10, 19, 10, 19, 10, -1.3384615384615386, 112.93846153846157, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0056107034958998705
# Specificity : 0.9990691521936164
# Accuracy: 0.8152562336547483
# ROC 0.502339927845
# TP 52 FP 38 TN 40785 FN 9216
#
#
#
# None
# Cross: Validation: [ 0.81583886  0.81687329  0.81337965  0.81601118  0.81597125]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0008880994671403197
# Specificity : 0.9991842218916455
# Accuracy: 0.9480081948554518
# ROC 0.500036160679
# TP 3 FP 51 TN 62466 FN 3375
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 11, 20, 7, 9, 5, 10, 6, 3, 17, 16, 10, 13, -0.48461538461538467, 63.16923076923078, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0015334063526834612
# Specificity : 0.9991455286736164
# Accuracy: 0.8173124912658961
# ROC 0.500339467513
# TP 14 FP 35 TN 40926 FN 9116
#
#
#
# None
# Cross: Validation: [ 0.8073345   0.81607474  0.81318001  0.81649032  0.81517269]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 10 TN 62507 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 10, 19, 11, 4, 10, 10, 20, 15, 13, 9, 0, 0, -0.21818181818181814, 99.63636363636363, 0.09090909090909091]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331728
# Test Data Points: 82933
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6547336435286297
# Specificity : 0.8981842240682203
# Accuracy: 0.7745288365306935
# ROC 0.776458933798
# TP 27580 FP 4155 TN 36654 FN 14544
#
#
#
# None
# Cross: Validation: [ 0.51383647  0.81633145  0.83704722  0.84528288  0.84100227]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.22498519834221434
# Specificity : 0.9116720252091431
# Accuracy: 0.8764701418924046
# ROC 0.568328611776
# TP 760 FP 5522 TN 56995 FN 2618
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 19, 1, 19, 10, 14, 10, 13, 10, 11, 8, 19, 12, -0.9000000000000002, 112.55384615384615, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331732
# Test Data Points: 82933
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6696553523565549
# Specificity : 0.9105557463089223
# Accuracy: 0.788094003593262
# ROC 0.790105549333
# TP 28232 FP 3647 TN 37127 FN 13927
#
#
#
# None
# Cross: Validation: [ 0.5069694   0.81056998  0.83708536  0.85101226  0.8223002 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.21906453522794553
# Specificity : 0.9253323096117856
# Accuracy: 0.8891266408680476
# ROC 0.57219842242
# TP 740 FP 4668 TN 57849 FN 2638
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 7, 5, 3, 11, 18, 10, 8, 9, 3, 1, 18, 20, -0.7076923076923076, 40.61538461538461, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 232034
# Test Data Points: 58009
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9558282208588957
# Specificity : 0.45118488904339765
# Accuracy: 0.8056853246909962
# ROC 0.703506554951
# TP 38950 FP 9472 TN 7787 FN 1800
#
#
#
# None
# Cross: Validation: [ 0.72949491  0.80727129  0.81623224  0.80490622  0.81350848]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.9342806394316163
# Specificity : 0.25239534846521744
# Accuracy: 0.28735108885347904
# ROC 0.593337993948
# TP 3156 FP 46738 TN 15779 FN 222
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 2, 2, 7, 3, 17, 10, 3, 19, 5, 2, 9, 17, -0.40769230769230774, 38.98461538461539, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305684
# Test Data Points: 76421
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7867265329030447
# Specificity : 0.6427695777963026
# Accuracy: 0.7098964944190733
# ROC 0.71474805535
# TP 28035 FP 14570 TN 26216 FN 7600
#
#
#
# None
# Cross: Validation: [ 0.62902044  0.70850944  0.72607006  0.72712998  0.71080869]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.5174659561870929
# Specificity : 0.6046995217300895
# Accuracy: 0.6002276348736626
# ROC 0.561082738959
# TP 1748 FP 24713 TN 37804 FN 1630
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 2, 1, 20, 10, 13, 10, 10, 3, 2, 2, 10, 18, 0.39999999999999997, 17.51538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.80530594779632
# Specificity : 0.48572056239015815
# Accuracy: 0.6476262735746803
# ROC 0.645513255093
# TP 7528 FP 4682 TN 4422 FN 1820
#
#
#
# None
# Cross: Validation: [ 0.60687188  0.5914806   0.60031433  0.65306233  0.63669377]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.8075784487862641
# Specificity : 0.4284594590271446
# Accuracy: 0.44789437741862054
# ROC 0.618018953907
# TP 2728 FP 35731 TN 26786 FN 650
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 13, 10, 10, 10, 11, 10, 9, 1, 20, 11, 20, 12, -0.29230769230769227, 95.76153846153848, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6929824561403509
# Specificity : 0.5932557117750439
# Accuracy: 0.6437784522003035
# ROC 0.643119083958
# TP 6478 FP 3703 TN 5401 FN 2870
#
#
#
# None
# Cross: Validation: [ 0.60969001  0.64177325  0.5883915   0.63121951  0.64287263]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.6551213735938425
# Specificity : 0.5776828702592894
# Accuracy: 0.5816526291827908
# ROC 0.616402121927
# TP 2213 FP 26402 TN 36115 FN 1165
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 10, 12, 9, 10, 10, 10, 9, 13, 17, 10, 1, 11, -0.7076923076923077, 117.10769230769232, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143810
# Test Data Points: 35953
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3436616655794738
# Specificity : 0.8927677069706597
# Accuracy: 0.7522877089533557
# ROC 0.618214686275
# TP 3161 FP 2869 TN 23886 FN 6037
#
#
#
# None
# Cross: Validation: [ 0.7619392   0.76522126  0.76636164  0.76613262  0.75976302]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.2676139727649497
# Specificity : 0.8698593982436778
# Accuracy: 0.838986266029289
# ROC 0.568736685504
# TP 904 FP 8136 TN 54381 FN 2474
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 9, 10, 7, 19, 8, 1, 2, 7, 18, 3, 18, 0, -1.5833333333333333, 18.14166666666667, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143720
# Test Data Points: 35930
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.33539630836047774
# Specificity : 0.8988398203592814
# Accuracy: 0.7544113554133036
# ROC 0.61711806436
# TP 3089 FP 2703 TN 24017 FN 6121
#
#
#
# None
# Cross: Validation: [ 0.76549498  0.76081935  0.76159198  0.75496117  0.75738262]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.26613380698638245
# Specificity : 0.8642289297311131
# Accuracy: 0.833568556036118
# ROC 0.565181368359
# TP 899 FP 8488 TN 54029 FN 2479
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 3, 11, 20, 20, 10, 10, 10, 5, 19, 16, 16, 11, -0.46923076923076923, 60.953846153846165, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6271929824561403
# Specificity : 0.7059534270650264
# Accuracy: 0.6660524604378929
# ROC 0.666573204761
# TP 5863 FP 2677 TN 6427 FN 3485
#
#
#
# None
# Cross: Validation: [ 0.62930848  0.69385432  0.68848905  0.6703523   0.63934959]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.633214920071048
# Specificity : 0.39462866100420685
# Accuracy: 0.4068593975263677
# ROC 0.513921790538
# TP 2139 FP 37846 TN 24671 FN 1239
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 6, 18, 10, 3, 7, 10, 2, 13, 9, 18, 2, 1, -0.6846153846153846, 45.9923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8406076166024818
# Specificity : 0.468695079086116
# Accuracy: 0.6571103403425103
# ROC 0.654651347844
# TP 7858 FP 4837 TN 4267 FN 1490
#
#
#
# None
# Cross: Validation: [ 0.62188381  0.70209191  0.63136787  0.66850949  0.65696477]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.8336293664890467
# Specificity : 0.23344050418286227
# Accuracy: 0.2642082100311101
# ROC 0.533534935336
# TP 2816 FP 47923 TN 14594 FN 562
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 3, 12, 12, 7, 12, 15, 5, 7, 19, 20, 16, 11, -0.18461538461538468, -30.653846153846157, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 2418 FN 106
#
#
#
# None
# Cross: Validation: [ 0.95288994  0.95326733  0.95326733  0.95324881  0.95245642]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 1.0
# Accuracy: 0.9999575461685417
# ROC 0.987804878049
# TP 40 FP 0 TN 23514 FN 1
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 5, 2, 3, 12, 5, 15, 16, 17, 1, 15, 7, 3, 0.08461538461538445, 24.20846153846154, 0.3076923076923077]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 2406 FN 119
#
#
#
# None
# Cross: Validation: [ 0.95249406  0.95287129  0.95326733  0.95324881  0.95285261]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 11, 1, 1, 4, 1, 15, 20, 12, 10, 1, 12, 16, 0.27692307692307694, 20.476923076923075, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19355
# Test Data Points: 4839
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8596491228070176
# Specificity : 0.758282208588957
# Accuracy: 0.8084314941103534
# ROC 0.808965665698
# TP 2058 FP 591 TN 1854 FN 336
#
#
#
# None
# Cross: Validation: [ 0.63119835  0.62926224  0.67224633  0.64778834  0.67755271]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.7813217657565705
# Accuracy: 0.7817023986414774
# ROC 0.890660882878
# TP 41 FP 5142 TN 18372 FN 0
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 5, 13, 19, 1, 19, 15, 11, 9, 10, 4, 7, 18, -0.6384615384615385, 46.907692307692315, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19363
# Test Data Points: 4841
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7834235735110371
# Specificity : 0.8143442622950819
# Accuracy: 0.7990084693245197
# ROC 0.798883917903
# TP 1881 FP 453 TN 1987 FN 520
#
#
#
# None
# Cross: Validation: [ 0.68194961  0.66783722  0.64635406  0.6642562   0.69855372]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8366079782257378
# Accuracy: 0.8368923795372533
# ROC 0.918303989113
# TP 41 FP 3842 TN 19672 FN 0
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 20, 9, 13, 7, 8, 15, 10, 7, 16, 3, 13, 3, -0.5923076923076923, 59.53076923076924, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19239
# Test Data Points: 4810
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9219532554257095
# Specificity : 0.7046396023198012
# Accuracy: 0.8128898128898129
# ROC 0.813296428873
# TP 2209 FP 713 TN 1701 FN 187
#
#
#
# None
# Cross: Validation: [ 0.82228227  0.82557173  0.77941788  0.8113953   0.83946766]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.7296929488815174
# Accuracy: 0.7301634472511144
# ROC 0.864846474441
# TP 41 FP 6356 TN 17158 FN 0
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 18, 17, 18, 3, 3, 15, 9, 15, 2, 17, 9, 1, -1.6230769230769229, 40.63076923076923, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19238
# Test Data Points: 4810
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9052808046940486
# Specificity : 0.7623762376237624
# Accuracy: 0.8332640332640333
# ROC 0.833828521159
# TP 2160 FP 576 TN 1848 FN 226
#
#
#
# None
# Cross: Validation: [ 0.797921    0.81517672  0.7970894   0.8224163   0.83073404]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.7940801224802245
# Accuracy: 0.7944385480789641
# ROC 0.89704006124
# TP 41 FP 4842 TN 18672 FN 0
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 12, 9, 13, 10, 15, 15, 19, 8, 7, 12, 13, 1, -0.3307692307692307, 39.42307692307693, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3220338983050847
# Specificity : 0.6722689075630253
# Accuracy: 0.4978902953586498
# ROC 0.497151402934
# TP 38 FP 39 TN 80 FN 80
#
#
#
# None
# Cross: Validation: [ 0.55462185  0.52966102  0.52542373  0.57627119  0.44915254]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.7230586033852173
# Accuracy: 0.7218424962852897
# ROC 0.373724423644
# TP 1 FP 6512 TN 17002 FN 40
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 10, 8, 4, 3, 16, 15, 19, 11, 18, 7, 17, 13, -0.9076923076923078, 119.35384615384616, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2627118644067797
# Specificity : 0.7394957983193278
# Accuracy: 0.5021097046413502
# ROC 0.501103831363
# TP 31 FP 31 TN 88 FN 87
#
#
#
# None
# Cross: Validation: [ 0.57142857  0.52542373  0.50423729  0.57627119  0.54661017]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.7268010546908225
# Accuracy: 0.7272765867119507
# ROC 0.863400527345
# TP 41 FP 6424 TN 17090 FN 0
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 12, 2, 1, 8, 5, 15, 18, 18, 13, 17, 13, 1, -0.2923076923076923, 62.30846153846154, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9230
# Test Data Points: 2308
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 2193 FN 115
#
#
#
# None
# Cross: Validation: [ 0.94759636  0.94887348  0.94841786  0.94885132  0.94885132]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 7, 10, 5, 15, 17, 15, 12, 3, 9, 11, 9, 13, -0.10000000000000006, 51.970000000000006, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9231
# Test Data Points: 2308
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 2192 FN 115
#
#
#
# None
# Cross: Validation: [ 0.94846254  0.94844021  0.94887348  0.94885132  0.9479844 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 2, 3, 9, 18, 10, 15, 8, 12, 4, 1, 7, 7, -0.7615384615384616, -3.1000000000000005, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.559322033898305
# Specificity : 0.7478991596638656
# Accuracy: 0.6540084388185654
# ROC 0.653610596781
# TP 66 FP 30 TN 89 FN 52
#
#
#
# None
# Cross: Validation: [ 0.59663866  0.65254237  0.68220339  0.59322034  0.62711864]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.428170451645828
# Accuracy: 0.4291233283803863
# ROC 0.701890103872
# TP 40 FP 13446 TN 10068 FN 1
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 10, 13, 15, 3, 9, 15, 3, 8, 2, 13, 1, 3, 1.0923076923076922, 34.307692307692314, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.576271186440678
# Specificity : 0.7394957983193278
# Accuracy: 0.6582278481012658
# ROC 0.65788349238
# TP 68 FP 31 TN 88 FN 50
#
#
#
# None
# Cross: Validation: [ 0.65546218  0.66101695  0.56355932  0.58474576  0.68220339]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.36982223356298377
# Accuracy: 0.370919125451072
# ROC 0.684911116781
# TP 41 FP 14818 TN 8696 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 9, 2, 1, 18, 12, 20, 17, 11, 11, 20, 19, 3, -0.6461538461538461, 25.800000000000008, 0.0]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.026203734032099576
# Specificity : 0.9917208752217622
# Accuracy: 0.8139436704661962
# ROC 0.508962304627
# TP 80 FP 112 TN 13416 FN 2973
#
#
#
# None
# Cross: Validation: [ 0.81835725  0.81841756  0.81887817  0.81761158  0.81809409]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0024330900243309003
# Specificity : 0.9964728907241327
# Accuracy: 0.9707940498638173
# ROC 0.499452990374
# TP 3 FP 164 TN 46333 FN 1230
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 17, 9, 1, 17, 2, 20, 19, 19, 19, 4, 8, 10, -1.6076923076923078, 52.04615384615385, 0.0]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0006459948320413437
# Specificity : 0.9989618094178717
# Accuracy: 0.8125565406187806
# ROC 0.499803902125
# TP 2 FP 14 TN 13471 FN 3094
#
#
#
# None
# Cross: Validation: [ 0.81853817  0.81733205  0.81821472  0.81869723  0.80162847]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 2 TN 46495 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 8, 2, 12, 9, 18, 20, 7, 5, 1, 7, 9, 17, -1.2923076923076922, -3.8307692307692314, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109781
# Test Data Points: 27446
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6632359291780625
# Specificity : 0.8336038961038961
# Accuracy: 0.7473584493186621
# ROC 0.748419912641
# TP 9215 FP 2255 TN 11297 FN 4679
#
#
#
# None
# Cross: Validation: [ 0.50564745  0.77592363  0.79675715  0.7847331   0.79034433]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.32765612327656124
# Specificity : 0.8632384885046347
# Accuracy: 0.8494028912633563
# ROC 0.595447305891
# TP 404 FP 6359 TN 40138 FN 829
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 16, 8, 12, 13, 16, 20, 1, 9, 7, 0, 0, 0, -1.04, -9.77, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109764
# Test Data Points: 27442
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6296668581275129
# Specificity : 0.8776824034334764
# Accuracy: 0.7518038043874353
# ROC 0.75367463078
# TP 8770 FP 1653 TN 11861 FN 5158
#
#
#
# None
# Cross: Validation: [ 0.51413891  0.76955032  0.78656026  0.80627528  0.78279883]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.25385239253852393
# Specificity : 0.9018861431920339
# Accuracy: 0.885145610727006
# ROC 0.577869267865
# TP 313 FP 4562 TN 41935 FN 920
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 10, 13, 2, 2, 8, 20, 11, 11, 11, 19, 12, 17, -0.6923076923076923, 33.06153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102896
# Test Data Points: 25724
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.49690301548492255
# Specificity : 0.8131410732867549
# Accuracy: 0.662299797854144
# ROC 0.655022044386
# TP 6097 FP 2514 TN 10940 FN 6173
#
#
#
# None
# Cross: Validation: [ 0.62309038  0.69216715  0.68092054  0.69525328  0.69486452]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.19383617193836172
# Specificity : 0.8186334602232402
# Accuracy: 0.8024931908652839
# ROC 0.506234816081
# TP 239 FP 8433 TN 38064 FN 994
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 19, 11, 9, 2, 11, 20, 11, 3, 2, 3, 2, 9, -0.26153846153846155, 37.41538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102895
# Test Data Points: 25724
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6053899550837076
# Specificity : 0.7400400623191632
# Accuracy: 0.6759446431348157
# ROC 0.672715008701
# TP 7413 FP 3504 TN 9975 FN 4832
#
#
#
# None
# Cross: Validation: [ 0.60719145  0.68890185  0.69132683  0.69987949  0.69047156]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.2635847526358475
# Specificity : 0.7391014474052089
# Accuracy: 0.7268175151896082
# ROC 0.501343100021
# TP 325 FP 12131 TN 34366 FN 908
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 2, 17, 13, 19, 12, 20, 11, 12, 1, 10, 7, 3, -0.06153846153846153, 4.453846153846156, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7032894736842106
# Specificity : 0.508235294117647
# Accuracy: 0.6068162926018288
# ROC 0.605762383901
# TP 2138 FP 1463 TN 1512 FN 902
#
#
#
# None
# Cross: Validation: [ 0.55019947  0.61053856  0.60126372  0.58995677  0.59743931]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.7453365774533658
# Specificity : 0.5084414048218164
# Accuracy: 0.5145610727006076
# ROC 0.626888991138
# TP 919 FP 22856 TN 23641 FN 314
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 5, 17, 7, 18, 8, 20, 9, 9, 15, 17, 2, 3, -1.9230769230769231, 30.315384615384627, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5723684210526315
# Specificity : 0.6228571428571429
# Accuracy: 0.5973399833748961
# ROC 0.597612781955
# TP 1740 FP 1122 TN 1853 FN 1300
#
#
#
# None
# Cross: Validation: [ 0.5490359   0.60388963  0.59577652  0.5959428   0.58762887]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6366585563665855
# Specificity : 0.6362776093081274
# Accuracy: 0.6362874502409386
# ROC 0.636468082837
# TP 785 FP 16912 TN 29585 FN 448
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 4, 20, 12, 12, 10, 20, 11, 11, 12, 12, 9, 12, 0.7307692307692307, 36.64615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47272
# Test Data Points: 11818
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1152669160149609
# Specificity : 0.966768052269911
# Accuracy: 0.7548654594686072
# ROC 0.541017484142
# TP 339 FP 295 TN 8582 FN 2602
#
#
#
# None
# Cross: Validation: [ 0.75023268  0.75514003  0.75215773  0.75137514  0.75357536]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.07785888077858881
# Specificity : 0.95831989160591
# Accuracy: 0.9355751099937146
# ROC 0.518089386192
# TP 96 FP 1938 TN 44559 FN 1137
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 3, 3, 20, 10, 14, 20, 9, 9, 18, 1, 4, 19, -0.007692307692307528, 102.53076923076925, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47240
# Test Data Points: 11810
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08969986357435197
# Specificity : 0.979049335435909
# Accuracy: 0.7582557154953429
# ROC 0.534374599505
# TP 263 FP 186 TN 8692 FN 2669
#
#
#
# None
# Cross: Validation: [ 0.7523495   0.75370417  0.74674005  0.74883563  0.75332374]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.043795620437956206
# Specificity : 0.9731165451534508
# Accuracy: 0.94910957469097
# ROC 0.508456082796
# TP 54 FP 1250 TN 45247 FN 1179
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 12, 3, 1, 14, 5, 20, 14, 15, 2, 10, 15, 2, 1.0923076923076922, 45.66153846153846, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7115131578947368
# Specificity : 0.6110924369747899
# Accuracy: 0.6618453865336659
# ROC 0.661302797435
# TP 2163 FP 1157 TN 1818 FN 877
#
#
#
# None
# Cross: Validation: [ 0.62084441  0.62117686  0.66943798  0.65547057  0.63202527]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6788321167883211
# Specificity : 0.34600081725702736
# Accuracy: 0.354598784831343
# ROC 0.512416467023
# TP 837 FP 30409 TN 16088 FN 396
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 1, 7, 16, 1, 16, 20, 12, 16, 17, 9, 11, 2, -1.1384615384615384, 18.55384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5970394736842105
# Specificity : 0.7226890756302521
# Accuracy: 0.6591853699085619
# ROC 0.659864274657
# TP 1815 FP 825 TN 2150 FN 1225
#
#
#
# None
# Cross: Validation: [ 0.61286569  0.68367686  0.66411706  0.64965081  0.63402062]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6358475263584753
# Specificity : 0.44843753360431854
# Accuracy: 0.45327886025560443
# ROC 0.542142529981
# TP 784 FP 25646 TN 20851 FN 449
#
#
#
# None
