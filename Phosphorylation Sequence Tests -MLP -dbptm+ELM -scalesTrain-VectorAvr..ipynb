# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]


for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos.csv", "S")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos.csv", "S")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 18, 3, 8, 9, 10, 10, 8, 6, 9, 3, 2, 3, -0.792307692307692, 93.56923076923078, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.023268282221745658
# Specificity : 0.9939408806574267
# Accuracy: 0.8132199397097283
# ROC 0.50860458144
# TP 217 FP 247 TN 40518 FN 9109
#
#
#
# None
# Cross: Validation: [ 0.81599856  0.81673354  0.81581522  0.81597125  0.81637053]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.015393724097098875
# Specificity : 0.997232752691268
# Accuracy: 0.946900371803627
# ROC 0.506313238394
# TP 52 FP 173 TN 62344 FN 3326
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 2, 20, 1, 20, 7, 10, 3, 4, 19, 9, 12, 12, 0.4, -3.8307692307692314, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.015348288075560802
# Specificity : 0.9972531515181243
# Accuracy: 0.8146173963386636
# ROC 0.506300719797
# TP 143 FP 112 TN 40662 FN 9174
#
#
#
# None
# Cross: Validation: [ 0.81535974  0.81331976  0.81553572  0.81579158  0.8171691 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.002368265245707519
# Specificity : 0.9976326439208535
# Accuracy: 0.9466120342969876
# ROC 0.500000454583
# TP 8 FP 148 TN 62369 FN 3370
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 17, 17, 13, 11, 12, 10, 11, 9, 8, 20, 17, 10, -1.3846153846153844, 161.67692307692306, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05543071161048689
# Specificity : 0.9906003043243509
# Accuracy: 0.8161346349643649
# ROC 0.523015507967
# TP 518 FP 383 TN 40363 FN 8827
#
#
#
# None
# Cross: Validation: [ 0.815759    0.81565551  0.81585514  0.81559193  0.81686963]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.004440497335701598
# Specificity : 0.9910264408081002
# Accuracy: 0.9404507170498521
# ROC 0.497733469072
# TP 15 FP 561 TN 61956 FN 3363
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 10, 1, 5, 20, 19, 10, 10, 5, 3, 20, 3, 3, 0.5923076923076922, 53.67692307692308, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.055639259578131726
# Specificity : 0.9897301404446187
# Accuracy: 0.8164540536224072
# ROC 0.522684700011
# TP 517 FP 419 TN 40380 FN 8775
#
#
#
# None
# Cross: Validation: [ 0.81611834  0.81577529  0.81579525  0.81653025  0.81549211]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.03315571343990527
# Specificity : 0.9865316633875586
# Accuracy: 0.9376583959329235
# ROC 0.509843688414
# TP 112 FP 842 TN 61675 FN 3266
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 20, 12, 5, 12, 5, 10, 8, 19, 5, 20, 12, 5, 0.7769230769230769, 33.06153846153847, 0.3076923076923077]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05818142124222246
# Specificity : 0.9893232347911067
# Accuracy: 0.8190293665528737
# ROC 0.523752328017
# TP 533 FP 437 TN 40493 FN 8628
#
#
#
# None
# Cross: Validation: [ 0.81599856  0.81581522  0.81433791  0.81571172  0.81445398]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.06719952634695085
# Specificity : 0.9646976022521874
# Accuracy: 0.9186888231277032
# ROC 0.5159485643
# TP 227 FP 2207 TN 60310 FN 3151
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 17, 5, 5, 2, 10, 10, 6, 19, 5, 11, 1, 3, 0.08461538461538452, 33.06153846153847, 0.3076923076923077]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0827970827970828
# Specificity : 0.9836141977579905
# Accuracy: 0.8159349983030884
# ROC 0.533205640278
# TP 772 FP 668 TN 40099 FN 8552
#
#
#
# None
# Cross: Validation: [ 0.81557933  0.81603482  0.81581522  0.81577161  0.81581154]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.06512729425695678
# Specificity : 0.9752227394148791
# Accuracy: 0.928568176644662
# ROC 0.520175016836
# TP 220 FP 1549 TN 60968 FN 3158
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 9, 7, 2, 10, 3, 10, 11, 11, 10, 11, 11, 7, -1.4615384615384615, 121.27692307692308, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.03977396218213432
# Specificity : 0.9930788231553719
# Accuracy: 0.8179513285819808
# ROC 0.516426392669
# TP 366 FP 283 TN 40606 FN 8836
#
#
#
# None
# Cross: Validation: [ 0.81561926  0.81699307  0.81589507  0.81495308  0.81571172]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 6, 20, 2, 1, 18, 10, 18, 20, 17, 5, 1, 13, -0.3461538461538463, -21.923076923076923, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.03034201779779136
# Specificity : 0.994357766656854
# Accuracy: 0.8148569603321955
# ROC 0.512349892227
# TP 283 FP 230 TN 40534 FN 9044
#
#
#
# None
# Cross: Validation: [ 0.8163579   0.80872811  0.81563554  0.81495308  0.8156119 ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 44 TN 62473 FN 3378
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 8, 20, 4, 12, 20, 10, 19, 17, 10, 8, 12, 7, -0.9923076923076923, 37.5, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.019714038128249567
# Specificity : 0.9966470055556915
# Accuracy: 0.8165937992853007
# ROC 0.508180521842
# TP 182 FP 137 TN 40722 FN 9050
#
#
#
# None
# Cross: Validation: [ 0.81633794  0.81577529  0.81545587  0.81537233  0.81577161]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0005920663114268798
# Specificity : 1.0
# Accuracy: 0.9487669777676607
# ROC 0.500296033156
# TP 2 FP 0 TN 62517 FN 3376
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 11, 1, 10, 3, 1, 10, 10, 2, 10, 5, 16, 10, 0.25384615384615383, 21.830769230769235, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.02952391328031376
# Specificity : 0.9946714900273759
# Accuracy: 0.8178115829190873
# ROC 0.512097701654
# TP 271 FP 218 TN 40694 FN 8908
#
#
#
# None
# Cross: Validation: [ 0.81376268  0.81587511  0.8139586   0.81607107  0.81477341]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 1.0
# Accuracy: 0.9487518021094165
# ROC 0.500148016578
# TP 1 FP 0 TN 62517 FN 3377
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 12, 8, 7, 7, 10, 10, 3, 17, 8, 4, 7, 10, -1.553846153846154, 53.67692307692308, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331698
# Test Data Points: 82925
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6879927589738704
# Specificity : 0.8803917737286894
# Accuracy: 0.7829846246608381
# ROC 0.784192266351
# TP 28884 FP 4897 TN 36045 FN 13099
#
#
#
# None
# Cross: Validation: [ 0.50970745  0.8145312   0.84228933  0.85239496  0.83915392]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.275902901124926
# Specificity : 0.88767855143401
# Accuracy: 0.8563168677441384
# ROC 0.581790726279
# TP 932 FP 7022 TN 55495 FN 2446
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 13, 11, 13, 13, 20, 10, 2, 7, 20, 3, 9, 3, 0.5538461538461539, 7.015384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331739
# Test Data Points: 82935
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7021534800713861
# Specificity : 0.8664874113908579
# Accuracy: 0.783215771387231
# ROC 0.784320445731
# TP 29508 FP 5462 TN 35448 FN 12517
#
#
#
# None
# Cross: Validation: [ 0.52497106  0.80367758  0.84126123  0.8152748   0.84018617]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.30876258140911783
# Specificity : 0.8878225122766608
# Accuracy: 0.8581379467334396
# ROC 0.598292546843
# TP 1043 FP 7013 TN 55504 FN 2335
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 20, 11, 5, 19, 3, 10, 11, 17, 9, 8, 19, 2, -0.8461538461538461, 91.16923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331655
# Test Data Points: 82914
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7029519857735625
# Specificity : 0.9228994329757726
# Accuracy: 0.8110210579636732
# ROC 0.812925709375
# TP 29647 FP 3141 TN 37598 FN 12528
#
#
#
# None
# Cross: Validation: [ 0.51608274  0.82244253  0.82694117  0.84446347  0.81771254]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8431024274718768
# Specificity : 0.2719100404689924
# Accuracy: 0.30119128917216786
# ROC 0.55750623397
# TP 2848 FP 45518 TN 16999 FN 530
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 19, 9, 10, 19, 12, 10, 9, 7, 20, 2, 8, 10, -1.6923076923076923, 72.66153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331741
# Test Data Points: 82936
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7669925954053541
# Specificity : 0.8156862745098039
# Accuracy: 0.7909472364232661
# ROC 0.791339434958
# TP 32318 FP 7520 TN 33280 FN 9818
#
#
#
# None
# Cross: Validation: [ 0.50720426  0.81786942  0.83018026  0.84136975  0.83710134]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8599763173475429
# Specificity : 0.25861765599756864
# Accuracy: 0.28944532969117537
# ROC 0.559296986673
# TP 2905 FP 46349 TN 16168 FN 473
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 20, 7, 2, 19, 9, 4, 2, 7, 10, 3, 2, 7, -0.7615384615384617, 12.192307692307693, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331687
# Test Data Points: 82922
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7404610964693592
# Specificity : 0.8762651635828943
# Accuracy: 0.8072887774052724
# ROC 0.808363130026
# TP 31186 FP 5049 TN 35756 FN 10931
#
#
#
# None
# Cross: Validation: [ 0.52061551  0.81568221  0.81458479  0.8247971   0.82792055]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.7661338069863824
# Specificity : 0.33210166834620986
# Accuracy: 0.35435162000151754
# ROC 0.549117737666
# TP 2588 FP 41755 TN 20762 FN 790
#
#
#
# None
# x ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 3, 9, 2, 12, 20, 10, 3, 2, 12, 19, 11, 18, 0.2153846153846153, -8.861538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331732
# Test Data Points: 82934
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7265182860132211
# Specificity : 0.8911937377690803
# Accuracy: 0.8076904526490944
# ROC 0.808856011891
# TP 30553 FP 4448 TN 36432 FN 11501
#
#
#
# None
# Cross: Validation: [ 0.52928835  0.80919537  0.84389809  0.84214969  0.83415528]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8049141503848432
# Specificity : 0.3233200569445111
# Accuracy: 0.34800819485545187
# ROC 0.564117103665
# TP 2719 FP 42304 TN 20213 FN 659
#
#
#
# None
# y ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 11, 20, 20, 11, 1, 10, 20, 2, 13, 20, 11, 1, -0.276923076923077, 9.230769230769232, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331724
# Test Data Points: 82931
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7928702402781416
# Specificity : 0.3865357369680981
# Accuracy: 0.5922875643607336
# ROC 0.589702988623
# TP 33295 FP 25114 TN 15824 FN 8698
#
#
#
# None
# Cross: Validation: [ 0.52095693  0.80693589  0.82911095  0.82897831  0.83682624]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 3378 FP 62517 TN 0 FN 0
#
#
#
# None
# x ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 9, 3, 9, 7, 3, 10, 3, 10, 9, 1, 1, 3, 0.01538461538461533, 27.00769230769231, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331736
# Test Data Points: 82935
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.850608596424496
# Specificity : 0.3756697903158719
# Accuracy: 0.6165551335383131
# ROC 0.61313919337
# TP 35780 FP 25517 TN 15354 FN 6284
#
#
#
# None
# Cross: Validation: [ 0.52272261  0.81549184  0.83731642  0.83268623  0.83482046]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 3378 FP 62517 TN 0 FN 0
#
#
#
# None
# y ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 10, 19, 7, 13, 1, 10, 20, 13, 19, 19, 20, 13, -0.03846153846153853, -15.392307692307691, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331731
# Test Data Points: 82933
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8096869350080883
# Specificity : 0.6494363889771866
# Accuracy: 0.7306621007319162
# ROC 0.729561661993
# TP 34036 FP 14337 TN 26560 FN 8000
#
#
#
# None
# Cross: Validation: [ 0.51246775  0.80906274  0.84113682  0.82632759  0.83349009]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8472468916518651
# Specificity : 0.15402210598717148
# Accuracy: 0.18955914712800667
# ROC 0.50063449882
# TP 2862 FP 52888 TN 9629 FN 516
#
#
#
# None
# x ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 10, 1, 1, 14, 1, 10, 20, 13, 1, 11, 3, 11, 0.2538461538461539, 33.53846153846154, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331716
# Test Data Points: 82929
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7385133053719106
# Specificity : 0.8097623256727559
# Accuracy: 0.7735050464855479
# ROC 0.774137815522
# TP 31166 FP 7748 TN 32980 FN 11035
#
#
#
# None
# Cross: Validation: [ 0.52281442  0.80970469  0.84637461  0.82563398  0.82477571]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9345766725873298
# Specificity : 0.1558296143448982
# Accuracy: 0.19575081569163064
# ROC 0.545203143466
# TP 3157 FP 52775 TN 9742 FN 221
#
#
#
# None
# y SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 11, 11, 11, 10, 17, 10, 1, 10, 1, 10, 1, 1, -1.3538461538461537, 126.60000000000002, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305900
# Test Data Points: 76475
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7029214867930871
# Specificity : 0.7139108255260705
# Accuracy: 0.7087806472703498
# ROC 0.70841615616
# TP 25095 FP 11665 TN 29109 FN 10606
#
#
#
# None
# Cross: Validation: [ 0.62216905  0.71598562  0.71891468  0.70828375  0.72177472]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.4487862640615749
# Specificity : 0.6808228161939952
# Accuracy: 0.668927839745049
# ROC 0.564804540128
# TP 1516 FP 19954 TN 42563 FN 1862
#
#
#
# None
# x SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 9, 11, 11, 10, 10, 10, 10, 8, 19, 9, 9, 3, -1.8153846153846156, 152.83076923076925, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305688
# Test Data Points: 76423
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7645224719101124
# Specificity : 0.6511525365602724
# Accuracy: 0.7039634664956884
# ROC 0.707837504235
# TP 27217 FP 14241 TN 26582 FN 8383
#
#
#
# None
# Cross: Validation: [ 0.62936551  0.7139698   0.71014891  0.72899165  0.72710738]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.450858496151569
# Specificity : 0.6164403282307213
# Accuracy: 0.6079520449199484
# ROC 0.533649412191
# TP 1523 FP 23979 TN 38538 FN 1855
#
#
#
# None
# y SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 11, 8, 13, 3, 2, 10, 13, 9, 3, 3, 2, 17, 0.9923076923076924, 87.47692307692309, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305677
# Test Data Points: 76420
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6685178952092449
# Specificity : 0.8681318681318682
# Accuracy: 0.7750065427898456
# ROC 0.768324881671
# TP 23834 FP 5376 TN 35392 FN 11818
#
#
#
# None
# Cross: Validation: [ 0.62457963  0.72373363  0.70506026  0.73166359  0.72662558]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.47217288336293667
# Specificity : 0.5238095238095238
# Accuracy: 0.5211624554215039
# ROC 0.497991203586
# TP 1595 FP 29770 TN 32747 FN 1783
#
#
#
# None
# x SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 11, 9, 18, 8, 10, 10, 7, 2, 11, 9, 11, 3, -1.1461538461538463, 123.23076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305895
# Test Data Points: 76474
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7027709221449405
# Specificity : 0.8354892449409574
# Accuracy: 0.7736093312759892
# ROC 0.769130083543
# TP 25058 FP 6715 TN 34103 FN 10598
#
#
#
# None
# Cross: Validation: [ 0.62279176  0.70822763  0.7269268   0.73045389  0.71073451]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.4849023090586146
# Specificity : 0.5204664331301886
# Accuracy: 0.5186432961529707
# ROC 0.502684371094
# TP 1638 FP 29979 TN 32538 FN 1740
#
#
#
# None
# y SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 10, 11, 20, 11, 2, 10, 11, 2, 10, 18, 17, 2, -0.6692307692307692, 106.46153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305728
# Test Data Points: 76432
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.526346834447503
# Specificity : 0.852608376193975
# Accuracy: 0.7006358593259367
# ROC 0.689477605321
# TP 18739 FP 6018 TN 34812 FN 16863
#
#
#
# None
# Cross: Validation: [ 0.633653    0.7263319   0.7206144   0.72596556  0.72375083]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5091770278271166
# Specificity : 0.5225138762256666
# Accuracy: 0.5218301843842477
# ROC 0.515845452026
# TP 1720 FP 29851 TN 32666 FN 1658
#
#
#
# None
# x SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 9, 15, 3, 10, 15, 10, 3, 1, 12, 2, 1, 12, 0.3692307692307692, 9.230769230769232, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305680
# Test Data Points: 76421
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8704264870931537
# Specificity : 0.5706824256393909
# Accuracy: 0.7104722523913584
# ROC 0.720554456366
# TP 31022 FP 17508 TN 23273 FN 4618
#
#
#
# None
# Cross: Validation: [ 0.62860994  0.71373986  0.71712902  0.73051557  0.719877  ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5091770278271166
# Specificity : 0.5084217092950717
# Accuracy: 0.5084604294711284
# ROC 0.508799368561
# TP 1720 FP 30732 TN 31785 FN 1658
#
#
#
# None
# y SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 3, 16, 14, 10, 11, 10, 12, 1, 10, 3, 10, 9, 0.5076923076923077, 66.13076923076925, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305884
# Test Data Points: 76471
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6757347379037907
# Specificity : 0.8554612781401736
# Accuracy: 0.7715735376809509
# ROC 0.765598008022
# TP 24119 FP 5894 TN 34884 FN 11574
#
#
#
# None
# Cross: Validation: [ 0.61984779  0.71315924  0.71997228  0.72555609  0.71749706]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.012137359384251036
# Specificity : 0.9986563654685925
# Accuracy: 0.9480840731466728
# ROC 0.505396862426
# TP 41 FP 84 TN 62433 FN 3337
#
#
#
# None
# x SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 5, 9, 7, 17, 20, 10, 10, 2, 8, 12, 9, 1, -1.2846153846153845, 43.323076923076925, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305856
# Test Data Points: 76464
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6647997523289522
# Specificity : 0.8662204089609851
# Accuracy: 0.7726250261560996
# ROC 0.765510080645
# TP 23621 FP 5476 TN 35457 FN 11910
#
#
#
# None
# Cross: Validation: [ 0.6304453   0.71370841  0.72108443  0.72788502  0.71097132]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.023978685612788632
# Specificity : 0.997536670025753
# Accuracy: 0.9476288033993474
# ROC 0.510757677819
# TP 81 FP 154 TN 62363 FN 3297
#
#
#
# None
# y SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 20, 2, 9, 17, 5, 10, 1, 15, 12, 8, 18, 19, -0.8538461538461538, 2.7, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305789
# Test Data Points: 76448
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.664336057057816
# Specificity : 0.8501285661809722
# Accuracy: 0.7635778568438677
# ROC 0.757232311619
# TP 23659 FP 6120 TN 34715 FN 11954
#
#
#
# None
# Cross: Validation: [ 0.61183273  0.72798148  0.72689576  0.71393253  0.71798763]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 20, 2, 4, 9, 17, 10, 17, 18, 18, 8, 9, 3, -1.6076923076923075, 69.82307692307693, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305772
# Test Data Points: 76444
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.691926405107956
# Specificity : 0.8360623542408249
# Accuracy: 0.7687326670503898
# ROC 0.763994379674
# TP 24708 FP 6678 TN 34057 FN 11001
#
#
#
# None
# Cross: Validation: [ 0.62000942  0.71110501  0.72545557  0.72320553  0.72559947]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9963369963369964
# Accuracy: 0.9452765763715001
# ROC 0.498316514746
# TP 1 FP 229 TN 62288 FN 3377
#
#
#
# None
# y random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 12, 10, 17, 1, 3, 10, 2, 10, 20, 12, 19, 0, -0.08333333333333333, -0.6666666666666643, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6454856653829696
# Specificity : 0.6494947275922671
# Accuracy: 0.647463689572946
# ROC 0.647490196488
# TP 6034 FP 3191 TN 5913 FN 3314
#
#
#
# None
# Cross: Validation: [ 0.62963364  0.50672014  0.64448298  0.61344173  0.63360434]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.6172291296625222
# Specificity : 0.6078506646192235
# Accuracy: 0.6083314363760528
# ROC 0.612539897141
# TP 2085 FP 24516 TN 38001 FN 1293
#
#
#
# None
# x random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 14, 1, 7, 14, 5, 10, 17, 7, 19, 7, 3, 7, -0.6923076923076923, -2.0769230769230753, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8280915703893881
# Specificity : 0.46924428822495606
# Accuracy: 0.651040537611099
# ROC 0.648667929307
# TP 7741 FP 4832 TN 4272 FN 1607
#
#
#
# None
# Cross: Validation: [ 0.62307609  0.62947106  0.63250596  0.64439024  0.63089431]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.7844878626406158
# Specificity : 0.4225090775309116
# Accuracy: 0.4410653312087412
# ROC 0.603498470086
# TP 2650 FP 36103 TN 26414 FN 728
#
#
#
# None
# y random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 10, 6, 13, 9, 10, 20, 3, 20, 7, 17, 9, 14, -0.9538461538461539, 116.72307692307693, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7181215233204964
# Specificity : 0.5963312829525483
# Accuracy: 0.658031649685671
# ROC 0.657226403137
# TP 6713 FP 3675 TN 5429 FN 2635
#
#
#
# None
# Cross: Validation: [ 0.63770865  0.64724691  0.64377845  0.62471545  0.56737127]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.7291296625222025
# Specificity : 0.41986979541564695
# Accuracy: 0.4357234995067911
# ROC 0.574499728969
# TP 2463 FP 36268 TN 26249 FN 915
#
#
#
# None
# x random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 4, 15, 20, 18, 1, 10, 11, 2, 11, 1, 10, 11, -0.9615384615384616, 95.02307692307693, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6667736414206248
# Specificity : 0.6449912126537786
# Accuracy: 0.6560264469976155
# ROC 0.655882427037
# TP 6233 FP 3232 TN 5872 FN 3115
#
#
#
# None
# Cross: Validation: [ 0.64968567  0.63158465  0.65076956  0.61777778  0.64325203]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.635287152161042
# Specificity : 0.48465217460850646
# Accuracy: 0.4923742317323014
# ROC 0.559969663385
# TP 2146 FP 32218 TN 30299 FN 1232
#
#
#
# None
# y random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 3, 5, 10, 3, 19, 10, 11, 12, 17, 1, 20, 11, 0.1923076923076922, 59.600000000000016, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6488018827556696
# Specificity : 0.6456502636203867
# Accuracy: 0.647246910903967
# ROC 0.647226073188
# TP 6065 FP 3226 TN 5878 FN 3283
#
#
#
# None
# Cross: Validation: [ 0.52194884  0.6452959   0.64264036  0.64075881  0.60373984]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8487270574304322
# Specificity : 0.34101124494137597
# Accuracy: 0.367038470293649
# ROC 0.594869151186
# TP 2867 FP 41198 TN 21319 FN 511
#
#
#
# None
# x random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 11, 19, 20, 10, 15, 10, 19, 4, 2, 2, 1, 10, -0.6615384615384615, 1.3615384615384614, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7403722721437741
# Specificity : 0.5600834797891037
# Accuracy: 0.6514199002818123
# ROC 0.650227875966
# TP 6921 FP 4005 TN 5099 FN 2427
#
#
#
# None
# Cross: Validation: [ 0.63949707  0.63581184  0.6402558   0.65056911  0.64384824]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8608644168146833
# Specificity : 0.3135307196442568
# Accuracy: 0.3415888914181653
# ROC 0.587197568229
# TP 2908 FP 42916 TN 19601 FN 470
#
#
#
# None
# y random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 11, 11, 11, 10, 11, 17, 12, 3, 2, 10, 0, 0, -0.3181818181818183, 134.65454545454548, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7295678219940094
# Specificity : 0.5719463971880492
# Accuracy: 0.6517992629525254
# ROC 0.650757109591
# TP 6820 FP 3897 TN 5207 FN 2528
#
#
#
# None
# Cross: Validation: [ 0.62952525  0.64383265  0.63402341  0.63897019  0.63907859]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.2812314979277679
# Specificity : 0.8796327398947487
# Accuracy: 0.8489566734957129
# ROC 0.580432118911
# TP 950 FP 7525 TN 54992 FN 2428
#
#
#
# None
# x random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 3, 3, 17, 7, 13, 10, 8, 10, 9, 7, 12, 13, -0.27692307692307705, 74.41538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.769576379974326
# Specificity : 0.539103690685413
# Accuracy: 0.6558638629958812
# ROC 0.65434003533
# TP 7194 FP 4196 TN 4908 FN 2154
#
#
#
# None
# Cross: Validation: [ 0.64659657  0.63050076  0.61700629  0.61560976  0.63674797]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.32386027235050324
# Specificity : 0.8516723451221268
# Accuracy: 0.824614917672054
# ROC 0.587766308736
# TP 1094 FP 9273 TN 53244 FN 2284
#
#
#
# None
# y random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 18, 10, 3, 18, 10, 16, 2, 15, 19, 17, 20, -1.0153846153846153, 21.646153846153847, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7795250320924262
# Specificity : 0.5219683655536028
# Accuracy: 0.6524495989594624
# ROC 0.650746698823
# TP 7287 FP 4352 TN 4752 FN 2061
#
#
#
# None
# Cross: Validation: [ 0.64209842  0.6341318   0.62822458  0.61100271  0.63598916]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.559206631142688
# Specificity : 0.6799270598397236
# Accuracy: 0.6737385234084529
# ROC 0.619566845491
# TP 1889 FP 20010 TN 42507 FN 1489
#
#
#
# None
# x random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 8, 17, 13, 15, 6, 10, 11, 16, 5, 13, 19, 3, -0.3846153846153847, 27.07692307692308, 0.3076923076923077]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7615532734274711
# Specificity : 0.5481107205623902
# Accuracy: 0.6562432256665944
# ROC 0.654831996995
# TP 7119 FP 4114 TN 4990 FN 2229
#
#
#
# None
# Cross: Validation: [ 0.57630609  0.64350748  0.64106872  0.63501355  0.63582656]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.48105387803433985
# Specificity : 0.7236271734088328
# Accuracy: 0.7111920479550801
# ROC 0.602340525722
# TP 1625 FP 17278 TN 45239 FN 1753
#
#
#
# None
# y ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 3, 10, 20, 3, 10, 10, 9, 12, 7, 7, 10, 8, -0.23846153846153878, 51.46153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143732
# Test Data Points: 35934
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.19638973466724663
# Specificity : 0.9630488443413868
# Accuracy: 0.7668503367284466
# ROC 0.579719289504
# TP 1806 FP 988 TN 25750 FN 7390
#
#
#
# None
# Cross: Validation: [ 0.76504146  0.75552402  0.76184115  0.74423912  0.76388734]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.10301953818827708
# Specificity : 0.9473583185373579
# Accuracy: 0.9040746642385613
# ROC 0.525188928363
# TP 348 FP 3291 TN 59226 FN 3030
#
#
#
# None
# x ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 3, 8, 9, 9, 13, 10, 19, 3, 20, 9, 8, 3, -0.776923076923077, 118.64615384615387, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143804
# Test Data Points: 35952
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5429691754710816
# Specificity : 0.798700085913862
# Accuracy: 0.733394526034713
# ROC 0.670834630692
# TP 4985 FP 5389 TN 21382 FN 4196
#
#
#
# None
# Cross: Validation: [ 0.74808077  0.76271139  0.76260013  0.76008345  0.76411683]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.4197750148016578
# Specificity : 0.7360717884735352
# Accuracy: 0.7198573488125047
# ROC 0.577923401638
# TP 1418 FP 16500 TN 46017 FN 1960
#
#
#
# None
# y ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 7, 1, 3, 7, 7, 10, 7, 7, 3, 18, 8, 7, -1.876923076923077, -22.692307692307693, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143732
# Test Data Points: 35933
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.32941816204458946
# Specificity : 0.9213478943825267
# Accuracy: 0.7698772715887903
# ROC 0.625383028214
# TP 3029 FP 2103 TN 24635 FN 6166
#
#
#
# None
# Cross: Validation: [ 0.76028274  0.75992097  0.76765091  0.75754202  0.76630858]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.31616341030195383
# Specificity : 0.8489210934625782
# Accuracy: 0.8216101373397071
# ROC 0.582542251882
# TP 1068 FP 9445 TN 53072 FN 2310
#
#
#
# None
# x ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 1, 3, 10, 6, 19, 10, 1, 11, 9, 9, 11, 1, -1.3923076923076925, 70.77692307692308, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143763
# Test Data Points: 35941
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.273142112125163
# Specificity : 0.9453192205557841
# Accuracy: 0.7731838290531705
# ROC 0.60923066634
# TP 2514 FP 1462 TN 25275 FN 6690
#
#
#
# None
# Cross: Validation: [ 0.75716432  0.76316741  0.76656187  0.75670562  0.75628826]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.22380106571936056
# Specificity : 0.900794983764416
# Accuracy: 0.866089991653388
# ROC 0.562298024742
# TP 756 FP 6202 TN 56315 FN 2622
#
#
#
# None
# y ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 9, 10, 12, 10, 10, 10, 9, 18, 19, 13, 19, 20, -1.2769230769230768, 56.930769230769236, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143707
# Test Data Points: 35927
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.28563656147986943
# Specificity : 0.9396342147585742
# Accuracy: 0.7723439196147744
# ROC 0.612635388119
# TP 2625 FP 1614 TN 25123 FN 6565
#
#
#
# None
# Cross: Validation: [ 0.76210755  0.76290812  0.76388232  0.75961699  0.7602572 ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.38661930136175254
# Specificity : 0.7921045475630628
# Accuracy: 0.7713180059185067
# ROC 0.589361924462
# TP 1306 FP 12997 TN 49520 FN 2072
#
#
#
# None
# x ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 16, 11, 3, 3, 2, 10, 2, 9, 12, 17, 8, 15, -0.5000000000000001, 16.030769230769234, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143763
# Test Data Points: 35941
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3098652759669709
# Specificity : 0.9282642031641546
# Accuracy: 0.7699006705433905
# ROC 0.619064739566
# TP 2852 FP 1918 TN 24819 FN 6352
#
#
#
# None
# Cross: Validation: [ 0.71618163  0.75813138  0.75384658  0.76471898  0.76046188]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.34221432800473656
# Specificity : 0.806244701441208
# Accuracy: 0.7824569390697321
# ROC 0.574229514723
# TP 1156 FP 12113 TN 50404 FN 2222
#
#
#
# None
# y ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 5, 13, 12, 1, 17, 10, 20, 7, 7, 15, 8, 20, -0.2846153846153847, 29.969230769230766, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143760
# Test Data Points: 35940
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3327900912646675
# Specificity : 0.9136370436864153
# Accuracy: 0.7648859209794101
# ROC 0.623213567476
# TP 3063 FP 2309 TN 24427 FN 6141
#
#
#
# None
# Cross: Validation: [ 0.75760274  0.76848168  0.76691708  0.76496285  0.7647959 ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.013617525162818236
# Specificity : 0.9988483132587936
# Accuracy: 0.9483420593368237
# ROC 0.506232919211
# TP 46 FP 72 TN 62445 FN 3332
#
#
#
# None
# x ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 10, 8, 3, 8, 19, 10, 3, 7, 19, 3, 7, 2, -0.6461538461538461, 65.69230769230771, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143750
# Test Data Points: 35938
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.26953125
# Specificity : 0.9422947384177831
# Accuracy: 0.7697701597195169
# ROC 0.605912994209
# TP 2484 FP 1542 TN 25180 FN 6732
#
#
#
# None
# Cross: Validation: [ 0.76659803  0.7564973   0.76164506  0.76286279  0.75729749]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.02427471876850207
# Specificity : 0.999280195786746
# Accuracy: 0.9492981258062069
# ROC 0.511777457278
# TP 82 FP 45 TN 62472 FN 3296
#
#
#
# None
# y ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 19, 19, 3, 8, 10, 3, 13, 9, 10, 18, 1, 5, -0.13846153846153852, 114.65384615384615, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143748
# Test Data Points: 35937
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.21030230273927752
# Specificity : 0.9620153880630462
# Accuracy: 0.7703481091910844
# ROC 0.586158845401
# TP 1927 FP 1017 TN 25757 FN 7236
#
#
#
# None
# Cross: Validation: [ 0.76473371  0.76567978  0.76803851  0.75217053  0.75681768]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9998400435081658
# Accuracy: 0.9486000455269747
# ROC 0.500068038332
# TP 1 FP 10 TN 62507 FN 3377
#
#
#
# None
# x ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 3, 18, 3, 5, 14, 10, 5, 16, 9, 18, 7, 11, -0.6000000000000001, 21.646153846153847, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143815
# Test Data Points: 35954
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2424374319912949
# Specificity : 0.9477656553579435
# Accuracy: 0.7674806697446738
# ROC 0.595101543675
# TP 2228 FP 1398 TN 25366 FN 6962
#
#
#
# None
# Cross: Validation: [ 0.75839243  0.75340713  0.76397619  0.7581843   0.76850332]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9999200217540829
# Accuracy: 0.9486759238181957
# ROC 0.500108027455
# TP 1 FP 5 TN 62512 FN 3377
#
#
#
# None
# y near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 19, 4, 7, 17, 18, 10, 17, 3, 1, 12, 3, 15, -0.9692307692307691, 58.61538461538462, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3461703038083012
# Specificity : 0.9096001757469244
# Accuracy: 0.6241599826577064
# ROC 0.627885239778
# TP 3236 FP 823 TN 8281 FN 6112
#
#
#
# None
# Cross: Validation: [ 0.61202038  0.72539562  0.69071103  0.62211382  0.6297019 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.413854351687389
# Specificity : 0.6178479453588623
# Accuracy: 0.6073905455649139
# ROC 0.515851148523
# TP 1398 FP 23891 TN 38626 FN 1980
#
#
#
# None
# x near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 3, 13, 8, 15, 10, 10, 5, 16, 10, 3, 16, 3, 0.36153846153846153, 18.24615384615385, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6448438168592212
# Specificity : 0.7469244288224957
# Accuracy: 0.6952091914155647
# ROC 0.695884122841
# TP 6028 FP 2304 TN 6800 FN 3320
#
#
#
# None
# Cross: Validation: [ 0.57262085  0.71661608  0.69190332  0.6804878   0.65723577]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.6503848431024275
# Specificity : 0.3978757777884415
# Accuracy: 0.4108202443280977
# ROC 0.524130310445
# TP 2197 FP 37643 TN 24874 FN 1181
#
#
#
# None
# y near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 3, 1, 2, 20, 9, 10, 9, 1, 11, 1, 17, 10, -0.707692307692308, 80.94615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6857081728712024
# Specificity : 0.695188927943761
# Accuracy: 0.6903858660307826
# ROC 0.690448550407
# TP 6410 FP 2775 TN 6329 FN 2938
#
#
#
# None
# Cross: Validation: [ 0.63071754  0.71726642  0.69943638  0.65620596  0.63506775]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6323268206039077
# Specificity : 0.46040277044643857
# Accuracy: 0.4692161772516883
# ROC 0.546364795525
# TP 2136 FP 33734 TN 28783 FN 1242
#
#
#
# None
# x near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 2, 2, 13, 2, 10, 10, 10, 18, 20, 9, 5, 9, 0.22307692307692284, 47.14615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6941591784338896
# Specificity : 0.6933216168717048
# Accuracy: 0.6937459353999567
# ROC 0.693740397653
# TP 6489 FP 2792 TN 6312 FN 2859
#
#
#
# None
# Cross: Validation: [ 0.53945372  0.67353132  0.68767613  0.66238482  0.64373984]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6441681468324453
# Specificity : 0.44024825247532673
# Accuracy: 0.45070187419379315
# ROC 0.542208199654
# TP 2176 FP 34994 TN 27523 FN 1202
#
#
#
# None
# y near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 10, 7, 4, 18, 1, 10, 4, 19, 7, 7, 0, 0, -1.281818181818182, 17.345454545454544, 0.09090909090909091]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7150192554557124
# Specificity : 0.6882688927943761
# Accuracy: 0.7018209408194234
# ROC 0.701644074125
# TP 6684 FP 2838 TN 6266 FN 2664
#
#
#
# None
# Cross: Validation: [ 0.6249729   0.65423802  0.7052352   0.64205962  0.63934959]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.14120781527531084
# Specificity : 0.9045699569717037
# Accuracy: 0.8654374383488884
# ROC 0.522888886124
# TP 477 FP 5966 TN 56551 FN 2901
#
#
#
# None
# x near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 15, 17, 19, 11, 5, 10, 1, 7, 7, 12, 10, 3, -0.7923076923076924, -8.553846153846152, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7236842105263158
# Specificity : 0.6630052724077329
# Accuracy: 0.6937459353999567
# ROC 0.693344741467
# TP 6765 FP 3068 TN 6036 FN 2583
#
#
#
# None
# Cross: Validation: [ 0.63180143  0.63478214  0.69239107  0.64850949  0.65436314]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.16370633510953228
# Specificity : 0.8691076027320569
# Accuracy: 0.8329463540481068
# ROC 0.516406968921
# TP 553 FP 8183 TN 54334 FN 2825
#
#
#
# None
# y near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 20, 4, 12, 2, 1, 10, 8, 1, 7, 2, 9, 2, 0.007692307692307699, 17.51538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7460419341035516
# Specificity : 0.5981985940246046
# Accuracy: 0.6730977671797095
# ROC 0.672120264064
# TP 6974 FP 3658 TN 5446 FN 2374
#
#
#
# None
# Cross: Validation: [ 0.59944721  0.71965099  0.65673098  0.66937669  0.64493225]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8345174659561871
# Specificity : 0.1858534478621815
# Accuracy: 0.21910615372941802
# ROC 0.510185456909
# TP 2819 FP 50898 TN 11619 FN 559
#
#
#
# None
# x near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 10, 10, 1, 19, 19, 10, 1, 9, 12, 9, 5, 11, -0.6153846153846154, 47.876923076923084, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6863500213949508
# Specificity : 0.6858523725834798
# Accuracy: 0.6861044873184479
# ROC 0.686101196989
# TP 6416 FP 2860 TN 6244 FN 2932
#
#
#
# None
# Cross: Validation: [ 0.62659874  0.69602211  0.69081942  0.68726287  0.64319783]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.7320899940793368
# Specificity : 0.3837996065070301
# Accuracy: 0.4016541467486152
# ROC 0.557944800293
# TP 2473 FP 38523 TN 23994 FN 905
#
#
#
# None
# y near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 10, 20, 9, 1, 1, 1, 17, 17, 14, 8, 0, 0, -1.3, 134.20000000000002, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7885109114249037
# Specificity : 0.5738137082601055
# Accuracy: 0.6825818339475396
# ROC 0.681162309843
# TP 7371 FP 3880 TN 5224 FN 1977
#
#
#
# None
# Cross: Validation: [ 0.62860395  0.71157598  0.64616302  0.68493225  0.65761518]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8774422735346359
# Specificity : 0.15670937504998642
# Accuracy: 0.19365657485393428
# ROC 0.517075824292
# TP 2964 FP 52720 TN 9797 FN 414
#
#
#
# None
# x near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 1, 12, 15, 20, 14, 10, 2, 20, 18, 3, 2, 1, 0.2153846153846154, -14.661538461538465, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7287120239623449
# Specificity : 0.6418057996485061
# Accuracy: 0.6858335139822241
# ROC 0.685258911805
# TP 6812 FP 3261 TN 5843 FN 2536
#
#
#
# None
# Cross: Validation: [ 0.60242792  0.66323434  0.69520919  0.63262873  0.66287263]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6489046773238603
# Specificity : 0.3092918726106499
# Accuracy: 0.3267015706806283
# ROC 0.479098274967
# TP 2192 FP 43181 TN 19336 FN 1186
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos.csv", "Y")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos.csv", "Y")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 1, 1, 18, 10, 17, 10, 17, 10, 10, 13, 5, 16, -1.2000000000000002, 116.26153846153846, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 40936 FN 9153
#
#
#
# None
# Cross: Validation: [ 0.81539966  0.81623445  0.81557565  0.81617089  0.81535237]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 10, 5, 11, 1, 20, 10, 7, 2, 13, 15, 20, 19, -0.2076923076923077, 44.78461538461539, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.024710255849551718
# Specificity : 0.9956038588350226
# Accuracy: 0.8183306382384061
# ROC 0.510157057342
# TP 226 FP 180 TN 40765 FN 8920
#
#
#
# None
# Cross: Validation: [ 0.815759    0.81635424  0.81613463  0.81645039  0.81076063]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 10, 19, 3, 9, 8, 10, 12, 7, 9, 20, 3, 12, -0.10769230769230759, 55.63076923076924, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06419807186678353
# Specificity : 0.9867929595000366
# Accuracy: 0.8186700205625761
# ROC 0.525495515683
# TP 586 FP 541 TN 40422 FN 8542
#
#
#
# None
# Cross: Validation: [ 0.81631797  0.81577529  0.8157154   0.81545219  0.81653025]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 248 TN 23266 FN 41
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 19, 15, 20, 10, 2, 10, 10, 10, 20, 18, 1, 10, -0.6538461538461539, 9.207692307692309, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.049158693500494885
# Specificity : 0.9913898238938484
# Accuracy: 0.8203469685172985
# ROC 0.520274258697
# TP 447 FP 353 TN 40645 FN 8646
#
#
#
# None
# Cross: Validation: [ 0.81653757  0.8141782   0.81579525  0.81581154  0.81579158]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 248 TN 23266 FN 41
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 19, 11, 11, 2, 5, 10, 9, 1, 11, 1, 5, 3, 0.12307692307692299, 53.67692307692308, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.07978895229891246
# Specificity : 0.9846583668267817
# Accuracy: 0.8168932542772155
# ROC 0.532223659563
# TP 741 FP 626 TN 40178 FN 8546
#
#
#
# None
# Cross: Validation: [ 0.81549948  0.8150566   0.81587511  0.81595129  0.81609104]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 448 TN 23066 FN 41
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 2, 12, 1, 13, 10, 3, 1, 5, 20, 3, 10, 1.5692307692307692, 10.984615384615386, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.07420686657974794
# Specificity : 0.9851052901900359
# Accuracy: 0.8177317282545766
# ROC 0.529656078385
# TP 683 FP 609 TN 40278 FN 8521
#
#
#
# None
# Cross: Validation: [ 0.81543959  0.81575533  0.81619453  0.81690956  0.81615093]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 328 TN 23186 FN 41
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 1, 7, 12, 13, 10, 10, 17, 9, 8, 12, 16, 8, -1.1307692307692307, 34.81538461538462, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.037132987910189985
# Specificity : 0.9935091973448943
# Accuracy: 0.8166337266175561
# ROC 0.515321092628
# TP 344 FP 265 TN 40562 FN 8920
#
#
#
# None
# Cross: Validation: [ 0.81585882  0.81545587  0.81603482  0.81597125  0.81080056]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 204 TN 23310 FN 41
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 1, 1, 10, 13, 3, 10, 17, 12, 2, 9, 20, 17, -0.3692307692307692, 48.353846153846156, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.03612497287914949
# Specificity : 0.9943972793775843
# Accuracy: 0.818051146912619
# ROC 0.515261126128
# TP 333 FP 229 TN 40644 FN 8885
#
#
#
# None
# Cross: Validation: [ 0.81420187  0.81677347  0.81579525  0.81551208  0.81579158]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 204 TN 23310 FN 41
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 10, 10, 20, 10, 10, 10, 9, 1, 17, 2, 0, 0, -1.0909090909090908, 79.12727272727273, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04638666520451804
# Specificity : 0.9902616420970419
# Accuracy: 0.8184304565690443
# ROC 0.518324153651
# TP 423 FP 399 TN 40573 FN 8696
#
#
#
# None
# Cross: Validation: [ 0.81577897  0.81575533  0.81511649  0.81595129  0.81431423]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 40 TN 23474 FN 41
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 17, 10, 1, 4, 17, 10, 13, 16, 11, 11, 20, 10, -0.9923076923076924, 93.12307692307694, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.036046893831488985
# Specificity : 0.9926276730788008
# Accuracy: 0.8183306382384061
# ROC 0.514337283455
# TP 329 FP 302 TN 40662 FN 8798
#
#
#
# None
# Cross: Validation: [ 0.81607842  0.815935    0.81579525  0.81593132  0.81525255]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 80 TN 23434 FN 41
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 3, 8, 19, 12, 3, 10, 11, 18, 10, 10, 14, 1, 0.2461538461538461, 122.81538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331743
# Test Data Points: 82936
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6619634670657261
# Specificity : 0.8988172490633494
# Accuracy: 0.7785883090575866
# ROC 0.780390358065
# TP 27868 FP 4132 TN 36705 FN 14231
#
#
#
# None
# Cross: Validation: [ 0.50614322  0.82189881  0.8188121   0.82622536  0.81653102]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 708 TN 22806 FN 41
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 13, 3, 10, 19, 18, 10, 1, 17, 9, 19, 10, 9, -1.5384615384615385, 68.4923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331724
# Test Data Points: 82931
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6991540569522221
# Specificity : 0.8627886540057609
# Accuracy: 0.779985771303855
# ROC 0.780971355479
# TP 29340 FP 5621 TN 35345 FN 12625
#
#
#
# None
# Cross: Validation: [ 0.51604929  0.81242238  0.83254754  0.83591178  0.8425419 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 1852 TN 21662 FN 41
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 20, 1, 2, 1, 7, 10, 3, 14, 15, 8, 3, 11, -0.17692307692307688, 4.453846153846156, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331738
# Test Data Points: 82935
# Scaling Data
# Finished Scaling Data
# Starting Training
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# Done training
# Test Results
# Sensitivity: 0.7146835503296599
# Specificity : 0.9012022872782366
# Accuracy: 0.8067161029722072
# ROC 0.807942918804
# TP 30026 FP 4043 TN 36879 FN 11987
#
#
#
# None
# Cross: Validation: [ 0.52605624  0.82023271  0.83694263  0.8323245   0.83302385]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.1322616313685464
# Accuracy: 0.13377202292506898
# ROC 0.566130815684
# TP 41 FP 20404 TN 3110 FN 0
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 16, 20, 3, 2, 3, 10, 3, 10, 17, 9, 13, 6, -0.015384615384615441, 27.261538461538468, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331692
# Test Data Points: 82924
# Scaling Data
# Finished Scaling Data
# Starting Training
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# Done training
# Test Results
# Sensitivity: 0.7211198824170875
# Specificity : 0.9170123462850691
# Accuracy: 0.8173628864984805
# ROC 0.819066114351
# TP 30419 FP 3381 TN 37360 FN 11764
#
#
#
# None
# Cross: Validation: [ 0.52235782  0.8065193   0.82195531  0.84237184  0.83112044]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.053840265373819855
# Accuracy: 0.055487157715983865
# ROC 0.526920132687
# TP 41 FP 22248 TN 1266 FN 0
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 16, 19, 18, 2, 15, 10, 9, 3, 13, 10, 18, 11, -0.5461538461538461, 31.323076923076925, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331720
# Test Data Points: 82930
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6943293142426527
# Specificity : 0.9209706914446696
# Accuracy: 0.8049198118895454
# ROC 0.807650002844
# TP 29484 FP 3198 TN 37268 FN 12980
#
#
#
# None
# Cross: Validation: [ 0.5153682   0.79734716  0.80895936  0.83271434  0.8335323 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3000765501403419
# Accuracy: 0.3012948418594778
# ROC 0.65003827507
# TP 41 FP 16458 TN 7056 FN 0
#
#
#
# None
# x ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 7, 3, 13, 9, 5, 10, 11, 3, 17, 2, 20, 18, 0.0, 73.55384615384615, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331762
# Test Data Points: 82941
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7326617405973057
# Specificity : 0.9077890923333007
# Accuracy: 0.8189194728783111
# ROC 0.820225416465
# TP 30837 FP 3767 TN 37085 FN 11252
#
#
#
# None
# Cross: Validation: [ 0.51845868  0.82149962  0.8280926   0.83087774  0.83146853]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.22165518414561539
# Accuracy: 0.2230099766503927
# ROC 0.610827592073
# TP 41 FP 18302 TN 5212 FN 0
#
#
#
# None
# y ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 7, 2, 2, 10, 1, 10, 3, 16, 7, 19, 7, 11, -1.1846153846153846, 15.115384615384615, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331718
# Test Data Points: 82930
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9032028131533929
# Specificity : 0.2570393222662945
# Accuracy: 0.5849752803569275
# ROC 0.58012106771
# TP 38014 FP 30344 TN 10498 FN 4074
#
#
#
# None
# Cross: Validation: [ 0.50159771  0.80687327  0.84232295  0.82409049  0.81907415]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 41 FP 23514 TN 0 FN 0
#
#
#
# None
# x ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 16, 5, 16, 4, 10, 10, 5, 10, 9, 10, 20, 1, -0.22307692307692314, 72.96923076923079, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331706
# Test Data Points: 82927
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8501319010385722
# Specificity : 0.43365973072215425
# Accuracy: 0.6449769074004847
# ROC 0.64189581588
# TP 35771 FP 23135 TN 17715 FN 6306
#
#
#
# None
# Cross: Validation: [ 0.5252267   0.81267862  0.83233244  0.83564865  0.83909751]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 41 FP 23514 TN 0 FN 0
#
#
#
# None
# y ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 7, 9, 3, 12, 5, 10, 7, 11, 9, 1, 10, 10, -0.32307692307692304, 29.400000000000002, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331733
# Test Data Points: 82934
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7485765799962042
# Specificity : 0.7951792457456721
# Accuracy: 0.7714929944293052
# ROC 0.771877912871
# TP 31554 FP 8353 TN 32429 FN 10598
#
#
#
# None
# Cross: Validation: [ 0.51449931  0.81319861  0.82559415  0.83245511  0.84172766]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.26341753848770944
# Accuracy: 0.26300148588410105
# ROC 0.143903891195
# TP 1 FP 17320 TN 6194 FN 40
#
#
#
# None
# x ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 12, 18, 9, 3, 18, 10, 12, 7, 9, 12, 2, 3, -0.09230769230769233, 7.015384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331717
# Test Data Points: 82930
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7939257858662255
# Specificity : 0.6991875923190547
# Accuracy: 0.7475220065115158
# ROC 0.746556689093
# TP 33591 FP 12219 TN 28401 FN 8719
#
#
#
# None
# Cross: Validation: [ 0.53060978  0.82726187  0.82798539  0.83543754  0.83822306]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.035298120268776045
# Accuracy: 0.036977287200169816
# ROC 0.517649060134
# TP 41 FP 22684 TN 830 FN 0
#
#
#
# None
# y SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 18, 10, 11, 10, 10, 10, 3, 10, 11, 1, 10, 1, -1.0000000000000004, 130.76923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305820
# Test Data Points: 76455
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7668816601233875
# Specificity : 0.6735874494423336
# Accuracy: 0.7171015630109214
# ROC 0.720234554783
# TP 27347 FP 13316 TN 27479 FN 8313
#
#
#
# None
# Cross: Validation: [ 0.62621639  0.71992675  0.71859264  0.72182329  0.71861511]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 792 TN 22722 FN 41
#
#
#
# None
# x SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [6, 12, 13, 5, 2, 5, 10, 2, 3, 5, 10, 5, 17, 1.5615384615384618, 2.7, 0.38461538461538464]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305792
# Test Data Points: 76448
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7660443897114388
# Specificity : 0.6397259264716717
# Accuracy: 0.6987625575554626
# ROC 0.702885158092
# TP 27370 FP 14670 TN 26049 FN 8359
#
#
#
# None
# Cross: Validation: [ 0.63302332  0.71665707  0.71775586  0.72382535  0.71801379]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.9402058348218083
# Accuracy: 0.9386117597113139
# ROC 0.482298039362
# TP 1 FP 1406 TN 22108 FN 40
#
#
#
# None
# y SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 3, 2, 8, 17, 19, 10, 2, 10, 6, 3, 8, 2, -0.6153846153846154, 58.61538461538462, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305755
# Test Data Points: 76439
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6968274931857139
# Specificity : 0.8217467933026534
# Accuracy: 0.76358926725886
# ROC 0.759287143244
# TP 24798 FP 7282 TN 33570 FN 10789
#
#
#
# None
# Cross: Validation: [ 0.63160649  0.7075315   0.71875613  0.72724299  0.73196578]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4849876669218338
# Accuracy: 0.48588410104011887
# ROC 0.742493833461
# TP 41 FP 12110 TN 11404 FN 0
#
#
#
# None
# x SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 8, 11, 11, 17, 5, 10, 10, 3, 11, 12, 18, 12, -0.34615384615384637, 92.32307692307694, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305992
# Test Data Points: 76498
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6264026032315978
# Specificity : 0.8926805385556915
# Accuracy: 0.7685952573923501
# ROC 0.759541570894
# TP 22330 FP 4384 TN 36466 FN 13318
#
#
#
# None
# Cross: Validation: [ 0.62657028  0.71879003  0.7138618   0.71171795  0.72822464]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4532618865356809
# Accuracy: 0.4542135427722352
# ROC 0.726630943268
# TP 41 FP 12856 TN 10658 FN 0
#
#
#
# None
# y SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 20, 10, 7, 2, 10, 10, 5, 20, 10, 3, 10, 10, -0.19230769230769226, 38.861538461538466, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305687
# Test Data Points: 76422
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7945505617977529
# Specificity : 0.7203958649747685
# Accuracy: 0.754939677056345
# ROC 0.757473213386
# TP 28286 FP 11414 TN 29408 FN 7314
#
#
#
# None
# Cross: Validation: [ 0.61461864  0.70178744  0.71840569  0.7175122   0.71352115]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3648039465850132
# Accuracy: 0.3659095733389938
# ROC 0.682401973293
# TP 41 FP 14936 TN 8578 FN 0
#
#
#
# None
# x SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 8, 8, 4, 10, 11, 10, 2, 5, 1, 3, 18, 19, -0.21538461538461537, 106.46153846153847, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305946
# Test Data Points: 76487
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5245088422409686
# Specificity : 0.8498750183796501
# Accuracy: 0.6980924863048623
# ROC 0.68719193031
# TP 18715 FP 6126 TN 34680 FN 16966
#
#
#
# None
# Cross: Validation: [ 0.62532685  0.70931008  0.72130847  0.71783071  0.70833878]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3630177766437016
# Accuracy: 0.3641265124177457
# ROC 0.681508888322
# TP 41 FP 14978 TN 8536 FN 0
#
#
#
# None
# y SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 10, 7, 2, 11, 1, 10, 11, 12, 10, 10, 0, 0, -0.8363636363636364, 141.5090909090909, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305701
# Test Data Points: 76426
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6376348605856803
# Specificity : 0.8805380329397904
# Accuracy: 0.7671211367859105
# ROC 0.759086446763
# TP 22754 FP 4867 TN 35874 FN 12931
#
#
#
# None
# Cross: Validation: [ 0.63859631  0.71886163  0.71293425  0.70919202  0.73856722]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 3540 TN 19974 FN 41
#
#
#
# None
# x SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 3, 18, 10, 3, 14, 10, 12, 12, 11, 11, 19, 9, 0.5692307692307691, 33.06153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 232049
# Test Data Points: 58013
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8719213031105878
# Specificity : 0.6378920517131428
# Accuracy: 0.802337407132884
# ROC 0.754906677412
# TP 35543 FP 6246 TN 11003 FN 5221
#
#
#
# None
# Cross: Validation: [ 0.75898921  0.80738468  0.81302144  0.81305592  0.81048749]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.6123160670239006
# Accuracy: 0.611292719167905
# ROC 0.318353155463
# TP 1 FP 9116 TN 14398 FN 40
#
#
#
# None
# y SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 1, 20, 10, 2, 2, 11, 12, 11, 10, 19, 18, 16, -0.3153846153846154, 55.430769230769236, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305963
# Test Data Points: 76491
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.744757691984658
# Specificity : 0.6762238791327382
# Accuracy: 0.7082271116863422
# ROC 0.710490785559
# TP 26602 FP 13201 TN 27571 FN 9117
#
#
#
# None
# Cross: Validation: [ 0.63149087  0.72077761  0.72697442  0.73288012  0.7107988 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 612 TN 22902 FN 41
#
#
#
# None
# x SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 1, 11, 20, 11, 1, 10, 19, 12, 19, 10, 12, 1, -0.530769230769231, 5.953846153846156, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305757
# Test Data Points: 76440
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7416975204757097
# Specificity : 0.7777777777777778
# Accuracy: 0.7609497645211931
# ROC 0.759737649127
# TP 26443 FP 9064 TN 31724 FN 9209
#
#
#
# None
# Cross: Validation: [ 0.62365746  0.71832442  0.71421656  0.72474784  0.71098523]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 838 TN 22676 FN 41
#
#
#
# None
# y random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 18, 2, 10, 9, 15, 10, 16, 14, 1, 9, 10, 11, -1.4076923076923078, 85.07692307692308, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8780487804878049
# Specificity : 0.3976274165202109
# Accuracy: 0.6410145241708216
# ROC 0.637838098504
# TP 8208 FP 5484 TN 3620 FN 1140
#
#
#
# None
# Cross: Validation: [ 0.50655755  0.64041838  0.62865814  0.59420054  0.59447154]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.5300671940120779
# Accuracy: 0.5291870091275738
# ROC 0.277228718957
# TP 1 FP 11050 TN 12464 FN 40
#
#
#
# None
# x random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 16, 10, 1, 17, 10, 20, 11, 10, 10, 10, 11, 0, -1.4666666666666668, 130.55000000000004, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8525887890457852
# Specificity : 0.4270650263620387
# Accuracy: 0.6426403641881638
# ROC 0.639826907704
# TP 7970 FP 5216 TN 3888 FN 1378
#
#
#
# None
# Cross: Validation: [ 0.64605463  0.61473011  0.61050293  0.59073171  0.63214092]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.5802500637917836
# Accuracy: 0.579282530248355
# ROC 0.302320153847
# TP 1 FP 9870 TN 13644 FN 40
#
#
#
# None
# y random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 10, 17, 3, 10, 10, 10, 10, 10, 18, 19, 10, 1, -1.3538461538461537, 98.12307692307694, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7008985879332478
# Specificity : 0.5972100175746925
# Accuracy: 0.6497398655972252
# ROC 0.649054302754
# TP 6552 FP 3667 TN 5437 FN 2796
#
#
#
# None
# Cross: Validation: [ 0.58015391  0.64865597  0.64448298  0.62357724  0.64747967]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.40078251254571745
# Accuracy: 0.4001273614943749
# ROC 0.212586378224
# TP 1 FP 14090 TN 9424 FN 40
#
#
#
# None
# x random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 10, 1, 2, 5, 8, 10, 14, 5, 13, 10, 13, 7, 0.9923076923076923, 55.04615384615385, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6818570817287121
# Specificity : 0.6237917398945518
# Accuracy: 0.6532083243008888
# ROC 0.652824410812
# TP 6374 FP 3425 TN 5679 FN 2974
#
#
#
# None
# Cross: Validation: [ 0.65255799  0.62627357  0.62004119  0.64189702  0.56921409]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.4833716084035043
# Accuracy: 0.4825727021863723
# ROC 0.253880926153
# TP 1 FP 12148 TN 11366 FN 40
#
#
#
# None
# y random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 1, 14, 5, 8, 8, 10, 1, 15, 3, 3, 18, 18, -0.5769230769230769, 39.753846153846155, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7054985023534446
# Specificity : 0.5940246045694201
# Accuracy: 0.6504985909386516
# ROC 0.649761553461
# TP 6595 FP 3696 TN 5408 FN 2753
#
#
#
# None
# Cross: Validation: [ 0.61001517  0.62752005  0.63760026  0.63067751  0.64834688]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.31496129965127156
# Accuracy: 0.316153682869879
# ROC 0.657480649826
# TP 41 FP 16108 TN 7406 FN 0
#
#
#
# None
# x random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 11, 8, 18, 1, 11, 10, 11, 4, 2, 2, 3, 4, -1.0248212535001446e-16, 79.6076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6803594351732991
# Specificity : 0.6271968365553603
# Accuracy: 0.6541296336440494
# ROC 0.653778135864
# TP 6360 FP 3394 TN 5710 FN 2988
#
#
#
# None
# Cross: Validation: [ 0.64247778  0.65553869  0.59820074  0.64861789  0.63609756]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.31912902951433186
# Accuracy: 0.32031415835279137
# ROC 0.659564514757
# TP 41 FP 16010 TN 7504 FN 0
#
#
#
# None
# y random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 10, 7, 1, 17, 17, 10, 11, 10, 11, 1, 0, 0, -1.5909090909090908, 190.79090909090905, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.651048352588789
# Specificity : 0.6415861159929701
# Accuracy: 0.6463797962280512
# ROC 0.646317234291
# TP 6086 FP 3263 TN 5841 FN 3262
#
#
#
# None
# Cross: Validation: [ 0.64480815  0.62968784  0.5619987   0.64509485  0.64742547]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.42349238751382157
# Accuracy: 0.42279770749310125
# ROC 0.223941315708
# TP 1 FP 13556 TN 9958 FN 40
#
#
#
# None
# x random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 10, 10, 3, 20, 2, 10, 4, 15, 9, 15, 20, 3, -0.2384615384615385, 63.730769230769226, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5676080445014976
# Specificity : 0.7335237258347979
# Accuracy: 0.6494688922610015
# ROC 0.650565885168
# TP 5306 FP 2426 TN 6678 FN 4042
#
#
#
# None
# Cross: Validation: [ 0.64686755  0.64762627  0.63911771  0.64720867  0.64558266]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.48422216551841457
# Accuracy: 0.4834217788155381
# ROC 0.25430620471
# TP 1 FP 12128 TN 11386 FN 40
#
#
#
# None
# y random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 19, 11, 1, 7, 1, 10, 15, 6, 2, 13, 19, 20, -1.0923076923076922, -34.930769230769236, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7152332049636286
# Specificity : 0.6023725834797891
# Accuracy: 0.6595491003685238
# ROC 0.658802894222
# TP 6686 FP 3620 TN 5484 FN 2662
#
#
#
# None
# Cross: Validation: [ 0.6453501   0.64058097  0.62556904  0.64585366  0.62655827]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.8184911116781491
# Accuracy: 0.8171088940776905
# ROC 0.42144067779
# TP 1 FP 4268 TN 19246 FN 40
#
#
#
# None
# x random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 17, 1, 2, 13, 15, 10, 13, 11, 13, 10, 9, 19, -0.1461538461538462, 38.400000000000006, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.76936243046641
# Specificity : 0.5347100175746925
# Accuracy: 0.653587686971602
# ROC 0.652036224021
# TP 7192 FP 4236 TN 4868 FN 2156
#
#
#
# None
# Cross: Validation: [ 0.63483633  0.55197269  0.63440277  0.61490515  0.6303523 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.7978225737858298
# Accuracy: 0.796476331988962
# ROC 0.411106408844
# TP 1 FP 4754 TN 18760 FN 40
#
#
#
# None
# y ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 9, 7, 9, 9, 2, 10, 20, 9, 8, 7, 12, 10, -1.9615384615384615, 57.407692307692315, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143748
# Test Data Points: 35937
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3478118520135327
# Specificity : 0.9036005079554792
# Accuracy: 0.7618888610624148
# ROC 0.625706179985
# TP 3187 FP 2581 TN 24193 FN 5976
#
#
#
# None
# Cross: Validation: [ 0.75557905  0.76682064  0.75565573  0.75709595  0.76071349]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 362 TN 23152 FN 41
#
#
#
# None
# x ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 11, 20, 18, 3, 12, 10, 1, 4, 10, 10, 2, 1, 0.5538461538461539, 44.06923076923078, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143817
# Test Data Points: 35955
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3378275524627596
# Specificity : 0.9075042977801031
# Accuracy: 0.7617855652899458
# ROC 0.622665925121
# TP 3107 FP 2475 TN 24283 FN 6090
#
#
#
# None
# Cross: Validation: [ 0.75691837  0.76131275  0.757864    0.75515937  0.76619475]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 334 TN 23180 FN 41
#
#
#
# None
# y ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 10, 3, 19, 19, 11, 10, 20, 2, 13, 10, 17, 19, -0.4153846153846154, 38.861538461538466, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143793
# Test Data Points: 35949
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.28314435237679897
# Specificity : 0.9442431937857116
# Accuracy: 0.7755709477315085
# ROC 0.613693773081
# TP 2597 FP 1493 TN 25284 FN 6575
#
#
#
# None
# Cross: Validation: [ 0.75826866  0.76308103  0.75145345  0.76173918  0.76757448]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.9238751382155311
# Accuracy: 0.922309488431331
# ROC 0.474132691059
# TP 1 FP 1790 TN 21724 FN 40
#
#
#
# None
# x ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 2, 2, 10, 1, 1, 5, 8, 11, 17, 9, 17, 17, -1.3923076923076925, 71.80000000000001, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143796
# Test Data Points: 35949
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.26373626373626374
# Specificity : 0.9443157186635772
# Accuracy: 0.7703134996801023
# ROC 0.6040259912
# TP 2424 FP 1490 TN 25268 FN 6767
#
#
#
# None
# Cross: Validation: [ 0.76834492  0.74280946  0.76586275  0.7507789   0.76593969]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1656 TN 21858 FN 41
#
#
#
# None
# y ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 19, 20, 8, 2, 2, 10, 2, 1, 17, 2, 11, 10, -0.4692307692307693, 36.31538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143744
# Test Data Points: 35936
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.268308631211857
# Specificity : 0.940134529147982
# Accuracy: 0.7685886019590383
# ROC 0.60422158018
# TP 2462 FP 1602 TN 25158 FN 6714
#
#
#
# None
# Cross: Validation: [ 0.75621226  0.75921752  0.76213268  0.75725616  0.76168081]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2446 TN 21068 FN 41
#
#
#
# None
# x ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 9, 20, 4, 1, 10, 10, 20, 14, 13, 14, 20, 19, 0.21538461538461537, 49.12307692307692, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143662
# Test Data Points: 35916
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2698706099815157
# Specificity : 0.9434484823533815
# Accuracy: 0.7709655863681925
# ROC 0.606659546167
# TP 2482 FP 1511 TN 25208 FN 6715
#
#
#
# None
# Cross: Validation: [ 0.75072391  0.76634369  0.76985188  0.75868022  0.75525546]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2484 TN 21030 FN 41
#
#
#
# None
# y ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 17, 18, 10, 14, 10, 10, 11, 3, 17, 0, 0, 0, -1.1, 155.66, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143769
# Test Data Points: 35943
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.23846823324630112
# Specificity : 0.9544316100332698
# Accuracy: 0.7713323873911471
# ROC 0.59644992164
# TP 2192 FP 1219 TN 25532 FN 7000
#
#
#
# None
# Cross: Validation: [ 0.76899535  0.75928554  0.76323624  0.7608369   0.75941126]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.8924895806753423
# Accuracy: 0.8909785608151136
# ROC 0.458439912289
# TP 1 FP 2528 TN 20986 FN 40
#
#
#
# None
# x ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 16, 3, 14, 1, 17, 10, 2, 2, 4, 19, 3, 1, 0.1538461538461538, 43.03076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143702
# Test Data Points: 35926
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.33521677713788983
# Specificity : 0.9162144968753508
# Accuracy: 0.7673829538495797
# ROC 0.625715637007
# TP 3085 FP 2239 TN 24484 FN 6118
#
#
#
# None
# Cross: Validation: [ 0.76214997  0.76607471  0.76281801  0.75724426  0.72960334]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.8833035638343115
# Accuracy: 0.8818085332201231
# ROC 0.453846903868
# TP 1 FP 2744 TN 20770 FN 40
#
#
#
# None
# y ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [6, 5, 20, 4, 10, 5, 10, 15, 15, 1, 3, 20, 12, 0.6615384615384615, 45.9923076923077, 0.38461538461538464]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143701
# Test Data Points: 35926
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2811039878300554
# Specificity : 0.9356359690154549
# Accuracy: 0.7679674887268274
# ROC 0.608369978423
# TP 2587 FP 1720 TN 25003 FN 6616
#
#
#
# None
# Cross: Validation: [ 0.75251907  0.75950565  0.76398708  0.76030619  0.76227592]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.9878370332567832
# Accuracy: 0.9861600509445978
# ROC 0.50611363858
# TP 1 FP 286 TN 23228 FN 40
#
#
#
# None
# x ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 13, 7, 12, 14, 19, 10, 8, 9, 16, 20, 12, 20, -0.6076923076923075, 52.11538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143713
# Test Data Points: 35929
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2714425481030547
# Specificity : 0.9381967826412271
# Accuracy: 0.7674858749199811
# ROC 0.604819665372
# TP 2497 FP 1652 TN 25078 FN 6702
#
#
#
# None
# Cross: Validation: [ 0.76770854  0.75977623  0.74800301  0.75818303  0.76546887]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 202 TN 23312 FN 41
#
#
#
# None
# y near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 5, 3, 10, 9, 12, 10, 9, 18, 7, 3, 17, 8, -0.4000000000000001, 80.17692307692309, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5528455284552846
# Specificity : 0.8067882249560633
# Accuracy: 0.6781378712334706
# ROC 0.679816876706
# TP 5168 FP 1759 TN 7345 FN 4180
#
#
#
# None
# Cross: Validation: [ 0.60931064  0.71406894  0.648385    0.65875339  0.63387534]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.7052819596835928
# Accuracy: 0.7057524941625982
# ROC 0.840445857891
# TP 40 FP 6930 TN 16584 FN 1
#
#
#
# None
# x near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 7, 5, 17, 8, 1, 10, 10, 20, 10, 10, 10, 11, -0.8692307692307693, 95.76153846153848, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5206461275139067
# Specificity : 0.8000878734622144
# Accuracy: 0.6585194016908736
# ROC 0.660367000488
# TP 4867 FP 1820 TN 7284 FN 4481
#
#
#
# None
# Cross: Validation: [ 0.64085194  0.72653371  0.6514199   0.59289973  0.66813008]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.7647359020158203
# Accuracy: 0.7651029505412863
# ROC 0.870172829057
# TP 40 FP 5532 TN 17982 FN 1
#
#
#
# None
# y near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 10, 10, 10, 10, 10, 10, 10, 10, 2, 10, 8, -0.40769230769230774, 127.75384615384617, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6339323919554986
# Specificity : 0.7348418277680141
# Accuracy: 0.6837199219596791
# ROC 0.684387109862
# TP 5926 FP 2414 TN 6690 FN 3422
#
#
#
# None
# Cross: Validation: [ 0.62833297  0.66751572  0.67201387  0.68168022  0.64195122]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.5059964276601174
# Accuracy: 0.5068562937805137
# ROC 0.75299821383
# TP 41 FP 11616 TN 11898 FN 0
#
#
#
# None
# x near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 2, 3, 6, 17, 13, 10, 11, 11, 10, 17, 2, 8, -0.5153846153846154, 99.16153846153848, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6957637997432606
# Specificity : 0.6761862917398945
# Accuracy: 0.6861044873184479
# ROC 0.685975045742
# TP 6504 FP 2948 TN 6156 FN 2844
#
#
#
# None
# Cross: Validation: [ 0.62562324  0.69081942  0.66583568  0.63121951  0.63284553]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.43820702560176916
# Accuracy: 0.43918488643600084
# ROC 0.719103512801
# TP 41 FP 13210 TN 10304 FN 0
#
#
#
# None
# y near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 17, 9, 2, 9, 7, 10, 16, 10, 17, 1, 7, 19, -2.607692307692307, 10.984615384615388, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7349165596919127
# Specificity : 0.6499340949033392
# Accuracy: 0.6929872100585303
# ROC 0.692425327298
# TP 6870 FP 3187 TN 5917 FN 2478
#
#
#
# None
# Cross: Validation: [ 0.62817039  0.66117494  0.71146759  0.61550136  0.64574526]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8719911542060049
# Accuracy: 0.8722139673105498
# ROC 0.935995577103
# TP 41 FP 3010 TN 20504 FN 0
#
#
#
# None
# x near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 1, 20, 2, 2, 5, 10, 11, 4, 14, 20, 15, 13, 0.9461538461538462, 55.776923076923076, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6815361574668378
# Specificity : 0.7177065026362038
# Accuracy: 0.69938218079341
# ROC 0.699621330052
# TP 6371 FP 2570 TN 6534 FN 2977
#
#
#
# None
# Cross: Validation: [ 0.58665727  0.62752005  0.69932799  0.66921409  0.59067751]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8962320319809475
# Accuracy: 0.8964126512417746
# ROC 0.94811601599
# TP 41 FP 2440 TN 21074 FN 0
#
#
#
# None
# y near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 5, 10, 7, 10, 17, 10, 17, 10, 17, 10, 0, 0, -1.763636363636364, 181.45454545454544, 0.09090909090909091]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.683461703038083
# Specificity : 0.7158391915641477
# Accuracy: 0.6994363754606546
# ROC 0.699650447301
# TP 6389 FP 2587 TN 6517 FN 2959
#
#
#
# None
# Cross: Validation: [ 0.6087687   0.69174073  0.70778235  0.6901897   0.63815718]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.24844773326528877
# Accuracy: 0.24975589046911484
# ROC 0.624223866633
# TP 41 FP 17672 TN 5842 FN 0
#
#
#
# None
# x near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 20, 2, 20, 6, 13, 10, 10, 11, 10, 12, 2, 8, -0.076923076923077, 61.10000000000001, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7049636285836542
# Specificity : 0.680140597539543
# Accuracy: 0.6927162367223065
# ROC 0.692552113062
# TP 6590 FP 2912 TN 6192 FN 2758
#
#
#
# None
# Cross: Validation: [ 0.60269889  0.72929764  0.71179276  0.68411924  0.64460705]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.2383261035978566
# Accuracy: 0.23965187858204204
# ROC 0.619163051799
# TP 41 FP 17910 TN 5604 FN 0
#
#
#
# None
# y near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 4, 5, 19, 3, 18, 10, 18, 1, 18, 10, 2, 9, -1.0076923076923079, 25.707692307692305, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7834830979888746
# Specificity : 0.5419595782073814
# Accuracy: 0.6643182310860611
# ROC 0.662721338098
# TP 7324 FP 4170 TN 4934 FN 2024
#
#
#
# None
# Cross: Validation: [ 0.63391502  0.6666486   0.64898114  0.68547425  0.64086721]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.45989623203198093
# Accuracy: 0.46083634047972827
# ROC 0.729948116016
# TP 41 FP 12700 TN 10814 FN 0
#
#
#
# None
# x near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 7, 19, 18, 1, 19, 10, 9, 9, 9, 9, 20, 9, -2.8692307692307697, 117.34615384615384, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7075310226786479
# Specificity : 0.6739894551845342
# Accuracy: 0.6909820073704748
# ROC 0.690760238932
# TP 6614 FP 2968 TN 6136 FN 2734
#
#
#
# None
# Cross: Validation: [ 0.59971819  0.68642966  0.57554737  0.60401084  0.6604336 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3853023730543506
# Accuracy: 0.3863723201018892
# ROC 0.692651186527
# TP 41 FP 14454 TN 9060 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos.csv", "T")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos.csv", "T")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 8, 12, 10, 3, 3, 10, 1, 9, 3, 20, 12, 9, 0.26153846153846155, -2.3692307692307693, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.017482517482517484
# Specificity : 0.9963848652873788
# Accuracy: 0.8175320915933002
# ROC 0.506933691385
# TP 160 FP 148 TN 40791 FN 8992
#
#
#
# None
# Cross: Validation: [ 0.81623812  0.81583518  0.81635424  0.81403474  0.81643043]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 6 TN 46491 FN 1233
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 2, 4, 3, 1, 11, 10, 11, 1, 11, 10, 11, 1, -0.16153846153846158, 99.93076923076923, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.017164179104477612
# Specificity : 0.9967576330721427
# Accuracy: 0.8133197580403665
# ROC 0.506960906088
# TP 161 FP 132 TN 40579 FN 9219
#
#
#
# None
# Cross: Validation: [ 0.8169568   0.80902757  0.81633427  0.8158315   0.81563186]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 2 TN 46495 FN 1233
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 14, 5, 19, 12, 20, 10, 11, 18, 10, 5, 19, 18, -0.13846153846153839, 55.48461538461538, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.059986959356661596
# Specificity : 0.9894103548631661
# Accuracy: 0.8186700205625761
# ROC 0.52469865711
# TP 552 FP 433 TN 40456 FN 8650
#
#
#
# None
# Cross: Validation: [ 0.81627805  0.81605478  0.81667365  0.81443402  0.81599122]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.004866180048661801
# Specificity : 0.9856334817300041
# Accuracy: 0.9602975068091347
# ROC 0.495249830889
# TP 6 FP 668 TN 45829 FN 1227
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 11, 10, 10, 10, 17, 10, 12, 11, 12, 2, 16, 11, -0.6923076923076924, 137.9923076923077, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04331182325276168
# Specificity : 0.9911839406075998
# Accuracy: 0.8181709289093849
# ROC 0.51724788193
# TP 396 FP 361 TN 40587 FN 8747
#
#
#
# None
# Cross: Validation: [ 0.81350315  0.81577529  0.81585514  0.81577161  0.81595129]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.038929440389294405
# Specificity : 0.9875475837150784
# Accuracy: 0.9630421118793212
# ROC 0.513238512052
# TP 48 FP 579 TN 45918 FN 1185
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 10, 8, 17, 10, 10, 10, 11, 12, 1, 3, 2, 7, -0.6153846153846155, 129.56153846153848, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0688750409970482
# Specificity : 0.9871043376318874
# Accuracy: 0.8194286398754267
# ROC 0.527989689314
# TP 630 FP 528 TN 40416 FN 8517
#
#
#
# None
# Cross: Validation: [ 0.81605845  0.81609471  0.81743227  0.81591136  0.81573168]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.21573398215733983
# Specificity : 0.9521689571370195
# Accuracy: 0.9331447726796565
# ROC 0.583951469647
# TP 266 FP 2224 TN 44273 FN 967
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 10, 7, 3, 9, 17, 10, 12, 15, 2, 1, 3, 8, -0.7384615384615386, 107.79230769230767, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.060767474725513644
# Specificity : 0.9885307639636115
# Accuracy: 0.8181509652432573
# ROC 0.524649119345
# TP 559 FP 469 TN 40423 FN 8640
#
#
#
# None
# Cross: Validation: [ 0.81557933  0.81609471  0.81563554  0.81684967  0.81601118]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.10381184103811841
# Specificity : 0.9845151300083876
# Accuracy: 0.9617640896710664
# ROC 0.544163485523
# TP 128 FP 720 TN 45777 FN 1105
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 10, 7, 8, 3, 10, 19, 3, 1, 2, 8, 3, -0.01538461538461533, 20.884615384615383, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05063561585300716
# Specificity : 0.9900319175055242
# Accuracy: 0.81447765067577
# ROC 0.520333766679
# TP 474 FP 406 TN 40324 FN 8887
#
#
#
# None
# Cross: Validation: [ 0.81623812  0.81645405  0.81631431  0.816111    0.81619086]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0008110300081103001
# Specificity : 1.0
# Accuracy: 0.9741881416300021
# ROC 0.500405515004
# TP 1 FP 0 TN 46497 FN 1232
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 3, 12, 3, 3, 10, 10, 19, 17, 3, 19, 1, 10, 0.12307692307692307, 18.24615384615385, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.033502100614025636
# Specificity : 0.994241325230347
# Accuracy: 0.8161945259627478
# ROC 0.513871712922
# TP 311 FP 235 TN 40573 FN 8972
#
#
#
# None
# Cross: Validation: [ 0.81681706  0.81605478  0.81587511  0.81647035  0.81722899]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0008110300081103001
# Specificity : 0.9991182226810332
# Accuracy: 0.9733291430965849
# ROC 0.499964626345
# TP 1 FP 41 TN 46456 FN 1232
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 4, 19, 18, 3, 19, 10, 13, 4, 19, 8, 3, 18, -0.13076923076923078, 24.04615384615385, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04237653655380634
# Specificity : 0.9900041649312786
# Accuracy: 0.8145575053402807
# ROC 0.516190350743
# TP 393 FP 408 TN 40409 FN 8881
#
#
#
# None
# Cross: Validation: [ 0.81639783  0.81627438  0.81513645  0.81645039  0.81643043]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0008110300081103001
# Specificity : 0.9988386347506291
# Accuracy: 0.9730567777079405
# ROC 0.499824832379
# TP 1 FP 54 TN 46443 FN 1232
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 20, 11, 18, 10, 13, 10, 20, 3, 11, 11, 2, 17, -0.7384615384615386, 53.67692307692308, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04218040233614536
# Specificity : 0.9924592973436162
# Accuracy: 0.8170529636062367
# ROC 0.51731984984
# TP 390 FP 308 TN 40537 FN 8856
#
#
#
# None
# Cross: Validation: [ 0.81639783  0.81567547  0.81693318  0.81730884  0.81601118]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0008110300081103001
# Specificity : 0.999096715917156
# Accuracy: 0.9733081919128431
# ROC 0.499953872963
# TP 1 FP 42 TN 46455 FN 1232
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 9, 15, 14, 7, 5, 10, 13, 2, 19, 12, 3, 3, 0.9461538461538462, 2.7, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331764
# Test Data Points: 82942
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6920440752992694
# Specificity : 0.875449014001906
# Accuracy: 0.7825347833425768
# ROC 0.783746544651
# TP 29079 FP 5097 TN 35826 FN 12940
#
#
#
# None
