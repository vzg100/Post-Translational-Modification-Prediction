# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 162268
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 4 TN 17717 FN 309
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 45 TN 62472 FN 3378
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 342566
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17711 FN 319
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 318312
# Test Data Points: 35368
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8213164354626934
# Specificity : 0.9312643549380987
# Accuracy: 0.8768095453517304
# ROC 0.8762903952
# TP 14387 FP 1227 TN 16624 FN 3130
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.08703374777975133
# Specificity : 0.942095749956012
# Accuracy: 0.8982623871310418
# ROC 0.514564748868
# TP 294 FP 3620 TN 58897 FN 3084
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 498610
# Test Data Points: 35368
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8299300217964897
# Specificity : 0.9074941451990632
# Accuracy: 0.8692603483374802
# ROC 0.868712083498
# TP 14469 FP 1659 TN 16275 FN 2965
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.1015393724097099
# Specificity : 0.9321624518131069
# Accuracy: 0.889581910615373
# ROC 0.516850912111
# TP 343 FP 4241 TN 58276 FN 3035
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284443
# Test Data Points: 31605
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8776958162058675
# Specificity : 0.7506861187346526
# Accuracy: 0.8220534725518114
# ROC 0.81419096747
# TP 15587 FP 3452 TN 10394 FN 2172
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.40941385435168737
# Specificity : 0.7508357726698338
# Accuracy: 0.7333333333333333
# ROC 0.580124813511
# TP 1383 FP 15577 TN 46940 FN 1995
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 464804
# Test Data Points: 31612
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9643915223336372
# Specificity : 0.6037695590327169
# Accuracy: 0.8039984815892699
# ROC 0.784080540683
# TP 16927 FP 5571 TN 8489 FN 625
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.5307874481941978
# Specificity : 0.6007166050834173
# Accuracy: 0.5971318005918507
# ROC 0.565752026639
# TP 1793 FP 24962 TN 37555 FN 1585
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8449367088607594
# Specificity : 0.33753943217665616
# Accuracy: 0.5908372827804107
# ROC 0.591238070519
# TP 267 FP 210 TN 107 FN 49
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.8703374777975134
# Specificity : 0.2900331109938097
# Accuracy: 0.31978147052128386
# ROC 0.580185294396
# TP 2940 FP 44385 TN 18132 FN 438
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6139240506329114
# Specificity : 0.5709779179810726
# Accuracy: 0.5924170616113744
# ROC 0.592450984307
# TP 194 FP 136 TN 181 FN 122
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.5985790408525755
# Specificity : 0.5735240014715998
# Accuracy: 0.5748084073146673
# ROC 0.586051521162
# TP 2022 FP 26662 TN 35855 FN 1356
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 157139
# Test Data Points: 17460
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 9 TN 17140 FN 311
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 3 TN 62514 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 337437
# Test Data Points: 17460
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.003067484662576687
# Specificity : 0.9997081825609898
# Accuracy: 0.9810996563573883
# ROC 0.501387833612
# TP 1 FP 5 TN 17129 FN 325
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 1.0
# Accuracy: 0.9487518021094165
# ROC 0.500148016578
# TP 1 FP 0 TN 62517 FN 3377
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8922558922558923
# Specificity : 0.7202380952380952
# Accuracy: 0.8009478672985783
# ROC 0.806246993747
# TP 265 FP 94 TN 242 FN 32
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.9215512137359384
# Specificity : 0.08186573252075435
# Accuracy: 0.12491084300781546
# ROC 0.501708473128
# TP 3113 FP 57399 TN 5118 FN 265
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9019607843137255
# Specificity : 0.599388379204893
# Accuracy: 0.7456556082148499
# ROC 0.750674581759
# TP 276 FP 131 TN 196 FN 30
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.9245115452930728
# Specificity : 0.05632068077482925
# Accuracy: 0.10082707337430762
# ROC 0.490416113034
# TP 3123 FP 58996 TN 3521 FN 255
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 11334
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1210 FN 50
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 23928
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 1201 FN 58
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21658
# Test Data Points: 2407
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9084096586178185
# Specificity : 0.8283582089552238
# Accuracy: 0.868300789364354
# ROC 0.868383933787
# TP 1091 FP 207 TN 999 FN 110
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8278472399421621
# Accuracy: 0.8281044364253873
# ROC 0.90172849802
# TP 40 FP 4048 TN 19466 FN 1
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 34252
# Test Data Points: 2407
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9691252144082333
# Specificity : 0.7993553585817889
# Accuracy: 0.8815953469048609
# ROC 0.884240286495
# TP 1130 FP 249 TN 992 FN 36
#
#
#
# None
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8098154291060645
# Accuracy: 0.8101464657185311
# ROC 0.904907714553
# TP 41 FP 4472 TN 19042 FN 0
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 17052
# Test Data Points: 1895
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9352459016393443
# Specificity : 0.8903703703703704
# Accuracy: 0.9192612137203167
# ROC 0.912808136005
# TP 1141 FP 74 TN 601 FN 79
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.834141362592498
# Accuracy: 0.8343876034812142
# ROC 0.904875559345
# TP 40 FP 3900 TN 19614 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 29639
# Test Data Points: 1894
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9534510433386838
# Specificity : 0.875
# Accuracy: 0.926610348468849
# ROC 0.914225521669
# TP 1188 FP 81 TN 567 FN 58
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8214680615803351
# Accuracy: 0.821736361706644
# ROC 0.898538908839
# TP 40 FP 4198 TN 19316 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8392857142857143
# Specificity : 0.14035087719298245
# Accuracy: 0.48672566371681414
# ROC 0.489818295739
# TP 47 FP 49 TN 8 FN 9
#
#
#
# None
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.22820447393042442
# Accuracy: 0.2295478666949692
# ROC 0.614102236965
# TP 41 FP 18148 TN 5366 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.125
# Specificity : 0.8070175438596491
# Accuracy: 0.4690265486725664
# ROC 0.46600877193
# TP 7 FP 11 TN 46 FN 49
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.8637407501913753
# Accuracy: 0.8622797707493102
# ROC 0.444065497047
# TP 1 FP 3204 TN 20310 FN 40
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 10377
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1094 FN 60
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 22971
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 14 TN 1087 FN 53
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 374 TN 23140 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.423728813559322
# Specificity : 0.8888888888888888
# Accuracy: 0.6460176991150443
# ROC 0.656308851224
# TP 25 FP 6 TN 48 FN 34
#
#
#
# None
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.21842306710895637
# Accuracy: 0.21978348545956272
# ROC 0.609211533554
# TP 41 FP 18378 TN 5136 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3559322033898305
# Specificity : 0.9259259259259259
# Accuracy: 0.6283185840707964
# ROC 0.640929064658
# TP 21 FP 4 TN 50 FN 38
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.5401037679680191
# Accuracy: 0.53920611335173
# ROC 0.282247005935
# TP 1 FP 10814 TN 12700 FN 40
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58739
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 6374 FN 152
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 124005
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.006329113924050633
# Specificity : 0.9981158737635422
# Accuracy: 0.9741075532403861
# ROC 0.502222493844
# TP 1 FP 12 TN 6357 FN 157
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 84 TN 46413 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 114817
# Test Data Points: 12758
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8899671310064173
# Specificity : 0.8710943633223426
# Accuracy: 0.8805455400532999
# ROC 0.880530747164
# TP 5686 FP 821 TN 5548 FN 703
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.31873479318734793
# Specificity : 0.8813686904531475
# Accuracy: 0.8668342761366017
# ROC 0.60005174182
# TP 393 FP 5516 TN 40981 FN 840
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 180083
# Test Data Points: 12758
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8671765256750429
# Specificity : 0.9004881121083294
# Accuracy: 0.883759209907509
# ROC 0.883832318892
# TP 5556 FP 632 TN 5719 FN 851
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.1897810218978102
# Specificity : 0.9044239413295482
# Accuracy: 0.8859627068929394
# ROC 0.547102481614
# TP 234 FP 4444 TN 42053 FN 999
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 98378
# Test Data Points: 10931
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9486692015209125
# Specificity : 0.8101320632171466
# Accuracy: 0.8901289909431891
# ROC 0.879400632369
# TP 5988 FP 877 TN 3742 FN 324
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.36658556366585565
# Specificity : 0.7869970105598211
# Accuracy: 0.776136601717997
# ROC 0.576791287113
# TP 452 FP 9904 TN 36593 FN 781
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 163653
# Test Data Points: 10932
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9307400379506642
# Specificity : 0.8776041666666666
# Accuracy: 0.9083424807903403
# ROC 0.904172102309
# TP 5886 FP 564 TN 4044 FN 438
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.25547445255474455
# Specificity : 0.8581843989934834
# Accuracy: 0.8426147077309868
# ROC 0.556829425774
# TP 315 FP 6594 TN 39903 FN 918
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.34210526315789475
# Specificity : 0.7733333333333333
# Accuracy: 0.5562913907284768
# ROC 0.557719298246
# TP 52 FP 34 TN 116 FN 100
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.5531224655312247
# Specificity : 0.5374755360560897
# Accuracy: 0.5378797402053216
# ROC 0.545299000794
# TP 682 FP 21506 TN 24991 FN 551
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4782608695652174
# Specificity : 0.6950354609929078
# Accuracy: 0.5794701986754967
# ROC 0.586648165279
# TP 77 FP 43 TN 98 FN 84
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.5944849959448499
# Specificity : 0.7362195410456589
# Accuracy: 0.7325581395348837
# ROC 0.665352268495
# TP 733 FP 12265 TN 34232 FN 500
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 55928
# Test Data Points: 6215
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.006711409395973154
# Specificity : 0.9995054401582592
# Accuracy: 0.9757039420756235
# ROC 0.503108424777
# TP 1 FP 3 TN 6063 FN 148
#
#
#
# None
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 121194
# Test Data Points: 6215
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.013986013986013986
# Specificity : 0.9991765480895916
# Accuracy: 0.9765084473049075
# ROC 0.506581281038
# TP 2 FP 5 TN 6067 FN 141
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.0008110300081103001
# Specificity : 0.9982364453620663
# Accuracy: 0.9724701445631678
# ROC 0.499523737685
# TP 1 FP 82 TN 46415 FN 1232
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7687074829931972
# Specificity : 0.8129032258064516
# Accuracy: 0.7913907284768212
# ROC 0.7908053544
# TP 113 FP 29 TN 126 FN 34
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.851581508515815
# Specificity : 0.17059165107426286
# Accuracy: 0.18818353236957888
# ROC 0.511086579795
# TP 1050 FP 38565 TN 7932 FN 183
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8363636363636363
# Specificity : 0.6861313868613139
# Accuracy: 0.7682119205298014
# ROC 0.761247511612
# TP 138 FP 43 TN 94 FN 27
#
#
#
# None
# Benchmark Results
# Sensitivity: 0.916463909164639
# Specificity : 0.1999268770028174
# Accuracy: 0.21843704169285566
# ROC 0.558195393084
# TP 1130 FP 37201 TN 9296 FN 103
#
#
#
# None
