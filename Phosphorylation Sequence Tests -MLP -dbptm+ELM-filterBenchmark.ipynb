# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data="Data/Benchmarks/phos.csv")
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9315709312445605
# Specificity : 0.9980439619550601
# Accuracy: 0.9858457607154978
# ROC 0.9648074466
# TP 8563 FP 80 TN 40819 FN 629
#
#
#
# None
# Cross: Validation: [ 0.98528707  0.98618514  0.98502725  0.9843881   0.98582551]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.931402110704286
# Specificity : 0.9974022791324593
# Accuracy: 0.9851669960671577
# ROC 0.964402194918
# TP 8649 FP 106 TN 40699 FN 637
#
#
#
# None
# Cross: Validation: [ 0.98514733  0.9853866   0.98588569  0.98548612  0.98532641]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 3 TN 62514 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.920973170973171
# Specificity : 0.98370761778952
# Accuracy: 0.9525233138948352
# ROC 0.952340394381
# TP 37211 FP 666 TN 40212 FN 3193
#
#
#
# None
# Cross: Validation: [ 0.96107427  0.94605202  0.94351694  0.94138852  0.93259187]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.004440497335701598
# Specificity : 0.9933778012380633
# Accuracy: 0.942681538811746
# ROC 0.498909149287
# TP 15 FP 414 TN 62103 FN 3363
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9225929503851775
# Specificity : 0.9890249566131358
# Accuracy: 0.9560296252552841
# ROC 0.955808953499
# TP 37246 FP 449 TN 40462 FN 3125
#
#
#
# None
# Cross: Validation: [ 0.95787557  0.95012426  0.94464881  0.94637123  0.93754998]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.014209591474245116
# Specificity : 0.9954572356319081
# Accuracy: 0.9451551711055467
# ROC 0.504833413553
# TP 48 FP 284 TN 62233 FN 3330
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323744
# Test Data Points: 80937
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9394286853781345
# Specificity : 0.9965947230456406
# Accuracy: 0.9682592633776889
# ROC 0.968011704212
# TP 37688 FP 139 TN 40680 FN 2430
#
#
#
# None
# Cross: Validation: [ 0.96955657  0.96718395  0.96646733  0.96816003  0.96636849]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.012137359384251036
# Specificity : 0.9972967352880017
# Accuracy: 0.9467941421959177
# ROC 0.504717047336
# TP 41 FP 169 TN 62348 FN 3337
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574179
# Test Data Points: 80932
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.939499912572128
# Specificity : 0.9965035819946698
# Accuracy: 0.9683067266347056
# ROC 0.968001747283
# TP 37611 FP 143 TN 40756 FN 2422
#
#
#
# None
# Cross: Validation: [ 0.96939444  0.96888708  0.96851639  0.96841754  0.9684299 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9985443959243085
# Accuracy: 0.9473708172091965
# ROC 0.49942021454
# TP 1 FP 91 TN 62426 FN 3377
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9360290971330766
# Specificity : 0.9600175746924429
# Accuracy: 0.9478647301105572
# ROC 0.948023335913
# TP 8750 FP 364 TN 8740 FN 598
#
#
#
# None
# Cross: Validation: [ 0.96249729  0.96298504  0.96325602  0.96281843  0.96216802]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.07282415630550622
# Specificity : 0.974119039621223
# Accuracy: 0.9279156233401624
# ROC 0.523471597963
# TP 246 FP 1618 TN 60899 FN 3132
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9348523748395379
# Specificity : 0.9941783831282952
# Accuracy: 0.96412313028398
# ROC 0.964515378984
# TP 8739 FP 53 TN 9051 FN 609
#
#
#
# None
# Cross: Validation: [ 0.96368957  0.96157598  0.9633644   0.96168022  0.96314363]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.013025458851391355
# Specificity : 0.9986563654685925
# Accuracy: 0.9481296001214052
# ROC 0.50584091216
# TP 44 FP 84 TN 62433 FN 3334
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187448
# Test Data Points: 46862
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9313346228239845
# Specificity : 0.9989615507508787
# Accuracy: 0.9855319875378772
# ROC 0.965148086787
# TP 8667 FP 39 TN 37517 FN 639
#
#
#
# None
# Cross: Validation: [ 0.9858097   0.98625782  0.9861935   0.98469943  0.98615053]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 3 TN 62514 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437880
# Test Data Points: 46857
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9284409584183948
# Specificity : 0.999520639147803
# Accuracy: 0.9854023945194955
# ROC 0.963980798783
# TP 8641 FP 18 TN 37532 FN 666
#
#
#
# None
# Cross: Validation: [ 0.98518898  0.98617069  0.98531703  0.98572221  0.9864265 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9999840043508166
# Accuracy: 0.9487366264511723
# ROC 0.500140018753
# TP 1 FP 1 TN 62516 FN 3377
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9620239623448866
# Specificity : 0.9635325131810193
# Accuracy: 0.9627682636028615
# ROC 0.962778237763
# TP 8993 FP 332 TN 8772 FN 355
#
#
#
# None
# Cross: Validation: [ 0.96390635  0.96818773  0.9634186   0.96585366  0.87084011]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.3981645944345767
# Specificity : 0.5914551242062159
# Accuracy: 0.5815463995750816
# ROC 0.49480985932
# TP 1345 FP 25541 TN 36976 FN 2033
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9566752246469833
# Specificity : 0.9828646748681898
# Accuracy: 0.9695967916756991
# ROC 0.969769949758
# TP 8943 FP 156 TN 8948 FN 405
#
#
#
# None
# Cross: Validation: [ 0.96423152  0.97344461  0.96005853  0.96433604  0.89279133]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.27856719952634695
# Specificity : 0.6887406625397892
# Accuracy: 0.6677137870855149
# ROC 0.483653931033
# TP 941 FP 19459 TN 43058 FN 2437
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data="Data/Benchmarks/phos.csv")
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.017857142857142856
# Specificity : 0.997513468711148
# Accuracy: 0.954059405940594
# ROC 0.507685305784
# TP 2 FP 6 TN 2407 FN 110
#
#
#
# None
# Cross: Validation: [ 0.9517023   0.95287129  0.95405941  0.9548336   0.95047544]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 22723
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05263157894736842
# Specificity : 0.997096640398175
# Accuracy: 0.9544554455445544
# ROC 0.524864109673
# TP 6 FP 7 TN 2404 FN 108
#
#
#
# None
# Cross: Validation: [ 0.9517023   0.95366337  0.95326733  0.95324881  0.95285261]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19375
# Test Data Points: 4844
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.940149625935162
# Specificity : 0.7854799015586547
# Accuracy: 0.8623038810900082
# ROC 0.862814763747
# TP 2262 FP 523 TN 1915 FN 144
#
#
#
# None
# Cross: Validation: [ 0.72569659  0.75        0.72295623  0.71381375  0.72991947]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8203623373309518
# Accuracy: 0.8206750159201868
# ROC 0.910181168665
# TP 41 FP 4224 TN 19290 FN 0
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 31999
# Test Data Points: 4844
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9187944746755965
# Specificity : 0.8635437881873728
# Accuracy: 0.8907927332782825
# ROC 0.891169131431
# TP 2195 FP 335 TN 2120 FN 194
#
#
#
# None
# Cross: Validation: [ 0.72363261  0.75371594  0.73720066  0.72620277  0.71030353]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8870460151399167
# Accuracy: 0.8872001698153258
# ROC 0.931327885619
# TP 40 FP 2656 TN 20858 FN 1
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19248
# Test Data Points: 4813
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9157631359466222
# Specificity : 0.8579710144927536
# Accuracy: 0.8867650114273842
# ROC 0.88686707522
# TP 2196 FP 343 TN 2072 FN 202
#
#
#
# None
# Cross: Validation: [ 0.83918554  0.8981924   0.8932059   0.90875078  0.89295365]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8708003742451306
# Accuracy: 0.8709828061982594
# ROC 0.923205065171
# TP 40 FP 3038 TN 20476 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 31872
# Test Data Points: 4813
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9311926605504587
# Specificity : 0.8426501035196687
# Accuracy: 0.8867650114273842
# ROC 0.886921382035
# TP 2233 FP 380 TN 2035 FN 165
#
#
#
# None
# Cross: Validation: [ 0.84728859  0.89736131  0.89029711  0.89170651  0.87362295]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8572765161180573
# Accuracy: 0.8574824877945234
# ROC 0.916443136108
# TP 40 FP 3356 TN 20158 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.711864406779661
# Specificity : 0.37815126050420167
# Accuracy: 0.5443037974683544
# ROC 0.545007833642
# TP 84 FP 74 TN 45 FN 34
#
#
#
# None
# Cross: Validation: [ 0.55882353  0.55084746  0.56779661  0.56779661  0.55508475]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.5364463723739049
# Accuracy: 0.5372107832731904
# ROC 0.756028064236
# TP 40 FP 10900 TN 12614 FN 1
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13569
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5084745762711864
# Specificity : 0.5882352941176471
# Accuracy: 0.5485232067510548
# ROC 0.548354935194
# TP 60 FP 49 TN 70 FN 58
#
#
#
# None
# Cross: Validation: [ 0.49579832  0.51694915  0.55508475  0.52542373  0.56779661]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6175044654248533
# Accuracy: 0.6181702398641478
# ROC 0.808752232712
# TP 41 FP 8994 TN 14520 FN 0
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9221
# Test Data Points: 2306
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 2191 FN 115
#
#
#
# None
# Cross: Validation: [ 0.94928479  0.94750542  0.9483731   0.94663774  0.9483731 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 21856
# Test Data Points: 2308
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06956521739130435
# Specificity : 0.9949840401276789
# Accuracy: 0.9488734835355286
# ROC 0.532274628759
# TP 8 FP 11 TN 2182 FN 107
#
#
#
# None
# Cross: Validation: [ 0.9462971   0.94844021  0.94800693  0.94887348  0.9479844 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 40 TN 23474 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5169491525423728
# Specificity : 0.6974789915966386
# Accuracy: 0.6075949367088608
# ROC 0.60721407207
# TP 61 FP 36 TN 83 FN 57
#
#
#
# None
# Cross: Validation: [ 0.63865546  0.66525424  0.63983051  0.61864407  0.65677966]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.33724589606192057
# Accuracy: 0.3383994905540225
# ROC 0.668622948031
# TP 41 FP 15584 TN 7930 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13569
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6271186440677966
# Specificity : 0.6974789915966386
# Accuracy: 0.6624472573839663
# ROC 0.662298817832
# TP 74 FP 36 TN 83 FN 44
#
#
#
# None
# Cross: Validation: [ 0.60504202  0.66949153  0.63135593  0.63135593  0.55932203]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.37917836182699666
# Accuracy: 0.38025896837189554
# ROC 0.689589180913
# TP 41 FP 14598 TN 8916 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data="Data/Benchmarks/phos.csv")
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9048089591567853
# Specificity : 0.9980066445182725
# Accuracy: 0.9809420420963754
# ROC 0.951407801838
# TP 2747 FP 27 TN 13518 FN 289
#
#
#
# None
# Cross: Validation: [ 0.98178748  0.97925461  0.98069964  0.98148372  0.98106152]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 2 TN 46495 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 149227
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8982213438735178
# Specificity : 0.9988925802879292
# Accuracy: 0.9804595621494482
# ROC 0.948556962081
# TP 2727 FP 15 TN 13530 FN 309
#
#
#
# None
# Cross: Validation: [ 0.9810638   0.98118442  0.98088058  0.98136309  0.97913148]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109538
# Test Data Points: 27385
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.861688217347087
# Specificity : 0.9385417431529481
# Accuracy: 0.8999087091473434
# ROC 0.90011498025
# TP 11862 FP 837 TN 12782 FN 1904
#
#
#
# None
# Cross: Validation: [ 0.9228803   0.84173818  0.80839176  0.85732545  0.8194201 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.2360097323600973
# Specificity : 0.9540400455943394
# Accuracy: 0.9354913052587471
# ROC 0.595024888977
# TP 291 FP 2137 TN 44360 FN 942
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 192442
# Test Data Points: 27385
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8865494537298314
# Specificity : 0.9476555588322029
# Accuracy: 0.9168157750593391
# ROC 0.917102506281
# TP 12253 FP 710 TN 12854 FN 1568
#
#
#
# None
# Cross: Validation: [ 0.92430439  0.84064269  0.82632194  0.8471005   0.87069091]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.21086780210867803
# Specificity : 0.9623201496870766
# Accuracy: 0.9429080243033732
# ROC 0.586593975898
# TP 260 FP 1752 TN 44745 FN 973
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 97610
# Test Data Points: 24403
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9364012409513961
# Specificity : 0.9795674183156926
# Accuracy: 0.9556202106298406
# ROC 0.957984329634
# TP 12677 FP 222 TN 10643 FN 861
#
#
#
# None
# Cross: Validation: [ 0.94537781  0.95713642  0.95295468  0.95717564  0.95983936]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.039740470397404706
# Specificity : 0.9682775232810719
# Accuracy: 0.9442908024303374
# ROC 0.504008996839
# TP 49 FP 1475 TN 45022 FN 1184
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 190532
# Test Data Points: 26907
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9551646706586826
# Specificity : 0.9607293127629734
# Accuracy: 0.9579663284647117
# ROC 0.957946991711
# TP 12761 FP 532 TN 13015 FN 599
#
#
#
# None
# Cross: Validation: [ 0.95666716  0.95469749  0.96064221  0.9574816   0.95755594]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.004866180048661801
# Specificity : 0.9730520248618191
# Accuracy: 0.9480410643201341
# ROC 0.488959102455
# TP 6 FP 1253 TN 45244 FN 1227
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9055921052631579
# Specificity : 0.9885714285714285
# Accuracy: 0.9466334164588529
# ROC 0.947081766917
# TP 2753 FP 34 TN 2941 FN 287
#
#
#
# None
# Cross: Validation: [ 0.95445479  0.94880319  0.9423013   0.94396408  0.94429664]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.032441200324412
# Specificity : 0.9904725036023829
# Accuracy: 0.965723863398282
# ROC 0.511456851963
# TP 40 FP 443 TN 46054 FN 1193
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 106963
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9151315789473684
# Specificity : 0.9684033613445379
# Accuracy: 0.9414796342477141
# ROC 0.941767470146
# TP 2782 FP 94 TN 2881 FN 258
#
#
#
# None
# Cross: Validation: [ 0.94697473  0.94863697  0.94961756  0.94313269  0.94446292]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.1070559610705596
# Specificity : 0.9729444910424329
# Accuracy: 0.9505761575529017
# ROC 0.540000226056
# TP 132 FP 1258 TN 45239 FN 1101
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 62430
# Test Data Points: 15608
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9053540587219344
# Specificity : 0.9996067018013057
# Accuracy: 0.9821245515120451
# ROC 0.952480380262
# TP 2621 FP 5 TN 12708 FN 274
#
#
#
# None
# Cross: Validation: [ 0.97981933  0.97936955  0.98007304  0.98199526  0.98064971]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 43 TN 46454 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 145344
# Test Data Points: 15610
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.901690238013108
# Specificity : 0.9991346078199984
# Accuracy: 0.9810377962844331
# ROC 0.950412422917
# TP 2614 FP 11 TN 12700 FN 285
#
#
#
# None
# Cross: Validation: [ 0.98116713  0.98103901  0.97898783  0.97885835  0.98110065]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 2 TN 46495 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9194078947368421
# Specificity : 0.9690756302521009
# Accuracy: 0.943973399833749
# ROC 0.944241762494
# TP 2795 FP 92 TN 2883 FN 245
#
#
#
# None
# Cross: Validation: [ 0.82912234  0.9502992   0.95177918  0.94861989  0.95443964]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.30900243309002434
# Specificity : 0.7758350001075338
# Accuracy: 0.763775403310287
# ROC 0.542418716599
# TP 381 FP 10423 TN 36074 FN 852
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 106963
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9121710526315789
# Specificity : 0.9885714285714285
# Accuracy: 0.9499584372402328
# ROC 0.950371240602
# TP 2773 FP 34 TN 2941 FN 267
#
#
#
# None
# Cross: Validation: [ 0.828125    0.95196144  0.95078151  0.94679082  0.91120718]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.137875101378751
# Specificity : 0.8560982428973912
# Accuracy: 0.8375445212654515
# ROC 0.496986672138
# TP 170 FP 6691 TN 39806 FN 1063
#
#
#
# None
