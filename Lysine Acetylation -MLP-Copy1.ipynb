# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using K acytelation.
#
# Training data is from CUCKOO group and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 296118
# Test Data Points: 32902
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 32083 FN 817
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.00031113876789047915
# Specificity : 0.9998895271763146
# Accuracy: 0.9183958195931206
# ROC 0.500100332972
# TP 1 FP 4 TN 36204 FN 3213
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 625138
# Test Data Points: 32902
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 32117 FN 785
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 577522
# Test Data Points: 64170
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8233195818728869
# Specificity : 0.9497040493564248
# Accuracy: 0.8862085086489013
# ROC 0.886511815615
# TP 26543 FP 1606 TN 30325 FN 5696
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.06253889234598631
# Specificity : 0.9470006628369421
# Accuracy: 0.874892192176957
# ROC 0.504769777591
# TP 201 FP 1919 TN 34289 FN 3013
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 906542
# Test Data Points: 64170
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7836388577129317
# Specificity : 0.9729856047859413
# Accuracy: 0.8783387875954496
# ROC 0.878312231249
# TP 25136 FP 867 TN 31227 FN 6940
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.024891101431238332
# Specificity : 0.9815510384445426
# Accuracy: 0.9035563898330882
# ROC 0.503221069938
# TP 80 FP 668 TN 35540 FN 3134
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 497868
# Test Data Points: 55319
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8726152313964707
# Specificity : 0.6215283767465931
# Accuracy: 0.7673674506046747
# ROC 0.747071804072
# TP 28038 FP 8776 TN 14412 FN 4093
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.47137523335407594
# Specificity : 0.605777728678745
# Accuracy: 0.5948201511846177
# ROC 0.538576481016
# TP 1515 FP 14274 TN 21934 FN 1699
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 826784
# Test Data Points: 55308
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8646251517131921
# Specificity : 0.6406040992448759
# Accuracy: 0.7707564909235554
# ROC 0.752614625479
# TP 27783 FP 8329 TN 14846 FN 4350
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.4477286869943995
# Specificity : 0.6189239946973044
# Accuracy: 0.6049667698239561
# ROC 0.533326340846
# TP 1439 FP 13798 TN 22410 FN 1775
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 14542
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.40417690417690416
# Specificity : 0.6109725685785536
# Accuracy: 0.5068069306930693
# ROC 0.507574736378
# TP 329 FP 312 TN 490 FN 485
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.4439950217797137
# Specificity : 0.6354673000441892
# Accuracy: 0.6198569326771853
# ROC 0.539731160912
# TP 1427 FP 13199 TN 23009 FN 1787
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 343562
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3891566265060241
# Specificity : 0.6590330788804071
# Accuracy: 0.5204207920792079
# ROC 0.524094852693
# TP 323 FP 268 TN 518 FN 507
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.38176726820161794
# Specificity : 0.7116659301811754
# Accuracy: 0.684769925422353
# ROC 0.546716599191
# TP 1227 FP 10440 TN 25768 FN 1987
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283057
# Test Data Points: 31451
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0012755102040816326
# Specificity : 0.9994456581993674
# Accuracy: 0.9745636068805443
# ROC 0.500360584202
# TP 1 FP 17 TN 30650 FN 783
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.0006222775357809583
# Specificity : 0.9998895271763146
# Accuracy: 0.9184211861397189
# ROC 0.500255902356
# TP 2 FP 4 TN 36204 FN 3212
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 612077
# Test Data Points: 31451
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 30584 FN 867
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 14542
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.807061790668348
# Specificity : 0.8055893074119077
# Accuracy: 0.8063118811881188
# ROC 0.80632554904
# TP 640 FP 160 TN 663 FN 153
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.842874922215308
# Specificity : 0.17377375165709236
# Accuracy: 0.22832428593171325
# ROC 0.508324336936
# TP 2709 FP 29916 TN 6292 FN 505
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 343562
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8270401948842875
# Specificity : 0.7383647798742138
# Accuracy: 0.7834158415841584
# ROC 0.782702487379
# TP 679 FP 208 TN 587 FN 142
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.8512756689483509
# Specificity : 0.15618095448519664
# Accuracy: 0.21285069250672214
# ROC 0.503728311717
# TP 2736 FP 30553 TN 5655 FN 478
#
#
#
# None

# %% [markdown]
# Chemical Vector

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="chemical", amino_acid="K", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="chemical", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 296118
# Test Data Points: 32902
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 32144 FN 758
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 625138
# Test Data Points: 32902
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 32087 FN 815
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 578286
# Test Data Points: 64254
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6143527000590007
# Specificity : 0.6575457864029204
# Accuracy: 0.6358981542005167
# ROC 0.635949243231
# TP 19784 FP 10976 TN 21075 FN 12419
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.4561294337274424
# Specificity : 0.6605446310207689
# Accuracy: 0.6438790523058191
# ROC 0.558337032374
# TP 1466 FP 12291 TN 23917 FN 1748
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 907306
# Test Data Points: 64254
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3262981470560849
# Specificity : 0.883034181364133
# Accuracy: 0.6038690198275594
# ROC 0.60466616421
# TP 10513 FP 3747 TN 28288 FN 21706
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.1748599875544493
# Specificity : 0.8817664604507292
# Accuracy: 0.8241337324336665
# ROC 0.528313224003
# TP 562 FP 4281 TN 31927 FN 2652
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 503324
# Test Data Points: 55925
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8739082798560025
# Specificity : 0.3732276897414512
# Accuracy: 0.6592221725525257
# ROC 0.623567984799
# TP 27917 FP 15030 TN 8950 FN 4028
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.8117610454262602
# Specificity : 0.3180236411842687
# Accuracy: 0.3582771041550403
# ROC 0.564892343305
# TP 2609 FP 24693 TN 11515 FN 605
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 832301
# Test Data Points: 55921
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7373897378556342
# Specificity : 0.6608219178082192
# Accuracy: 0.7049051340283614
# ROC 0.699105827832
# TP 23741 FP 8047 TN 15678 FN 8455
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.5423148724331052
# Specificity : 0.5411511268228016
# Accuracy: 0.5412460047689107
# ROC 0.541732999628
# TP 1743 FP 16614 TN 19594 FN 1471
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 14542
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5355329949238579
# Specificity : 0.5265700483091788
# Accuracy: 0.530940594059406
# ROC 0.531051521617
# TP 422 FP 392 TN 436 FN 366
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.5560049782202863
# Specificity : 0.5399911621741051
# Accuracy: 0.5412967378621074
# ROC 0.547998070197
# TP 1787 FP 16656 TN 19552 FN 1427
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Timing out Random Data incorperation into test Data
# Random Data Added: 225601
# Finished with Random Data
# Training Data Points: 240143
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.10157194679564692
# Specificity : 0.9226869455006337
# Accuracy: 0.5024752475247525
# ROC 0.512129446148
# TP 84 FP 61 TN 728 FN 743
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.07716241443683883
# Specificity : 0.9355391073795846
# Accuracy: 0.8655573030287657
# ROC 0.506350760908
# TP 248 FP 2334 TN 33874 FN 2966
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 282056
# Test Data Points: 31340
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 30574 FN 766
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 611076
# Test Data Points: 31340
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 30552 FN 788
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 14542
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.69875
# Specificity : 0.6997549019607843
# Accuracy: 0.6992574257425742
# ROC 0.69925245098
# TP 559 FP 245 TN 571 FN 241
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.670192906036092
# Specificity : 0.24972381794078657
# Accuracy: 0.28400385571508296
# ROC 0.459958361988
# TP 2154 FP 27166 TN 9042 FN 1060
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 343562
# Test Data Points: 1616
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.12549019607843137
# Specificity : 0.8719153936545241
# Accuracy: 0.5185643564356436
# ROC 0.498702794866
# TP 96 FP 109 TN 742 FN 669
#
#
#
# None
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.10423148724331052
# Specificity : 0.8928689792311092
# Accuracy: 0.8285728780883771
# ROC 0.498550233237
# TP 335 FP 3879 TN 32329 FN 2879
#
#
#
# None
