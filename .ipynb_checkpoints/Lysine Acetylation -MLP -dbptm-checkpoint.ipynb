# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using K acytelation.
#
# Training data is from CUCKOO group and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=-1)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 263216
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0006150061500615006
# Specificity : 0.9998597650285145
# Accuracy: 0.9751686827548477
# ROC 0.500237385589
# TP 1 FP 9 TN 64169 FN 1625
#
#
#
# None
# Cross: Validation: [ 0.97519945  0.97538144  0.97522947  0.97524467  0.97544185]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.0006222775357809583
# Specificity : 0.9999447635881573
# Accuracy: 0.9184719192329156
# ROC 0.500283520562
# TP 2 FP 2 TN 36206 FN 3212
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 592236
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 64180 FN 1624
#
#
#
# None
# Cross: Validation: [ 0.97518426  0.97524467  0.97539663  0.97522947  0.97535067]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 513353
# Test Data Points: 128339
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8096185222593427
# Specificity : 0.9435171292823206
# Accuracy: 0.8763742899664171
# ROC 0.876567825771
# TP 52103 FP 3614 TN 60370 FN 12252
#
#
#
# None
# Cross: Validation: [ 0.83285803  0.87028004  0.87025667  0.87461235  0.84469915]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.058182949595519604
# Specificity : 0.9488234644277508
# Accuracy: 0.876211252600071
# ROC 0.503503207012
# TP 187 FP 1853 TN 34355 FN 3027
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 842373
# Test Data Points: 128339
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7945762922465208
# Specificity : 0.963364865921351
# Accuracy: 0.8786884734959755
# ROC 0.878970579084
# TP 51158 FP 2343 TN 61612 FN 13226
#
#
#
# None
# Cross: Validation: [ 0.82887642  0.86405429  0.86851127  0.87440197  0.85890383]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.040759178593652766
# Specificity : 0.9668029164825453
# Accuracy: 0.8913043478260869
# ROC 0.503781047538
# TP 131 FP 1202 TN 35006 FN 3083
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 513472
# Test Data Points: 128369
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7477118302255592
# Specificity : 0.7413115934091727
# Accuracy: 0.7445255474452555
# ROC 0.744511711817
# TP 48199 FP 16532 TN 47375 FN 16263
#
#
#
# None
# Cross: Validation: [ 0.72762115  0.74075315  0.74423532  0.76200455  0.75616197]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.3254511512134412
# Specificity : 0.7510771100309324
# Accuracy: 0.7163766424838922
# ROC 0.538264130622
# TP 1046 FP 9013 TN 27195 FN 2168
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 842501
# Test Data Points: 128371
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7299061353888233
# Specificity : 0.763631819814754
# Accuracy: 0.746726285531779
# ROC 0.746768977602
# TP 46968 FP 15133 TN 48890 FN 17380
#
#
#
# None
# Cross: Validation: [ 0.73323622  0.75403132  0.74670094  0.76007634  0.7473553 ]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.28313627878033604
# Specificity : 0.7780600972160848
# Accuracy: 0.7377099081731013
# ROC 0.530598187998
# TP 910 FP 8036 TN 28172 FN 2304
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.28205128205128205
# Specificity : 0.7772898368883312
# Accuracy: 0.526299504950495
# ROC 0.52967055947
# TP 462 FP 355 TN 1239 FN 1176
#
#
#
# None
# Cross: Validation: [ 0.53001238  0.53094059  0.5417698   0.5157797   0.5377709 ]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.2598008711885501
# Specificity : 0.802529827662395
# Accuracy: 0.75828217746436
# ROC 0.531165349425
# TP 835 FP 7150 TN 29058 FN 2379
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 341946
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.38705738705738707
# Specificity : 0.6649937264742786
# Accuracy: 0.5241336633663366
# ROC 0.526025556766
# TP 634 FP 534 TN 1060 FN 1004
#
#
#
# None
# Cross: Validation: [ 0.5102104   0.54888614  0.51268564  0.51237624  0.51733746]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.3839452395768513
# Specificity : 0.7100916924436589
# Accuracy: 0.6835015980924357
# ROC 0.54701846601
# TP 1234 FP 10497 TN 25711 FN 1980
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 251616
# Test Data Points: 62905
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0018598884066955983
# Specificity : 0.9997715851987209
# Accuracy: 0.9741832922661156
# ROC 0.500815736803
# TP 3 FP 14 TN 61278 FN 1610
#
#
#
# None
# Cross: Validation: [ 0.97418329  0.97421509  0.97427827  0.97389673  0.97426196]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 4 TN 36204 FN 3214
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 580622
# Test Data Points: 62901
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0012399256044637321
# Specificity : 0.9999673671844407
# Accuracy: 0.9743565285130602
# ROC 0.500603646394
# TP 2 FP 2 TN 61286 FN 1611
#
#
#
# None
# Cross: Validation: [ 0.97427704  0.97391138  0.97414985  0.97411806  0.97410134]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.00031113876789047915
# Specificity : 1.0
# Accuracy: 0.918497285779514
# ROC 0.500155569384
# TP 1 FP 0 TN 36208 FN 3213
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data

# %% [markdown]
# Chemical Vector

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="chemical", amino_acid="K", imbalance_function=i, random_data=-1)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="chemical", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
