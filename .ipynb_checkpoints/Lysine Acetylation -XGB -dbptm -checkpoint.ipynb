# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using K acytelation.
#
# Training data is from CUCKOO group and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=-1)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="sequence", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 263216
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 64149 FN 1655
#
#
#
# None
# Cross: Validation: [ 0.9754426   0.97544222  0.97544222  0.97544222  0.97545705]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 592236
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 64255 FN 1549
#
#
#
# None
# Cross: Validation: [ 0.9754426   0.97544222  0.97544222  0.97544222  0.97545705]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 513353
# Test Data Points: 128339
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8427182656769264
# Specificity : 0.9955586832434123
# Accuracy: 0.9188711147819447
# ROC 0.91913847446
# TP 54266 FP 284 TN 63661 FN 10128
#
#
#
# None
# Cross: Validation: [ 0.87105345  0.91876919  0.91773286  0.93058954  0.91762377]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.012445550715619166
# Specificity : 0.9893946089262041
# Accuracy: 0.9097458272030846
# ROC 0.500920079821
# TP 40 FP 384 TN 35824 FN 3174
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 842373
# Test Data Points: 128339
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.848339907444793
# Specificity : 1.0
# Accuracy: 0.9239046587553277
# ROC 0.924169953722
# TP 54628 FP 0 TN 63945 FN 9766
#
#
#
# None
# Cross: Validation: [ 0.88503974  0.94087488  0.94163849  0.94329037  0.94174757]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 513471
# Test Data Points: 128368
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8576652514797484
# Specificity : 0.9861350462165126
# Accuracy: 0.9215458681291288
# ROC 0.921900148848
# TP 55352 FP 885 TN 62945 FN 9186
#
#
#
# None
# Cross: Validation: [ 0.87448683  0.9392294   0.93534214  0.92843955  0.93217104]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.7464219041692595
# Specificity : 0.2910958904109589
# Accuracy: 0.3282177464360002
# ROC 0.51875889729
# TP 2399 FP 25668 TN 10540 FN 815
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 842499
# Test Data Points: 128370
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8885877141352498
# Specificity : 0.9883086760280843
# Accuracy: 0.9381553322427358
# ROC 0.938448195082
# TP 57369 FP 746 TN 63062 FN 7193
#
#
#
# None
# Cross: Validation: [ 0.87436415  0.92745969  0.93542884  0.93917535  0.93299005]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.5314250155569384
# Specificity : 0.482628148475475
# Accuracy: 0.4866064633960733
# ROC 0.507026582016
# TP 1708 FP 18733 TN 17475 FN 1506
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6355311355311355
# Specificity : 0.6204516938519448
# Accuracy: 0.6280940594059405
# ROC 0.627991414692
# TP 1041 FP 605 TN 989 FN 597
#
#
#
# None
# Cross: Validation: [ 0.63056931  0.63335396  0.6460396   0.63366337  0.63003096]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.6341008089607966
# Specificity : 0.6069376933274414
# Accuracy: 0.6091522500126832
# ROC 0.620519251144
# TP 2038 FP 14232 TN 21976 FN 1176
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 341946
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6428571428571429
# Specificity : 0.6010037641154329
# Accuracy: 0.6222153465346535
# ROC 0.621930453486
# TP 1053 FP 636 TN 958 FN 585
#
#
#
# None
# Cross: Validation: [ 0.63985149  0.6302599   0.63706683  0.62469059  0.64241486]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.6390790292470442
# Specificity : 0.5794575784357048
# Accuracy: 0.5843184008929024
# ROC 0.609268303841
# TP 2054 FP 15227 TN 20981 FN 1160
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 251608
# Test Data Points: 62902
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 61289 FN 1613
#
#
#
# None
# Cross: Validation: [ 0.97430965  0.97430924  0.97430924  0.97430924  0.97432473]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 580645
# Test Data Points: 62907
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 61295 FN 1612
#
#
#
# None
# Cross: Validation: [ 0.97431128  0.97431128  0.97431128  0.97431088  0.97432637]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7924297924297924
# Specificity : 0.8444165621079046
# Accuracy: 0.818069306930693
# ROC 0.818423177269
# TP 1298 FP 248 TN 1346 FN 340
#
#
#
# None
# Cross: Validation: [ 0.8230198   0.8282797   0.83694307  0.81714109  0.80371517]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.819539514623522
# Specificity : 0.2364394608926204
# Accuracy: 0.2839784891684846
# ROC 0.527989487758
# TP 2634 FP 27647 TN 8561 FN 580
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 341946
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7887667887667887
# Specificity : 0.8469259723964868
# Accuracy: 0.817450495049505
# ROC 0.817846380582
# TP 1292 FP 244 TN 1350 FN 346
#
#
#
# None
# Cross: Validation: [ 0.83199257  0.84405941  0.82425743  0.82611386  0.79876161]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.8151835718730553
# Specificity : 0.2477076889085285
# Accuracy: 0.293972908528233
# ROC 0.531445630391
# TP 2620 FP 27239 TN 8969 FN 594
#
#
#
# None

# %% [markdown]
# Chemical Vector

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/k_acetylation.csv")
    y.process_data(vector_function="chemical", amino_acid="K", imbalance_function=i, random_data=-1)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/acet.csv", "K")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/k_acetylation.csv")
    x.process_data(vector_function="chemical", amino_acid="K", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/acet.csv", "K")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 263216
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 64163 FN 1641
#
#
#
# None
# Cross: Validation: [ 0.9754426   0.97544222  0.97544222  0.97544222  0.97545705]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 592236
# Test Data Points: 65804
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 64190 FN 1614
#
#
#
# None
# Cross: Validation: [ 0.9754426   0.97544222  0.97544222  0.97544222  0.97545705]
# Number of data points in benchmark 39422
# Benchmark Results
# Failed
# TP 0 FP 0 TN 36208 FN 3214
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 514038
# Test Data Points: 128510
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6810050843253969
# Specificity : 0.9781711928497766
# Accuracy: 0.8289938526184732
# ROC 0.829588138588
# TP 43933 FP 1397 TN 62601 FN 20579
#
#
#
# None
# Cross: Validation: [ 0.79997821  0.83398179  0.836385    0.83346692  0.83646282]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.7790914747977598
# Specificity : 0.24958572691117986
# Accuracy: 0.29275531429151236
# ROC 0.514338600854
# TP 2504 FP 27171 TN 9037 FN 710
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 843064
# Test Data Points: 128512
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6761810414215838
# Specificity : 0.9767165300118921
# Accuracy: 0.8256349601593626
# ROC 0.826448785717
# TP 43684 FP 1488 TN 62420 FN 20920
#
#
#
# None
# Cross: Validation: [ 0.79397255  0.83828622  0.83517364  0.83490129  0.83788158]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.6281891723708775
# Specificity : 0.3894719399027839
# Accuracy: 0.4089340977119375
# ROC 0.508830556137
# TP 2019 FP 22106 TN 14102 FN 1195
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 487850
# Test Data Points: 121963
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7418808441502325
# Specificity : 0.9806882351105981
# Accuracy: 0.8674024089272976
# ROC 0.86128453963
# TP 42923 FP 1238 TN 62868 FN 14934
#
#
#
# None
# Cross: Validation: [ 0.82977764  0.87801218  0.87663371  0.87850314  0.87754383]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.7753578095830741
# Specificity : 0.25939019001325675
# Accuracy: 0.30145603977474505
# ROC 0.517373999798
# TP 2492 FP 26816 TN 9392 FN 722
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 817275
# Test Data Points: 122064
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.740510589819274
# Specificity : 0.9813974520902528
# Accuracy: 0.8670697339100799
# ROC 0.860954020955
# TP 42900 FP 1193 TN 62938 FN 15033
#
#
#
# None
# Cross: Validation: [ 0.8290501   0.87634356  0.87574551  0.87636712  0.87636712]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.6244555071561917
# Specificity : 0.3986964206805126
# Accuracy: 0.41710212571660493
# ROC 0.511575963918
# TP 2007 FP 21772 TN 14436 FN 1207
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 12926
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6672771672771672
# Specificity : 0.4604767879548306
# Accuracy: 0.5652846534653465
# ROC 0.563876977616
# TP 1093 FP 860 TN 734 FN 545
#
#
#
# None
# Cross: Validation: [ 0.5674505   0.5572401   0.57456683  0.58044554  0.58544892]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.7087741132545116
# Specificity : 0.45415377817057007
# Accuracy: 0.4749124854142357
# ROC 0.581463945713
# TP 2278 FP 19764 TN 16444 FN 936
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 329020
# Filtering Random Data
# Random Data Added: 329020
# Finished with Random Data
# Training Data Points: 341946
# Test Data Points: 3232
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4468864468864469
# Specificity : 0.6530740276035132
# Accuracy: 0.5485767326732673
# ROC 0.549980237245
# TP 732 FP 553 TN 1041 FN 906
#
#
#
# None
# Cross: Validation: [ 0.5730198   0.57858911  0.5730198   0.59158416  0.56501548]
# Number of data points in benchmark 39422
# Benchmark Results
# Sensitivity: 0.40510267579340387
# Specificity : 0.6926922227132125
# Accuracy: 0.6692455989041652
# ROC 0.548897449253
# TP 1302 FP 11127 TN 25081 FN 1912
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
