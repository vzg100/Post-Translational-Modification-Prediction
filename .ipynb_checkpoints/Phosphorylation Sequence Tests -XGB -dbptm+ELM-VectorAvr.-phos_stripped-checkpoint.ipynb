# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 9, 17, 3, 1, 19, 10, 13, 11, 7, 10, 4, 10, -1.0846153846153848, 55.63076923076923, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08537122714254242
# Specificity : 0.9847853119742521
# Accuracy: 0.8217843524784891
# ROC 0.535078269558
# TP 775 FP 624 TN 40389 FN 8303
#
#
#
# None
# Cross: Validation: [ 0.81937235  0.82018726  0.82068635  0.82104212  0.82010381]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.007400828892835998
# Specificity : 0.9827406945310876
# Accuracy: 0.9327414826618105
# ROC 0.495070761712
# TP 25 FP 1079 TN 61438 FN 3353
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 3, 1, 17, 8, 10, 10, 11, 11, 17, 18, 18, 15, -1.8076923076923077, 124.96923076923078, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08878856282919488
# Specificity : 0.9852897911150338
# Accuracy: 0.818789802559342
# ROC 0.537039176972
# TP 826 FP 600 TN 40188 FN 8477
#
#
#
# None
# Cross: Validation: [ 0.82061008  0.8201673   0.82054661  0.81960471  0.82032342]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.006808762581409118
# Specificity : 0.9822768207047683
# Accuracy: 0.9322710372562409
# ROC 0.494542791643
# TP 23 FP 1108 TN 61409 FN 3355
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 19, 10, 12, 2, 5, 9, 19, 12, 2, 12, 18, 0, 0.5083333333333333, 41.26666666666667, 0.08333333333333333]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331761
# Test Data Points: 82941
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6784747613846811
# Specificity : 0.9866251867819611
# Accuracy: 0.8301443194559989
# ROC 0.832549974083
# TP 28576 FP 546 TN 40277 FN 13542
#
#
#
# None
# Cross: Validation: [ 0.49301922  0.88013021  0.92459609  0.9190258   0.91649385]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.018058022498519833
# Specificity : 0.9909144712638163
# Accuracy: 0.941042567721375
# ROC 0.504486246881
# TP 61 FP 568 TN 61949 FN 3317
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 1, 10, 7, 2, 2, 10, 10, 11, 5, 1, 10, 5, -0.05384615384615386, 82.15384615384616, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331693
# Test Data Points: 82924
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6741802306268685
# Specificity : 0.9883515621168277
# Accuracy: 0.8286744488929623
# ROC 0.831265896372
# TP 28414 FP 475 TN 40303 FN 13732
#
#
#
# None
# Cross: Validation: [ 0.49279469  0.88495351  0.91838211  0.91572905  0.91695911]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.005920663114268798
# Specificity : 0.9925940144280756
# Accuracy: 0.9420138098490022
# ROC 0.499257338771
# TP 20 FP 463 TN 62054 FN 3358
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 10, 13, 10, 10, 4, 10, 9, 1, 19, 9, 0, 0, -0.5363636363636363, 84.05454545454546, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305877
# Test Data Points: 76470
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7676550317189726
# Specificity : 0.9373018408828373
# Accuracy: 0.8579181378318295
# ROC 0.852478436301
# TP 27469 FP 2551 TN 38136 FN 8314
#
#
#
# None
# Cross: Validation: [ 0.56843771  0.91035583  0.91688135  0.92381226  0.91854215]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.08229721728833629
# Specificity : 0.9184701761120975
# Accuracy: 0.8756051293724866
# ROC 0.5003836967
# TP 278 FP 5097 TN 57420 FN 3100
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 18, 7, 19, 19, 19, 10, 19, 20, 9, 20, 10, 18, -2.6846153846153844, 45.51538461538462, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305986
# Test Data Points: 76497
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7655453905700211
# Specificity : 0.9275114712486576
# Accuracy: 0.8522948612363883
# ROC 0.846528430909
# TP 27196 FP 2970 TN 38002 FN 8329
#
#
#
# None
# Cross: Validation: [ 0.5714267   0.90708132  0.92208743  0.92121157  0.92049257]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.09591474245115453
# Specificity : 0.9077210998608378
# Accuracy: 0.8661051673116321
# ROC 0.501817921156
# TP 324 FP 5769 TN 56748 FN 3054
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 10, 2, 17, 16, 10, 10, 9, 19, 10, 19, 13, 20, -1.276923076923077, 98.12307692307694, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.733632862644416
# Specificity : 0.6353251318101933
# Accuracy: 0.6851289833080425
# ROC 0.684478997227
# TP 6858 FP 3320 TN 5784 FN 2490
#
#
#
# None
# Cross: Validation: [ 0.68274442  0.68404509  0.68323217  0.68390244  0.68509485]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.5970988750740083
# Specificity : 0.6047155173792729
# Accuracy: 0.6043250625995903
# ROC 0.600907196227
# TP 2017 FP 24712 TN 37805 FN 1361
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 1, 8, 10, 9, 10, 10, 19, 9, 12, 5, 18, 4, -0.9307692307692308, 80.94615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7396234488660676
# Specificity : 0.6353251318101933
# Accuracy: 0.6881638846737481
# ROC 0.687474290338
# TP 6914 FP 3320 TN 5784 FN 2434
#
#
#
# None
# Cross: Validation: [ 0.68550835  0.68512898  0.68583351  0.68607046  0.68319783]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.5852575488454707
# Specificity : 0.5971015883679639
# Accuracy: 0.5964944229455953
# ROC 0.591179568607
# TP 1977 FP 25188 TN 37329 FN 1401
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 11, 10, 19, 2, 1, 10, 11, 5, 8, 10, 10, 11, -0.9538461538461539, 169.89230769230772, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143733
# Test Data Points: 35934
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2891330360056565
# Specificity : 0.9535544669234509
# Accuracy: 0.783575443869316
# ROC 0.621343751465
# TP 2658 FP 1242 TN 25499 FN 6535
#
#
#
# None
# Cross: Validation: [ 0.78557912  0.7836311   0.78037513  0.78189965  0.78183792]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.14801657785671996
# Specificity : 0.9269958571268615
# Accuracy: 0.8870627513468397
# ROC 0.537506217492
# TP 500 FP 4564 TN 57953 FN 2878
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 9, 11, 1, 4, 10, 10, 20, 11, 17, 3, 17, 7, -1.3384615384615384, 96.4923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143788
# Test Data Points: 35947
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.28265361609570416
# Specificity : 0.9547697368421053
# Accuracy: 0.782846969149025
# ROC 0.618711676469
# TP 2599 FP 1210 TN 25542 FN 6596
#
#
#
# None
# Cross: Validation: [ 0.78162902  0.78251919  0.78421009  0.78231236  0.78133867]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.14801657785671996
# Specificity : 0.9314906345474031
# Accuracy: 0.8913271113134532
# ROC 0.539753606202
# TP 500 FP 4283 TN 58234 FN 2878
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 19, 2, 7, 10, 18, 10, 3, 13, 10, 13, 7, 17, -0.5769230769230771, 27.77692307692308, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7036799315361575
# Specificity : 0.7305579964850615
# Accuracy: 0.7169412529807067
# ROC 0.717118964011
# TP 6578 FP 2453 TN 6651 FN 2770
#
#
#
# None
# Cross: Validation: [ 0.64361587  0.74663993  0.74279211  0.72287263  0.70178862]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.6986382474837182
# Specificity : 0.41044835804661134
# Accuracy: 0.42522194400182106
# ROC 0.554543302765
# TP 2360 FP 36857 TN 25660 FN 1018
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 10, 5, 1, 1, 19, 10, 11, 12, 17, 3, 10, 11, -0.5461538461538461, 130.76923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6989730423620025
# Specificity : 0.7292398945518453
# Accuracy: 0.713906351615001
# ROC 0.714106468457
# TP 6534 FP 2465 TN 6639 FN 2814
#
#
#
# None
# Cross: Validation: [ 0.64800564  0.74837416  0.74317147  0.71636856  0.70254743]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.6752516281823564
# Specificity : 0.401074907625126
# Accuracy: 0.4151301312694438
# ROC 0.538163267904
# TP 2281 FP 37443 TN 25074 FN 1097
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 9, 9, 11, 12, 15, 8, 11, 8, 11, 2, 8, -1.1538461538461537, 132.2153846153846, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.041666666666666664
# Specificity : 1.0
# Accuracy: 0.9544554455445544
# ROC 0.520833333333
# TP 5 FP 0 TN 2405 FN 115
#
#
#
# None
# Cross: Validation: [ 0.95368171  0.95445545  0.95485149  0.95562599  0.9544374 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 11, 11, 11, 8, 13, 15, 12, 9, 7, 20, 3, 2, -0.11538461538461543, 87.47692307692309, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.026785714285714284
# Specificity : 1.0
# Accuracy: 0.9568316831683168
# ROC 0.513392857143
# TP 3 FP 0 TN 2413 FN 109
#
#
#
# None
# Cross: Validation: [ 0.95526524  0.95485149  0.95445545  0.9548336   0.95522979]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 11, 7, 7, 11, 10, 15, 16, 1, 15, 18, 8, 4, -1.5846153846153848, 22.246153846153856, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19352
# Test Data Points: 4838
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8380634390651085
# Specificity : 0.9987714987714987
# Accuracy: 0.9191814799503927
# ROC 0.918417468918
# TP 2008 FP 3 TN 2439 FN 388
#
#
#
# None
# Cross: Validation: [ 0.82992354  0.9566026   0.94212484  0.93694439  0.93632417]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 18, 12, 15, 13, 15, 15, 11, 20, 10, 2, 1, 1, -0.3076923076923077, 50.12307692307694, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19355
# Test Data Points: 4839
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8554166666666667
# Specificity : 0.998359983599836
# Accuracy: 0.9274643521388717
# ROC 0.926888325133
# TP 2053 FP 4 TN 2435 FN 347
#
#
#
# None
# Cross: Validation: [ 0.83636364  0.95081628  0.92953089  0.94357172  0.9518396 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 19, 18, 4, 20, 7, 15, 3, 10, 19, 9, 18, 1, -1.2384615384615385, 4.946153846153847, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19238
# Test Data Points: 4810
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9090528080469404
# Specificity : 0.9715346534653465
# Accuracy: 0.9405405405405406
# ROC 0.940293730756
# TP 2169 FP 69 TN 2355 FN 217
#
#
#
# None
# Cross: Validation: [ 0.85987526  0.96590437  0.96819127  0.9731753   0.96236224]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.9715913923619971
# Accuracy: 0.9715983867544046
# ROC 0.97360057423
# TP 40 FP 668 TN 22846 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 15, 10, 7, 7, 7, 15, 12, 14, 7, 3, 3, 5, -0.17692307692307713, -3.8307692307692314, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19236
# Test Data Points: 4809
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9239130434782609
# Specificity : 0.971038477451386
# Accuracy: 0.9475982532751092
# ROC 0.947475760465
# TP 2210 FP 70 TN 2347 FN 182
#
#
#
# None
# Cross: Validation: [ 0.85738046  0.96403326  0.96485756  0.97171381  0.96734609]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.9734626180147997
# Accuracy: 0.9734663553385693
# ROC 0.974536187056
# TP 40 FP 624 TN 22890 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 9, 7, 15, 10, 19, 15, 19, 1, 20, 10, 17, 3, -1.2769230769230768, 35.73076923076923, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6271186440677966
# Specificity : 0.5714285714285714
# Accuracy: 0.5991561181434599
# ROC 0.599273607748
# TP 74 FP 51 TN 68 FN 44
#
#
#
# None
# Cross: Validation: [ 0.57142857  0.5720339   0.56355932  0.65254237  0.58898305]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6080632814493493
# Accuracy: 0.6087454892804075
# ROC 0.804031640725
# TP 41 FP 9216 TN 14298 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 1, 11, 10, 16, 10, 15, 10, 10, 10, 11, 3, 10, -0.40769230769230763, 87.47692307692309, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6016949152542372
# Specificity : 0.6554621848739496
# Accuracy: 0.6286919831223629
# ROC 0.628578550064
# TP 71 FP 41 TN 78 FN 47
#
#
#
# None
# Cross: Validation: [ 0.6092437   0.62288136  0.61864407  0.65254237  0.51694915]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6775537977375181
# Accuracy: 0.678115049883252
# ROC 0.838776898869
# TP 41 FP 7582 TN 15932 FN 0
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 9, 4, 16, 11, 2, 15, 20, 9, 9, 9, 3, 17, -1.0461538461538462, 139.14615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9225
# Test Data Points: 2307
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06086956521739131
# Specificity : 1.0
# Accuracy: 0.953185955786736
# ROC 0.530434782609
# TP 7 FP 0 TN 2192 FN 108
#
#
#
# None
# Cross: Validation: [ 0.95147314  0.94839549  0.95143105  0.94926279  0.95056375]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 1, 1, 5, 10, 9, 15, 12, 3, 6, 17, 7, 7, -0.8, 51.753846153846155, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9224
# Test Data Points: 2306
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05217391304347826
# Specificity : 1.0
# Accuracy: 0.9527320034692107
# ROC 0.526086956522
# TP 6 FP 0 TN 2191 FN 109
#
#
#
# None
# Cross: Validation: [ 0.95058518  0.94926279  0.95056375  0.94969644  0.95010846]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 1, 3, 10, 12, 3, 15, 5, 3, 5, 3, 12, 5, 2.4846153846153842, 9.230769230769232, 0.38461538461538464]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6779661016949152
# Specificity : 0.8151260504201681
# Accuracy: 0.7468354430379747
# ROC 0.746546076058
# TP 80 FP 22 TN 97 FN 38
#
#
#
# None
# Cross: Validation: [ 0.74789916  0.77542373  0.69915254  0.66101695  0.6779661 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.38207025601769157
# Accuracy: 0.38314582891105925
# ROC 0.691035128009
# TP 41 FP 14530 TN 8984 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 12, 2, 13, 4, 11, 15, 15, 13, 1, 3, 12, 4, 2.0307692307692307, 52.52307692307693, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.652542372881356
# Specificity : 0.7647058823529411
# Accuracy: 0.7088607594936709
# ROC 0.708624127617
# TP 77 FP 28 TN 91 FN 41
#
#
#
# None
# Cross: Validation: [ 0.74789916  0.77118644  0.75423729  0.67372881  0.66949153]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.37900825040401465
# Accuracy: 0.3800891530460624
# ROC 0.689504125202
# TP 41 FP 14602 TN 8912 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 5, 20, 2, 17, 12, 20, 1, 19, 19, 10, 4, 17, -0.7307692307692307, 20.000000000000007, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.026948051948051947
# Specificity : 0.9941485815865492
# Accuracy: 0.8144864604064893
# ROC 0.510548316767
# TP 83 FP 79 TN 13422 FN 2997
#
#
#
# None
# Cross: Validation: [ 0.82052828  0.82076951  0.81827503  0.8194813   0.82110977]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.004866180048661801
# Specificity : 0.9951824848914984
# Accuracy: 0.96959983239053
# ROC 0.50002433247
# TP 6 FP 224 TN 46273 FN 1227
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [6, 8, 2, 2, 6, 12, 20, 2, 3, 18, 9, 9, 2, -0.10000000000000003, 21.24615384615385, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.03126028298782494
# Specificity : 0.9940924531088465
# Accuracy: 0.8176225800615162
# ROC 0.512676368048
# TP 95 FP 80 TN 13462 FN 2944
#
#
#
# None
# Cross: Validation: [ 0.81986491  0.81968399  0.8199035   0.81960193  0.82056695]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0056772100567721
# Specificity : 0.9934834505451965
# Accuracy: 0.9679656400586634
# ROC 0.499580330301
# TP 7 FP 303 TN 46194 FN 1226
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 19, 18, 2, 1, 7, 20, 20, 3, 3, 7, 8, 3, -0.2384615384615385, 14.353846153846154, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109781
# Test Data Points: 27446
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6695337911095048
# Specificity : 0.9988979501873485
# Accuracy: 0.8328718210303869
# ROC 0.834215870648
# TP 9263 FP 15 TN 13596 FN 4572
#
#
#
# None
# Cross: Validation: [ 0.49457116  0.85841288  0.89845145  0.92570596  0.89910731]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 41 TN 46456 FN 1233
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 9, 12, 2, 19, 11, 20, 2, 16, 17, 17, 10, 3, -1.0923076923076922, 99.10769230769232, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109770
# Test Data Points: 27443
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6749802343132322
# Specificity : 0.99830007390983
# Accuracy: 0.8343839959188135
# ROC 0.836640154112
# TP 9391 FP 23 TN 13507 FN 4522
#
#
#
# None
# Cross: Validation: [ 0.4946072   0.88740298  0.92504191  0.92653597  0.92828511]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0008110300081103001
# Specificity : 0.9991182226810332
# Accuracy: 0.9733291430965849
# ROC 0.499964626345
# TP 1 FP 41 TN 46456 FN 1232
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 13, 9, 20, 10, 20, 3, 20, 9, 9, 1, 12, 0.09999999999999995, 97.73846153846155, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102903
# Test Data Points: 25726
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7689465473355777
# Specificity : 0.953864324204621
# Accuracy: 0.8663220088626292
# ROC 0.86140543577
# TP 9365 FP 625 TN 12922 FN 2814
#
#
#
# None
# Cross: Validation: [ 0.54429199  0.92121118  0.93185617  0.93896987  0.92684159]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0535279805352798
# Specificity : 0.9577607157451018
# Accuracy: 0.9344018437041692
# ROC 0.50564434814
# TP 66 FP 1964 TN 44533 FN 1167
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 8, 11, 11, 8, 6, 20, 16, 5, 7, 7, 19, 12, -1.546153846153846, 37.392307692307696, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102842
# Test Data Points: 25711
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7698270234986945
# Specificity : 0.9487922705314009
# Accuracy: 0.8634825561043911
# ROC 0.859309647015
# TP 9435 FP 689 TN 12766 FN 2821
#
#
#
# None
# Cross: Validation: [ 0.54488177  0.93104119  0.92851031  0.93061066  0.93329444]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.1192214111922141
# Specificity : 0.9494160913607329
# Accuracy: 0.9279698302954117
# ROC 0.534318751276
# TP 147 FP 2352 TN 44145 FN 1086
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 7, 7, 17, 7, 3, 20, 11, 9, 8, 3, 2, 13, -0.7538461538461536, 55.96153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6411184210526316
# Specificity : 0.6309243697478991
# Accuracy: 0.6360764754779717
# ROC 0.6360213954
# TP 1949 FP 1098 TN 1877 FN 1091
#
#
#
# None
# Cross: Validation: [ 0.63630319  0.64145612  0.63584968  0.64649152  0.6434985 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6942416869424168
# Specificity : 0.6572036905606813
# Accuracy: 0.6581604860674628
# ROC 0.675722688752
# TP 856 FP 15939 TN 30558 FN 377
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 12, 13, 19, 11, 13, 20, 4, 13, 11, 7, 10, 12, 0.8692307692307693, 7.015384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6453947368421052
# Specificity : 0.6278991596638656
# Accuracy: 0.6367414796342478
# ROC 0.636646948253
# TP 1962 FP 1107 TN 1868 FN 1078
#
#
#
# None
# Cross: Validation: [ 0.63513963  0.64527926  0.6443299   0.63402062  0.64266711]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6942416869424168
# Specificity : 0.650622620814246
# Accuracy: 0.651749423842447
# ROC 0.672432153878
# TP 856 FP 16245 TN 30252 FN 377
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 12, 20, 1, 2, 10, 20, 11, 9, 1, 20, 2, 11, -0.06153846153846161, 11.292307692307695, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47262
# Test Data Points: 11816
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.18104330037504263
# Specificity : 0.9697174378025442
# Accuracy: 0.7739505754908599
# ROC 0.575380369089
# TP 531 FP 269 TN 8614 FN 2402
#
#
#
# None
# Cross: Validation: [ 0.76880765  0.76574137  0.76580618  0.7720694   0.76893779]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.154095701540957
# Specificity : 0.9657397251435577
# Accuracy: 0.9447726796564005
# ROC 0.559917713342
# TP 190 FP 1593 TN 44904 FN 1043
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 5, 10, 17, 11, 10, 20, 11, 7, 20, 10, 17, 2, -0.8846153846153846, 68.4923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 47256
# Test Data Points: 11815
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.19510537049626106
# Specificity : 0.9683308914684999
# Accuracy: 0.7757934828607702
# ROC 0.581718130982
# TP 574 FP 281 TN 8592 FN 2368
#
#
#
# None
# Cross: Validation: [ 0.76859924  0.76648328  0.76747926  0.77247334  0.76957589]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.1549067315490673
# Specificity : 0.9629223390756393
# Accuracy: 0.942049025769956
# ROC 0.558914535312
# TP 191 FP 1724 TN 44773 FN 1042
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 1, 17, 20, 12, 19, 3, 1, 3, 20, 0, 0, 0.4181818181818182, -4.572727272727272, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6394736842105263
# Specificity : 0.7371428571428571
# Accuracy: 0.687780548628429
# ROC 0.688308270677
# TP 1944 FP 782 TN 2193 FN 1096
#
#
#
# None
# Cross: Validation: [ 0.66007314  0.72506649  0.71300299  0.6950449   0.66794147]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6512570965125709
# Specificity : 0.43751209755468096
# Accuracy: 0.4430337314058244
# ROC 0.544384597034
# TP 803 FP 26154 TN 20343 FN 430
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 12, 20, 5, 20, 19, 20, 10, 20, 6, 7, 13, 3, 0.5538461538461539, -2.6461538461538474, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6592105263157895
# Specificity : 0.7310924369747899
# Accuracy: 0.6947630922693266
# ROC 0.695151481645
# TP 2004 FP 800 TN 2175 FN 1036
#
#
#
# None
# Cross: Validation: [ 0.6584109   0.72606383  0.71267044  0.68922514  0.67259727]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.6196269261962692
# Specificity : 0.43845839516527946
# Accuracy: 0.4431384873245338
# ROC 0.529042660681
# TP 764 FP 26110 TN 20387 FN 469
#
#
#
# None
