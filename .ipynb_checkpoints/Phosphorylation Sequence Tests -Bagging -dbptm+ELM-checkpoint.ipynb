# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 225408
# Test Data Points: 25046
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9251550044286979
# Specificity : 0.9995616171456405
# Accuracy: 0.9861454922941787
# ROC 0.962358310787
# TP 4178 FP 9 TN 20521 FN 338
#
#
#
# None
# Cross: Validation: [ 0.98738321  0.98636482  0.98576591  0.98708325  0.98752246]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 475862
# Test Data Points: 25046
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9265608465608466
# Specificity : 0.9984252743467349
# Accuracy: 0.9848678431685698
# ROC 0.962493060454
# TP 4378 FP 32 TN 20289 FN 347
#
#
#
# None
# Cross: Validation: [ 0.98674439  0.9875826   0.98634485  0.9869435   0.98654422]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 365767
# Test Data Points: 40641
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9497782158698866
# Specificity : 0.9940052085892586
# Accuracy: 0.971924903422652
# ROC 0.97189171223
# TP 19271 FP 122 TN 20229 FN 1019
#
#
#
# None
# Cross: Validation: [ 0.96278435  0.97037474  0.97321637  0.97423752  0.97198607]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 616221
# Test Data Points: 40641
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9410952146028614
# Specificity : 0.9933729321093712
# Accuracy: 0.9672990329962353
# ROC 0.967234073356
# TP 19076 FP 135 TN 20236 FN 1194
#
#
#
# None
# Cross: Validation: [ 0.96336257  0.97391796  0.97282268  0.97395455  0.96945166]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 364282
# Test Data Points: 40476
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9670587062693112
# Specificity : 0.9983341499265066
# Accuracy: 0.9828293309615574
# ROC 0.982696428098
# TP 19405 FP 34 TN 20376 FN 661
#
#
#
# None
# Cross: Validation: [ 0.97067434  0.98464522  0.98760979  0.9862633   0.98620153]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.31557134399052694
# Specificity : 0.7216117216117216
# Accuracy: 0.7007967220578193
# ROC 0.518591532801
# TP 1066 FP 17404 TN 45113 FN 2312
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 585083
# Test Data Points: 37182
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9628287379401538
# Specificity : 0.99934379287717
# Accuracy: 0.9792910548114679
# ROC 0.981086265409
# TP 19660 FP 11 TN 16752 FN 759
#
#
#
# None
# Cross: Validation: [ 0.96202412  0.98345929  0.98664641  0.9857992   0.98645814]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.27146240378922437
# Specificity : 0.8360925828174737
# Accuracy: 0.8071477350330071
# ROC 0.553777493303
# TP 917 FP 10247 TN 52270 FN 2461
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 83030
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.93173550181896
# Specificity : 0.9973643751372722
# Accuracy: 0.96412313028398
# ROC 0.964549938478
# TP 4354 FP 12 TN 4541 FN 319
#
#
#
# None
# Cross: Validation: [ 0.96374377  0.96694125  0.96222632  0.96428184  0.96487805]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9986403698194091
# Accuracy: 0.9474618711586615
# ROC 0.499468201488
# TP 1 FP 85 TN 62432 FN 3377
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 333484
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9289535630216135
# Specificity : 0.9978036459477267
# Accuracy: 0.9629308476045957
# ROC 0.963378604485
# TP 4341 FP 10 TN 4543 FN 332
#
#
#
# None
# Cross: Validation: [ 0.9664535   0.96255148  0.96477347  0.96401084  0.96428184]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 1.0
# Accuracy: 0.9487518021094165
# ROC 0.500148016578
# TP 1 FP 0 TN 62517 FN 3377
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 210854
# Test Data Points: 23429
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9294830196841878
# Specificity : 0.999734127406147
# Accuracy: 0.9858722096547015
# ROC 0.964608573545
# TP 4297 FP 5 TN 18801 FN 326
#
#
#
# None
# Cross: Validation: [ 0.98587191  0.98559447  0.98619203  0.98578624  0.98661858]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 461288
# Test Data Points: 23426
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.927288465700065
# Specificity : 0.999734113267748
# Accuracy: 0.9854435242892513
# ROC 0.963511289484
# TP 4285 FP 5 TN 18800 FN 336
#
#
#
# None
# Cross: Validation: [ 0.98559324  0.98663906  0.9865534   0.98612623  0.98510171]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 83030
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9415792852557243
# Specificity : 0.9960465627059082
# Accuracy: 0.9684587036635595
# ROC 0.968812923981
# TP 4400 FP 18 TN 4535 FN 273
#
#
#
# None
# Cross: Validation: [ 0.96900065  0.96764578  0.97078907  0.97143631  0.96330623]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.11308466548253404
# Specificity : 0.8914375289921141
# Accuracy: 0.8515365353972228
# ROC 0.502261097237
# TP 382 FP 6787 TN 55730 FN 2996
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 333484
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9420072758399315
# Specificity : 0.9967054689215902
# Accuracy: 0.9690006503360069
# ROC 0.969356372381
# TP 4402 FP 15 TN 4538 FN 271
#
#
#
# None
# Cross: Validation: [ 0.9685129   0.96986777  0.96878387  0.97273713  0.96065041]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.09680284191829484
# Specificity : 0.9203256714173744
# Accuracy: 0.8781091129827756
# ROC 0.508564256668
# TP 327 FP 4981 TN 57536 FN 3051
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 11361
# Test Data Points: 1263
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.03333333333333333
# Specificity : 1.0
# Accuracy: 0.9540775930324624
# ROC 0.516666666667
# TP 2 FP 0 TN 1203 FN 58
#
#
#
# None
# Cross: Validation: [ 0.95407759  0.95405941  0.95485149  0.9544374   0.9548336 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 23985
# Test Data Points: 1263
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.01818181818181818
# Specificity : 1.0
# Accuracy: 0.9572446555819477
# ROC 0.509090909091
# TP 1 FP 0 TN 1208 FN 54
#
#
#
# None
# Cross: Validation: [ 0.95407759  0.95366337  0.95485149  0.95562599  0.9544374 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21797
# Test Data Points: 2422
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8828451882845189
# Specificity : 0.9910350448247759
# Accuracy: 0.9376548307184145
# ROC 0.936940116555
# TP 1055 FP 11 TN 1216 FN 140
#
#
#
# None
# Cross: Validation: [ 0.83013416  0.94880264  0.95004129  0.95354119  0.94610778]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 4348 TN 19166 FN 41
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 34421
# Test Data Points: 2422
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8212244897959183
# Specificity : 0.9891395154553049
# Accuracy: 0.9042113955408753
# ROC 0.905182002626
# TP 1006 FP 13 TN 1184 FN 219
#
#
#
# None
# Cross: Validation: [ 0.83570691  0.91824938  0.95829893  0.94156515  0.92917613]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 4388 TN 19126 FN 41
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21654
# Test Data Points: 2407
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9428807947019867
# Specificity : 0.9733110925771477
# Accuracy: 0.9580390527627752
# ROC 0.95809594364
# TP 1139 FP 32 TN 1167 FN 69
#
#
#
# None
# Cross: Validation: [ 0.87596094  0.96717224  0.96862664  0.96736645  0.97256288]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.49383346091690056
# Accuracy: 0.49467204415198474
# ROC 0.734721608507
# TP 40 FP 11902 TN 11612 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 34273
# Test Data Points: 2406
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9371859296482412
# Specificity : 0.9752475247524752
# Accuracy: 0.956359102244389
# ROC 0.9562167272
# TP 1119 FP 30 TN 1182 FN 75
#
#
#
# None
# Cross: Validation: [ 0.86803824  0.97381546  0.97277073  0.96923077  0.97713098]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.5023390320660033
# Accuracy: 0.5031628104436425
# ROC 0.738974394082
# TP 40 FP 11702 TN 11812 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1063
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5737704918032787
# Specificity : 0.7068965517241379
# Accuracy: 0.6386554621848739
# ROC 0.640333521764
# TP 35 FP 17 TN 41 FN 26
#
#
#
# None
# Cross: Validation: [ 0.57142857  0.64830508  0.58050847  0.62711864  0.63983051]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.7168495364463724
# Accuracy: 0.7156442368923795
# ROC 0.370619890174
# TP 1 FP 6658 TN 16856 FN 40
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13687
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6065573770491803
# Specificity : 0.6724137931034483
# Accuracy: 0.6386554621848739
# ROC 0.639485585076
# TP 37 FP 19 TN 39 FN 24
#
#
#
# None
# Cross: Validation: [ 0.58823529  0.58474576  0.61016949  0.61016949  0.6059322 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6605426554393128
# Accuracy: 0.6611335172999363
# ROC 0.83027132772
# TP 41 FP 7982 TN 15532 FN 0
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 10381
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04838709677419355
# Specificity : 1.0
# Accuracy: 0.9488734835355286
# ROC 0.524193548387
# TP 3 FP 0 TN 1092 FN 59
#
#
#
# None
# Cross: Validation: [ 0.95017331  0.9514521   0.95058518  0.95101864  0.94969644]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 23003
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.08064516129032258
# Specificity : 0.9990842490842491
# Accuracy: 0.949740034662045
# ROC 0.539864705187
# TP 5 FP 1 TN 1091 FN 57
#
#
#
# None
# Cross: Validation: [ 0.95233969  0.94971825  0.9501301   0.9509974   0.95143105]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1063
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5573770491803278
# Specificity : 0.7241379310344828
# Accuracy: 0.6386554621848739
# ROC 0.640757490107
# TP 34 FP 16 TN 42 FN 27
#
#
#
# None
# Cross: Validation: [ 0.71008403  0.76694915  0.69067797  0.73728814  0.65677966]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3804541974993621
# Accuracy: 0.3815325833156442
# ROC 0.69022709875
# TP 41 FP 14568 TN 8946 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13687
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6721311475409836
# Specificity : 0.7931034482758621
# Accuracy: 0.7310924369747899
# ROC 0.732617297908
# TP 41 FP 12 TN 46 FN 20
#
#
#
# None
# Cross: Validation: [ 0.72689076  0.74576271  0.69915254  0.69915254  0.71186441]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.39746533979756743
# Accuracy: 0.3985141158989599
# ROC 0.698732669899
# TP 41 FP 14168 TN 9346 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 74613
# Test Data Points: 8291
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8959731543624161
# Specificity : 0.9995588883987648
# Accuracy: 0.9809431914123748
# ROC 0.947766021381
# TP 1335 FP 3 TN 6798 FN 155
#
#
#
# None
# Cross: Validation: [ 0.9819684   0.98257146  0.98094089  0.98039807  0.98130277]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 157517
# Test Data Points: 8291
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8876329787234043
# Specificity : 1.0
# Accuracy: 0.9796164515739959
# ROC 0.943816489362
# TP 1335 FP 0 TN 6787 FN 169
#
#
#
# None
# Cross: Validation: [ 0.98021952  0.98269208  0.98190591  0.98112183  0.98136309]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 123230
# Test Data Points: 13693
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9246106825789551
# Specificity : 0.9934036939313984
# Accuracy: 0.9588841013656613
# ROC 0.959007188255
# TP 6353 FP 45 TN 6777 FN 518
#
#
#
# None
# Cross: Validation: [ 0.94581173  0.95585174  0.95303827  0.95555799  0.96779141]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 206134
# Test Data Points: 13693
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8858056080197588
# Specificity : 0.9969162995594714
# Accuracy: 0.9410647776236033
# ROC 0.94136095379
# TP 6097 FP 21 TN 6789 FN 786
#
#
#
# None
# Cross: Validation: [ 0.94639597  0.94175644  0.9512489   0.95376862  0.94818142]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 121123
# Test Data Points: 13459
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9494347693247784
# Specificity : 0.9989874150151887
# Accuracy: 0.9748866929192362
# ROC 0.97421109217
# TP 6215 FP 7 TN 6906 FN 331
#
#
#
# None
# Cross: Validation: [ 0.95738752  0.97678047  0.9773369   0.97755982  0.97599941]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.1873479318734793
# Specificity : 0.9167688237950835
# Accuracy: 0.8979258328095537
# ROC 0.552058377834
# TP 231 FP 3870 TN 42627 FN 1002
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 204084
# Test Data Points: 13465
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9492034866245868
# Specificity : 0.9991190720892673
# Accuracy: 0.9744522836984776
# ROC 0.974161279357
# TP 6316 FP 6 TN 6805 FN 338
#
#
#
# None
# Cross: Validation: [ 0.95766803  0.97634608  0.97753351  0.97675282  0.97894385]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.046228710462287104
# Specificity : 0.9619115211734091
# Accuracy: 0.9382568615126755
# ROC 0.504070115818
# TP 57 FP 1771 TN 44726 FN 1176
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 27066
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9060272197018795
# Specificity : 0.9959044368600682
# Accuracy: 0.9498005319148937
# ROC 0.950965828281
# TP 1398 FP 6 TN 1459 FN 145
#
#
#
# None
# Cross: Validation: [ 0.94996676  0.95212766  0.94911872  0.9501164   0.95128035]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0032441200324412004
# Specificity : 0.9963008366131149
# Accuracy: 0.9706473915776241
# ROC 0.499772478323
# TP 4 FP 172 TN 46325 FN 1229
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 109970
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.898250162022035
# Specificity : 0.9993174061433447
# Accuracy: 0.9474734042553191
# ROC 0.948783784083
# TP 1386 FP 1 TN 1464 FN 157
#
#
#
# None
# Cross: Validation: [ 0.94980053  0.94863697  0.95061523  0.94812105  0.94911872]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 1 TN 46496 FN 1233
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 70252
# Test Data Points: 7806
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9026017344896597
# Specificity : 1.0
# Accuracy: 0.9812964386369459
# ROC 0.951300867245
# TP 1353 FP 0 TN 6307 FN 146
#
#
#
# None
# Cross: Validation: [ 0.97918401  0.98027159  0.9809109   0.98001409  0.98123118]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 153163
# Test Data Points: 7807
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9029451137884873
# Specificity : 1.0
# Accuracy: 0.9814269245548867
# ROC 0.951472556894
# TP 1349 FP 0 TN 6313 FN 145
#
#
#
# None
# Cross: Validation: [ 0.98104265  0.98104265  0.9803369   0.98091334  0.97834999]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 27066
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9202851587815943
# Specificity : 0.9979522184300341
# Accuracy: 0.9581117021276596
# ROC 0.959118688606
# TP 1420 FP 3 TN 1462 FN 123
#
#
#
# None
# Cross: Validation: [ 0.94930186  0.95362367  0.9539408   0.95427336  0.95227802]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.10786699107866991
# Specificity : 0.9193496354603523
# Accuracy: 0.8983867588518751
# ROC 0.51360831327
# TP 133 FP 3750 TN 42747 FN 1100
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 109970
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.916396629941672
# Specificity : 0.9986348122866894
# Accuracy: 0.9564494680851063
# ROC 0.957515721114
# TP 1414 FP 2 TN 1463 FN 129
#
#
#
# None
# Cross: Validation: [ 0.94996676  0.95428856  0.95410708  0.95028267  0.95660126]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.10381184103811841
# Specificity : 0.9532012818031271
# Accuracy: 0.9312591661428871
# ROC 0.528506561421
# TP 128 FP 2176 TN 44321 FN 1105
#
#
#
# None
