# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s.csv")
    y.process_data(vector_function="chemical", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("svc")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s.csv")
    x.process_data(vector_function="chemical", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("svc")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 162268
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17717 FN 313
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 342566
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17699 FN 331
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 319478
# Test Data Points: 35498
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7410441857837043
# Specificity : 0.5217977528089888
# Accuracy: 0.6311059778015663
# ROC 0.631420969296
# TP 13115 FP 8512 TN 9288 FN 4583
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.835109532267614
# Specificity : 0.5656381464241726
# Accuracy: 0.5794521587373852
# ROC 0.700373839346
# TP 2821 FP 27155 TN 35362 FN 557
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 499776
# Test Data Points: 35498
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.24384222633675587
# Specificity : 0.8801697312588401
# Accuracy: 0.5606794748999944
# ROC 0.562005978798
# TP 4346 FP 2118 TN 15557 FN 13477
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.20485494375370042
# Specificity : 0.9009709359054338
# Accuracy: 0.8652856817664466
# ROC 0.55291293983
# TP 692 FP 6191 TN 56326 FN 2686
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 290071
# Test Data Points: 32231
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8334454158260479
# Specificity : 0.4770973795787864
# Accuracy: 0.6743818063355155
# ROC 0.655271397702
# TP 14872 FP 7523 TN 6864 FN 2972
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.9105979869745412
# Specificity : 0.4829086488475135
# Accuracy: 0.5048334471507702
# ROC 0.696753317911
# TP 3076 FP 32327 TN 30190 FN 302
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 470543
# Test Data Points: 32250
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.40262668395242657
# Specificity : 0.8208698049486526
# Accuracy: 0.5907906976744186
# ROC 0.611748244451
# TP 7143 FP 2599 TN 11910 FN 10598
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.3475429248075784
# Specificity : 0.8078602620087336
# Accuracy: 0.7842628424007891
# ROC 0.577701593408
# TP 1174 FP 12012 TN 50505 FN 2204
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7311475409836066
# Specificity : 0.5213414634146342
# Accuracy: 0.6224328593996841
# ROC 0.626244502199
# TP 223 FP 157 TN 171 FN 82
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.8490230905861457
# Specificity : 0.5730121406977302
# Accuracy: 0.5871613931254268
# ROC 0.711017615642
# TP 2868 FP 26694 TN 35823 FN 510
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 311 FN 322
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 156883
# Test Data Points: 17432
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17096 FN 336
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 337181
# Test Data Points: 17432
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17114 FN 318
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6026490066225165
# Specificity : 0.8368580060422961
# Accuracy: 0.7251184834123223
# ROC 0.719753506332
# TP 182 FP 54 TN 277 FN 120
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.5837773830669035
# Specificity : 0.3243277828430667
# Accuracy: 0.33762804461643525
# ROC 0.454052582955
# TP 1972 FP 42241 TN 20276 FN 1406
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 323 FN 310
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y.csv")
    y.process_data(vector_function="chemical", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("svc")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y.csv")
    x.process_data(vector_function="chemical", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("svc")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 11334
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1217 FN 43
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 23928
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1214 FN 46
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21744
# Test Data Points: 2416
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6812080536912751
# Specificity : 0.5196078431372549
# Accuracy: 0.5993377483443708
# ROC 0.600407948414
# TP 812 FP 588 TN 636 FN 380
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.5497150633665051
# Accuracy: 0.5504988325196349
# ROC 0.774857531683
# TP 41 FP 10588 TN 12926 FN 0
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 34338
# Test Data Points: 2416
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3314873417721519
# Specificity : 0.8428819444444444
# Accuracy: 0.5753311258278145
# ROC 0.587184643108
# TP 419 FP 181 TN 971 FN 845
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8282725184996172
# Accuracy: 0.8285714285714286
# ROC 0.91413625925
# TP 41 FP 4038 TN 19476 FN 0
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 18143
# Test Data Points: 2016
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8637123745819398
# Specificity : 0.3621951219512195
# Accuracy: 0.6597222222222222
# ROC 0.612953748267
# TP 1033 FP 523 TN 297 FN 163
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3399676788296334
# Accuracy: 0.341116535767353
# ROC 0.669983839415
# TP 41 FP 15520 TN 7994 FN 0
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 30724
# Test Data Points: 2015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6411522633744856
# Specificity : 0.67375
# Accuracy: 0.6540942928039702
# ROC 0.657451131687
# TP 779 FP 261 TN 539 FN 436
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6031300501828698
# Accuracy: 0.603820844831246
# ROC 0.801565025091
# TP 41 FP 9332 TN 14182 FN 0
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7818181818181819
# Specificity : 0.27586206896551724
# Accuracy: 0.5221238938053098
# ROC 0.528840125392
# TP 43 FP 42 TN 16 FN 12
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.47554648294632984
# Accuracy: 0.47645935045637866
# ROC 0.737773241473
# TP 41 FP 12332 TN 11182 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 59 FN 54
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 10404
# Test Data Points: 1157
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1095 FN 62
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 22998
# Test Data Points: 1157
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1109 FN 48
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5272727272727272
# Specificity : 0.8103448275862069
# Accuracy: 0.672566371681416
# ROC 0.668808777429
# TP 29 FP 11 TN 47 FN 26
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.45572850216892064
# Accuracy: 0.4549777117384844
# ROC 0.240059373036
# TP 1 FP 12798 TN 10716 FN 40
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 54 FN 59
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t.csv")
    y.process_data(vector_function="chemical", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("svc")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t.csv")
    x.process_data(vector_function="chemical", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("svc")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58739
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6387 FN 140
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 124005
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6370 FN 157
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 114707
# Test Data Points: 12746
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7544705333540662
# Specificity : 0.5159144893111639
# Accuracy: 0.6362780480150636
# ROC 0.635192511333
# TP 4852 FP 3057 TN 3258 FN 1579
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.8069748580697486
# Specificity : 0.5825322063789061
# Accuracy: 0.5883301906557721
# ROC 0.694753532224
# TP 995 FP 19411 TN 27086 FN 238
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 179973
# Test Data Points: 12746
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.25446217027325857
# Specificity : 0.8866718628215121
# Accuracy: 0.5726502432135572
# ROC 0.570567016547
# TP 1611 FP 727 TN 5688 FN 4720
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.31386861313868614
# Specificity : 0.9124889777835129
# Accuracy: 0.8970249319086528
# ROC 0.613178795461
# TP 387 FP 4069 TN 42428 FN 846
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 102210
# Test Data Points: 11357
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8642207588585764
# Specificity : 0.4741916047399076
# Accuracy: 0.6932288456458572
# ROC 0.669206181799
# TP 5512 FP 2618 TN 2361 FN 866
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.9124087591240876
# Specificity : 0.48785943179129837
# Accuracy: 0.49882673371045466
# ROC 0.700134095458
# TP 1125 FP 23813 TN 22684 FN 108
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 167466
# Test Data Points: 11356
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.460290216882509
# Specificity : 0.8111987062866384
# Accuracy: 0.6131560408594575
# ROC 0.635744461585
# TP 2950 FP 934 TN 4013 FN 3459
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.3884833738848337
# Specificity : 0.8120954040045595
# Accuracy: 0.8011523151058034
# ROC 0.600289388945
# TP 479 FP 8737 TN 37760 FN 754
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.78125
# Specificity : 0.5563380281690141
# Accuracy: 0.6754966887417219
# ROC 0.668794014085
# TP 125 FP 63 TN 79 FN 35
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.8710462287104623
# Specificity : 0.5835215175172592
# Accuracy: 0.5909490886235073
# ROC 0.727283873114
# TP 1074 FP 19365 TN 27132 FN 159
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 153 FN 149
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 56144
# Test Data Points: 6239
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6092 FN 147
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 121410
# Test Data Points: 6239
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6101 FN 138
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6180555555555556
# Specificity : 0.7658227848101266
# Accuracy: 0.695364238410596
# ROC 0.691939170183
# TP 89 FP 37 TN 121 FN 55
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.643146796431468
# Specificity : 0.3315697786953997
# Accuracy: 0.33961868845589777
# ROC 0.487358287563
# TP 793 FP 31080 TN 15417 FN 440
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 155 FN 147
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
