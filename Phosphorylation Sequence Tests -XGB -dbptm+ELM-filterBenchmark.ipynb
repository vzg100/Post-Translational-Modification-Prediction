# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data="Data/Benchmarks/phos.csv")
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9273568661213948
# Specificity : 0.9997058751439987
# Accuracy: 0.9862849613703061
# ROC 0.963531370633
# TP 8617 FP 12 TN 40787 FN 675
#
#
#
# None
# Cross: Validation: [ 0.98716362  0.98650456  0.98744285  0.98638451  0.98668397]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9313001953548947
# Specificity : 0.9988012818944639
# Accuracy: 0.9863847797009443
# ROC 0.965050738625
# TP 8581 FP 49 TN 40828 FN 633
#
#
#
# None
# Cross: Validation: [ 0.98682424  0.98558623  0.98720329  0.98708325  0.9874426 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9472874755041798
# Specificity : 0.9936537381922917
# Accuracy: 0.9706577101941389
# ROC 0.970470606848
# TP 38188 FP 260 TN 40709 FN 2125
#
#
#
# None
# Cross: Validation: [ 0.96277204  0.96991954  0.9737208   0.97171541  0.97308104]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.941720674813239
# Specificity : 0.9947376150381829
# Accuracy: 0.9683693806746881
# ROC 0.968229144926
# TP 38070 FP 215 TN 40641 FN 2356
#
#
#
# None
# Cross: Validation: [ 0.96300579  0.97078074  0.97378231  0.9729088   0.97288419]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323711
# Test Data Points: 80928
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9684124060337532
# Specificity : 0.997840702753104
# Accuracy: 0.9832320086990906
# ROC 0.983126554393
# TP 38905 FP 88 TN 40666 FN 1269
#
#
#
# None
# Cross: Validation: [ 0.9707645   0.98630882  0.98618525  0.98744548  0.98667935]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.29988158673771464
# Specificity : 0.7764927939600429
# Accuracy: 0.7520600956066469
# ROC 0.538187190349
# TP 1013 FP 13973 TN 48544 FN 2365
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574182
# Test Data Points: 80933
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9607652156539547
# Specificity : 0.9970898953340507
# Accuracy: 0.9791185301422164
# ROC 0.978927555494
# TP 38470 FP 119 TN 40773 FN 1571
#
#
#
# None
# Cross: Validation: [ 0.97127253  0.98430781  0.98681609  0.98637127  0.98608709]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.08555358200118414
# Specificity : 0.9308508085800662
# Accuracy: 0.887518021094165
# ROC 0.508202195291
# TP 289 FP 4323 TN 58194 FN 3089
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9302524604193411
# Specificity : 0.9973637961335676
# Accuracy: 0.9633644049425536
# ROC 0.963808128276
# TP 8696 FP 24 TN 9080 FN 652
#
#
#
# None
# Cross: Validation: [ 0.96601994  0.96287665  0.96607414  0.96352304  0.96379404]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9980005438520723
# Accuracy: 0.9468548448288945
# ROC 0.499148288504
# TP 1 FP 125 TN 62392 FN 3377
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9311082584510055
# Specificity : 0.9979130052724078
# Accuracy: 0.9640689356167353
# ROC 0.964510631862
# TP 8704 FP 19 TN 9085 FN 644
#
#
#
# None
# Cross: Validation: [ 0.96271407  0.96271407  0.96683286  0.96428184  0.96579946]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9993441783834797
# Accuracy: 0.9481296001214052
# ROC 0.49982010577
# TP 1 FP 41 TN 62476 FN 3377
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187439
# Test Data Points: 46860
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9300526485441066
# Specificity : 0.9995206774425479
# Accuracy: 0.9857234314980794
# ROC 0.964786662993
# TP 8656 FP 18 TN 37535 FN 651
#
#
#
# None
# Cross: Validation: [ 0.98623589  0.98559539  0.98578745  0.98608592  0.98632066]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437890
# Test Data Points: 46859
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9308047706027721
# Specificity : 0.9993342564976566
# Accuracy: 0.9857231268272904
# ROC 0.96506951355
# TP 8663 FP 25 TN 37527 FN 644
#
#
#
# None
# Cross: Validation: [ 0.9862356   0.98533931  0.98582983  0.98593623  0.98668317]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9503637141634574
# Specificity : 0.9972539543057997
# Accuracy: 0.9734988077173207
# ROC 0.973808834235
# TP 8884 FP 25 TN 9079 FN 464
#
#
#
# None
# Cross: Validation: [ 0.96786256  0.97046391  0.97024713  0.97062331  0.96205962]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.10065127294256956
# Specificity : 0.8913415550970136
# Accuracy: 0.8508081038015024
# ROC 0.49599641402
# TP 340 FP 6793 TN 55724 FN 3038
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9442661531878477
# Specificity : 0.9979130052724078
# Accuracy: 0.9707348796878387
# ROC 0.97108957923
# TP 8827 FP 19 TN 9085 FN 521
#
#
#
# None
# Cross: Validation: [ 0.96753739  0.9685129   0.97035552  0.97273713  0.96200542]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.09680284191829484
# Specificity : 0.917350480669258
# Accuracy: 0.8752864405493588
# ROC 0.507076661294
# TP 327 FP 5167 TN 57350 FN 3051
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data="Data/Benchmarks/phos.csv")
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 10099
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06363636363636363
# Specificity : 1.0
# Accuracy: 0.9592079207920792
# ROC 0.531818181818
# TP 7 FP 0 TN 2415 FN 103
#
#
#
# None
# Cross: Validation: [ 0.95486936  0.95366337  0.95485149  0.95522979  0.95522979]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 22723
# Test Data Points: 2525
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.032520325203252036
# Specificity : 1.0
# Accuracy: 0.9528712871287128
# ROC 0.516260162602
# TP 4 FP 0 TN 2402 FN 119
#
#
#
# None
# Cross: Validation: [ 0.95407759  0.95445545  0.95445545  0.95285261  0.9548336 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19375
# Test Data Points: 4844
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8735825283494331
# Specificity : 0.9926918392204629
# Accuracy: 0.9341453344343518
# ROC 0.933137183785
# TP 2080 FP 18 TN 2445 FN 301
#
#
#
# None
# Cross: Validation: [ 0.8373581   0.94240297  0.9576796   0.95416064  0.93846789]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 4348 TN 19166 FN 41
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 31999
# Test Data Points: 4844
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8479800083298625
# Specificity : 0.9979533360622186
# Accuracy: 0.9236168455821635
# ROC 0.922966672196
# TP 2036 FP 5 TN 2438 FN 365
#
#
#
# None
# Cross: Validation: [ 0.83570691  0.94942197  0.95148637  0.93908734  0.96035515]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 4348 TN 19166 FN 41
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 19246
# Test Data Points: 4812
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9240400667779632
# Specificity : 0.9685430463576159
# Accuracy: 0.9463840399002493
# ROC 0.946291556568
# TP 2214 FP 76 TN 2340 FN 182
#
#
#
# None
# Cross: Validation: [ 0.8645054   0.96820449  0.96820449  0.96466431  0.97297859]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.4303819001445947
# Accuracy: 0.4313309276162174
# ROC 0.702995828121
# TP 40 FP 13394 TN 10120 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 31873
# Test Data Points: 4813
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9193954659949622
# Specificity : 0.9691484985602633
# Accuracy: 0.94452524413048
# ROC 0.944271982278
# TP 2190 FP 75 TN 2356 FN 192
#
#
#
# None
# Cross: Validation: [ 0.86557241  0.97506753  0.96904218  0.96799667  0.97672002]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.504975759122225
# Accuracy: 0.5057949479940564
# ROC 0.74029275761
# TP 40 FP 11640 TN 11874 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5677966101694916
# Specificity : 0.7058823529411765
# Accuracy: 0.6371308016877637
# ROC 0.636839481555
# TP 67 FP 35 TN 84 FN 51
#
#
#
# None
# Cross: Validation: [ 0.64705882  0.61440678  0.61440678  0.58898305  0.66101695]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6168240197329251
# Accuracy: 0.6174909785608151
# ROC 0.808412009866
# TP 41 FP 9010 TN 14504 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13569
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.576271186440678
# Specificity : 0.6722689075630253
# Accuracy: 0.6244725738396625
# ROC 0.624270047002
# TP 68 FP 39 TN 80 FN 50
#
#
#
# None
# Cross: Validation: [ 0.59243697  0.63135593  0.61864407  0.66101695  0.6440678 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6152079612145955
# Accuracy: 0.6158777329654002
# ROC 0.807603980607
# TP 41 FP 9048 TN 14466 FN 0
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 9225
# Test Data Points: 2307
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.043478260869565216
# Specificity : 0.9995437956204379
# Accuracy: 0.951885565669701
# ROC 0.521511028245
# TP 5 FP 1 TN 2191 FN 110
#
#
#
# None
# Cross: Validation: [ 0.95103986  0.95056375  0.9518647   0.94969644  0.95056375]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 21852
# Test Data Points: 2307
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05217391304347826
# Specificity : 0.9995437956204379
# Accuracy: 0.9523190290420459
# ROC 0.525858854332
# TP 6 FP 1 TN 2191 FN 109
#
#
#
# None
# Cross: Validation: [ 0.95060659  0.9514521   0.95101864  0.95101864  0.94969644]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 945
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6101694915254238
# Specificity : 0.773109243697479
# Accuracy: 0.6919831223628692
# ROC 0.691639367611
# TP 72 FP 27 TN 92 FN 46
#
#
#
# None
# Cross: Validation: [ 0.72689076  0.72457627  0.71186441  0.78813559  0.66525424]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3997618440078251
# Accuracy: 0.4008066227977075
# ROC 0.699880922004
# TP 41 FP 14114 TN 9400 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13569
# Test Data Points: 237
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6101694915254238
# Specificity : 0.8067226890756303
# Accuracy: 0.7088607594936709
# ROC 0.708446090301
# TP 72 FP 23 TN 96 FN 46
#
#
#
# None
# Cross: Validation: [ 0.74789916  0.72881356  0.70338983  0.72033898  0.70338983]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.40758696946499956
# Accuracy: 0.4086181277860327
# ROC 0.703793484732
# TP 41 FP 13930 TN 9584 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i)
    y.supervised_training("xgb")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data="Data/Benchmarks/phos.csv")
    x.supervised_training("xgb")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 66323
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9008237232289951
# Specificity : 0.9998523549387273
# Accuracy: 0.9817260720101321
# ROC 0.950338039084
# TP 2734 FP 2 TN 13544 FN 301
#
#
#
# None
# Cross: Validation: [ 0.98263177  0.9819684   0.98094089  0.98112183  0.98057901]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 149227
# Test Data Points: 16581
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8972760091893666
# Specificity : 0.9996305600709324
# Accuracy: 0.9808214221096435
# ROC 0.94845328463
# TP 2734 FP 5 TN 13529 FN 313
#
#
#
# None
# Cross: Validation: [ 0.98178748  0.98172717  0.98232811  0.97961399  0.9818456 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 109538
# Test Data Points: 27385
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9228486646884273
# Specificity : 0.9935878537735849
# Accuracy: 0.9578966587547928
# ROC 0.958218259231
# TP 12751 FP 87 TN 13481 FN 1066
#
#
#
# None
# Cross: Validation: [ 0.94727233  0.95727588  0.95873503  0.95541192  0.95964797]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 192442
# Test Data Points: 27385
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9102017207721784
# Specificity : 0.9954257045890512
# Accuracy: 0.9523826912543363
# ROC 0.952813712681
# TP 12589 FP 62 TN 13492 FN 1242
#
#
#
# None
# Cross: Validation: [ 0.94756445  0.95369728  0.95833333  0.96377447  0.95479112]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 107623
# Test Data Points: 26906
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9494919081671057
# Specificity : 0.9994126716100139
# Accuracy: 0.9747639931613766
# ROC 0.974452289889
# TP 12614 FP 8 TN 13613 FN 671
#
#
#
# None
# Cross: Validation: [ 0.95841231  0.97472777  0.97885151  0.978517    0.97747631]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.2197891321978913
# Specificity : 0.8914338559476955
# Accuracy: 0.8740833857112927
# ROC 0.555611494073
# TP 271 FP 5048 TN 41449 FN 962
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 190591
# Test Data Points: 26922
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.942814371257485
# Specificity : 0.9999262645627489
# Accuracy: 0.971584577668821
# ROC 0.97137031791
# TP 12596 FP 1 TN 13561 FN 764
#
#
#
# None
# Cross: Validation: [ 0.95743416  0.97626565  0.97748969  0.97815832  0.977824  ]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.18085969180859693
# Specificity : 0.9026603866916145
# Accuracy: 0.8840142468049444
# ROC 0.54176003925
# TP 223 FP 4526 TN 41971 FN 1010
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8967105263157895
# Specificity : 0.9956302521008403
# Accuracy: 0.9456359102244389
# ROC 0.946170389208
# TP 2726 FP 13 TN 2962 FN 314
#
#
#
# None
# Cross: Validation: [ 0.94680851  0.94930186  0.94895244  0.95194546  0.9524443 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0040551500405515
# Specificity : 0.9964298771963782
# Accuracy: 0.9707940498638173
# ROC 0.500242513618
# TP 5 FP 166 TN 46331 FN 1228
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 106963
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9006578947368421
# Specificity : 0.9983193277310924
# Accuracy: 0.9489609310058188
# ROC 0.949488611234
# TP 2738 FP 5 TN 2970 FN 302
#
#
#
# None
# Cross: Validation: [ 0.95295878  0.94797207  0.95028267  0.94812105  0.9501164 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 2 TN 46495 FN 1233
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 62449
# Test Data Points: 15613
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8978605935127675
# Specificity : 0.9997640581989776
# Accuracy: 0.980849292256453
# ROC 0.948812325856
# TP 2602 FP 3 TN 12712 FN 296
#
#
#
# None
# Cross: Validation: [ 0.97969641  0.97969641  0.9814886   0.97995132  0.98123239]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 145359
# Test Data Points: 15614
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9002760524499654
# Specificity : 1.0
# Accuracy: 0.9814909696426284
# ROC 0.950138026225
# TP 2609 FP 0 TN 12716 FN 289
#
#
#
# None
# Cross: Validation: [ 0.97918668  0.98168428  0.97828732  0.98225837  0.9803369 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 24059
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9105263157894737
# Specificity : 0.9963025210084033
# Accuracy: 0.9529509559434747
# ROC 0.953414418399
# TP 2768 FP 11 TN 2964 FN 272
#
#
#
# None
# Cross: Validation: [ 0.94830452  0.95661569  0.949285    0.95843033  0.9516129 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.07380373073803731
# Specificity : 0.9292427468438824
# Accuracy: 0.9071443536559816
# ROC 0.501523238791
# TP 91 FP 3290 TN 43207 FN 1142
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 106963
# Test Data Points: 6015
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9016447368421052
# Specificity : 0.9979831932773109
# Accuracy: 0.9492934330839568
# ROC 0.94981396506
# TP 2741 FP 6 TN 2969 FN 299
#
#
#
# None
# Cross: Validation: [ 0.95395612  0.95229388  0.95643499  0.95028267  0.9524443 ]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0705596107055961
# Specificity : 0.9566208572596081
# Accuracy: 0.933731405824429
# ROC 0.513590233983
# TP 87 FP 2017 TN 44480 FN 1146
#
#
#
# None
