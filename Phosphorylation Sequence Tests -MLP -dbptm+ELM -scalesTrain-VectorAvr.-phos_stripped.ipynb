# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]


for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 12, 18, 7, 15, 1, 10, 20, 2, 15, 19, 3, 5, 0.10769230769230773, 39.13076923076923, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.002651957144372547
# Specificity : 0.9993606138107417
# Accuracy: 0.8117825557485376
# ROC 0.501006285478
# TP 25 FP 26 TN 40638 FN 9402
#
#
#
# None
# Cross Validation: [ 0.81330352  0.81327983  0.81533609  0.81621082  0.81692953]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.007594936708860759
# Specificity : 0.9994297120045623
# Accuracy: 0.9465514914293427
# ROC 0.503512324357
# TP 3 FP 4 TN 7010 FN 392
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 4, 10, 12, 10, 11, 10, 7, 9, 13, 7, 13, 12, 0.5230769230769231, 86.8692307692308, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04
# Specificity : 0.9908048225770952
# Accuracy: 0.8161745622966201
# ROC 0.515402411289
# TP 368 FP 376 TN 40515 FN 8832
#
#
#
# None
# Cross Validation: [ 0.815759    0.81629434  0.81533609  0.81593132  0.81672989]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.05569620253164557
# Specificity : 0.9895922440832621
# Accuracy: 0.939802942367391
# ROC 0.522644223307
# TP 22 FP 73 TN 6941 FN 373
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 7, 10, 3, 7, 3, 10, 11, 12, 8, 7, 8, 7, -1.3461538461538463, 62.96923076923077, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06386881001186752
# Specificity : 0.9893194845916418
# Accuracy: 0.8180711105787467
# ROC 0.526594147302
# TP 592 FP 436 TN 40386 FN 8677
#
#
#
# None
# Cross Validation: [ 0.81681706  0.81521631  0.81515642  0.81551208  0.81567179]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.07088607594936709
# Specificity : 0.9804676361562589
# Accuracy: 0.9319746254555271
# ROC 0.525676856053
# TP 28 FP 137 TN 6877 FN 367
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 10, 17, 17, 3, 19, 10, 8, 13, 8, 17, 0, 0, -1.9272727272727272, 113.6909090909091, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05856879939374256
# Specificity : 0.9893033729867332
# Accuracy: 0.8176718372561937
# ROC 0.52393608619
# TP 541 FP 437 TN 40417 FN 8696
#
#
#
# None
# Cross Validation: [ 0.81587878  0.81561558  0.8163742   0.81670992  0.8158914 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0759493670886076
# Specificity : 0.9804676361562589
# Accuracy: 0.9322445674180051
# ROC 0.528208501622
# TP 30 FP 137 TN 6877 FN 365
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 12, 1, 20, 6, 7, 10, 17, 10, 20, 4, 9, 7, -1.3461538461538463, 33.223076923076924, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05287206266318538
# Specificity : 0.9903665126286706
# Accuracy: 0.8183306382384061
# ROC 0.521619287646
# TP 486 FP 394 TN 40505 FN 8706
#
#
#
# None
# Cross Validation: [ 0.8153797   0.81647402  0.81627438  0.8171691   0.81463366]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.13924050632911392
# Specificity : 0.9664955802680354
# Accuracy: 0.9223916857875557
# ROC 0.552868043299
# TP 55 FP 235 TN 6779 FN 340
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 11, 1, 11, 10, 9, 19, 10, 10, 10, 2, 0, -0.7833333333333335, 137.5666666666667, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06818916298610363
# Specificity : 0.9882621054695158
# Accuracy: 0.8177516919207043
# ROC 0.528225634228
# TP 633 FP 479 TN 40329 FN 8650
#
#
#
# None
# Cross Validation: [ 0.81482073  0.81621449  0.81555569  0.81680974  0.81629068]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.10632911392405063
# Specificity : 0.9689193042486456
# Accuracy: 0.9229315697125118
# ROC 0.537624209086
# TP 42 FP 218 TN 6796 FN 353
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 3, 8, 11, 2, 11, 10, 17, 2, 3, 1, 20, 3, 0.46923076923076923, 101.85384615384616, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0530466724286949
# Specificity : 0.9897881719113506
# Accuracy: 0.816693617615939
# ROC 0.52141742217
# TP 491 FP 417 TN 40418 FN 8765
#
#
#
# None
# Cross Validation: [ 0.81571908  0.81743227  0.81525623  0.81676981  0.81680974]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 7014 FN 395
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 5, 12, 12, 2, 12, 10, 10, 3, 3, 10, 2, 10, 2.0153846153846153, 24.04615384615385, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04504795775406833
# Specificity : 0.991571106537293
# Accuracy: 0.8162344532950031
# ROC 0.518309532146
# TP 418 FP 344 TN 40468 FN 8861
#
#
#
# None
# Cross Validation: [ 0.81603849  0.81579525  0.81577529  0.81579158  0.81631064]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1 TN 7013 FN 395
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 2, 1, 2, 2, 2, 10, 11, 10, 2, 2, 2, 2, 0.7692307692307693, 51.315384615384616, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.029079861111111112
# Specificity : 0.9942262996941896
# Accuracy: 0.8166536902836837
# ROC 0.511653080403
# TP 268 FP 236 TN 40639 FN 8948
#
#
#
# None
# Cross Validation: [ 0.81589875  0.81545587  0.81573536  0.81577161  0.8158914 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 7014 FN 395
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 3, 8, 7, 7, 10, 10, 1, 3, 3, 2, 10, 11, -5.124106267500723e-17, 97.73846153846155, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04018048990116029
# Specificity : 0.9924968736973739
# Accuracy: 0.8155357249805354
# ROC 0.516338681799
# TP 374 FP 306 TN 40477 FN 8934
#
#
#
# None
# Cross Validation: [ 0.81571908  0.81260107  0.81623445  0.81547215  0.81525255]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.012658227848101266
# Specificity : 0.9981465640148275
# Accuracy: 0.9456066945606695
# ROC 0.505402395931
# TP 5 FP 13 TN 7001 FN 390
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 8, 17, 11, 10, 10, 19, 10, 1, 14, 10, 16, 0, -1.508333333333333, 67.08333333333334, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331691
# Test Data Points: 82923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6353680601847443
# Specificity : 0.9269532491018843
# Accuracy: 0.7792530419787032
# ROC 0.781160654643
# TP 26688 FP 2989 TN 37930 FN 15316
#
#
#
# None
# Cross Validation: [ 0.5305581   0.81143953  0.82152117  0.83958419  0.84044041]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.24556962025316456
# Specificity : 0.9281437125748503
# Accuracy: 0.891753273046295
# ROC 0.586856666414
# TP 97 FP 504 TN 6510 FN 298
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 17, 3, 11, 3, 11, 10, 5, 3, 3, 3, 11, 5, 0.8461538461538459, 83.30769230769232, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331681
# Test Data Points: 82921
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6980316736709642
# Specificity : 0.8613616312126262
# Accuracy: 0.77840354071948
# ROC 0.779696652442
# TP 29399 FP 5657 TN 35147 FN 12718
#
#
#
# None
# Cross Validation: [ 0.50525795  0.81505065  0.83488905  0.84270381  0.82554269]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.4379746835443038
# Specificity : 0.8591388651268891
# Accuracy: 0.8366851127007693
# ROC 0.648556774336
# TP 173 FP 988 TN 6026 FN 222
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [6, 17, 5, 6, 12, 4, 10, 8, 4, 3, 7, 11, 13, 0.2307692307692307, 38.98461538461538, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331742
# Test Data Points: 82936
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6899926364046652
# Specificity : 0.9109630971912727
# Accuracy: 0.7987966624867368
# ROC 0.800477866798
# TP 29048 FP 3636 TN 37201 FN 13051
#
#
#
# None
# Cross Validation: [ 0.50300831  0.81870358  0.839959    0.83852415  0.83518418]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8531645569620253
# Specificity : 0.31151981750784147
# Accuracy: 0.3403968146848428
# ROC 0.582342187235
# TP 337 FP 4829 TN 2185 FN 58
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 7, 2, 8, 9, 12, 10, 19, 9, 1, 2, 19, 8, -1.676923076923077, 10.984615384615388, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331678
# Test Data Points: 82920
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7108929250665652
# Specificity : 0.8929410612884277
# Accuracy: 0.8005909310178485
# ROC 0.801916993177
# TP 29903 FP 4374 TN 36482 FN 12161
#
#
#
# None
# Cross Validation: [ 0.52709205  0.8055837   0.84387173  0.8334881   0.82548029]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8379746835443038
# Specificity : 0.2979754776161962
# Accuracy: 0.32676474557970037
# ROC 0.56797508058
# TP 331 FP 4924 TN 2090 FN 64
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 12, 19, 2, 3, 4, 10, 3, 17, 9, 3, 5, 18, 0.2153846153846153, 46.284615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331780
# Test Data Points: 82945
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7458269208002841
# Specificity : 0.7850896585605502
# Accuracy: 0.7650973536680933
# ROC 0.76545828968
# TP 31500 FP 8749 TN 31961 FN 10735
#
#
#
# None
# Cross Validation: [ 0.51596219  0.8083911   0.83287721  0.82899512  0.83029514]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.7113924050632912
# Specificity : 0.4459652124322783
# Accuracy: 0.4601160750438656
# ROC 0.578678808748
# TP 281 FP 3886 TN 3128 FN 114
#
#
#
# None
# x ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 7, 12, 7, 17, 17, 10, 3, 17, 3, 15, 2, 17, -1.4461538461538461, 136.45384615384614, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331728
# Test Data Points: 82932
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7432942909410563
# Specificity : 0.819127837222399
# Accuracy: 0.7806395601215453
# ROC 0.781211064082
# TP 31286 FP 7387 TN 33454 FN 10805
#
#
#
# None
# Cross Validation: [ 0.51423438  0.81089326  0.83031882  0.80877104  0.82511968]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.789873417721519
# Specificity : 0.41573994867408043
# Accuracy: 0.4356863274396005
# ROC 0.602806683198
# TP 312 FP 4098 TN 2916 FN 83
#
#
#
# None
# y ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 17, 2, 18, 8, 10, 11, 13, 10, 10, 10, 18, 0, -0.9750000000000001, 108.21666666666668, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331753
# Test Data Points: 82939
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9226594301221167
# Specificity : 0.20576594185194233
# Accuracy: 0.5688759208574977
# ROC 0.564212685987
# TP 38760 FP 32508 TN 8422 FN 3249
#
#
#
# None
# Cross Validation: [ 0.51626477  0.82108322  0.83728809  0.83605826  0.8389761 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 395 FP 7014 TN 0 FN 0
#
#
#
# None
# x ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 7, 19, 17, 12, 17, 10, 8, 2, 3, 3, 5, 13, -0.2538461538461537, 52.04615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331723
# Test Data Points: 82931
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8111068775004763
# Specificity : 0.4423410439922812
# Accuracy: 0.629065126430406
# ROC 0.626723960746
# TP 34060 FP 22830 TN 18109 FN 7932
#
#
#
# None
# Cross Validation: [ 0.51022524  0.80890138  0.83078704  0.8351863   0.83511395]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 395 FP 7014 TN 0 FN 0
#
#
#
# None
# y ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 1, 2, 15, 10, 3, 10, 13, 17, 19, 6, 19, 19, -1.0, -3.8307692307692314, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331753
# Test Data Points: 82939
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8295716697980831
# Specificity : 0.6216374841044703
# Accuracy: 0.7270524120136486
# ROC 0.725604576951
# TP 34881 FP 15472 TN 25420 FN 7166
#
#
#
# None
# Cross Validation: [ 0.51042923  0.81556102  0.83748101  0.82596638  0.83239287]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9620253164556962
# Specificity : 0.08411747932706017
# Accuracy: 0.1309218518018626
# ROC 0.523071397891
# TP 380 FP 6424 TN 590 FN 15
#
#
#
# None
# x ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 10, 10, 3, 1, 3, 10, 18, 1, 12, 10, 19, 0, -0.225, 28.74166666666667, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331689
# Test Data Points: 82923
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8058074932332969
# Specificity : 0.6620757260139689
# Accuracy: 0.7350795316136657
# ROC 0.733941609624
# TP 33939 FP 13789 TN 27016 FN 8179
#
#
#
# None
# Cross Validation: [ 0.51230042  0.80709582  0.82674079  0.84021128  0.8417549 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8860759493670886
# Specificity : 0.1394354148845167
# Accuracy: 0.17924146308543662
# ROC 0.512755682126
# TP 350 FP 6036 TN 978 FN 45
#
#
#
# None
# y SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 11, 12, 7, 1, 2, 10, 5, 12, 20, 0, 0, 0, 0.48, 43.849999999999994, 0.1]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 306132
# Test Data Points: 76533
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7004386822766772
# Specificity : 0.7251129000589044
# Accuracy: 0.713574536474462
# ROC 0.712775791168
# TP 25068 FP 11200 TN 29544 FN 10721
#
#
#
# None
# Cross Validation: [ 0.62377505  0.71211112  0.70714594  0.72100924  0.7203784 ]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.5240506329113924
# Specificity : 0.6703735386370117
# Accuracy: 0.662572546902416
# ROC 0.597212085774
# TP 207 FP 2312 TN 4702 FN 188
#
#
#
# None
# x SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 1, 10, 13, 7, 1, 10, 17, 15, 5, 0, 0, 0, -0.56, 3.740000000000001, 0.2]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305684
# Test Data Points: 76421
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.747748000561246
# Specificity : 0.6720933653704703
# Accuracy: 0.7073710105860954
# ROC 0.709920682966
# TP 26646 FP 13374 TN 27412 FN 8989
#
#
#
# None
# Cross Validation: [ 0.62343304  0.70542128  0.70970021  0.72252391  0.71546716]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.5949367088607594
# Specificity : 0.6123467351012262
# Accuracy: 0.6114185450128222
# ROC 0.603641721981
# TP 235 FP 2719 TN 4295 FN 160
#
#
#
# None
# y SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 2, 11, 8, 16, 2, 10, 2, 19, 9, 12, 12, 12, 0.4692307692307693, 32.330769230769235, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305736
# Test Data Points: 76434
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6965904307562789
# Specificity : 0.843501066202603
# Accuracy: 0.7750085040688699
# ROC 0.770045748479
# TP 24823 FP 6385 TN 34414 FN 10812
#
#
#
# None
# Cross Validation: [ 0.62691176  0.71898631  0.72899495  0.72128896  0.72217498]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.4708860759493671
# Specificity : 0.49729113202167097
# Accuracy: 0.49588338507220947
# ROC 0.484088603986
# TP 186 FP 3526 TN 3488 FN 209
#
#
#
# None
# x SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 15, 1, 7, 5, 13, 10, 20, 18, 3, 2, 3, 1, 0.1923076923076922, 18.407692307692304, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305788
# Test Data Points: 76448
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7203079076277117
# Specificity : 0.8250374481251381
# Accuracy: 0.776096169945584
# ROC 0.772672677876
# TP 25733 FP 7125 TN 33598 FN 9992
#
#
#
# None
# Cross Validation: [ 0.60365216  0.72045993  0.73102934  0.71343545  0.70931495]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.47341772151898737
# Specificity : 0.4991445680068435
# Accuracy: 0.49777297880955595
# ROC 0.486281144763
# TP 187 FP 3513 TN 3501 FN 208
#
#
#
# None
# y SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 1, 5, 11, 2, 3, 10, 8, 7, 18, 10, 11, 5, -0.7230769230769233, 95.76153846153848, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 306097
# Test Data Points: 76525
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.551035254616676
# Specificity : 0.8718891749417678
# Accuracy: 0.7220385494936296
# ROC 0.711462214779
# TP 19694 FP 5225 TN 35560 FN 16046
#
#
#
# None
# Cross Validation: [ 0.62868829  0.70551722  0.73016309  0.72977105  0.73123465]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.47848101265822784
# Specificity : 0.49258625605930995
# Accuracy: 0.49183425563503846
# ROC 0.485533634359
# TP 189 FP 3559 TN 3455 FN 206
#
#
#
# None
# x SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 1, 19, 1, 9, 10, 10, 9, 1, 1, 0, 0, 0, -1.4500000000000004, 71.58000000000001, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 232253
# Test Data Points: 58064
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9489870996223083
# Specificity : 0.49381145170618856
# Accuracy: 0.8134472306420502
# ROC 0.721399275664
# TP 38694 FP 8752 TN 8538 FN 2080
#
#
#
# None
# Cross Validation: [ 0.74840265  0.80729552  0.80867334  0.81482183  0.81094673]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5139240506329114
# Specificity : 0.4499572284003422
# Accuracy: 0.4533675259819139
# ROC 0.481940639517
# TP 203 FP 3858 TN 3156 FN 192
#
#
#
# None
# y SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 18, 9, 7, 3, 3, 10, 3, 7, 15, 9, 10, 3, -0.707692307692308, 23.4, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305752
# Test Data Points: 76439
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6352217093299762
# Specificity : 0.8887550990317983
# Accuracy: 0.7701958424364526
# ROC 0.761988404181
# TP 22706 FP 4527 TN 36167 FN 13039
#
#
#
# None
# Cross Validation: [ 0.6203247   0.7289568   0.72513671  0.71769277  0.70758   ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 7014 FN 395
#
#
#
# None
# x SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 15, 8, 12, 12, 7, 10, 2, 11, 7, 1, 17, 5, -0.3153846153846154, 34.57769230769231, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305794
# Test Data Points: 76449
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6869592088998764
# Specificity : 0.7060191418010917
# Accuracy: 0.6971445015631336
# ROC 0.69648917535
# TP 24453 FP 12010 TN 28843 FN 11143
#
#
#
# None
# Cross Validation: [ 0.62444735  0.71851823  0.71987495  0.72154929  0.72059439]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.005063291139240506
# Specificity : 0.9994297120045623
# Accuracy: 0.9464165204481036
# ROC 0.502246501572
# TP 2 FP 4 TN 7010 FN 393
#
#
#
# None
# y SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 13, 10, 5, 19, 3, 10, 3, 2, 17, 1, 3, 19, 0.23846153846153845, 5.661538461538462, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305768
# Test Data Points: 76443
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6987029794896322
# Specificity : 0.8238386308068459
# Accuracy: 0.7656554556990176
# ROC 0.761270805148
# TP 24834 FP 7205 TN 33695 FN 10709
#
#
#
# None
# Cross Validation: [ 0.62876915  0.72312341  0.71383533  0.71235708  0.72147511]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.002531645569620253
# Specificity : 0.9978614200171086
# Accuracy: 0.9447968686732352
# ROC 0.500196532793
# TP 1 FP 15 TN 6999 FN 394
#
#
#
# None
# x SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 10, 20, 10, 20, 12, 10, 20, 10, 20, 20, 20, 20, -0.36153846153846153, 24.04615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305678
# Test Data Points: 76420
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7367036902330526
# Specificity : 0.8023944735354132
# Accuracy: 0.7716697199685946
# ROC 0.769549081884
# TP 26332 FP 8038 TN 32639 FN 9411
#
#
#
# None
# Cross Validation: [ 0.63648735  0.72657681  0.72691346  0.71517555  0.71698138]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.002531645569620253
# Specificity : 0.9994297120045623
# Accuracy: 0.9462815494668646
# ROC 0.500980678787
# TP 1 FP 4 TN 7010 FN 394
#
#
#
# None
# y random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 11, 7, 10, 2, 18, 10, 16, 19, 10, 16, 15, 9, -1.9692307692307693, 61.53846153846153, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7797389816003423
# Specificity : 0.5085676625659051
# Accuracy: 0.6459462388900932
# ROC 0.644153322083
# TP 7289 FP 4474 TN 4630 FN 2059
#
#
#
# None
# Cross Validation: [ 0.59326902  0.63667895  0.63342727  0.63859079  0.64113821]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.8
# Specificity : 0.44425434844596523
# Accuracy: 0.4632204076123633
# ROC 0.622127174223
# TP 316 FP 3898 TN 3116 FN 79
#
#
#
# None
# x random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 8, 10, 5, 5, 11, 10, 13, 4, 7, 7, 11, 5, 0.24615384615384603, 81.67692307692309, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6163885323063757
# Specificity : 0.6655316344463972
# Accuracy: 0.6406351615001084
# ROC 0.640960083376
# TP 5762 FP 3045 TN 6059 FN 3586
#
#
#
# None
# Cross Validation: [ 0.62968784  0.64730111  0.63060915  0.64298103  0.62899729]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.6708860759493671
# Specificity : 0.6213287710293698
# Accuracy: 0.6239708462680523
# ROC 0.646107423489
# TP 265 FP 2656 TN 4358 FN 130
#
#
#
# None
# y random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 9, 1, 3, 10, 11, 10, 7, 17, 17, 17, 3, 10, -1.6307692307692307, 196.12307692307695, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7752460419341035
# Specificity : 0.5258128295254832
# Accuracy: 0.6521786256232387
# ROC 0.65052943573
# TP 7247 FP 4317 TN 4787 FN 2101
#
#
#
# None
# Cross Validation: [ 0.64800564  0.62936267  0.63055495  0.64872629  0.64411924]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8379746835443038
# Specificity : 0.3790989449672084
# Accuracy: 0.4035632339047105
# ROC 0.608536814256
# TP 331 FP 4355 TN 2659 FN 64
#
#
#
# None
# x random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 9, 10, 12, 12, 10, 10, 3, 19, 10, 11, 2, 7, -0.19230769230769224, 117.10769230769232, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7367351305091998
# Specificity : 0.5575571177504394
# Accuracy: 0.6483308042488619
# ROC 0.64714612413
# TP 6887 FP 4028 TN 5076 FN 2461
#
#
#
# None
# Cross Validation: [ 0.63033817  0.62584002  0.642261    0.65127371  0.60130081]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.7974683544303798
# Specificity : 0.4049044767607642
# Accuracy: 0.42583344580915106
# ROC 0.601186415596
# TP 315 FP 4174 TN 2840 FN 80
#
#
#
# None
# y random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 2, 17, 17, 10, 10, 20, 12, 17, 7, 8, 19, -1.3615384615384616, 134.90769230769232, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.715875053487377
# Specificity : 0.5902899824253075
# Accuracy: 0.6539128549750705
# ROC 0.653082517956
# TP 6692 FP 3730 TN 5374 FN 2656
#
#
#
# None
# Cross Validation: [ 0.56622588  0.60844353  0.64507912  0.63685637  0.63355014]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8810126582278481
# Specificity : 0.3296264613629883
# Accuracy: 0.35902281009582937
# ROC 0.605319559795
# TP 348 FP 4702 TN 2312 FN 47
#
#
#
# None
# x random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 5, 18, 5, 19, 3, 10, 19, 10, 9, 7, 8, 18, -1.6153846153846154, 54.97692307692308, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7102053915275995
# Specificity : 0.593695079086116
# Accuracy: 0.6527205722956861
# ROC 0.651950235307
# TP 6639 FP 3699 TN 5405 FN 2709
#
#
#
# None
# Cross Validation: [ 0.64822241  0.6381964   0.62275092  0.61821138  0.64406504]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9164556962025316
# Specificity : 0.3015397775876818
# Accuracy: 0.33432312052908625
# ROC 0.608997736895
# TP 362 FP 4899 TN 2115 FN 33
#
#
#
# None
# y random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 3, 13, 10, 7, 8, 10, 18, 17, 3, 5, 4, 9, -0.38461538461538464, 61.215384615384615, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8932391955498502
# Specificity : 0.3858743409490334
# Accuracy: 0.6429113375243876
# ROC 0.639556768249
# TP 8350 FP 5591 TN 3513 FN 998
#
#
#
# None
# Cross Validation: [ 0.63234338  0.61006937  0.65537611  0.63485095  0.64487805]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.3265822784810127
# Specificity : 0.846307385229541
# Accuracy: 0.8185990012147388
# ROC 0.586444831855
# TP 129 FP 1078 TN 5936 FN 266
#
#
#
# None
# x random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 10, 18, 11, 10, 10, 11, 19, 5, 20, 11, 3, -0.43846153846153846, 73.66153846153846, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6974753958065897
# Specificity : 0.609182776801406
# Accuracy: 0.6539128549750705
# ROC 0.653329086304
# TP 6520 FP 3558 TN 5546 FN 2828
#
#
#
# None
# Cross Validation: [ 0.53728593  0.63608281  0.64415781  0.59062331  0.6397832 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.25316455696202533
# Specificity : 0.8865126889078985
# Accuracy: 0.8527466594682144
# ROC 0.569838622935
# TP 100 FP 796 TN 6218 FN 295
#
#
#
# None
# y random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 1, 10, 17, 8, 11, 10, 12, 9, 20, 3, 19, 0, -0.7916666666666666, 73.36666666666667, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.769576379974326
# Specificity : 0.5297671353251318
# Accuracy: 0.651257316280078
# ROC 0.64967175765
# TP 7194 FP 4281 TN 4823 FN 2154
#
#
#
# None
# Cross Validation: [ 0.64448298  0.6310969   0.64253197  0.60265583  0.63680217]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5037974683544304
# Specificity : 0.7239806102081551
# Accuracy: 0.7122418679983803
# ROC 0.613889039281
# TP 199 FP 1936 TN 5078 FN 196
#
#
#
# None
# x random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 15, 19, 4, 18, 3, 10, 2, 8, 19, 16, 8, 10, -1.3384615384615384, 85.55384615384615, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7382327770646128
# Specificity : 0.562280316344464
# Accuracy: 0.6514199002818123
# ROC 0.650256546705
# TP 6901 FP 3985 TN 5119 FN 2447
#
#
#
# None
# Cross Validation: [ 0.64285714  0.63489053  0.62491871  0.64406504  0.64758808]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.18227848101265823
# Specificity : 0.9284288565725691
# Accuracy: 0.8886489404777973
# ROC 0.555353668793
# TP 72 FP 502 TN 6512 FN 323
#
#
#
# None
# y ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 7, 7, 12, 13, 13, 10, 2, 11, 10, 2, 19, 2, 0.45384615384615395, 25.8, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143813
# Test Data Points: 35954
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.12110990206746464
# Specificity : 0.9811687341204604
# Accuracy: 0.7613339266840964
# ROC 0.551139318094
# TP 1113 FP 504 TN 26260 FN 8077
#
#
#
# None
# Cross Validation: [ 0.75777382  0.75693942  0.74422874  0.76110478  0.75920672]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.13924050632911392
# Specificity : 0.9647847162817222
# Accuracy: 0.9207720340126873
# ROC 0.552012611305
# TP 55 FP 247 TN 6767 FN 340
#
#
#
# None
# x ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 20, 10, 10, 12, 17, 3, 2, 5, 3, 2, 20, 0, 1.05, 22.81666666666667, 0.08333333333333333]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143816
# Test Data Points: 35954
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2465425242295546
# Specificity : 0.9457248515184341
# Accuracy: 0.7671469099404795
# ROC 0.596133687874
# TP 2264 FP 1453 TN 25318 FN 6919
#
#
#
# None
# Cross Validation: [ 0.75577806  0.76189682  0.76364243  0.77083971  0.7516758 ]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.26329113924050634
# Specificity : 0.9153122326775022
# Accuracy: 0.8805506816034553
# ROC 0.589301685959
# TP 104 FP 594 TN 6420 FN 291
#
#
#
# None
# y ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 7, 8, 9, 18, 7, 10, 18, 1, 16, 13, 7, 5, -1.5615384615384613, 76.15384615384617, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143796
# Test Data Points: 35949
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.27146121205527146
# Specificity : 0.9433066746393602
# Accuracy: 0.771537455840218
# ROC 0.607383943347
# TP 2495 FP 1517 TN 25241 FN 6696
#
#
#
# None
# Cross Validation: [ 0.76300417  0.76392211  0.74714178  0.76121064  0.76630132]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.3291139240506329
# Specificity : 0.8927858568577132
# Accuracy: 0.8627345120799028
# ROC 0.610949890454
# TP 130 FP 752 TN 6262 FN 265
#
#
#
# None
# x ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 1, 20, 11, 1, 10, 10, 8, 18, 12, 6, 8, 17, -0.9153846153846155, 32.330769230769235, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143714
# Test Data Points: 35929
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.26435406698564595
# Specificity : 0.9462836194965024
# Accuracy: 0.77174427342815
# ROC 0.605318843241
# TP 2431 FP 1436 TN 25297 FN 6765
#
#
#
# None
# Cross Validation: [ 0.76562109  0.76397896  0.76642823  0.7586562   0.76333222]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.32151898734177214
# Specificity : 0.8953521528371827
# Accuracy: 0.8647590767984883
# ROC 0.608435570089
# TP 127 FP 734 TN 6280 FN 268
#
#
#
# None
# y ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 12, 14, 20, 10, 3, 10, 11, 1, 1, 11, 20, 2, 0.7538461538461537, 71.06923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143734
# Test Data Points: 35934
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.29262722923010004
# Specificity : 0.9367192759368689
# Accuracy: 0.771887349028775
# ROC 0.614673252583
# TP 2691 FP 1692 TN 25046 FN 6505
#
#
#
# None
# Cross Validation: [ 0.75513441  0.75708243  0.76117326  0.7610553   0.75704784]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.3949367088607595
# Specificity : 0.8504419731964642
# Accuracy: 0.8261573761641248
# ROC 0.622689341029
# TP 156 FP 1049 TN 5965 FN 239
#
#
#
# None
# x ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 8, 10, 19, 10, 19, 10, 5, 18, 11, 20, 3, 0, -0.775, 75.48333333333335, 0.16666666666666666]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143761
# Test Data Points: 35941
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2954150369404607
# Specificity : 0.9261697273441298
# Accuracy: 0.7646420522523024
# ROC 0.610792382142
# TP 2719 FP 1974 TN 24763 FN 6485
#
#
#
# None
# Cross Validation: [ 0.76152583  0.76355694  0.76806433  0.76424597  0.76682712]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.3949367088607595
# Specificity : 0.8661248930710008
# Accuracy: 0.8410041841004184
# ROC 0.630530800966
# TP 156 FP 939 TN 6075 FN 239
#
#
#
# None
# y ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 10, 11, 10, 3, 16, 10, 11, 2, 19, 11, 1, 16, -0.9769230769230771, 114.74615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143808
# Test Data Points: 35953
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.18156120895846922
# Specificity : 0.966660437301439
# Accuracy: 0.7658053569938531
# ROC 0.57411082313
# TP 1670 FP 892 TN 25863 FN 7528
#
#
#
# None
# Cross Validation: [ 0.76611131  0.76460935  0.7623286   0.76531946  0.7467108 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.015189873417721518
# Specificity : 0.9987168520102652
# Accuracy: 0.9462815494668646
# ROC 0.506953362714
# TP 6 FP 9 TN 7005 FN 389
#
#
#
# None
# x ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 17, 7, 3, 17, 9, 10, 8, 9, 1, 17, 9, 12, -2.1615384615384614, 61.961538461538474, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143758
# Test Data Points: 35940
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3284639703477597
# Specificity : 0.9190421040833863
# Accuracy: 0.7683082915971063
# ROC 0.623753037216
# TP 3013 FP 2167 TN 24600 FN 6160
#
#
#
# None
# Cross Validation: [ 0.75684474  0.76611018  0.75066778  0.76610368  0.76329336]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.017721518987341773
# Specificity : 0.9955802680353578
# Accuracy: 0.943447158860845
# ROC 0.506650893511
# TP 7 FP 31 TN 6983 FN 388
#
#
#
# None
# y ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 16, 8, 3, 10, 8, 10, 5, 3, 7, 10, 10, 7, -1.130769230769231, 66.13076923076925, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143805
# Test Data Points: 35952
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2839559960788585
# Specificity : 0.9285047252624108
# Accuracy: 0.7639074321317312
# ROC 0.606230360671
# TP 2607 FP 1914 TN 24857 FN 6574
#
#
#
# None
# Cross Validation: [ 0.76335113  0.75342123  0.75509012  0.75950599  0.76305981]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.09873417721518987
# Specificity : 0.9833190761334474
# Accuracy: 0.9361587258739371
# ROC 0.541026626674
# TP 39 FP 117 TN 6897 FN 356
#
#
#
# None
# x ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 8, 10, 11, 10, 1, 10, 10, 2, 20, 20, 3, 17, -0.9615384615384616, 136.09230769230768, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143757
# Test Data Points: 35940
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.27482830044696394
# Specificity : 0.9399260283184518
# Accuracy: 0.770172509738453
# ROC 0.607377164383
# TP 2521 FP 1608 TN 25159 FN 6652
#
#
#
# None
# Cross Validation: [ 0.75639955  0.76115748  0.76611018  0.76039957  0.76643108]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.017721518987341773
# Specificity : 0.9968634160250927
# Accuracy: 0.9446618976919963
# ROC 0.507292467506
# TP 7 FP 22 TN 6992 FN 388
#
#
#
# None
# y near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 3, 18, 4, 8, 3, 10, 19, 1, 1, 8, 1, 19, -0.44615384615384607, 12.923076923076925, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6706247325631151
# Specificity : 0.7004613356766256
# Accuracy: 0.6853457619770215
# ROC 0.68554303412
# TP 6269 FP 2727 TN 6377 FN 3079
#
#
#
# None
# Cross Validation: [ 0.62827878  0.72642532  0.69938218  0.66298103  0.65631436]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.6886075949367089
# Specificity : 0.4023381807812946
# Accuracy: 0.41760021595357
# ROC 0.545472887859
# TP 272 FP 4192 TN 2822 FN 123
#
#
#
# None
# x near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 11, 13, 20, 20, 11, 10, 17, 11, 5, 17, 3, 1, -0.6769230769230768, 83.30769230769232, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4959349593495935
# Specificity : 0.8473198594024605
# Accuracy: 0.6693041404725775
# ROC 0.671627409376
# TP 4636 FP 1390 TN 7714 FN 4712
#
#
#
# None
# Cross Validation: [ 0.63965966  0.60427054  0.70621071  0.65902439  0.6498645 ]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.5113924050632911
# Specificity : 0.5337895637296834
# Accuracy: 0.5325954919692266
# ROC 0.522590984396
# TP 202 FP 3270 TN 3744 FN 193
#
#
#
# None
# y near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 1, 9, 20, 10, 20, 10, 17, 3, 3, 8, 11, 20, -1.0846153846153845, 51.60769230769231, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6695549850235345
# Specificity : 0.7190246045694201
# Accuracy: 0.6939627140689356
# ROC 0.694289794796
# TP 6259 FP 2558 TN 6546 FN 3089
#
#
#
# None
# Cross Validation: [ 0.62714069  0.6889768   0.68816388  0.6199458   0.63300813]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6860759493670886
# Specificity : 0.49672084402623323
# Accuracy: 0.5068160345525712
# ROC 0.591398396697
# TP 271 FP 3530 TN 3484 FN 124
#
#
#
# None
# x near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [4, 3, 18, 13, 19, 12, 10, 2, 20, 2, 5, 15, 17, 0.5, 55.10076923076923, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6810012836970475
# Specificity : 0.703317223198594
# Accuracy: 0.6920117060481249
# ROC 0.692159253448
# TP 6366 FP 2701 TN 6403 FN 2982
#
#
#
# None
# Cross Validation: [ 0.62833297  0.65618903  0.68176891  0.68498645  0.58276423]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6962025316455697
# Specificity : 0.47619047619047616
# Accuracy: 0.4879200971791065
# ROC 0.586196503918
# TP 275 FP 3674 TN 3340 FN 120
#
#
#
# None
# y near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 19, 17, 5, 11, 6, 10, 12, 3, 5, 3, 3, 1, 0.46153846153846145, 30.84615384615385, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7284980744544287
# Specificity : 0.64048769771529
# Accuracy: 0.6850747886407977
# ROC 0.684492886085
# TP 6810 FP 3273 TN 5831 FN 2538
#
#
#
# None
# Cross Validation: [ 0.58990895  0.66269239  0.66095816  0.68531165  0.6396206 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.1468354430379747
# Specificity : 0.9289991445680068
# Accuracy: 0.887299230665407
# ROC 0.537917293803
# TP 58 FP 498 TN 6516 FN 337
#
#
#
# None
# x near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 12, 12, 7, 10, 13, 18, 17, 2, 7, 20, 11, 12, -0.26923076923076916, 21.830769230769235, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6749037227214377
# Specificity : 0.6942003514938488
# Accuracy: 0.6844244526338609
# ROC 0.684552037108
# TP 6309 FP 2784 TN 6320 FN 3039
#
#
#
# None
# Cross Validation: [ 0.6301214   0.64946889  0.68518318  0.60915989  0.63788618]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.09873417721518987
# Specificity : 0.9459652124322783
# Accuracy: 0.9007963287893103
# ROC 0.522349694824
# TP 39 FP 379 TN 6635 FN 356
#
#
#
# None
# y near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 19, 17, 20, 20, 7, 10, 3, 3, 16, 3, 16, 7, -1.2461538461538455, 21.646153846153847, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6116816431322208
# Specificity : 0.7614235500878734
# Accuracy: 0.6855625406460004
# ROC 0.68655259661
# TP 5718 FP 2172 TN 6932 FN 3630
#
#
#
# None
# Cross Validation: [ 0.62584002  0.72718405  0.64204422  0.58509485  0.64878049]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8582278481012658
# Specificity : 0.20943826632449386
# Accuracy: 0.24402753408017278
# ROC 0.533833057213
# TP 339 FP 5545 TN 1469 FN 56
#
#
#
# None
# x near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 11, 5, 17, 8, 11, 10, 4, 18, 3, 11, 20, 11, -1.1076923076923075, 83.30769230769232, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6267650834403081
# Specificity : 0.7565905096660809
# Accuracy: 0.6908194233687405
# ROC 0.691677796553
# TP 5859 FP 2216 TN 6888 FN 3489
#
#
#
# None
# Cross Validation: [ 0.63136787  0.72122263  0.6666486   0.67669377  0.62655827]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8405063291139241
# Specificity : 0.21043627031650983
# Accuracy: 0.24402753408017278
# ROC 0.525471299715
# TP 332 FP 5538 TN 1476 FN 63
#
#
#
# None
# y near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 19, 17, 16, 9, 2, 10, 1, 5, 10, 17, 17, 11, -2.0461538461538464, 91.93846153846155, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6506204535729568
# Specificity : 0.7357205623901582
# Accuracy: 0.692607847387817
# ROC 0.693170507982
# TP 6082 FP 2406 TN 6698 FN 3266
#
#
#
# None
# Cross Validation: [ 0.55598309  0.68030566  0.65185346  0.67425474  0.66363144]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5848101265822785
# Specificity : 0.38751069289991447
# Accuracy: 0.3980294236739101
# ROC 0.486160409741
# TP 231 FP 4296 TN 2718 FN 164
#
#
#
# None
# x near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 20, 9, 11, 2, 1, 10, 20, 9, 10, 9, 4, 20, -1.023076923076923, 95.90769230769233, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6924475823705606
# Specificity : 0.6925527240773286
# Accuracy: 0.6924994580533276
# ROC 0.692500153224
# TP 6473 FP 2799 TN 6305 FN 2875
#
#
#
# None
# Cross Validation: [ 0.59765879  0.6320724   0.70127899  0.6698645   0.66200542]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6658227848101266
# Specificity : 0.28970630168234957
# Accuracy: 0.3097584019435821
# ROC 0.477764543246
# TP 263 FP 4982 TN 2032 FN 132
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 4, 19, 9, 13, 10, 5, 3, 7, 0, 0, 0, 0.4299999999999999, 19.770000000000003, 0.1]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.003152516577888901
# Specificity : 0.9994375427956569
# Accuracy: 0.8164740172885349
# ROC 0.501295029687
# TP 29 FP 23 TN 40869 FN 9170
#
#
#
# None
# Cross Validation: [ 0.81595864  0.815935    0.81683336  0.81690956  0.81431423]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 0 TN 953 FN 2
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 6, 12, 18, 7, 10, 10, 5, 19, 8, 2, 9, 17, -0.8923076923076922, 45.22307692307693, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05411841108345059
# Specificity : 0.9889846274356213
# Accuracy: 0.8165538719530454
# ROC 0.52155151926
# TP 500 FP 450 TN 40402 FN 8739
#
#
#
# None
# Cross Validation: [ 0.81535974  0.81471721  0.81555569  0.81605111  0.81579158]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 1 TN 952 FN 2
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 1, 11, 2, 3, 1, 10, 9, 11, 4, 4, 3, 1, 0.07692307692307684, 45.66153846153846, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06598706565822646
# Specificity : 0.9864040226518258
# Accuracy: 0.8187698388932143
# ROC 0.526195544155
# TP 602 FP 557 TN 40411 FN 8521
#
#
#
# None
# Cross Validation: [ 0.81653757  0.81583518  0.81507656  0.81547215  0.8156119 ]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 7 TN 946 FN 2
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 9, 1, 16, 9, 20, 10, 2, 20, 13, 6, 18, 3, -0.6461538461538461, 12.923076923076925, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.055767195767195764
# Specificity : 0.9903545680470461
# Accuracy: 0.8140384500209619
# ROC 0.523060881907
# TP 527 FP 392 TN 40249 FN 8923
#
#
#
# None
# Cross Validation: [ 0.81581889  0.81575533  0.8154958   0.8084448   0.81475344]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 10 TN 943 FN 2
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 8, 2, 3, 10, 10, 3, 19, 9, 19, 19, 11, -0.6384615384615385, 63.938461538461546, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06273909716908951
# Specificity : 0.9892775145327537
# Accuracy: 0.8200475135253839
# ROC 0.526008305851
# TP 574 FP 439 TN 40503 FN 8575
#
#
#
# None
# Cross Validation: [ 0.815759    0.8168134   0.81629434  0.81670992  0.8158315 ]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 9 TN 944 FN 2
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 11, 20, 11, 19, 12, 10, 12, 12, 19, 3, 20, 2, 0.7692307692307695, 6.6846153846153875, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05228970444949659
# Specificity : 0.9918000685367406
# Accuracy: 0.8185502385658102
# ROC 0.522044886493
# TP 483 FP 335 TN 40519 FN 8754
#
#
#
# None
# Cross Validation: [ 0.81593867  0.81433791  0.81665369  0.81674985  0.81189858]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 7 TN 946 FN 2
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 1, 18, 20, 12, 13, 10, 17, 12, 5, 7, 17, 19, -0.7692307692307693, 17.969230769230776, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.052294672887056526
# Specificity : 0.9908743944805989
# Accuracy: 0.8181709289093849
# ROC 0.521584533684
# TP 482 FP 373 TN 40501 FN 8735
#
#
#
# None
# Cross Validation: [ 0.81176635  0.81541594  0.81729253  0.81595129  0.81621082]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 3 TN 950 FN 2
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 17, 8, 19, 17, 7, 10, 12, 8, 17, 13, 7, 2, -1.7999999999999998, 13.523076923076928, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.036601450868322706
# Specificity : 0.9929256214475642
# Accuracy: 0.8192290032141503
# ROC 0.514763536158
# TP 333 FP 290 TN 40703 FN 8765
#
#
#
# None
# Cross Validation: [ 0.81701669  0.81667365  0.80794953  0.81389499  0.80806548]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 9 TN 944 FN 2
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 7, 10, 19, 4, 19, 10, 8, 17, 8, 12, 18, 15, -1.7999999999999998, 47.876923076923084, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05313217448343719
# Specificity : 0.9897909339585775
# Accuracy: 0.8187498752270868
# ROC 0.521461554221
# TP 486 FP 418 TN 40526 FN 8661
#
#
#
# None
# Cross Validation: [ 0.81633794  0.81579525  0.81605478  0.81609104  0.81595129]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1 TN 952 FN 2
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 3, 10, 7, 11, 13, 10, 11, 11, 11, 10, 3, 0, -0.3416666666666666, 87.65, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06068860318152103
# Specificity : 0.9869479138660083
# Accuracy: 0.8172326366013855
# ROC 0.523818258524
# TP 557 FP 534 TN 40379 FN 8621
#
#
#
# None
# Cross Validation: [ 0.81567915  0.81443772  0.81519634  0.81668996  0.81645039]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2 TN 951 FN 2
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 12, 10, 13, 10, 7, 20, 2, 3, 15, 10, 0, 0, 0.22727272727272735, 9.09090909090909, 0.09090909090909091]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331720
# Test Data Points: 82931
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6624578725020174
# Specificity : 0.9023457607176998
# Accuracy: 0.7804680999867359
# ROC 0.78240181661
# TP 27912 FP 3984 TN 36813 FN 14222
#
#
#
# None
# Cross Validation: [ 0.51252246  0.80939346  0.83639214  0.82810804  0.84274689]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 14 TN 939 FN 2
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 19, 9, 11, 2, 9, 10, 11, 10, 9, 20, 11, 1, -1.8615384615384616, 117.1076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331700
# Test Data Points: 82926
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7007780624347661
# Specificity : 0.8855531027716458
# Accuracy: 0.7916214456262209
# ROC 0.793165582603
# TP 29542 FP 4666 TN 36104 FN 12614
#
#
#
# None
# Cross Validation: [ 0.51128717  0.80516129  0.84352125  0.83623756  0.84294242]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 46 TN 907 FN 2
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 7, 11, 11, 3, 20, 10, 12, 11, 11, 9, 11, 9, -0.6615384615384616, 82.9, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331681
# Test Data Points: 82921
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7055670200906093
# Specificity : 0.9184779942102939
# Accuracy: 0.8102290131571014
# ROC 0.81202250715
# TP 29746 FP 3323 TN 37439 FN 12413
#
#
#
# None
# Cross Validation: [ 0.52700128  0.80267728  0.82451761  0.83750603  0.84020743]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.05246589716684155
# Accuracy: 0.05445026178010471
# ROC 0.526232948583
# TP 2 FP 903 TN 50 FN 0
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 5, 20, 8, 6, 19, 10, 9, 20, 16, 18, 9, 10, -1.9461538461538461, 60.2923076923077, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331725
# Test Data Points: 82932
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6956057007125891
# Specificity : 0.9182748824451411
# Accuracy: 0.8052380263348285
# ROC 0.806940291579
# TP 29285 FP 3337 TN 37495 FN 12815
#
#
#
# None
# Cross Validation: [ 0.50464833  0.81046894  0.81095127  0.82953299  0.81887352]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3389296956977964
# Accuracy: 0.3403141361256545
# ROC 0.669464847849
# TP 2 FP 630 TN 323 FN 0
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 1, 9, 2, 20, 20, 10, 12, 10, 10, 10, 18, 10, -0.8692307692307693, 26.530769230769234, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331712
# Test Data Points: 82929
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7405808851583365
# Specificity : 0.8610006586490376
# Accuracy: 0.800106114869346
# ROC 0.800790771904
# TP 31057 FP 5698 TN 35295 FN 10879
#
#
#
# None
# Cross Validation: [ 0.53750799  0.81224677  0.82136311  0.83549585  0.83740112]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.3147953830010493
# Accuracy: 0.3162303664921466
# ROC 0.657397691501
# TP 2 FP 653 TN 300 FN 0
#
#
#
# None
# x ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 10, 9, 19, 9, 12, 10, 8, 13, 18, 11, 11, 3, -0.8769230769230768, 81.09230769230771, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331707
# Test Data Points: 82927
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7603082943590722
# Specificity : 0.8416343645627636
# Accuracy: 0.8005354106623899
# ROC 0.800971329461
# TP 31863 FP 6496 TN 34523 FN 10045
#
#
#
# None
# Cross Validation: [ 0.52374349  0.80456305  0.82610006  0.83219979  0.82647179]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.2885624344176285
# Accuracy: 0.28900523560209423
# ROC 0.394281217209
# TP 1 FP 678 TN 275 FN 1
#
#
#
# None
# y ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 18, 10, 19, 11, 9, 10, 20, 5, 17, 8, 18, 0, -2.2166666666666663, 66.03333333333335, 0.08333333333333333]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331767
# Test Data Points: 82942
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8396728113895977
# Specificity : 0.3840132653807701
# Accuracy: 0.6143811338043452
# ROC 0.611843038385
# TP 35210 FP 25261 TN 15748 FN 6723
#
#
#
# None
# Cross Validation: [ 0.50878314  0.80911963  0.83182224  0.83590745  0.81960671]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 2 FP 953 TN 0 FN 0
#
#
#
# None
# x ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [17, 3, 10, 2, 17, 3, 10, 1, 11, 1, 1, 10, 0, -0.4000000000000001, 19.45, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331740
# Test Data Points: 82936
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8147610779440098
# Specificity : 0.4536962316288851
# Accuracy: 0.636731937879811
# ROC 0.634228654786
# TP 34255 FP 22340 TN 18553 FN 7788
#
#
#
# None
# Cross Validation: [ 0.50577554  0.80274914  0.84151444  0.84507144  0.83250739]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 2 FP 953 TN 0 FN 0
#
#
#
# None
# y ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 18, 6, 17, 20, 1, 10, 5, 16, 1, 11, 1, 16, -0.9692307692307693, -13.253846153846153, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331700
# Test Data Points: 82925
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8057530013075003
# Specificity : 0.6511992168379833
# Accuracy: 0.7295990352728369
# ROC 0.728476109073
# TP 33894 FP 14252 TN 26608 FN 8171
#
#
#
# None
# Cross Validation: [ 0.53810626  0.81231233  0.83762436  0.84018089  0.83779123]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.048268625393494226
# Accuracy: 0.050261780104712044
# ROC 0.524134312697
# TP 2 FP 907 TN 46 FN 0
#
#
#
# None
# x ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 8, 7, 11, 1, 20, 10, 1, 3, 17, 7, 17, 12, -1.276923076923077, 36.792307692307695, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331686
# Test Data Points: 82922
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7195449255397478
# Specificity : 0.8157230701389059
# Accuracy: 0.7668893659101325
# ROC 0.767633997839
# TP 30295 FP 7522 TN 33297 FN 11808
#
#
#
# None
# Cross Validation: [ 0.51668415  0.79056222  0.83405892  0.84181329  0.8379542 ]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.07974816369359916
# Accuracy: 0.08167539267015707
# ROC 0.539874081847
# TP 2 FP 877 TN 76 FN 0
#
#
#
# None
# y SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 17, 17, 3, 14, 18, 10, 1, 10, 17, 12, 1, 11, -0.48461538461538467, 61.57692307692309, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305854
# Test Data Points: 76464
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7656975598772903
# Specificity : 0.6578066596633523
# Accuracy: 0.7079409918392969
# ROC 0.71175210977
# TP 27206 FP 14007 TN 26926 FN 8325
#
#
#
# None
# Cross Validation: [ 0.6257765   0.72029975  0.72181316  0.70464146  0.71246224]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.8467995802728226
# Accuracy: 0.8460732984293193
# ROC 0.673399790136
# TP 1 FP 146 TN 807 FN 1
#
#
#
# None
# x SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 19, 11, 2, 19, 9, 10, 1, 1, 10, 6, 14, 14, -0.5230769230769232, 35.292307692307695, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305799
# Test Data Points: 76450
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7422483880011214
# Specificity : 0.6937714565963707
# Accuracy: 0.7163897972531066
# ROC 0.718009922299
# TP 26476 FP 12488 TN 28292 FN 9194
#
#
#
# None
# Cross Validation: [ 0.62084211  0.71706998  0.71714846  0.71736713  0.71652997]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 39 TN 914 FN 2
#
#
#
# None
# y SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 17, 10, 17, 10, 17, 10, 17, 10, 16, 17, 15, 16, -2.630769230769231, 207.38461538461533, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305660
# Test Data Points: 76416
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7209490805432899
# Specificity : 0.8208643008318157
# Accuracy: 0.7740787269681743
# ROC 0.770906690688
# TP 25797 FP 7279 TN 33355 FN 9985
#
#
#
# None
# Cross Validation: [ 0.61913735  0.73184584  0.71890336  0.70152457  0.72404633]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4438614900314795
# Accuracy: 0.44502617801047123
# ROC 0.721930745016
# TP 2 FP 530 TN 423 FN 0
#
#
#
# None
# x SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 7, 20, 15, 8, 2, 10, 10, 8, 11, 1, 10, 20, -1.2999999999999998, 53.67692307692308, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 232039
# Test Data Points: 58010
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9327063996091842
# Specificity : 0.5282952548330404
# Accuracy: 0.813704533701086
# ROC 0.730500827221
# TP 38185 FP 8052 TN 9018 FN 2755
#
#
#
# None
# Cross Validation: [ 0.75451208  0.80842958  0.8114463   0.81071903  0.80735748]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4333683105981112
# Accuracy: 0.43455497382198954
# ROC 0.716684155299
# TP 2 FP 540 TN 413 FN 0
#
#
#
# None
# y SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 2, 1, 5, 1, 10, 10, 10, 18, 5, 1, 18, 1, -0.13846153846153844, 9.207692307692309, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305861
# Test Data Points: 76466
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7345851235980135
# Specificity : 0.7754775502166207
# Accuracy: 0.7563099939842545
# ROC 0.755031336907
# TP 26329 FP 9121 TN 31503 FN 9513
#
#
#
# None
# Cross Validation: [ 0.62118299  0.71290133  0.72236971  0.71984568  0.71203819]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.391395592864638
# Accuracy: 0.39267015706806285
# ROC 0.695697796432
# TP 2 FP 580 TN 373 FN 0
#
#
#
# None
# x SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 1, 20, 10, 10, 10, 3, 8, 10, 7, 2, 3, 0.053846153846153794, 91.20769230769231, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305773
# Test Data Points: 76444
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7989300918664576
# Specificity : 0.6791359842906235
# Accuracy: 0.73508712259955
# ROC 0.739033038079
# TP 28525 FP 13072 TN 27668 FN 7179
#
#
#
# None
# Cross Validation: [ 0.61202171  0.71663854  0.72596575  0.71501642  0.71529113]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.38719832109129065
# Accuracy: 0.38848167539267014
# ROC 0.693599160546
# TP 2 FP 584 TN 369 FN 0
#
#
#
# None
# y SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 4, 9, 9, 3, 20, 10, 12, 13, 1, 13, 18, 4, 0.9692307692307692, 27.77692307692308, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305698
# Test Data Points: 76425
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6840479600146014
# Specificity : 0.8447025384690777
# Accuracy: 0.7698397121360812
# ROC 0.764375249242
# TP 24361 FP 6338 TN 34474 FN 11252
#
#
#
# None
# Cross Validation: [ 0.6237537   0.71156035  0.71306134  0.71434366  0.71693447]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 162 TN 791 FN 2
#
#
#
# None
# x SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [16, 10, 10, 5, 10, 1, 10, 17, 10, 17, 10, 17, 10, -1.5307692307692309, 169.89230769230772, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305774
# Test Data Points: 76444
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7500560161326462
# Specificity : 0.7806823760432008
# Accuracy: 0.7663780021976871
# ROC 0.765369196088
# TP 26780 FP 8935 TN 31805 FN 8924
#
#
#
# None
# Cross Validation: [ 0.6186801   0.71974256  0.71785513  0.7186662   0.71853538]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.7995802728226653
# Accuracy: 0.7989528795811518
# ROC 0.649790136411
# TP 1 FP 191 TN 762 FN 1
#
#
#
# None
# y SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 5, 3, 2, 2, 11, 10, 10, 15, 15, 7, 3, 3, 0.3538461538461538, 56.63846153846155, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305738
# Test Data Points: 76435
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6900637336103546
# Specificity : 0.8442353863491597
# Accuracy: 0.7723948452933865
# ROC 0.76714955998
# TP 24578 FP 6358 TN 34460 FN 11039
#
#
#
# None
# Cross Validation: [ 0.61974724  0.7248381   0.71926106  0.72119737  0.72081796]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 23 TN 930 FN 2
#
#
#
# None
# x SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 15, 16, 12, 11, 10, 10, 6, 9, 8, 2, 17, 4, -1.2384615384615385, 77.9846153846154, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 305824
# Test Data Points: 76457
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.800236140784887
# Specificity : 0.726843585667115
# Accuracy: 0.7609898374249578
# ROC 0.763539863226
# TP 28466 FP 11168 TN 29717 FN 7106
#
#
#
# None
# Cross Validation: [ 0.62663981  0.71970807  0.71135032  0.71430627  0.72122528]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 39 TN 914 FN 2
#
#
#
# None
# y random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 12, 12, 3, 7, 11, 10, 9, 13, 10, 7, 18, 12, 0.4153846153846152, 35.54615384615386, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.31225930680359437
# Specificity : 0.8503954305799648
# Accuracy: 0.5777693474962063
# ROC 0.581327368692
# TP 2919 FP 1362 TN 7742 FN 6429
#
#
#
# None
# Cross Validation: [ 0.61906568  0.64665077  0.56465424  0.54151762  0.55848238]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 54 TN 899 FN 2
#
#
#
# None
# x random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 10, 3, 3, 1, 5, 10, 12, 18, 2, 10, 10, 9, 0.3230769230769231, 53.67692307692308, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9329268292682927
# Specificity : 0.25823813708260107
# Accuracy: 0.6000433557337957
# ROC 0.595582483175
# TP 8721 FP 6753 TN 2351 FN 627
#
#
#
# None
# Cross Validation: [ 0.64610882  0.58378496  0.642261    0.61750678  0.64086721]
# Number of data points in benchmark 955
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.44805876180482684
# Accuracy: 0.4481675392670157
# ROC 0.474029380902
# TP 1 FP 526 TN 427 FN 1
#
#
#
# None
# y random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [13, 13, 2, 2, 10, 2, 10, 12, 7, 10, 10, 8, 7, 0.3153846153846152, 36.64615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6972614462986735
# Specificity : 0.6133567662565905
# Accuracy: 0.6558638629958812
# ROC 0.655309106278
# TP 6518 FP 3520 TN 5584 FN 2830
#
#
#
# None
# Cross Validation: [ 0.6504444   0.61424236  0.63451116  0.63582656  0.50731707]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.4690451206715635
# Accuracy: 0.46910994764397906
# ROC 0.484522560336
# TP 1 FP 506 TN 447 FN 1
#
#
#
# None
# x random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 15, 20, 11, 10, 11, 10, 10, 10, 17, 11, 13, 10, -0.9538461538461542, 125.3923076923077, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7258237056054772
# Specificity : 0.5716168717047452
# Accuracy: 0.6497398655972252
# ROC 0.648720288655
# TP 6785 FP 3900 TN 5204 FN 2563
#
#
#
# None
# Cross Validation: [ 0.62979623  0.62275092  0.64394104  0.64449864  0.63658537]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.40083945435466944
# Accuracy: 0.40104712041884816
# ROC 0.450419727177
# TP 1 FP 571 TN 382 FN 1
#
#
#
# None
# y random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [2, 9, 7, 10, 2, 12, 10, 20, 10, 12, 11, 20, 7, -0.3615384615384615, 24.04615384615385, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7280701754385965
# Specificity : 0.5817223198594025
# Accuracy: 0.6558638629958812
# ROC 0.654896247649
# TP 6806 FP 3808 TN 5296 FN 2542
#
#
#
# None
# Cross Validation: [ 0.62735747  0.64437459  0.62508129  0.64238482  0.58092141]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.3242392444910808
# Accuracy: 0.32460732984293195
# ROC 0.412119622246
# TP 1 FP 644 TN 309 FN 1
#
#
#
# None
# x random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 20, 12, 11, 12, 17, 10, 10, 12, 19, 9, 3, 12, 0.13076923076923078, 64.35384615384616, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7215447154471545
# Specificity : 0.5885325131810193
# Accuracy: 0.6559180576631259
# ROC 0.655038614314
# TP 6745 FP 3746 TN 5358 FN 2603
#
#
#
# None
# Cross Validation: [ 0.63353566  0.64285714  0.63944288  0.6395122   0.63723577]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.36096537250786986
# Accuracy: 0.362303664921466
# ROC 0.680482686254
# TP 2 FP 609 TN 344 FN 0
#
#
#
# None
# y random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 3, 20, 1, 3, 5, 10, 12, 9, 20, 11, 3, 4, 0.9076923076923076, 2.7, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7787762088147198
# Specificity : 0.5190026362038664
# Accuracy: 0.6506069802731411
# ROC 0.648889422509
# TP 7280 FP 4379 TN 4725 FN 2068
#
#
#
# None
# Cross Validation: [ 0.64730111  0.60286148  0.64648819  0.64758808  0.55214092]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.36096537250786986
# Accuracy: 0.3612565445026178
# ROC 0.430482686254
# TP 1 FP 609 TN 344 FN 1
#
#
#
# None
# x random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [3, 16, 11, 17, 11, 2, 10, 12, 3, 11, 18, 20, 20, -0.3538461538461538, 39.13076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8478818998716303
# Specificity : 0.4353031634446397
# Accuracy: 0.6443203988727509
# ROC 0.641592531658
# TP 7926 FP 5141 TN 3963 FN 1422
#
#
#
# None
# Cross Validation: [ 0.64312812  0.60210275  0.64009321  0.63718157  0.62693767]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.23294858342077648
# Accuracy: 0.23350785340314137
# ROC 0.36647429171
# TP 1 FP 731 TN 222 FN 1
#
#
#
# None
# y random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 15, 17, 17, 15, 7, 10, 19, 8, 7, 13, 18, 16, -2.5307692307692307, 27.953846153846158, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7344886606760804
# Specificity : 0.5709578207381371
# Accuracy: 0.6538044656405809
# ROC 0.652723240707
# TP 6866 FP 3906 TN 5198 FN 2482
#
#
#
# None
# Cross Validation: [ 0.64562107  0.63060915  0.64784305  0.64493225  0.64124661]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.8835257082896117
# Accuracy: 0.8827225130890053
# ROC 0.691762854145
# TP 1 FP 111 TN 842 FN 1
#
#
#
# None
# x random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 5, 10, 11, 10, 16, 10, 10, 2, 10, 16, 3, 9, -0.8461538461538461, 72.66153846153847, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7286050492083869
# Specificity : 0.5971001757469244
# Accuracy: 0.6637220897463689
# ROC 0.662852612478
# TP 6811 FP 3668 TN 5436 FN 2537
#
#
#
# None
# Cross Validation: [ 0.50330587  0.65196185  0.65120312  0.63728997  0.62379404]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.863588667366212
# Accuracy: 0.86282722513089
# ROC 0.681794333683
# TP 1 FP 130 TN 823 FN 1
#
#
#
# None
# y ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [15, 7, 15, 3, 20, 20, 10, 3, 5, 11, 17, 16, 13, -0.2384615384615385, 66.86153846153847, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143760
# Test Data Points: 35941
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.42014341590612775
# Specificity : 0.8554437670643678
# Accuracy: 0.7439692829915695
# ROC 0.637793591485
# TP 3867 FP 3865 TN 22872 FN 5337
#
#
#
# None
# Cross Validation: [ 0.76661751  0.7607746   0.76770262  0.76101171  0.75987089]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 11 TN 942 FN 2
#
#
#
# None
# x ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 16, 4, 7, 13, 17, 10, 8, 10, 5, 0, 0, 0, -0.8300000000000001, 107.64999999999999, 0.1]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143796
# Test Data Points: 35950
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.13734887267182225
# Specificity : 0.9718704471590273
# Accuracy: 0.7587482614742698
# ROC 0.554609659915
# TP 1261 FP 753 TN 26016 FN 7920
#
#
#
# None
# Cross Validation: [ 0.76528512  0.75783032  0.76358832  0.75803939  0.76098809]
# Number of data points in benchmark 955
# Benchmark Results
# Failed
# TP 0 FP 2 TN 951 FN 2
#
#
#
# None
# y ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 16, 2, 14, 16, 3, 10, 8, 17, 3, 8, 9, 10, -1.1538461538461537, 137.63076923076923, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143738
# Test Data Points: 35935
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3081945804766569
# Specificity : 0.928923951245046
# Accuracy: 0.7701961875608738
# ROC 0.618559265861
# TP 2832 FP 1901 TN 24845 FN 6357
#
#
#
# None
# Cross Validation: [ 0.758091    0.76232086  0.76769167  0.76028274  0.76442923]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.9045120671563484
# Accuracy: 0.9036649214659686
# ROC 0.702256033578
# TP 1 FP 91 TN 862 FN 1
#
#
#
# None
# x ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 20, 1, 15, 11, 10, 10, 11, 2, 20, 20, 20, 10, -0.6923076923076923, 83.90769230769232, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143776
# Test Data Points: 35945
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2947012647187091
# Specificity : 0.9301908639300788
# Accuracy: 0.7680344971484212
# ROC 0.612446064324
# TP 2703 FP 1869 TN 24904 FN 6469
#
#
#
# None
# Cross Validation: [ 0.76642092  0.75206566  0.7678954   0.76546198  0.76103831]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.912906610703043
# Accuracy: 0.912041884816754
# ROC 0.706453305352
# TP 1 FP 83 TN 870 FN 1
#
#
#
# None
# y ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 10, 20, 9, 9, 12, 10, 10, 3, 17, 11, 11, 17, -1.3692307692307693, 117.4, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143749
# Test Data Points: 35938
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3283420138888889
# Specificity : 0.9192799940124242
# Accuracy: 0.7677388836329234
# ROC 0.623811003951
# TP 3026 FP 2157 TN 24565 FN 6190
#
#
#
# None
# Cross Validation: [ 0.76375981  0.75733207  0.76273026  0.76316888  0.75834817]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 100 TN 853 FN 2
#
#
#
# None
# x ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [1, 16, 9, 10, 10, 16, 10, 13, 8, 9, 19, 18, 4, -1.5615384615384615, 68.4923076923077, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143764
# Test Data Points: 35941
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2605014653207424
# Specificity : 0.9448518407662376
# Accuracy: 0.7694276731309646
# ROC 0.602676653043
# TP 2400 FP 1474 TN 25254 FN 6813
#
#
#
# None
# Cross Validation: [ 0.76434255  0.76186634  0.75810356  0.76552588  0.76708403]
# Number of data points in benchmark 955
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 86 TN 867 FN 2
#
#
#
# None
# y ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 17, 5, 11, 1, 19, 10, 17, 19, 15, 10, 20, 9, -1.9846153846153847, 62.69230769230771, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 143735
# Test Data Points: 35934
# Scaling Data
# Finished Scaling Data
# Starting Training

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
        del x
