# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]


for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos_stripped.csv", "S")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 12, 18, 7, 15, 1, 10, 20, 2, 15, 19, 3, 5, 0.10769230769230773, 39.13076923076923, 0.23076923076923078]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.002651957144372547
# Specificity : 0.9993606138107417
# Accuracy: 0.8117825557485376
# ROC 0.501006285478
# TP 25 FP 26 TN 40638 FN 9402
#
#
#
# None
# Cross Validation: [ 0.81330352  0.81327983  0.81533609  0.81621082  0.81692953]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.007594936708860759
# Specificity : 0.9994297120045623
# Accuracy: 0.9465514914293427
# ROC 0.503512324357
# TP 3 FP 4 TN 7010 FN 392
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 4, 10, 12, 10, 11, 10, 7, 9, 13, 7, 13, 12, 0.5230769230769231, 86.8692307692308, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04
# Specificity : 0.9908048225770952
# Accuracy: 0.8161745622966201
# ROC 0.515402411289
# TP 368 FP 376 TN 40515 FN 8832
#
#
#
# None
# Cross Validation: [ 0.815759    0.81629434  0.81533609  0.81593132  0.81672989]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.05569620253164557
# Specificity : 0.9895922440832621
# Accuracy: 0.939802942367391
# ROC 0.522644223307
# TP 22 FP 73 TN 6941 FN 373
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 7, 10, 3, 7, 3, 10, 11, 12, 8, 7, 8, 7, -1.3461538461538463, 62.96923076923077, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06386881001186752
# Specificity : 0.9893194845916418
# Accuracy: 0.8180711105787467
# ROC 0.526594147302
# TP 592 FP 436 TN 40386 FN 8677
#
#
#
# None
# Cross Validation: [ 0.81681706  0.81521631  0.81515642  0.81551208  0.81567179]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.07088607594936709
# Specificity : 0.9804676361562589
# Accuracy: 0.9319746254555271
# ROC 0.525676856053
# TP 28 FP 137 TN 6877 FN 367
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [7, 10, 17, 17, 3, 19, 10, 8, 13, 8, 17, 0, 0, -1.9272727272727272, 113.6909090909091, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05856879939374256
# Specificity : 0.9893033729867332
# Accuracy: 0.8176718372561937
# ROC 0.52393608619
# TP 541 FP 437 TN 40417 FN 8696
#
#
#
# None
# Cross Validation: [ 0.81587878  0.81561558  0.8163742   0.81670992  0.8158914 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0759493670886076
# Specificity : 0.9804676361562589
# Accuracy: 0.9322445674180051
# ROC 0.528208501622
# TP 30 FP 137 TN 6877 FN 365
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [18, 12, 1, 20, 6, 7, 10, 17, 10, 20, 4, 9, 7, -1.3461538461538463, 33.223076923076924, 0.07692307692307693]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05287206266318538
# Specificity : 0.9903665126286706
# Accuracy: 0.8183306382384061
# ROC 0.521619287646
# TP 486 FP 394 TN 40505 FN 8706
#
#
#
# None
# Cross Validation: [ 0.8153797   0.81647402  0.81627438  0.8171691   0.81463366]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.13924050632911392
# Specificity : 0.9664955802680354
# Accuracy: 0.9223916857875557
# ROC 0.552868043299
# TP 55 FP 235 TN 6779 FN 340
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [11, 12, 11, 1, 11, 10, 9, 19, 10, 10, 10, 2, 0, -0.7833333333333335, 137.5666666666667, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06818916298610363
# Specificity : 0.9882621054695158
# Accuracy: 0.8177516919207043
# ROC 0.528225634228
# TP 633 FP 479 TN 40329 FN 8650
#
#
#
# None
# Cross Validation: [ 0.81482073  0.81621449  0.81555569  0.81680974  0.81629068]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.10632911392405063
# Specificity : 0.9689193042486456
# Accuracy: 0.9229315697125118
# ROC 0.537624209086
# TP 42 FP 218 TN 6796 FN 353
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [12, 3, 8, 11, 2, 11, 10, 17, 2, 3, 1, 20, 3, 0.46923076923076923, 101.85384615384616, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0530466724286949
# Specificity : 0.9897881719113506
# Accuracy: 0.816693617615939
# ROC 0.52141742217
# TP 491 FP 417 TN 40418 FN 8765
#
#
#
# None
# Cross Validation: [ 0.81571908  0.81743227  0.81525623  0.81676981  0.81680974]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 7014 FN 395
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [5, 5, 12, 12, 2, 12, 10, 10, 3, 3, 10, 2, 10, 2.0153846153846153, 24.04615384615385, 0.15384615384615385]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04504795775406833
# Specificity : 0.991571106537293
# Accuracy: 0.8162344532950031
# ROC 0.518309532146
# TP 418 FP 344 TN 40468 FN 8861
#
#
#
# None
# Cross Validation: [ 0.81603849  0.81579525  0.81577529  0.81579158  0.81631064]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1 TN 7013 FN 395
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [10, 2, 1, 2, 2, 2, 10, 11, 10, 2, 2, 2, 2, 0.7692307692307693, 51.315384615384616, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.029079861111111112
# Specificity : 0.9942262996941896
# Accuracy: 0.8166536902836837
# ROC 0.511653080403
# TP 268 FP 236 TN 40639 FN 8948
#
#
#
# None
# Cross Validation: [ 0.81589875  0.81545587  0.81573536  0.81577161  0.8158914 ]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 7014 FN 395
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [14, 3, 8, 7, 7, 10, 10, 1, 3, 3, 2, 10, 11, -5.124106267500723e-17, 97.73846153846155, 0.0]
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04018048990116029
# Specificity : 0.9924968736973739
# Accuracy: 0.8155357249805354
# ROC 0.516338681799
# TP 374 FP 306 TN 40477 FN 8934
#
#
#
# None
# Cross Validation: [ 0.81571908  0.81260107  0.81623445  0.81547215  0.81525255]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.012658227848101266
# Specificity : 0.9981465640148275
# Accuracy: 0.9456066945606695
# ROC 0.505402395931
# TP 5 FP 13 TN 7001 FN 390
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [20, 8, 17, 11, 10, 10, 19, 10, 1, 14, 10, 16, 0, -1.508333333333333, 67.08333333333334, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331691
# Test Data Points: 82923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6353680601847443
# Specificity : 0.9269532491018843
# Accuracy: 0.7792530419787032
# ROC 0.781160654643
# TP 26688 FP 2989 TN 37930 FN 15316
#
#
#
# None
# Cross Validation: [ 0.5305581   0.81143953  0.82152117  0.83958419  0.84044041]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.24556962025316456
# Specificity : 0.9281437125748503
# Accuracy: 0.891753273046295
# ROC 0.586856666414
# TP 97 FP 504 TN 6510 FN 298
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [9, 17, 3, 11, 3, 11, 10, 5, 3, 3, 3, 11, 5, 0.8461538461538459, 83.30769230769232, 0.15384615384615385]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331681
# Test Data Points: 82921
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6980316736709642
# Specificity : 0.8613616312126262
# Accuracy: 0.77840354071948
# ROC 0.779696652442
# TP 29399 FP 5657 TN 35147 FN 12718
#
#
#
# None
# Cross Validation: [ 0.50525795  0.81505065  0.83488905  0.84270381  0.82554269]
# Number of data points in benchmark 7409
# Benchmark Results
# Sensitivity: 0.4379746835443038
# Specificity : 0.8591388651268891
# Accuracy: 0.8366851127007693
# ROC 0.648556774336
# TP 173 FP 988 TN 6026 FN 222
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [6, 17, 5, 6, 12, 4, 10, 8, 4, 3, 7, 11, 13, 0.2307692307692307, 38.98461538461538, 0.23076923076923078]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331742
# Test Data Points: 82936
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6899926364046652
# Specificity : 0.9109630971912727
# Accuracy: 0.7987966624867368
# ROC 0.800477866798
# TP 29048 FP 3636 TN 37201 FN 13051
#
#
#
# None
# Cross Validation: [ 0.50300831  0.81870358  0.839959    0.83852415  0.83518418]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8531645569620253
# Specificity : 0.31151981750784147
# Accuracy: 0.3403968146848428
# ROC 0.582342187235
# TP 337 FP 4829 TN 2185 FN 58
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [8, 7, 2, 8, 9, 12, 10, 19, 9, 1, 2, 19, 8, -1.676923076923077, 10.984615384615388, 0.0]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331678
# Test Data Points: 82920
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7108929250665652
# Specificity : 0.8929410612884277
# Accuracy: 0.8005909310178485
# ROC 0.801916993177
# TP 29903 FP 4374 TN 36482 FN 12161
#
#
#
# None
# Cross Validation: [ 0.52709205  0.8055837   0.84387173  0.8334881   0.82548029]
# Number of data points in benchmark 7409
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8379746835443038
# Specificity : 0.2979754776161962
# Accuracy: 0.32676474557970037
# ROC 0.56797508058
# TP 331 FP 4924 TN 2090 FN 64
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Sample Vector [19, 12, 19, 2, 3, 4, 10, 3, 17, 9, 3, 5, 18, 0.2153846153846153, 46.284615384615385, 0.07692307692307693]
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 331780
# Test Data Points: 82945
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7458269208002841
# Specificity : 0.7850896585605502
# Accuracy: 0.7650973536680933
# ROC 0.76545828968
# TP 31500 FP 8749 TN 31961 FN 10735
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos_stripped.csv", "Y")
        del x

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training("mlp_adam", scale=j)
        y.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training("mlp_adam", scale=j)
        x.benchmark("Data/Benchmarks/phos_stripped.csv", "T")
        del x
