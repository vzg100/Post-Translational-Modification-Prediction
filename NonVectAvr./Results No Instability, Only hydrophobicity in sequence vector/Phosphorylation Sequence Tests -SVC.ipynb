# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("svc")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("svc")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 162268
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17720 FN 310
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 342566
# Test Data Points: 18030
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17688 FN 342
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 318312
# Test Data Points: 35368
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9876956225901565
# Specificity : 0.9999436047823145
# Accuracy: 0.9938362361456684
# ROC 0.993819613686
# TP 17419 FP 1 TN 17731 FN 217
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0011841326228537595
# Specificity : 0.9999360174032663
# Accuracy: 0.9487366264511723
# ROC 0.500560075013
# TP 4 FP 4 TN 62513 FN 3374
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 498610
# Test Data Points: 35368
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9899663677130045
# Specificity : 0.9998858968507531
# Accuracy: 0.9948823795521375
# ROC 0.994926132282
# TP 17661 FP 2 TN 17526 FN 179
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0011841326228537595
# Specificity : 0.9999360174032663
# Accuracy: 0.9487366264511723
# ROC 0.500560075013
# TP 4 FP 4 TN 62513 FN 3374
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284400
# Test Data Points: 31600
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9965976750779699
# Specificity : 1.0
# Accuracy: 0.9981012658227848
# ROC 0.998298837539
# TP 17575 FP 0 TN 13965 FN 60
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0011841326228537595
# Specificity : 0.9999360174032663
# Accuracy: 0.9487366264511723
# ROC 0.500560075013
# TP 4 FP 4 TN 62513 FN 3374
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 464730
# Test Data Points: 31604
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9956502090159304
# Specificity : 1.0
# Accuracy: 0.9975635995443615
# ROC 0.997825104508
# TP 17625 FP 0 TN 13902 FN 77
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0011841326228537595
# Specificity : 0.9999360174032663
# Accuracy: 0.9487366264511723
# ROC 0.500560075013
# TP 4 FP 4 TN 62513 FN 3374
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.011904761904761904
# Specificity : 1.0
# Accuracy: 0.4755134281200632
# ROC 0.505952380952
# TP 4 FP 0 TN 297 FN 332
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.07223208999407933
# Specificity : 0.9998400435081658
# Accuracy: 0.9522877304803096
# ROC 0.536036066751
# TP 244 FP 10 TN 62507 FN 3134
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.003257328990228013
# Specificity : 1.0
# Accuracy: 0.5165876777251185
# ROC 0.501628664495
# TP 1 FP 0 TN 326 FN 306
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0011841326228537595
# Specificity : 0.9999520130524497
# Accuracy: 0.9487518021094165
# ROC 0.500568072838
# TP 4 FP 3 TN 62514 FN 3374
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 157139
# Test Data Points: 17460
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17154 FN 306
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 337437
# Test Data Points: 17460
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 17166 FN 294
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5691
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9733727810650887
# Specificity : 0.2033898305084746
# Accuracy: 0.6145339652448657
# ROC 0.588381305787
# TP 329 FP 235 TN 60 FN 9
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 9.597389510053266e-05
# Accuracy: 0.05135442749829274
# ROC 0.500047986948
# TP 3378 FP 62511 TN 6 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 180298
# Filtering Random Data
# Random Data Added: 180298
# Finished with Random Data
# Training Data Points: 185989
# Test Data Points: 633
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 310 FN 321
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0005920663114268798
# Specificity : 0.9999360174032663
# Accuracy: 0.948706275134684
# ROC 0.500264041857
# TP 2 FP 4 TN 62513 FN 3376
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("svc")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("svc")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 11334
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1189 FN 71
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 23928
# Test Data Points: 1260
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1202 FN 58
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21658
# Test Data Points: 2407
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8903061224489796
# Specificity : 1.0
# Accuracy: 0.9464063149148317
# ROC 0.945153061224
# TP 1047 FP 0 TN 1231 FN 129
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 34252
# Test Data Points: 2407
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8609271523178808
# Specificity : 1.0
# Accuracy: 0.930203572912339
# ROC 0.930463576159
# TP 1040 FP 0 TN 1199 FN 168
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 17016
# Test Data Points: 1891
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9652605459057072
# Specificity : 1.0
# Accuracy: 0.9777895293495505
# ROC 0.982630272953
# TP 1167 FP 0 TN 682 FN 42
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 29621
# Test Data Points: 1892
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9552845528455285
# Specificity : 1.0
# Accuracy: 0.9709302325581395
# ROC 0.977642276423
# TP 1175 FP 0 TN 662 FN 55
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 1.0
# Specificity : 0.03636363636363636
# Accuracy: 0.5309734513274337
# ROC 0.518181818182
# TP 58 FP 53 TN 2 FN 0
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 8.505571149102662e-05
# Accuracy: 0.0018255147527064318
# ROC 0.500042527856
# TP 41 FP 23512 TN 2 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 61 FN 52
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 10377
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1098 FN 56
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 22971
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1100 FN 54
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.034482758620689655
# Specificity : 1.0
# Accuracy: 0.504424778761062
# ROC 0.51724137931
# TP 2 FP 0 TN 55 FN 56
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 2 TN 23512 FN 41
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12594
# Filtering Random Data
# Random Data Added: 12594
# Finished with Random Data
# Training Data Points: 13603
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 57 FN 56
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("svc")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("svc")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58739
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6372 FN 155
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 124005
# Test Data Points: 6527
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6387 FN 140
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 114817
# Test Data Points: 12758
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9742259940279743
# Specificity : 1.0
# Accuracy: 0.9871453205831635
# ROC 0.987112997014
# TP 6199 FP 0 TN 6395 FN 164
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 180083
# Test Data Points: 12758
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9709632816100784
# Specificity : 0.9996799487918067
# Accuracy: 0.9850290014108795
# ROC 0.985321615201
# TP 6320 FP 2 TN 6247 FN 189
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 98384
# Test Data Points: 10932
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9849765258215962
# Specificity : 1.0
# Accuracy: 0.991218441273326
# ROC 0.992488262911
# TP 6294 FP 0 TN 4542 FN 96
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 163659
# Test Data Points: 10933
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9884712571067593
# Specificity : 1.0
# Accuracy: 0.993322967163633
# ROC 0.994235628553
# TP 6259 FP 0 TN 4601 FN 73
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.01910828025477707
# Specificity : 1.0
# Accuracy: 0.4900662251655629
# ROC 0.509554140127
# TP 3 FP 0 TN 145 FN 154
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0340632603406326
# Specificity : 0.9999569864722455
# Accuracy: 0.9750052377959355
# ROC 0.517010123406
# TP 42 FP 2 TN 46495 FN 1191
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.018867924528301886
# Specificity : 1.0
# Accuracy: 0.48344370860927155
# ROC 0.509433962264
# TP 3 FP 0 TN 143 FN 156
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 55928
# Test Data Points: 6215
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6065 FN 150
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 121194
# Test Data Points: 6215
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 6069 FN 146
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2710
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 1.0
# Specificity : 0.018867924528301886
# Accuracy: 0.48344370860927155
# ROC 0.509433962264
# TP 143 FP 156 TN 3 FN 0
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.0026023184291459663
# Accuracy: 0.028367902786507436
# ROC 0.501301159215
# TP 1233 FP 46376 TN 121 FN 0
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 65266
# Filtering Random Data
# Random Data Added: 65266
# Finished with Random Data
# Training Data Points: 67976
# Test Data Points: 302
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.006802721088435374
# Specificity : 1.0
# Accuracy: 0.5165562913907285
# ROC 0.503401360544
# TP 1 FP 0 TN 155 FN 146
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
