# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
benchmarks = ["Data/Benchmarks/phos_CDK1.csv", "Data/Benchmarks/phos_CK2.csv", "Data/Benchmarks/phos_MAPK1.csv", "Data/Benchmarks/phos_PKA.csv", "Data/Benchmarks/phos_PKC.csv"]
for j in benchmarks:
    for i in par:
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training("bagging")
        y.benchmark(j, "S")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training("bagging")
        x.benchmark(j, "S")
        del x
# Out:
# y pass   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9294219528036372
# Specificity : 0.9994778067885117
# Accuracy: 0.9865578875919986
# ROC 0.964449879796
# TP 12879 FP 32 TN 61248 FN 978
#
#
#
# None
# Cross: Validation: [ 0.98604568  0.98750275  0.98676409  0.98652426  0.98634458]
# Number of data points in benchmark 1808
# Benchmark Results
# Failed
# TP 0 FP 3 TN 1741 FN 64
#
#
#
# None
# x pass   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9295621233025924
# Specificity : 0.9994459472672164
# Accuracy: 0.9866377417251154
# ROC 0.964504035285
# TP 12801 FP 34 TN 61332 FN 970
#
#
#
# None
# Cross: Validation: [ 0.98652479  0.98700365  0.98614522  0.987223    0.98648433]
# Number of data points in benchmark 1808
# Benchmark Results
# Failed
# TP 0 FP 3 TN 1741 FN 64
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9815260382333553
# Specificity : 0.9990202961971164
# Accuracy: 0.9903135585574502
# ROC 0.990273167215
# TP 59559 FP 60 TN 61183 FN 1121
#
#
#
# None
# Cross: Validation: [ 0.96491271  0.99276593  0.99718261  0.99702267  0.99719492]
# Number of data points in benchmark 1808
# Benchmark Results
# Failed
# TP 0 FP 1 TN 1743 FN 64
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9818049970334234
# Specificity : 0.9988897415383611
# Accuracy: 0.9903873756387228
# ROC 0.990347369286
# TP 59572 FP 68 TN 61179 FN 1104
#
#
#
# None
# Cross: Validation: [ 0.96556476  0.99212618  0.99705958  0.9971334   0.9971211 ]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.015625
# Specificity : 0.9994266055045872
# Accuracy: 0.9646017699115044
# ROC 0.507525802752
# TP 1 FP 1 TN 1743 FN 63
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 260257
# Test Data Points: 111539
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9777049821542072
# Specificity : 0.9994420087684336
# Accuracy: 0.9874841983521458
# ROC 0.988573495461
# TP 59991 FP 28 TN 50152 FN 1368
#
#
#
# None
# Cross: Validation: [ 0.96247983  0.99129897  0.99498379  0.99440552  0.99483586]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.625
# Specificity : 0.35607798165137616
# Accuracy: 0.3655973451327434
# ROC 0.490538990826
# TP 40 FP 1123 TN 621 FN 24
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 260279
# Test Data Points: 111549
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9778282094401541
# Specificity : 0.9993836978131213
# Accuracy: 0.9875480730441331
# ROC 0.988605953627
# TP 59891 FP 31 TN 50269 FN 1358
#
#
#
# None
# Cross: Validation: [ 0.96253715  0.99057365  0.99443286  0.99464802  0.99482283]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.625
# Specificity : 0.36123853211009177
# Accuracy: 0.37057522123893805
# ROC 0.493119266055
# TP 40 FP 1114 TN 630 FN 24
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9344167569519682
# Specificity : 0.9924812030075187
# Accuracy: 0.9634353434259494
# ROC 0.96344897998
# TP 12937 FP 104 TN 13728 FN 908
#
#
#
# None
# Cross: Validation: [ 0.9614134   0.96433991  0.96314763  0.96249322  0.96710027]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.171875
# Specificity : 0.9885321100917431
# Accuracy: 0.9596238938053098
# ROC 0.580203555046
# TP 11 FP 20 TN 1724 FN 53
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9322499097146985
# Specificity : 0.9950838635049162
# Accuracy: 0.9636521299273765
# ROC 0.96366688661
# TP 12907 FP 68 TN 13764 FN 938
#
#
#
# None
# Cross: Validation: [ 0.9634186   0.96282246  0.96493605  0.96476965  0.96379404]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.15625
# Specificity : 0.9931192660550459
# Accuracy: 0.963495575221239
# ROC 0.574684633028
# TP 10 FP 12 TN 1732 FN 54
#
#
#
# None
# y ncl   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164014
# Test Data Points: 70293
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9307246376811594
# Specificity : 0.9998583895349866
# Accuracy: 0.9862859744213507
# ROC 0.965291513608
# TP 12844 FP 8 TN 56485 FN 956
#
#
#
# None
# Cross: Validation: [ 0.9863002   0.98670565  0.98593743  0.98610785  0.98572343]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.03125
# Specificity : 1.0
# Accuracy: 0.9657079646017699
# ROC 0.515625
# TP 2 FP 0 TN 1744 FN 62
#
#
#
# None
# x ncl   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164014
# Test Data Points: 70293
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.93
# Specificity : 0.9996105712212132
# Accuracy: 0.9859445463986457
# ROC 0.964805285611
# TP 12834 FP 22 TN 56471 FN 966
#
#
#
# None
# Cross: Validation: [ 0.98659895  0.98649225  0.98600145  0.98629991  0.98553137]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.015625
# Specificity : 0.9988532110091743
# Accuracy: 0.9640486725663717
# ROC 0.507239105505
# TP 1 FP 2 TN 1742 FN 63
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9487179487179487
# Specificity : 0.9908906882591093
# Accuracy: 0.9697944141344799
# ROC 0.969804318489
# TP 13135 FP 126 TN 13706 FN 710
#
#
#
# None
# Cross: Validation: [ 0.97024713  0.97165619  0.97040971  0.96428184  0.93826558]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.1875
# Specificity : 0.8411697247706422
# Accuracy: 0.8180309734513275
# ROC 0.514334862385
# TP 12 FP 277 TN 1467 FN 52
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.948790176959191
# Specificity : 0.9900954308849046
# Accuracy: 0.969433103298768
# ROC 0.969442803922
# TP 13136 FP 137 TN 13695 FN 709
#
#
#
# None
# Cross: Validation: [ 0.96927162  0.97149361  0.97122263  0.96303523  0.93159892]
# Number of data points in benchmark 1808
# Benchmark Results
# Sensitivity: 0.265625
# Specificity : 0.8211009174311926
# Accuracy: 0.8014380530973452
# ROC 0.543362958716
# TP 17 FP 312 TN 1432 FN 47
#
#
#
# None
# y pass   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9302038743379526
# Specificity : 0.999543632037031
# Accuracy: 0.9868240680357214
# ROC 0.964873753187
# TP 12821 FP 28 TN 61326 FN 962
#
#
#
# None
# Cross: Validation: [ 0.98624531  0.98720329  0.98624503  0.9869435   0.98680375]
# Number of data points in benchmark 1148
# Benchmark Results
# Failed
# TP 0 FP 0 TN 1067 FN 81
#
#
#
# None
# x pass   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9302710085543814
# Specificity : 0.9994773462254598
# Accuracy: 0.9866643597694877
# ROC 0.96487417739
# TP 12941 FP 32 TN 61194 FN 970
#
#
#
# None
# Cross: Validation: [ 0.9872834   0.98680402  0.98630493  0.98680375  0.98620483]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.012345679012345678
# Specificity : 0.9990627928772259
# Accuracy: 0.9294425087108014
# ROC 0.505704235945
# TP 1 FP 1 TN 1066 FN 80
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9811165440147511
# Specificity : 0.9990356640842077
# Accuracy: 0.9901085111094707
# ROC 0.990076104049
# TP 59594 FP 59 TN 61123 FN 1147
#
#
#
# None
# Cross: Validation: [ 0.96497423  0.99258138  0.99665358  0.99686274  0.99681352]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.024691358024691357
# Specificity : 1.0
# Accuracy: 0.931184668989547
# ROC 0.512345679012
# TP 2 FP 0 TN 1067 FN 79
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9815172368269056
# Specificity : 0.9989074780680298
# Accuracy: 0.9902643471699352
# ROC 0.990212357447
# TP 59477 FP 67 TN 61259 FN 1120
#
#
#
# None
# Cross: Validation: [ 0.96450672  0.99274132  0.99721952  0.99703498  0.9975517 ]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.012345679012345678
# Specificity : 0.9971883786316776
# Accuracy: 0.9277003484320557
# ROC 0.504767028822
# TP 1 FP 3 TN 1064 FN 80
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283272
# Test Data Points: 121403
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.980794492758443
# Specificity : 0.999216505615043
# Accuracy: 0.9900908544269911
# ROC 0.990005499187
# TP 58984 FP 48 TN 61216 FN 1155
#
#
#
# None
# Cross: Validation: [ 0.97158248  0.9934886   0.99476123  0.99576203  0.99530482]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.5432098765432098
# Specificity : 0.38706654170571697
# Accuracy: 0.3980836236933798
# ROC 0.465138209124
# TP 44 FP 654 TN 413 FN 37
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283240
# Test Data Points: 121390
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9796810827887797
# Specificity : 0.9991346797498735
# Accuracy: 0.9894966636460993
# ROC 0.989407881269
# TP 58919 FP 53 TN 61196 FN 1222
#
#
#
# None
# Cross: Validation: [ 0.97224659  0.99350023  0.99545264  0.99497071  0.99503244]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.5308641975308642
# Specificity : 0.40487347703842547
# Accuracy: 0.4137630662020906
# ROC 0.467868837285
# TP 43 FP 635 TN 432 FN 38
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9333333333333333
# Specificity : 0.9944331983805668
# Accuracy: 0.9638689164288037
# ROC 0.963883265857
# TP 12922 FP 77 TN 13755 FN 923
#
#
#
# None
# Cross: Validation: [ 0.96488186  0.96265987  0.96629092  0.96460705  0.96406504]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.04938271604938271
# Specificity : 0.9915651358950328
# Accuracy: 0.9250871080139372
# ROC 0.520473925972
# TP 4 FP 9 TN 1058 FN 77
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.933911159263272
# Specificity : 0.995373048004627
# Accuracy: 0.9646276691837988
# ROC 0.964642103634
# TP 12930 FP 64 TN 13768 FN 915
#
#
#
# None
# Cross: Validation: [ 0.9624431   0.96374377  0.96455669  0.96672087  0.96330623]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.037037037037037035
# Specificity : 0.9925023430178069
# Accuracy: 0.9250871080139372
# ROC 0.514769690027
# TP 3 FP 8 TN 1059 FN 78
#
#
#
# None
# y ncl   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164028
# Test Data Points: 70299
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9287732772987465
# Specificity : 0.9997876031009947
# Accuracy: 0.9858461713537888
# ROC 0.9642804402
# TP 12818 FP 12 TN 56486 FN 983
#
#
#
# None
# Cross: Validation: [ 0.9862587   0.98613067  0.98587462  0.98677051  0.98581   ]
# Number of data points in benchmark 1148
# Benchmark Results
# Failed
# TP 0 FP 0 TN 1067 FN 81
#
#
#
# None
# x ncl   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164009
# Test Data Points: 70291
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9347101449275362
# Specificity : 0.9997698748473208
# Accuracy: 0.986996912833791
# ROC 0.967240009887
# TP 12899 FP 13 TN 56478 FN 901
#
#
#
# None
# Cross: Validation: [ 0.98600115  0.98627857  0.98553137  0.9870249   0.98600055]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.012345679012345678
# Specificity : 1.0
# Accuracy: 0.9303135888501742
# ROC 0.506172839506
# TP 1 FP 0 TN 1067 FN 80
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9482845792704948
# Specificity : 0.9894447657605553
# Accuracy: 0.9688550059616288
# ROC 0.968864672516
# TP 13129 FP 146 TN 13686 FN 716
#
#
#
# None
# Cross: Validation: [ 0.97133102  0.96889226  0.97306525  0.96466125  0.93804878]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.2345679012345679
# Specificity : 0.8031865042174321
# Accuracy: 0.7630662020905923
# ROC 0.518877202726
# TP 19 FP 210 TN 857 FN 62
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9479234380642831
# Specificity : 0.9900954308849046
# Accuracy: 0.9689995302959136
# ROC 0.969009434475
# TP 13124 FP 137 TN 13695 FN 721
#
#
#
# None
# Cross: Validation: [ 0.96997615  0.9705723   0.97208975  0.96227642  0.93279133]
# Number of data points in benchmark 1148
# Benchmark Results
# Sensitivity: 0.25925925925925924
# Specificity : 0.8144329896907216
# Accuracy: 0.7752613240418118
# ROC 0.536846124475
# TP 21 FP 198 TN 869 FN 60
#
#
#
# None
# y pass   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9304010538641686
# Specificity : 0.9994306443479251
# Accuracy: 0.986877304124466
# ROC 0.964915849106
# TP 12713 FP 35 TN 61438 FN 951
#
#
#
# None
# Cross: Validation: [ 0.98652479  0.98700365  0.9864846   0.98690357  0.98668397]
# Number of data points in benchmark 741
# Benchmark Results
# Failed
# TP 0 FP 1 TN 709 FN 31
#
#
#
# None
# x pass   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9275023727823611
# Specificity : 0.9993489583333334
# Accuracy: 0.9862517800817174
# ROC 0.963425665558
# TP 12704 FP 40 TN 61400 FN 993
#
#
#
# None
# Cross: Validation: [ 0.98698395  0.98672416  0.98644467  0.98664404  0.98658415]
# Number of data points in benchmark 741
# Benchmark Results
# Failed
# TP 0 FP 0 TN 710 FN 31
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9810872755453691
# Specificity : 0.9989392257980286
# Accuracy: 0.9900592997219556
# ROC 0.990013250672
# TP 59500 FP 65 TN 61211 FN 1147
#
#
#
# None
# Cross: Validation: [ 0.96523258  0.99282744  0.99676431  0.99707189  0.99638292]
# Number of data points in benchmark 741
# Benchmark Results
# Failed
# TP 0 FP 0 TN 710 FN 31
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9820489573889393
# Specificity : 0.9990205360932449
# Accuracy: 0.9905760192908639
# ROC 0.990534746741
# TP 59576 FP 60 TN 61198 FN 1089
#
#
#
# None
# Cross: Validation: [ 0.96538021  0.99299968  0.99687504  0.99724413  0.99718261]
# Number of data points in benchmark 741
# Benchmark Results
# Failed
# TP 0 FP 0 TN 710 FN 31
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283282
# Test Data Points: 121407
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9798317371641394
# Specificity : 0.9994123696195093
# Accuracy: 0.989712290065647
# ROC 0.989622053392
# TP 58931 FP 36 TN 61227 FN 1213
#
#
#
# None
# Cross: Validation: [ 0.97196654  0.99259927  0.99511972  0.99498375  0.99423008]
# Number of data points in benchmark 741
# Benchmark Results
# Sensitivity: 0.5806451612903226
# Specificity : 0.3704225352112676
# Accuracy: 0.3792172739541161
# ROC 0.475533848251
# TP 18 FP 447 TN 263 FN 13
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283262
# Test Data Points: 121399
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9799933477465491
# Specificity : 0.9993308198273189
# Accuracy: 0.9897527986227234
# ROC 0.989662083787
# TP 58927 FP 41 TN 61228 FN 1203
#
#
#
# None
# Cross: Validation: [ 0.97133431  0.99277171  0.99487224  0.99535412  0.9947981 ]
# Number of data points in benchmark 741
# Benchmark Results
# Sensitivity: 0.5483870967741935
# Specificity : 0.37183098591549296
# Accuracy: 0.3792172739541161
# ROC 0.460109041345
# TP 17 FP 446 TN 264 FN 14
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9325388226796677
# Specificity : 0.9950838635049162
# Accuracy: 0.9637966542616613
# ROC 0.963811343092
# TP 12911 FP 68 TN 13764 FN 934
#
#
#
# None
# Cross: Validation: [ 0.967429    0.96428571  0.96195534  0.96449864  0.96308943]
# Number of data points in benchmark 741
# Benchmark Results
# Sensitivity: 0.0967741935483871
# Specificity : 0.9873239436619718
# Accuracy: 0.9500674763832658
# ROC 0.542049068605
# TP 3 FP 9 TN 701 FN 28
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9315276273022752
# Specificity : 0.9942163100057837
# Accuracy: 0.9628572460888102
# ROC 0.962871968654
# TP 12897 FP 80 TN 13752 FN 948
#
#
#
# None
# Cross: Validation: [ 0.96466508  0.9654238   0.96293085  0.96308943  0.96449864]
# Number of data points in benchmark 741
# Benchmark Results
# Sensitivity: 0.03225806451612903
# Specificity : 0.9816901408450704
# Accuracy: 0.941970310391363
# ROC 0.506974102681
# TP 1 FP 13 TN 697 FN 30
#
#
#
# None
# y ncl   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164013
# Test Data Points: 70292
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9347148757336425
# Specificity : 0.9996813651732135
# Accuracy: 0.986925965970523
# ROC 0.967198120453
# TP 12900 FP 18 TN 56473 FN 901
#
#
#
# None
# Cross: Validation: [ 0.98595877  0.98634288  0.98649197  0.98604353  0.98600085]
# Number of data points in benchmark 741
# Benchmark Results
# Failed
# TP 0 FP 1 TN 709 FN 31
#
#
#
# None
# x ncl   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164017
# Test Data Points: 70294
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9279037750887617
# Specificity : 0.9997698829943533
# Accuracy: 0.9856602270464051
# ROC 0.963836829042
# TP 12806 FP 13 TN 56480 FN 995
#
#
#
# None
# Cross: Validation: [ 0.98659924  0.98655656  0.98625782  0.98591579  0.98542498]
# Number of data points in benchmark 741
# Benchmark Results
# Failed
# TP 0 FP 0 TN 710 FN 31
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9479956663055255
# Specificity : 0.9903123192596877
# Accuracy: 0.9691440546301984
# ROC 0.969153992783
# TP 13125 FP 134 TN 13698 FN 720
#
#
#
# None
# Cross: Validation: [ 0.97127683  0.97127683  0.97100585  0.96444444  0.93945799]
# Number of data points in benchmark 741
# Benchmark Results
# Sensitivity: 0.2903225806451613
# Specificity : 0.8323943661971831
# Accuracy: 0.8097165991902834
# ROC 0.561358473421
# TP 9 FP 119 TN 591 FN 22
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9462621885157096
# Specificity : 0.9887218045112782
# Accuracy: 0.9674820247859234
# ROC 0.967491996513
# TP 13101 FP 156 TN 13676 FN 744
#
#
#
# None
# Cross: Validation: [ 0.96997615  0.97181877  0.97317364  0.96395664  0.93495935]
# Number of data points in benchmark 741
# Benchmark Results
# Sensitivity: 0.25806451612903225
# Specificity : 0.8225352112676056
# Accuracy: 0.7989203778677463
# ROC 0.540299863698
# TP 8 FP 126 TN 584 FN 23
#
#
#
# None
# y pass   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9277912176526648
# Specificity : 0.9993495511903213
# Accuracy: 0.9863582522592065
# ROC 0.963570384421
# TP 12656 FP 40 TN 61456 FN 985
#
#
#
# None
# Cross: Validation: [ 0.98746307  0.98612525  0.98658442  0.98598523  0.98710321]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.018518518518518517
# Specificity : 0.9996440014239943
# Accuracy: 0.9461460787613598
# ROC 0.509081259971
# TP 3 FP 1 TN 2808 FN 159
#
#
#
# None
# x pass   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9253548526550904
# Specificity : 0.9996408632341898
# Accuracy: 0.9859190545270639
# ROC 0.962497857945
# TP 12843 FP 22 TN 61236 FN 1036
#
#
#
# None
# Cross: Validation: [ 0.98642498  0.98696373  0.98646463  0.98656418  0.98688361]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.006172839506172839
# Specificity : 0.9989320042719829
# Accuracy: 0.9447997307303938
# ROC 0.502552421889
# TP 1 FP 3 TN 2806 FN 161
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9811825736423863
# Specificity : 0.9989901293285989
# Accuracy: 0.9901495205990666
# ROC 0.990086351485
# TP 59390 FP 62 TN 61332 FN 1139
#
#
#
# None
# Cross: Validation: [ 0.96510956  0.99297507  0.99704728  0.99733025  0.99665358]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.018518518518518517
# Specificity : 0.9992880028479886
# Accuracy: 0.9458094917536183
# ROC 0.508903260683
# TP 3 FP 2 TN 2807 FN 159
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9821263227513227
# Specificity : 0.9989909346874338
# Accuracy: 0.9906252306783789
# ROC 0.990558628719
# TP 59399 FP 62 TN 61381 FN 1081
#
#
#
# None
# Cross: Validation: [ 0.96573699  0.9926675   0.99745328  0.99718261  0.99685043]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.018518518518518517
# Specificity : 0.9989320042719829
# Accuracy: 0.9454729047458769
# ROC 0.508725261395
# TP 3 FP 3 TN 2806 FN 159
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283267
# Test Data Points: 121401
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.98031188110573
# Specificity : 0.9993313109567146
# Accuracy: 0.9899177107272592
# ROC 0.989821596031
# TP 58904 FP 41 TN 61273 FN 1183
#
#
#
# None
# Cross: Validation: [ 0.97110027  0.99325376  0.99535418  0.99488466  0.99482288]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.6728395061728395
# Specificity : 0.3819864720541118
# Accuracy: 0.3978458431504544
# ROC 0.527412989113
# TP 109 FP 1736 TN 1073 FN 53
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283233
# Test Data Points: 121387
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9800809419915727
# Specificity : 0.9994620500782473
# Accuracy: 0.9898753573282147
# ROC 0.989771496035
# TP 58847 FP 33 TN 61311 FN 1196
#
#
#
# None
# Cross: Validation: [ 0.97196169  0.993117    0.99484702  0.99546488  0.99420437]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.6728395061728395
# Specificity : 0.3556425774296903
# Accuracy: 0.3729384045775833
# ROC 0.514241041801
# TP 109 FP 1810 TN 999 FN 53
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9321776814734561
# Specificity : 0.9935656448814344
# Accuracy: 0.9628572460888102
# ROC 0.962871663177
# TP 12906 FP 89 TN 13743 FN 939
#
#
#
# None
# Cross: Validation: [ 0.9643941   0.96249729  0.9623889   0.96601626  0.96476965]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.04938271604938271
# Specificity : 0.9928800284798861
# Accuracy: 0.9414338606529788
# ROC 0.521131372265
# TP 8 FP 20 TN 2789 FN 154
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9313109425785482
# Specificity : 0.9938548293811452
# Accuracy: 0.9625681974202406
# ROC 0.96258288598
# TP 12894 FP 85 TN 13747 FN 951
#
#
#
# None
# Cross: Validation: [ 0.96368957  0.96368957  0.96509863  0.96439024  0.96330623]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.06172839506172839
# Specificity : 0.9943040227839088
# Accuracy: 0.9434533826994278
# ROC 0.528016208923
# TP 10 FP 16 TN 2793 FN 152
#
#
#
# None
# y ncl   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 163977
# Test Data Points: 70276
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9320388349514563
# Specificity : 0.9997520983107271
# Accuracy: 0.9864534122602311
# ROC 0.965895466631
# TP 12864 FP 14 TN 56460 FN 938
#
#
#
# None
# Cross: Validation: [ 0.98527246  0.98670253  0.98623295  0.98661686  0.98608324]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.018518518518518517
# Specificity : 0.9996440014239943
# Accuracy: 0.9461460787613598
# ROC 0.509081259971
# TP 3 FP 1 TN 2808 FN 159
#
#
#
# None
# x ncl   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164013
# Test Data Points: 70292
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9289181943337439
# Specificity : 0.9997698748473208
# Accuracy: 0.9858589882205656
# ROC 0.964344034591
# TP 12820 FP 13 TN 56478 FN 981
#
#
#
# None
# Cross: Validation: [ 0.98674832  0.98610815  0.98551034  0.98691848  0.98544601]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.012345679012345678
# Specificity : 0.9996440014239943
# Accuracy: 0.9458094917536183
# ROC 0.505994840218
# TP 2 FP 1 TN 2808 FN 160
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.948790176959191
# Specificity : 0.9906015037593985
# Accuracy: 0.9696860208837663
# ROC 0.969695840359
# TP 13136 FP 130 TN 13702 FN 709
#
#
#
# None
# Cross: Validation: [ 0.96981357  0.97192716  0.97073488  0.96373984  0.93555556]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.4012345679012346
# Specificity : 0.8180847276610893
# Accuracy: 0.7953550992931673
# ROC 0.609659647781
# TP 65 FP 511 TN 2298 FN 97
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9472733838931022
# Specificity : 0.9913967611336032
# Accuracy: 0.9693247100480543
# ROC 0.969335072513
# TP 13115 FP 119 TN 13713 FN 730
#
#
#
# None
# Cross: Validation: [ 0.96986777  0.97165619  0.97442012  0.96097561  0.93696477]
# Number of data points in benchmark 2971
# Benchmark Results
# Sensitivity: 0.2345679012345679
# Specificity : 0.8013527945888217
# Accuracy: 0.7704476607202962
# ROC 0.517960347912
# TP 38 FP 558 TN 2251 FN 124
#
#
#
# None
# y pass   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.931896800230614
# Specificity : 0.9993307324398883
# Accuracy: 0.986877304124466
# ROC 0.965613766335
# TP 12931 FP 41 TN 61220 FN 945
#
#
#
# None
# Cross: Validation: [ 0.98664457  0.98698369  0.9871434   0.98624476  0.98646436]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.039473684210526314
# Specificity : 1.0
# Accuracy: 0.9497936726272352
# ROC 0.519736842105
# TP 3 FP 0 TN 1378 FN 73
#
#
#
# None
# x pass   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.930254273811234
# Specificity : 0.9995589316344033
# Accuracy: 0.9867175958582323
# ROC 0.964906602723
# TP 12951 FP 27 TN 61188 FN 971
#
#
#
# None
# Cross: Validation: [ 0.98676435  0.98702362  0.98686391  0.9859453   0.98686365]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.013157894736842105
# Specificity : 1.0
# Accuracy: 0.9484181568088033
# ROC 0.506578947368
# TP 1 FP 0 TN 1378 FN 75
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9814153319396204
# Specificity : 0.9991009252296728
# Accuracy: 0.9902889528636927
# ROC 0.990258128585
# TP 59620 FP 55 TN 61119 FN 1129
#
#
#
# None
# Cross: Validation: [ 0.96506034  0.99247066  0.99724413  0.99683813  0.99675201]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.039473684210526314
# Specificity : 1.0
# Accuracy: 0.9497936726272352
# ROC 0.519736842105
# TP 3 FP 0 TN 1378 FN 73
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9819975623414698
# Specificity : 0.9991014393308174
# Accuracy: 0.9905842211887831
# ROC 0.990549500836
# TP 59621 FP 55 TN 61154 FN 1093
#
#
#
# None
# Cross: Validation: [ 0.96546633  0.99244605  0.99701037  0.99766243  0.99685043]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.02631578947368421
# Specificity : 0.9992743105950653
# Accuracy: 0.9484181568088033
# ROC 0.512795050034
# TP 2 FP 1 TN 1377 FN 74
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 260178
# Test Data Points: 111505
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9771398798378299
# Specificity : 0.9991415109407443
# Accuracy: 0.98702300345276
# ROC 0.988140695389
# TP 60013 FP 43 TN 50045 FN 1404
#
#
#
# None
# Cross: Validation: [ 0.96254944  0.99074485  0.99478046  0.9949957   0.9944576 ]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.631578947368421
# Specificity : 0.4223512336719884
# Accuracy: 0.4332874828060523
# ROC 0.52696509052
# TP 48 FP 796 TN 582 FN 28
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283272
# Test Data Points: 121403
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9789986531202713
# Specificity : 0.9992817968137895
# Accuracy: 0.9892342034381358
# ROC 0.989140224967
# TP 58876 FP 44 TN 61220 FN 1263
#
#
#
# None
# Cross: Validation: [ 0.97169368  0.99314265  0.99476123  0.9955767   0.9953666 ]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.6710526315789473
# Specificity : 0.44194484760522496
# Accuracy: 0.45392022008253097
# ROC 0.556498739592
# TP 51 FP 769 TN 609 FN 25
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9351390393643915
# Specificity : 0.9927703875072296
# Accuracy: 0.9639411785959461
# ROC 0.963954713436
# TP 12947 FP 100 TN 13732 FN 898
#
#
#
# None
# Cross: Validation: [ 0.96233471  0.96618253  0.96450249  0.96439024  0.96390244]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.039473684210526314
# Specificity : 0.9934687953555879
# Accuracy: 0.9436038514442916
# ROC 0.516471239783
# TP 3 FP 9 TN 1369 FN 73
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9326832791621524
# Specificity : 0.9939994216310005
# Accuracy: 0.9633269501752357
# ROC 0.963341350397
# TP 12913 FP 83 TN 13749 FN 932
#
#
#
# None
# Cross: Validation: [ 0.96352699  0.96466508  0.96569478  0.96216802  0.96525745]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.07894736842105263
# Specificity : 0.9927431059506531
# Accuracy: 0.9449793672627235
# ROC 0.535845237186
# TP 6 FP 10 TN 1368 FN 70
#
#
#
# None
# y ncl   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 163991
# Test Data Points: 70283
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9289233444428344
# Specificity : 0.9997344239655813
# Accuracy: 0.9858287210278446
# ROC 0.964328884204
# TP 12821 FP 15 TN 56466 FN 981
#
#
#
# None
# Cross: Validation: [ 0.98604234  0.98593533  0.98704514  0.985871    0.98576429]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.013157894736842105
# Specificity : 1.0
# Accuracy: 0.9484181568088033
# ROC 0.506578947368
# TP 1 FP 0 TN 1378 FN 75
#
#
#
# None
# x ncl   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164005
# Test Data Points: 70289
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.92971523802623
# Specificity : 0.9996105367511684
# Accuracy: 0.9858868386233977
# ROC 0.964662887389
# TP 12831 FP 22 TN 56466 FN 970
#
#
#
# None
# Cross: Validation: [ 0.98651302  0.98619262  0.98563776  0.98606428  0.9864911 ]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.05263157894736842
# Specificity : 1.0
# Accuracy: 0.9504814305364512
# ROC 0.526315789474
# TP 4 FP 0 TN 1378 FN 72
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9487179487179487
# Specificity : 0.9889386928860613
# Accuracy: 0.9688188748780576
# ROC 0.968828320802
# TP 13135 FP 153 TN 13679 FN 710
#
#
#
# None
# Cross: Validation: [ 0.97008454  0.97106005  0.97089746  0.96363144  0.93880759]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.21052631578947367
# Specificity : 0.8076923076923077
# Accuracy: 0.7764786795048143
# ROC 0.509109311741
# TP 16 FP 265 TN 1113 FN 60
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9483568075117371
# Specificity : 0.9880711393869288
# Accuracy: 0.9682046464573473
# ROC 0.968213973449
# TP 13130 FP 165 TN 13667 FN 715
#
#
#
# None
# Cross: Validation: [ 0.96829612  0.97274008  0.97214394  0.96352304  0.93810298]
# Number of data points in benchmark 1454
# Benchmark Results
# Sensitivity: 0.27631578947368424
# Specificity : 0.793178519593614
# Accuracy: 0.7661623108665749
# ROC 0.534747154534
# TP 21 FP 285 TN 1093 FN 55
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
benchmarks = ["Data/Benchmarks/phos_CDK1.csv", "Data/Benchmarks/phos_CK2.csv", "Data/Benchmarks/phos_MAPK1.csv", "Data/Benchmarks/phos_PKA.csv", "Data/Benchmarks/phos_PKC.csv"]
for j in benchmarks:
    for i in par:
        try:
            print("y", i, " ", j)
            y = Predictor()
            y.load_data(file="Data/Training/clean_Y_filtered.csv")
            y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
            y.supervised_training("bagging")
            y.benchmark(j, "Y")
            del y
            print("x", i, " ", j)
            x = Predictor()
            x.load_data(file="Data/Training/clean_Y_filtered.csv")
            x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
            x.supervised_training("bagging")
            x.benchmark(j, "Y")
            del x
        except:
            print("Benchmark not relevant")
# Out:
# y pass   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04225352112676056
# Specificity : 0.9983543609434997
# Accuracy: 0.9625131995776135
# ROC 0.520303941035
# TP 6 FP 6 TN 3640 FN 136
#
#
#
# None
# Cross: Validation: [ 0.95328583  0.95247525  0.95366337  0.95285261  0.9548336 ]
# Number of data points in benchmark 0
# Benchmark not relevant
# y ADASYN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9447988904299583
# Specificity : 0.995356459983611
# Accuracy: 0.9702725020644096
# ROC 0.970077675207
# TP 3406 FP 17 TN 3644 FN 199
#
#
#
# None
# Cross: Validation: [ 0.87265222  0.99339389  0.98451693  0.98699153  0.98946934]
# Number of data points in benchmark 0
# Benchmark not relevant
# y SMOTEENN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16846
# Test Data Points: 7220
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9402524544179524
# Specificity : 0.9835841313269493
# Accuracy: 0.9621883656509695
# ROC 0.961918292872
# TP 3352 FP 60 TN 3595 FN 213
#
#
#
# None
# Cross: Validation: [ 0.89156627  0.98379726  0.98234317  0.98503741  0.97921862]
# Number of data points in benchmark 0
# Benchmark not relevant
# y random_under_sample   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5428571428571428
# Specificity : 0.7111111111111111
# Accuracy: 0.6281690140845071
# ROC 0.626984126984
# TP 95 FP 52 TN 128 FN 80
#
#
#
# None
# Cross: Validation: [ 0.56722689  0.56779661  0.58474576  0.55508475  0.6059322 ]
# Number of data points in benchmark 0
# Benchmark not relevant
# y ncl   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8079
# Test Data Points: 3463
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04819277108433735
# Specificity : 0.9981801637852593
# Accuracy: 0.9526422177302917
# ROC 0.523186467435
# TP 8 FP 6 TN 3291 FN 158
#
#
#
# None
# Cross: Validation: [ 0.95064935  0.95060659  0.95147314  0.95103986  0.95060659]
# Number of data points in benchmark 0
# Benchmark not relevant
# y near_miss   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5314285714285715
# Specificity : 0.7555555555555555
# Accuracy: 0.6450704225352113
# ROC 0.643492063492
# TP 93 FP 44 TN 136 FN 82
#
#
#
# None
# Cross: Validation: [ 0.56722689  0.68644068  0.61016949  0.64830508  0.63983051]
# Number of data points in benchmark 0
# Benchmark not relevant
# y pass   Data/Benchmarks/phos_CK2.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.03932584269662921
# Specificity : 0.9977839335180055
# Accuracy: 0.9527455121436114
# ROC 0.518554888107
# TP 7 FP 8 TN 3602 FN 171
#
#
#
# None
# Cross: Validation: [ 0.95566112  0.95524752  0.95366337  0.9548336   0.95522979]
# Number of data points in benchmark 398
# Benchmark Results
# Failed
# TP 0 FP 0 TN 397 FN 1
#
#
#
# None
# x pass   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.032679738562091505
# Specificity : 0.9994497936726272
# Accuracy: 0.9604012671594508
# ROC 0.516064766117
# TP 5 FP 2 TN 3633 FN 148
#
#
#
# None
# Cross: Validation: [ 0.95447348  0.9560396   0.95445545  0.95324881  0.95562599]
# Number of data points in benchmark 398
# Benchmark Results
# Failed
# TP 0 FP 1 TN 396 FN 1
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9445368829728231
# Specificity : 0.9959016393442623
# Accuracy: 0.970410129369667
# ROC 0.970219261159
# TP 3406 FP 15 TN 3645 FN 200
#
#
#
# None
# Cross: Validation: [ 0.86934985  0.99153592  0.98369116  0.98761098  0.99318604]
# Number of data points in benchmark 398
# Benchmark Results
# Failed
# TP 0 FP 74 TN 323 FN 1
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9407530454042082
# Specificity : 0.9975369458128078
# Accuracy: 0.9693091109276081
# ROC 0.969144995609
# TP 3398 FP 9 TN 3645 FN 214
#
#
#
# None
# Cross: Validation: [ 0.87203302  0.99112304  0.98864575  0.99091472  0.98699153]
# Number of data points in benchmark 398
# Benchmark Results
# Failed
# TP 0 FP 75 TN 322 FN 1
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16841
# Test Data Points: 7219
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.939317673378076
# Specificity : 0.9821575624485315
# Accuracy: 0.960936417786397
# ROC 0.960737617913
# TP 3359 FP 65 TN 3578 FN 217
#
#
#
# None
# Cross: Validation: [ 0.89445252  0.98005402  0.98025769  0.98316358  0.9806693 ]
# Number of data points in benchmark 398
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.05037783375314862
# Accuracy: 0.052763819095477386
# ROC 0.525188916877
# TP 1 FP 377 TN 20 FN 0
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16840
# Test Data Points: 7218
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9314493564633464
# Specificity : 0.9816136114160263
# Accuracy: 0.9567747298420615
# ROC 0.95653148394
# TP 3329 FP 67 TN 3577 FN 245
#
#
#
# None
# Cross: Validation: [ 0.89297589  0.98171239  0.98108894  0.98274787  0.9821243 ]
# Number of data points in benchmark 398
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.017632241813602016
# Accuracy: 0.020100502512562814
# ROC 0.508816120907
# TP 1 FP 390 TN 7 FN 0
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.48
# Specificity : 0.7222222222222222
# Accuracy: 0.6028169014084507
# ROC 0.601111111111
# TP 84 FP 50 TN 130 FN 91
#
#
#
# None
# Cross: Validation: [ 0.62605042  0.61016949  0.60169492  0.64830508  0.61440678]
# Number of data points in benchmark 398
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6221662468513854
# Accuracy: 0.6231155778894473
# ROC 0.811083123426
# TP 1 FP 150 TN 247 FN 0
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5428571428571428
# Specificity : 0.6722222222222223
# Accuracy: 0.6084507042253521
# ROC 0.60753968254
# TP 95 FP 59 TN 121 FN 80
#
#
#
# None
# Cross: Validation: [ 0.57563025  0.58898305  0.55508475  0.51271186  0.61864407]
# Number of data points in benchmark 398
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6876574307304786
# Accuracy: 0.6884422110552764
# ROC 0.843828715365
# TP 1 FP 124 TN 273 FN 0
#
#
#
# None
# y ncl   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8076
# Test Data Points: 3462
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.04216867469879518
# Specificity : 0.9990898058252428
# Accuracy: 0.9532062391681109
# ROC 0.520629240262
# TP 7 FP 3 TN 3293 FN 159
#
#
#
# None
# Cross: Validation: [ 0.94846254  0.95277296  0.95015171  0.95231903  0.95058518]
# Number of data points in benchmark 398
# Benchmark Results
# Failed
# TP 0 FP 1 TN 396 FN 1
#
#
#
# None
# x ncl   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8073
# Test Data Points: 3460
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.059880239520958084
# Specificity : 0.998177953234133
# Accuracy: 0.9528901734104046
# ROC 0.529029096378
# TP 10 FP 6 TN 3287 FN 157
#
#
#
# None
# Cross: Validation: [ 0.95103986  0.95101864  0.9501301   0.9518647   0.94709454]
# Number of data points in benchmark 398
# Benchmark Results
# Failed
# TP 0 FP 1 TN 396 FN 1
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5314285714285715
# Specificity : 0.7611111111111111
# Accuracy: 0.647887323943662
# ROC 0.64626984127
# TP 93 FP 43 TN 137 FN 82
#
#
#
# None
# Cross: Validation: [ 0.67226891  0.68220339  0.60169492  0.6440678   0.58474576]
# Number of data points in benchmark 398
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4534005037783375
# Accuracy: 0.4547738693467337
# ROC 0.726700251889
# TP 1 FP 217 TN 180 FN 0
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5428571428571428
# Specificity : 0.7666666666666667
# Accuracy: 0.6563380281690141
# ROC 0.654761904762
# TP 95 FP 42 TN 138 FN 80
#
#
#
# None
# Cross: Validation: [ 0.62605042  0.63983051  0.65254237  0.65677966  0.63559322]
# Number of data points in benchmark 398
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4534005037783375
# Accuracy: 0.4547738693467337
# ROC 0.726700251889
# TP 1 FP 217 TN 180 FN 0
#
#
#
# None
# y pass   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05
# Specificity : 0.9991685144124168
# Accuracy: 0.954065469904963
# ROC 0.524584257206
# TP 9 FP 3 TN 3605 FN 171
#
#
#
# None
# Cross: Validation: [ 0.95407759  0.95445545  0.95445545  0.9544374   0.9540412 ]
# Number of data points in benchmark 0
# Benchmark not relevant
# y ADASYN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9516759776536313
# Specificity : 0.9970157352143245
# Accuracy: 0.9746765758326452
# ROC 0.974345856434
# TP 3407 FP 11 TN 3675 FN 173
#
#
#
# None
# Cross: Validation: [ 0.87719298  0.98947151  0.98843931  0.98678505  0.9874045 ]
# Number of data points in benchmark 0
# Benchmark not relevant
# y SMOTEENN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16841
# Test Data Points: 7219
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9381991051454138
# Specificity : 0.9884710403513588
# Accuracy: 0.9635683612688738
# ROC 0.963335072748
# TP 3355 FP 42 TN 3601 FN 221
#
#
#
# None
# Cross: Validation: [ 0.90047787  0.98213173  0.98025769  0.9806693   0.97672002]
# Number of data points in benchmark 0
# Benchmark not relevant
# y random_under_sample   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5371428571428571
# Specificity : 0.6944444444444444
# Accuracy: 0.6169014084507042
# ROC 0.615793650794
# TP 94 FP 55 TN 125 FN 81
#
#
#
# None
# Cross: Validation: [ 0.6302521   0.58898305  0.5720339   0.58050847  0.66949153]
# Number of data points in benchmark 0
# Benchmark not relevant
# y ncl   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8071
# Test Data Points: 3460
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.029940119760479042
# Specificity : 0.998177953234133
# Accuracy: 0.9514450867052023
# ROC 0.514059036497
# TP 5 FP 6 TN 3287 FN 162
#
#
#
# None
# Cross: Validation: [ 0.95058518  0.9518647   0.9501301   0.94709454  0.95229835]
# Number of data points in benchmark 0
# Benchmark not relevant
# y near_miss   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5942857142857143
# Specificity : 0.7555555555555555
# Accuracy: 0.676056338028169
# ROC 0.674920634921
# TP 104 FP 44 TN 136 FN 71
#
#
#
# None
# Cross: Validation: [ 0.6302521   0.64830508  0.61864407  0.66525424  0.63135593]
# Number of data points in benchmark 0
# Benchmark not relevant
# y pass   Data/Benchmarks/phos_PKA.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.05
# Specificity : 0.9988913525498891
# Accuracy: 0.9538014783526927
# ROC 0.524445676275
# TP 9 FP 4 TN 3604 FN 171
#
#
#
# None
# Cross: Validation: [ 0.95407759  0.9560396   0.95564356  0.95324881  0.9540412 ]
# Number of data points in benchmark 0
# Benchmark not relevant
# y ADASYN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9448447893569845
# Specificity : 0.9956260251503554
# Accuracy: 0.970410129369667
# ROC 0.970235407254
# TP 3409 FP 16 TN 3642 FN 199
#
#
#
# None
# Cross: Validation: [ 0.86831785  0.98451693  0.98781998  0.99277307  0.98926285]
# Number of data points in benchmark 0
# Benchmark not relevant
# y SMOTEENN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16841
# Test Data Points: 7218
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9344953612594883
# Specificity : 0.9857962305381044
# Accuracy: 0.9605153782211139
# ROC 0.960145795899
# TP 3324 FP 52 TN 3609 FN 233
#
#
#
# None
# Cross: Validation: [ 0.89715354  0.97693267  0.98524522  0.98108501  0.9821243 ]
# Number of data points in benchmark 0
# Benchmark not relevant
# y random_under_sample   Data/Benchmarks/phos_PKA.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5028571428571429
# Specificity : 0.6222222222222222
# Accuracy: 0.5633802816901409
# ROC 0.56253968254
# TP 88 FP 68 TN 112 FN 87
#
#
#
# None
# Cross: Validation: [ 0.55462185  0.58898305  0.51694915  0.55508475  0.58050847]
# Number of data points in benchmark 0
# Benchmark not relevant
# y ncl   Data/Benchmarks/phos_PKA.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8076
# Test Data Points: 3462
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06626506024096386
# Specificity : 0.9996966019417476
# Accuracy: 0.9549393414211439
# ROC 0.532980831091
# TP 11 FP 1 TN 3295 FN 155
#
#
#
# None
# Cross: Validation: [ 0.94889563  0.95017331  0.94928479  0.94971825  0.95101864]
# Number of data points in benchmark 0
# Benchmark not relevant
# y near_miss   Data/Benchmarks/phos_PKA.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5142857142857142
# Specificity : 0.7888888888888889
# Accuracy: 0.6535211267605634
# ROC 0.651587301587
# TP 90 FP 38 TN 142 FN 85
#
#
#
# None
# Cross: Validation: [ 0.64285714  0.6440678   0.66525424  0.64830508  0.61864407]
# Number of data points in benchmark 0
# Benchmark not relevant
# y pass   Data/Benchmarks/phos_PKC.csv
# Loading Data
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.06358381502890173
# Specificity : 0.9994467496542185
# Accuracy: 0.9567053854276664
# ROC 0.531515282342
# TP 11 FP 2 TN 3613 FN 162
#
#
#
# None
# Cross: Validation: [ 0.95288994  0.95485149  0.95485149  0.95602219  0.95522979]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.9982394366197183
# Accuracy: 0.9982425307557118
# ROC 0.99911971831
# TP 1 FP 1 TN 567 FN 0
#
#
#
# None
# x pass   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0446927374301676
# Specificity : 0.999168744804655
# Accuracy: 0.954065469904963
# ROC 0.521930741117
# TP 8 FP 3 TN 3606 FN 171
#
#
#
# None
# Cross: Validation: [ 0.95486936  0.95524752  0.95366337  0.9544374   0.9544374 ]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.9982394366197183
# Accuracy: 0.9982425307557118
# ROC 0.99911971831
# TP 1 FP 1 TN 567 FN 0
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9461410327595781
# Specificity : 0.9959061135371179
# Accuracy: 0.9712358932012112
# ROC 0.971023573148
# TP 3408 FP 15 TN 3649 FN 194
#
#
#
# None
# Cross: Validation: [ 0.86831785  0.99029727  0.99483898  0.99091472  0.99194714]
# Number of data points in benchmark 569
# Benchmark Results
# Failed
# TP 0 FP 107 TN 461 FN 1
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.949374130737135
# Specificity : 0.9978207572868428
# Accuracy: 0.973850812001101
# ROC 0.973597444012
# TP 3413 FP 8 TN 3663 FN 182
#
#
#
# None
# Cross: Validation: [ 0.86584107  0.9954583   0.98843931  0.98533967  0.98884989]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.7852112676056338
# Accuracy: 0.7855887521968365
# ROC 0.892605633803
# TP 1 FP 122 TN 446 FN 0
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16841
# Test Data Points: 7218
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9350576328366601
# Specificity : 0.989620322316307
# Accuracy: 0.9627320587420338
# ROC 0.962338977576
# TP 3326 FP 38 TN 3623 FN 231
#
#
#
# None
# Cross: Validation: [ 0.89715354  0.98711554  0.98129676  0.9792143   0.98254001]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.035211267605633804
# Accuracy: 0.03690685413005272
# ROC 0.517605633803
# TP 1 FP 548 TN 20 FN 0
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16844
# Test Data Points: 7220
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9359730412805392
# Specificity : 0.9885214539491665
# Accuracy: 0.9626038781163435
# ROC 0.962247247615
# TP 3333 FP 42 TN 3617 FN 228
#
#
#
# None
# Cross: Validation: [ 0.89509763  0.9844172   0.97963848  0.98607648  0.97921862]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.03345070422535211
# Accuracy: 0.0351493848857645
# ROC 0.516725352113
# TP 1 FP 549 TN 19 FN 0
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5028571428571429
# Specificity : 0.75
# Accuracy: 0.6281690140845071
# ROC 0.626428571429
# TP 88 FP 45 TN 135 FN 87
#
#
#
# None
# Cross: Validation: [ 0.62605042  0.57627119  0.50847458  0.56779661  0.58474576]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6919014084507042
# Accuracy: 0.6924428822495606
# ROC 0.845950704225
# TP 1 FP 175 TN 393 FN 0
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.4685714285714286
# Specificity : 0.6944444444444444
# Accuracy: 0.5830985915492958
# ROC 0.581507936508
# TP 82 FP 55 TN 125 FN 93
#
#
#
# None
# Cross: Validation: [ 0.60504202  0.56355932  0.61864407  0.57627119  0.59322034]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.6496478873239436
# Accuracy: 0.6502636203866432
# ROC 0.824823943662
# TP 1 FP 199 TN 369 FN 0
#
#
#
# None
# y ncl   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8065
# Test Data Points: 3457
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0718562874251497
# Specificity : 0.9990881458966565
# Accuracy: 0.9542956320509112
# ROC 0.535472216661
# TP 12 FP 3 TN 3287 FN 155
#
#
#
# None
# Cross: Validation: [ 0.95143105  0.95052083  0.94965278  0.95052083  0.95052083]
# Number of data points in benchmark 569
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.9982394366197183
# Accuracy: 0.9982425307557118
# ROC 0.99911971831
# TP 1 FP 1 TN 567 FN 0
#
#
#
# None
# x ncl   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8069
# Test Data Points: 3459
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0718562874251497
# Specificity : 0.9975698663426489
# Accuracy: 0.9528765539173172
# ROC 0.534713076884
# TP 12 FP 8 TN 3284 FN 155
#
#
#
# None
# Cross: Validation: [ 0.95058518  0.95056375  0.94924078  0.95097614  0.94967462]
# Number of data points in benchmark 569
# Benchmark Results
# Failed
# TP 0 FP 2 TN 566 FN 1
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5542857142857143
# Specificity : 0.7666666666666667
# Accuracy: 0.6619718309859155
# ROC 0.660476190476
# TP 97 FP 42 TN 138 FN 78
#
#
#
# None
# Cross: Validation: [ 0.60504202  0.62711864  0.6440678   0.65254237  0.63983051]
# Number of data points in benchmark 569
# Benchmark Results
# Failed
# TP 0 FP 258 TN 310 FN 1
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5085714285714286
# Specificity : 0.8055555555555556
# Accuracy: 0.6591549295774648
# ROC 0.657063492063
# TP 89 FP 35 TN 145 FN 86
#
#
#
# None
# Cross: Validation: [ 0.6302521   0.65254237  0.61016949  0.67372881  0.65254237]
# Number of data points in benchmark 569
# Benchmark Results
# Failed
# TP 0 FP 280 TN 288 FN 1
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
benchmarks = ["Data/Benchmarks/phos_CDK1.csv", "Data/Benchmarks/phos_CK2.csv", "Data/Benchmarks/phos_MAPK1.csv", "Data/Benchmarks/phos_PKA.csv", "Data/Benchmarks/phos_PKC.csv"]
for j in benchmarks:
    for i in par:
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_t_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training("bagging")
        y.benchmark(j, "T")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_t_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training("bagging")
        x.benchmark(j, "T")
        del x
# Out:
# y pass   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8983498349834983
# Specificity : 0.9992620652334334
# Accuracy: 0.9808218076551946
# ROC 0.948805950108
# TP 4083 FP 15 TN 20312 FN 462
#
#
#
# None
# Cross: Validation: [ 0.98027982  0.98317453  0.98112183  0.97967431  0.98154403]
# Number of data points in benchmark 1196
# Benchmark Results
# Failed
# TP 0 FP 0 TN 1153 FN 43
#
#
#
# None
# x pass   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9016023470999774
# Specificity : 0.9990704955726236
# Accuracy: 0.9817063364425861
# ROC 0.950336421336
# TP 3995 FP 19 TN 20422 FN 436
#
#
#
# None
# Cross: Validation: [ 0.98027982  0.98058135  0.98178528  0.9818456   0.98094089]
# Number of data points in benchmark 1196
# Benchmark Results
# Failed
# TP 0 FP 1 TN 1152 FN 43
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9748321337133472
# Specificity : 0.9990675304279545
# Accuracy: 0.9868539572023274
# ROC 0.986949832071
# TP 20180 FP 19 TN 20357 FN 521
#
#
#
# None
# Cross: Validation: [ 0.94971883  0.99050575  0.99576395  0.99459538  0.99346334]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.09302325581395349
# Specificity : 0.9453599306157849
# Accuracy: 0.9147157190635451
# ROC 0.519191593215
# TP 4 FP 63 TN 1090 FN 39
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9736728112817057
# Specificity : 0.9991133004926108
# Accuracy: 0.9862453441098424
# ROC 0.986393055887
# TP 20230 FP 18 TN 20282 FN 547
#
#
#
# None
# Cross: Validation: [ 0.95052216  0.9921855   0.99390155  0.9946319   0.99335378]
# Number of data points in benchmark 1196
# Benchmark Results
# Failed
# TP 0 FP 0 TN 1153 FN 43
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94196
# Test Data Points: 40370
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9703729522481701
# Specificity : 0.9993099028934785
# Accuracy: 0.9849145405003715
# ROC 0.984841427571
# TP 19488 FP 14 TN 20273 FN 595
#
#
#
# None
# Cross: Validation: [ 0.95976072  0.98926209  0.9901163   0.99208561  0.99215963]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.46511627906976744
# Specificity : 0.4293148308759757
# Accuracy: 0.4306020066889632
# ROC 0.447215554973
# TP 20 FP 658 TN 495 FN 23
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94217
# Test Data Points: 40379
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9728774758634419
# Specificity : 0.9989154547695341
# Accuracy: 0.9859580474999381
# ROC 0.985896465316
# TP 19549 FP 22 TN 20263 FN 545
#
#
#
# None
# Cross: Validation: [ 0.96073551  0.98889302  0.99179019  0.99175304  0.99286723]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.4883720930232558
# Specificity : 0.39722463139635733
# Accuracy: 0.4005016722408027
# ROC 0.44279836221
# TP 21 FP 695 TN 458 FN 22
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9065049614112458
# Specificity : 0.9901960784313726
# Accuracy: 0.9481325501496176
# ROC 0.948350519921
# TP 4111 FP 44 TN 4444 FN 424
#
#
#
# None
# Cross: Validation: [ 0.94514628  0.95146277  0.94778849  0.95044895  0.94945128]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.06976744186046512
# Specificity : 0.997398091934085
# Accuracy: 0.9640468227424749
# ROC 0.533582766897
# TP 3 FP 3 TN 1150 FN 40
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9029768467475193
# Specificity : 0.9884135472370766
# Accuracy: 0.9454726809265211
# ROC 0.945695196992
# TP 4095 FP 52 TN 4436 FN 440
#
#
#
# None
# Cross: Validation: [ 0.95079787  0.95129654  0.94861989  0.94778849  0.94562687]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.046511627906976744
# Specificity : 0.9913269731136166
# Accuracy: 0.9573578595317725
# ROC 0.51891930051
# TP 2 FP 10 TN 1143 FN 41
#
#
#
# None
# y ncl   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54639
# Test Data Points: 23417
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9031818181818182
# Specificity : 0.9994741547036862
# Accuracy: 0.9813810479566127
# ROC 0.951327986443
# TP 3974 FP 10 TN 19007 FN 426
#
#
#
# None
# Cross: Validation: [ 0.98039969  0.98136049  0.98097495  0.98059061  0.9785394 ]
# Number of data points in benchmark 1196
# Benchmark Results
# Failed
# TP 0 FP 0 TN 1153 FN 43
#
#
#
# None
# x ncl   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54646
# Test Data Points: 23420
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8995454545454545
# Specificity : 0.9994216614090431
# Accuracy: 0.9806575576430402
# ROC 0.949483557977
# TP 3958 FP 11 TN 19009 FN 442
#
#
#
# None
# Cross: Validation: [ 0.98187524  0.97860894  0.98040095  0.97892782  0.98212913]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.023255813953488372
# Specificity : 1.0
# Accuracy: 0.9648829431438127
# ROC 0.511627906977
# TP 1 FP 0 TN 1153 FN 42
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9045203969128996
# Specificity : 0.9922014260249554
# Accuracy: 0.9481325501496176
# ROC 0.948360911469
# TP 4102 FP 35 TN 4453 FN 433
#
#
#
# None
# Cross: Validation: [ 0.94980053  0.95561835  0.9516129   0.94878617  0.94529431]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.18604651162790697
# Specificity : 0.9210754553339116
# Accuracy: 0.8946488294314381
# ROC 0.553560983481
# TP 8 FP 91 TN 1062 FN 35
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_CDK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9133406835722161
# Specificity : 0.9915329768270945
# Accuracy: 0.9522331818685581
# ROC 0.9524368302
# TP 4142 FP 38 TN 4450 FN 393
#
#
#
# None
# Cross: Validation: [ 0.95196144  0.95146277  0.95377453  0.94579315  0.94778849]
# Number of data points in benchmark 1196
# Benchmark Results
# Sensitivity: 0.20930232558139536
# Specificity : 0.9297484822202949
# Accuracy: 0.9038461538461539
# ROC 0.569525403901
# TP 9 FP 81 TN 1072 FN 34
#
#
#
# None
# y pass   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9016172506738545
# Specificity : 0.9992654260528894
# Accuracy: 0.9817867481505307
# ROC 0.950441338363
# TP 4014 FP 15 TN 20405 FN 438
#
#
#
# None
# Cross: Validation: [ 0.98088289  0.98027982  0.98124246  0.98220748  0.98094089]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 0 TN 704 FN 15
#
#
#
# None
# x pass   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9058535499666147
# Specificity : 0.9994111585455616
# Accuracy: 0.9825104535220328
# ROC 0.952632354256
# TP 4070 FP 12 TN 20367 FN 423
#
#
#
# None
# Cross: Validation: [ 0.98130503  0.98118442  0.98069964  0.9827503   0.97985525]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 1 TN 703 FN 15
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9744897959183674
# Specificity : 0.9990640855130289
# Accuracy: 0.9866348564890328
# ROC 0.986776940716
# TP 20246 FP 19 TN 20282 FN 530
#
#
#
# None
# Cross: Validation: [ 0.95033959  0.99116305  0.99514315  0.99233129  0.9944128 ]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 1 TN 703 FN 15
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9747353224254091
# Specificity : 0.9991624377986894
# Accuracy: 0.9868052681549285
# ROC 0.986948880112
# TP 20255 FP 17 TN 20280 FN 525
#
#
#
# None
# Cross: Validation: [ 0.95055868  0.98959284  0.99415717  0.99466842  0.99448583]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 0 TN 704 FN 15
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 85485
# Test Data Points: 36637
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9693661798692039
# Specificity : 0.9982208588957056
# Accuracy: 0.9822037830608401
# ROC 0.983793519382
# TP 19714 FP 29 TN 16271 FN 623
#
#
#
# None
# Cross: Validation: [ 0.94857728  0.98616172  0.9916885   0.98955945  0.99009171]
# Number of data points in benchmark 719
# Benchmark Results
# Sensitivity: 0.26666666666666666
# Specificity : 0.41761363636363635
# Accuracy: 0.4144645340751043
# ROC 0.342140151515
# TP 4 FP 410 TN 294 FN 11
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 85366
# Test Data Points: 36586
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9666124981533462
# Specificity : 0.9979114196203698
# Accuracy: 0.9805390039905975
# ROC 0.982261958887
# TP 19629 FP 34 TN 16245 FN 678
#
#
#
# None
# Cross: Validation: [ 0.94912058  0.98544545  0.99126691  0.99134891  0.99069291]
# Number of data points in benchmark 719
# Benchmark Results
# Sensitivity: 0.26666666666666666
# Specificity : 0.4659090909090909
# Accuracy: 0.4617524339360223
# ROC 0.366287878788
# TP 4 FP 376 TN 328 FN 11
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9018743109151047
# Specificity : 0.9895276292335116
# Accuracy: 0.9454726809265211
# ROC 0.945700970074
# TP 4090 FP 47 TN 4441 FN 445
#
#
#
# None
# Cross: Validation: [ 0.95212766  0.94581117  0.94828733  0.94945128  0.94978384]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 11 TN 693 FN 15
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.908710033076075
# Specificity : 0.9908645276292335
# Accuracy: 0.9495733126454616
# ROC 0.949787280353
# TP 4121 FP 41 TN 4447 FN 414
#
#
#
# None
# Cross: Validation: [ 0.94763963  0.94780585  0.94911872  0.94861989  0.94961756]
# Number of data points in benchmark 719
# Benchmark Results
# Sensitivity: 0.06666666666666667
# Specificity : 0.9900568181818182
# Accuracy: 0.9707927677329624
# ROC 0.528361742424
# TP 1 FP 7 TN 697 FN 14
#
#
#
# None
# y ncl   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54634
# Test Data Points: 23416
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9056389267849022
# Specificity : 0.9996845094121358
# Accuracy: 0.9820208404509737
# ROC 0.952661718099
# TP 3983 FP 6 TN 19012 FN 415
#
#
#
# None
# Cross: Validation: [ 0.98078278  0.98014221  0.98097373  0.98045999  0.97930681]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 2 TN 702 FN 15
#
#
#
# None
# x ncl   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54639
# Test Data Points: 23418
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9
# Specificity : 0.9994741823535598
# Accuracy: 0.9807840122982321
# ROC 0.949737091177
# TP 3960 FP 10 TN 19008 FN 440
#
#
#
# None
# Cross: Validation: [ 0.97975916  0.97982321  0.98129524  0.97988598  0.98033438]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 1 TN 703 FN 15
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9049614112458655
# Specificity : 0.9922014260249554
# Accuracy: 0.9483542059182091
# ROC 0.948581418635
# TP 4104 FP 35 TN 4453 FN 431
#
#
#
# None
# Cross: Validation: [ 0.95079787  0.95445479  0.95061523  0.94795477  0.94778849]
# Number of data points in benchmark 719
# Benchmark Results
# Failed
# TP 0 FP 75 TN 629 FN 15
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_CK2.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9049614112458655
# Specificity : 0.9935383244206774
# Accuracy: 0.9490191732239831
# ROC 0.949249867833
# TP 4104 FP 29 TN 4459 FN 431
#
#
#
# None
# Cross: Validation: [ 0.9502992   0.95478723  0.9501164   0.94762221  0.95144662]
# Number of data points in benchmark 719
# Benchmark Results
# Sensitivity: 0.13333333333333333
# Specificity : 0.9005681818181818
# Accuracy: 0.8845618915159944
# ROC 0.516950757576
# TP 2 FP 70 TN 634 FN 13
#
#
#
# None
# y pass   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9000676742612227
# Specificity : 0.9991193306913254
# Accuracy: 0.981465101318752
# ROC 0.949593502476
# TP 3990 FP 18 TN 20421 FN 443
#
#
#
# None
# Cross: Validation: [ 0.98118442  0.98148595  0.98190591  0.98069964  0.98082027]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.038461538461538464
# Specificity : 1.0
# Accuracy: 0.9406175771971497
# ROC 0.519230769231
# TP 1 FP 0 TN 395 FN 25
#
#
#
# None
# x pass   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.895925597874225
# Specificity : 0.999361367655728
# Accuracy: 0.9805805725313606
# ROC 0.947643482765
# TP 4046 FP 13 TN 20343 FN 470
#
#
#
# None
# Cross: Validation: [ 0.98021952  0.98088289  0.98130277  0.9827503   0.98136309]
# Number of data points in benchmark 421
# Benchmark Results
# Failed
# TP 0 FP 0 TN 395 FN 26
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9744331886155331
# Specificity : 0.9991644959944955
# Accuracy: 0.9866835455364316
# ROC 0.986798842305
# TP 20200 FP 17 TN 20330 FN 530
#
#
#
# None
# Cross: Validation: [ 0.95026656  0.98995801  0.99528922  0.99477797  0.99255039]
# Number of data points in benchmark 421
# Benchmark Results
# Failed
# TP 0 FP 0 TN 395 FN 26
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9757124195655329
# Specificity : 0.9992159937279498
# Accuracy: 0.987389536723714
# ROC 0.987464206647
# TP 20167 FP 16 TN 20392 FN 502
#
#
#
# None
# Cross: Validation: [ 0.95059519  0.98886252  0.99477797  0.9950336   0.99485101]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.038461538461538464
# Specificity : 0.9822784810126582
# Accuracy: 0.9239904988123515
# ROC 0.510370009737
# TP 1 FP 7 TN 388 FN 25
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94235
# Test Data Points: 40387
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9689601913208111
# Specificity : 0.9991139988186651
# Accuracy: 0.9841285562185852
# ROC 0.98403709507
# TP 19448 FP 18 TN 20298 FN 623
#
#
#
# None
# Cross: Validation: [ 0.95948004  0.99015785  0.99145744  0.9911603   0.99227455]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.43544303797468353
# Accuracy: 0.43942992874109266
# ROC 0.467721518987
# TP 13 FP 223 TN 172 FN 13
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94219
# Test Data Points: 40380
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9691770573566085
# Specificity : 0.9987702902115101
# Accuracy: 0.9840762753838533
# ROC 0.983973673784
# TP 19432 FP 25 TN 20305 FN 618
#
#
#
# None
# Cross: Validation: [ 0.95936258  0.98967349  0.99119581  0.99205022  0.99212452]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.5
# Specificity : 0.3848101265822785
# Accuracy: 0.3919239904988123
# ROC 0.442405063291
# TP 13 FP 243 TN 152 FN 13
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9040793825799338
# Specificity : 0.9908645276292335
# Accuracy: 0.9472459270752521
# ROC 0.947471955105
# TP 4100 FP 41 TN 4447 FN 435
#
#
#
# None
# Cross: Validation: [ 0.94980053  0.94963431  0.9446292   0.94911872  0.94728966]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.038461538461538464
# Specificity : 0.9924050632911392
# Accuracy: 0.9334916864608076
# ROC 0.515433300876
# TP 1 FP 3 TN 392 FN 25
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9020948180815876
# Specificity : 0.9890819964349377
# Accuracy: 0.9453618530422254
# ROC 0.945588407258
# TP 4091 FP 49 TN 4439 FN 444
#
#
#
# None
# Cross: Validation: [ 0.94697473  0.95146277  0.94728966  0.95294313  0.94762221]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.038461538461538464
# Specificity : 0.9848101265822785
# Accuracy: 0.9263657957244655
# ROC 0.511635832522
# TP 1 FP 6 TN 389 FN 25
#
#
#
# None
# y ncl   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54632
# Test Data Points: 23415
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9020231870879746
# Specificity : 0.9992111905763568
# Accuracy: 0.9809523809523809
# ROC 0.950617188832
# TP 3968 FP 15 TN 19001 FN 431
#
#
#
# None
# Cross: Validation: [ 0.97994875  0.98090967  0.97911461  0.98135691  0.98045999]
# Number of data points in benchmark 421
# Benchmark Results
# Failed
# TP 0 FP 0 TN 395 FN 26
#
#
#
# None
# x ncl   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54638
# Test Data Points: 23417
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9006818181818181
# Specificity : 0.9993689856444234
# Accuracy: 0.9808258957167869
# ROC 0.950025401913
# TP 3963 FP 12 TN 19005 FN 437
#
#
#
# None
# Cross: Validation: [ 0.98104023  0.98116833  0.97975786  0.97962844  0.98058937]
# Number of data points in benchmark 421
# Benchmark Results
# Failed
# TP 0 FP 0 TN 395 FN 26
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9131201764057332
# Specificity : 0.9922014260249554
# Accuracy: 0.9524548376371496
# ROC 0.952660801215
# TP 4141 FP 35 TN 4453 FN 394
#
#
#
# None
# Cross: Validation: [ 0.95295878  0.95212766  0.9524443   0.94878617  0.94429664]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.07692307692307693
# Specificity : 0.9291139240506329
# Accuracy: 0.8764845605700713
# ROC 0.503018500487
# TP 2 FP 28 TN 367 FN 24
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_MAPK1.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9115766262403528
# Specificity : 0.9930926916221033
# Accuracy: 0.9521223539842625
# ROC 0.952334658931
# TP 4134 FP 31 TN 4457 FN 401
#
#
#
# None
# Cross: Validation: [ 0.94980053  0.95262633  0.95527103  0.95194546  0.94346525]
# Number of data points in benchmark 421
# Benchmark Results
# Sensitivity: 0.038461538461538464
# Specificity : 0.9189873417721519
# Accuracy: 0.8646080760095012
# ROC 0.478724440117
# TP 1 FP 32 TN 363 FN 25
#
#
#
# None
# y pass   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8901785714285714
# Specificity : 0.9992153785798352
# Accuracy: 0.9795754261820521
# ROC 0.944696975004
# TP 3988 FP 16 TN 20376 FN 492
#
#
#
# None
# Cross: Validation: [ 0.98245085  0.98124472  0.98293124  0.97931242  0.98057901]
# Number of data points in benchmark 2130
# Benchmark Results
# Failed
# TP 0 FP 1 TN 2100 FN 29
#
#
#
# None
# x pass   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9049217002237137
# Specificity : 0.999019703950593
# Accuracy: 0.9821083949823094
# ROC 0.951970702087
# TP 4045 FP 20 TN 20382 FN 425
#
#
#
# None
# Cross: Validation: [ 0.98214932  0.98124472  0.98106152  0.98136309  0.98015682]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.034482758620689655
# Specificity : 1.0
# Accuracy: 0.9868544600938968
# ROC 0.51724137931
# TP 1 FP 0 TN 2101 FN 28
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9754287916746964
# Specificity : 0.9989173761133803
# Accuracy: 0.9870487133919225
# ROC 0.987173083894
# TP 20246 FP 22 TN 20299 FN 510
#
#
#
# None
# Cross: Validation: [ 0.94997444  0.98959284  0.99448583  0.99331727  0.9956544 ]
# Number of data points in benchmark 2130
# Benchmark Results
# Failed
# TP 0 FP 0 TN 2101 FN 29
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9767127258672336
# Specificity : 0.999263948181952
# Accuracy: 0.9879007717214012
# ROC 0.987988337025
# TP 20216 FP 15 TN 20364 FN 482
#
#
#
# None
# Cross: Validation: [ 0.94924414  0.99134563  0.99521618  0.99554484  0.99375548]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.034482758620689655
# Specificity : 0.9533555449785817
# Accuracy: 0.9408450704225352
# ROC 0.4939191518
# TP 1 FP 98 TN 2003 FN 28
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94244
# Test Data Points: 40391
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9673469387755103
# Specificity : 0.9988670508841929
# Accuracy: 0.9831893243544354
# ROC 0.98310699483
# TP 19434 FP 23 TN 20278 FN 656
#
#
#
# None
# Cross: Validation: [ 0.95903892  0.98856209  0.9930553   0.9911981   0.99156949]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.7241379310344828
# Specificity : 0.4797715373631604
# Accuracy: 0.4830985915492958
# ROC 0.601954734199
# TP 21 FP 1093 TN 1008 FN 8
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94211
# Test Data Points: 40377
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9690886392009987
# Specificity : 0.9983294025157232
# Accuracy: 0.9838274265051886
# ROC 0.983709020858
# TP 19406 FP 34 TN 20318 FN 619
#
#
#
# None
# Cross: Validation: [ 0.95980534  0.98900364  0.99078649  0.99230969  0.99171527]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.7586206896551724
# Specificity : 0.37505949547834366
# Accuracy: 0.38028169014084506
# ROC 0.566840092567
# TP 22 FP 1313 TN 788 FN 7
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9153252480705623
# Specificity : 0.9910873440285205
# Accuracy: 0.953008977058628
# ROC 0.95320629605
# TP 4151 FP 40 TN 4448 FN 384
#
#
#
# None
# Cross: Validation: [ 0.94980053  0.94996676  0.94861989  0.94895244  0.94429664]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.10344827586206896
# Specificity : 0.9938124702522608
# Accuracy: 0.9816901408450704
# ROC 0.548630373057
# TP 3 FP 13 TN 2088 FN 26
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9042998897464167
# Specificity : 0.9937611408199644
# Accuracy: 0.9487975174553918
# ROC 0.949030515283
# TP 4101 FP 28 TN 4460 FN 434
#
#
#
# None
# Cross: Validation: [ 0.9481383   0.95129654  0.94595943  0.94945128  0.94778849]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.1724137931034483
# Specificity : 0.9928605425987624
# Accuracy: 0.9816901408450704
# ROC 0.582637167851
# TP 5 FP 15 TN 2086 FN 24
#
#
#
# None
# y ncl   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54636
# Test Data Points: 23416
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9022282855843565
# Specificity : 0.9994216005889157
# Accuracy: 0.9811667236077896
# ROC 0.950824943087
# TP 3968 FP 11 TN 19007 FN 430
#
#
#
# None
# Cross: Validation: [ 0.98110307  0.98039844  0.98180653  0.97841127  0.98026906]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.034482758620689655
# Specificity : 0.9995240361732508
# Accuracy: 0.9863849765258216
# ROC 0.517003397397
# TP 1 FP 1 TN 2100 FN 28
#
#
#
# None
# x ncl   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54634
# Test Data Points: 23416
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8963165075034106
# Specificity : 0.9993164370596277
# Accuracy: 0.9799709600273318
# ROC 0.947816472282
# TP 3942 FP 13 TN 19005 FN 456
#
#
#
# None
# Cross: Validation: [ 0.9783486   0.97975786  0.98084561  0.98110065  0.98167724]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.034482758620689655
# Specificity : 0.9995240361732508
# Accuracy: 0.9863849765258216
# ROC 0.517003397397
# TP 1 FP 1 TN 2100 FN 28
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9153252480705623
# Specificity : 0.9917557932263814
# Accuracy: 0.953341460711515
# ROC 0.953540520648
# TP 4151 FP 37 TN 4451 FN 384
#
#
#
# None
# Cross: Validation: [ 0.95445479  0.94946809  0.9501164   0.94895244  0.94645826]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.10344827586206896
# Specificity : 0.9024274155164208
# Accuracy: 0.8915492957746479
# ROC 0.502937845689
# TP 3 FP 205 TN 1896 FN 26
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_PKA.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9095920617420066
# Specificity : 0.9910873440285205
# Accuracy: 0.95012745206694
# ROC 0.950339702885
# TP 4125 FP 40 TN 4448 FN 410
#
#
#
# None
# Cross: Validation: [ 0.9509641   0.95428856  0.95427336  0.95028267  0.94180246]
# Number of data points in benchmark 2130
# Benchmark Results
# Sensitivity: 0.1724137931034483
# Specificity : 0.9019514516896716
# Accuracy: 0.892018779342723
# ROC 0.537182622397
# TP 5 FP 206 TN 1895 FN 24
#
#
#
# None
# y pass   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8906284454244763
# Specificity : 0.9994591139302749
# Accuracy: 0.9796156320360244
# ROC 0.945043779677
# TP 4039 FP 11 TN 20326 FN 496
#
#
#
# None
# Cross: Validation: [ 0.98082258  0.98190809  0.9818456   0.98202654  0.98003619]
# Number of data points in benchmark 1064
# Benchmark Results
# Failed
# TP 0 FP 1 TN 1035 FN 28
#
#
#
# None
# x pass   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8983420593368238
# Specificity : 0.9990634858044164
# Accuracy: 0.9805001608234158
# ROC 0.948702772571
# TP 4118 FP 19 TN 20269 FN 466
#
#
#
# None
# Cross: Validation: [ 0.98166687  0.9810035   0.98039807  0.98166466  0.98118215]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.03571428571428571
# Specificity : 1.0
# Accuracy: 0.974624060150376
# ROC 0.517857142857
# TP 1 FP 0 TN 1036 FN 27
#
#
#
# None
# y ADASYN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9741720575456213
# Specificity : 0.9989687177724303
# Accuracy: 0.986464444823137
# ROC 0.986570387659
# TP 20179 FP 21 TN 20342 FN 535
#
#
#
# None
# Cross: Validation: [ 0.9501205   0.99101698  0.99543529  0.99430324  0.99200263]
# Number of data points in benchmark 1064
# Benchmark Results
# Failed
# TP 0 FP 1 TN 1035 FN 28
#
#
#
# None
# x ADASYN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9744307217290621
# Specificity : 0.9989680082559339
# Accuracy: 0.986586167441634
# ROC 0.986699364992
# TP 20198 FP 21 TN 20328 FN 530
#
#
#
# None
# Cross: Validation: [ 0.94968232  0.99098046  0.99368244  0.99357289  0.99532574]
# Number of data points in benchmark 1064
# Benchmark Results
# Failed
# TP 0 FP 2 TN 1034 FN 28
#
#
#
# None
# y SMOTEENN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94201
# Test Data Points: 40372
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.969506098780244
# Specificity : 0.9989689709347996
# Accuracy: 0.9843703556920638
# ROC 0.984237534858
# TP 19394 FP 21 TN 20347 FN 610
#
#
#
# None
# Cross: Validation: [ 0.96061822  0.98870518  0.99297763  0.9924203   0.99156573]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.6785714285714286
# Specificity : 0.4198841698841699
# Accuracy: 0.4266917293233083
# ROC 0.549227799228
# TP 19 FP 601 TN 435 FN 9
#
#
#
# None
# x SMOTEENN   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94221
# Test Data Points: 40381
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9694238334744285
# Specificity : 0.9985221674876847
# Accuracy: 0.9840519055991679
# ROC 0.983973000481
# TP 19467 FP 30 TN 20270 FN 614
#
#
#
# None
# Cross: Validation: [ 0.96017979  0.9887077   0.99309064  0.99060178  0.99127043]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.6785714285714286
# Specificity : 0.4826254826254826
# Accuracy: 0.48778195488721804
# ROC 0.580598455598
# TP 19 FP 536 TN 500 FN 9
#
#
#
# None
# y random_under_sample   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9042998897464167
# Specificity : 0.9881907308377896
# Accuracy: 0.9460268203479996
# ROC 0.946245310292
# TP 4101 FP 53 TN 4435 FN 434
#
#
#
# None
# Cross: Validation: [ 0.95229388  0.94913564  0.94496176  0.94429664  0.949285  ]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.07142857142857142
# Specificity : 0.9893822393822393
# Accuracy: 0.9652255639097744
# ROC 0.530405405405
# TP 2 FP 11 TN 1025 FN 26
#
#
#
# None
# x random_under_sample   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9040793825799338
# Specificity : 0.9915329768270945
# Accuracy: 0.9475784107281392
# ROC 0.947806179704
# TP 4100 FP 38 TN 4450 FN 435
#
#
#
# None
# Cross: Validation: [ 0.94913564  0.95046543  0.94745594  0.949285    0.94612571]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.07142857142857142
# Specificity : 0.9961389961389961
# Accuracy: 0.9718045112781954
# ROC 0.533783783784
# TP 2 FP 4 TN 1032 FN 26
#
#
#
# None
# y ncl   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54639
# Test Data Points: 23417
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9022727272727272
# Specificity : 0.9992638165851606
# Accuracy: 0.9810394158090276
# ROC 0.950768271929
# TP 3970 FP 14 TN 19003 FN 430
#
#
#
# None
# Cross: Validation: [ 0.97969511  0.98014348  0.98110307  0.97943758  0.98155029]
# Number of data points in benchmark 1064
# Benchmark Results
# Failed
# TP 0 FP 1 TN 1035 FN 28
#
#
#
# None
# x ncl   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54637
# Test Data Points: 23416
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9006366530241019
# Specificity : 0.9994741823535598
# Accuracy: 0.9809104885548343
# ROC 0.950055417689
# TP 3961 FP 10 TN 19008 FN 437
#
#
#
# None
# Cross: Validation: [ 0.98007943  0.98084684  0.9796925   0.98065343  0.98180653]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.03571428571428571
# Specificity : 1.0
# Accuracy: 0.974624060150376
# ROC 0.517857142857
# TP 1 FP 0 TN 1036 FN 27
#
#
#
# None
# y near_miss   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.911135611907387
# Specificity : 0.9904188948306596
# Accuracy: 0.9505707636041228
# ROC 0.950777253369
# TP 4132 FP 43 TN 4445 FN 403
#
#
#
# None
# Cross: Validation: [ 0.95162899  0.95079787  0.95410708  0.94629199  0.94745594]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.07142857142857142
# Specificity : 0.916023166023166
# Accuracy: 0.893796992481203
# ROC 0.493725868726
# TP 2 FP 87 TN 949 FN 26
#
#
#
# None
# x near_miss   Data/Benchmarks/phos_PKC.csv
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9084895259095921
# Specificity : 0.9908645276292335
# Accuracy: 0.9494624847611659
# ROC 0.949677026769
# TP 4120 FP 41 TN 4447 FN 415
#
#
#
# None
# Cross: Validation: [ 0.95445479  0.94963431  0.95493848  0.94945128  0.94546059]
# Number of data points in benchmark 1064
# Benchmark Results
# Sensitivity: 0.14285714285714285
# Specificity : 0.9025096525096525
# Accuracy: 0.8825187969924813
# ROC 0.522683397683
# TP 4 FP 101 TN 935 FN 24
#
#
#
# None
