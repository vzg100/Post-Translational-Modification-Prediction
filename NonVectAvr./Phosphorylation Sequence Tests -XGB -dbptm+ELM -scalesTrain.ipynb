# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training("xgb", scale=j)
        y.benchmark("Data/Benchmarks/phos.csv", "S")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training("xgb", scale=j)
        x.benchmark("Data/Benchmarks/phos.csv", "S")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9287343834872352
# Specificity : 0.9994374602553441
# Accuracy: 0.9864446706993272
# ROC 0.964085921871
# TP 8549 FP 23 TN 40863 FN 656
#
#
#
# None
# Cross: Validation: [ 0.98648487  0.98696373  0.98616518  0.98742264  0.98710321]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9293655984303466
# Specificity : 0.9985336168340787
# Accuracy: 0.9858657243816255
# ROC 0.963949607632
# TP 8526 FP 60 TN 40857 FN 648
#
#
#
# None
# Cross: Validation: [ 0.98776252  0.98656445  0.98688387  0.9862248   0.9867239 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.931715210355987
# Specificity : 0.9995590504887191
# Accuracy: 0.9870036533509013
# ROC 0.965637130422
# TP 8637 FP 18 TN 40803 FN 633
#
#
#
# None
# Cross: Validation: [ 0.98730336  0.98702362  0.98654449  0.98638451  0.9869435 ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.027827116637063352
# Specificity : 0.9737991266375546
# Accuracy: 0.925305410122164
# ROC 0.500813121637
# TP 94 FP 1638 TN 60879 FN 3284
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6924735820573646
# Specificity : 0.9330181052012642
# Accuracy: 0.88848296101096
# ROC 0.812745843629
# TP 6422 FP 2734 TN 38083 FN 2852
#
#
#
# None
# Cross: Validation: [ 0.98730336  0.98656445  0.98694376  0.98670393  0.98662408]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.17850799289520428
# Specificity : 0.8712990066701857
# Accuracy: 0.8357842021397678
# ROC 0.524903499783
# TP 603 FP 8046 TN 54471 FN 2775
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9353951133612151
# Specificity : 0.9996098036824778
# Accuracy: 0.9879619093250285
# ROC 0.967502458522
# TP 8499 FP 16 TN 40989 FN 587
#
#
#
# None
# Cross: Validation: [ 0.98614549  0.98694376  0.98788205  0.98652426  0.98668397]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.028123149792776792
# Specificity : 0.965593358606459
# Accuracy: 0.9175354731011458
# ROC 0.4968582542
# TP 95 FP 2151 TN 60366 FN 3283
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5049859093865163
# Specificity : 0.986908112076349
# Accuracy: 0.8981453754167416
# ROC 0.745947010731
# TP 4659 FP 535 TN 40330 FN 4567
#
#
#
# None
# Cross: Validation: [ 0.98654476  0.987363    0.98674413  0.98658415  0.98696347]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0020722320899940793
# Specificity : 0.9822768207047683
# Accuracy: 0.9320282267243342
# ROC 0.492174526397
# TP 7 FP 1108 TN 61409 FN 3371
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9306846096336644
# Specificity : 0.999680809271263
# Accuracy: 0.9867840530234973
# ROC 0.965182709452
# TP 8714 FP 13 TN 40715 FN 649
#
#
#
# None
# Cross: Validation: [ 0.98626527  0.9869238   0.9869238   0.98684368  0.98718307]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0008880994671403197
# Specificity : 0.9963529919861798
# Accuracy: 0.9453221033462327
# ROC 0.498620545727
# TP 3 FP 228 TN 62289 FN 3375
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9340183883180098
# Specificity : 0.999118640748176
# Accuracy: 0.9871034716815396
# ROC 0.966568514533
# TP 8635 FP 36 TN 40810 FN 610
#
#
#
# None
# Cross: Validation: [ 0.98702388  0.98650456  0.98656445  0.98690357  0.98706329]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 186 TN 62331 FN 3378
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9311468288444831
# Specificity : 0.9996086392877235
# Accuracy: 0.987023617017029
# ROC 0.965377734066
# TP 8574 FP 16 TN 40867 FN 634
#
#
#
# None
# Cross: Validation: [ 0.98620538  0.98674413  0.98768242  0.9869435   0.98650429]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9299459459459459
# Specificity : 0.9987267696677359
# Accuracy: 0.9860254337106467
# ROC 0.964336357807
# TP 8602 FP 52 TN 40789 FN 648
#
#
#
# None
# Cross: Validation: [ 0.98684421  0.98708351  0.98748278  0.98684368  0.9859453 ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9999840043508166
# Accuracy: 0.9487366264511723
# ROC 0.500140018753
# TP 1 FP 1 TN 62516 FN 3377
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9461311954074184
# Specificity : 0.9958893048520884
# Accuracy: 0.9711498240692896
# ROC 0.97101025013
# TP 38236 FP 168 TN 40701 FN 2177
#
#
#
# None
# Cross: Validation: [ 0.9634979   0.97127285  0.97203528  0.9749757   0.9724905 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9430321895303738
# Specificity : 0.9944856995809132
# Accuracy: 0.9688614945498388
# ROC 0.968758944556
# TP 38173 FP 225 TN 40578 FN 2306
#
#
#
# None
# Cross: Validation: [ 0.96368244  0.97028862  0.97338861  0.97241668  0.9737454 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9553591379695608
# Specificity : 0.6964028776978417
# Accuracy: 0.8247213405181959
# ROC 0.825881007834
# TP 38479 FP 12449 TN 28556 FN 1798
#
#
#
# None
# Cross: Validation: [ 0.96362093  0.96941512  0.97522176  0.97486497  0.96895954]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8602723505032563
# Specificity : 0.18990034710558729
# Accuracy: 0.22426587753243796
# ROC 0.525086348804
# TP 2906 FP 50645 TN 11872 FN 472
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9519768420010887
# Specificity : 0.4007194596711042
# Accuracy: 0.6748357569941684
# ROC 0.676348150836
# TP 38477 FP 24489 TN 16375 FN 1941
#
#
#
# None
# Cross: Validation: [ 0.96327645  0.96971039  0.97428673  0.97320407  0.97156777]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.7448194197750148
# Specificity : 0.15941263976198475
# Accuracy: 0.1894225662038091
# ROC 0.452116029768
# TP 2516 FP 52551 TN 9966 FN 862
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9474739473749351
# Specificity : 0.9907785632169851
# Accuracy: 0.9692551856499594
# ROC 0.969126255296
# TP 38277 FP 377 TN 40506 FN 2122
#
#
#
# None
# Cross: Validation: [ 0.96317803  0.96902143  0.97224444  0.97493879  0.97346243]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8084665482534044
# Specificity : 0.21867651998656365
# Accuracy: 0.24891114652098034
# ROC 0.51357153412
# TP 2731 FP 48846 TN 13671 FN 647
#
#
#
# None
# x ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9890767101621194
# Specificity : 0.0962075554902249
# Accuracy: 0.5406978174749637
# ROC 0.542642132826
# TP 40022 FP 36891 TN 3927 FN 442
#
#
#
# None
# Cross: Validation: [ 0.96291968  0.97178957  0.97325328  0.9716908   0.97490188]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9467140319715808
# Specificity : 0.06239902746452965
# Accuracy: 0.10773199787540784
# ROC 0.504556529718
# TP 3198 FP 58616 TN 3901 FN 180
#
#
#
# None
# y ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9878703519586399
# Specificity : 0.14516443361753958
# Accuracy: 0.5622770109003223
# ROC 0.566517392788
# TP 39744 FP 35091 TN 5959 FN 488
#
#
#
# None
# Cross: Validation: [ 0.96383008  0.97166654  0.97262583  0.97399146  0.97134632]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 3378 FP 62517 TN 0 FN 0
#
#
#
# None
# x ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9766126642299714
# Specificity : 0.2918607501838686
# Accuracy: 0.6329814719126006
# ROC 0.634236707207
# TP 39545 FP 28885 TN 11905 FN 947
#
#
#
# None
# Cross: Validation: [ 0.96335027  0.97176497  0.97262583  0.97123559  0.97352395]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 3378 FP 62517 TN 0 FN 0
#
#
#
# None
# y ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9716008799031118
# Specificity : 0.6402273228327169
# Accuracy: 0.805172116827834
# ROC 0.805914101368
# TP 39310 FP 14687 TN 26136 FN 1149
#
#
#
# None
# Cross: Validation: [ 0.96325185  0.97370882  0.9729211   0.97149395  0.97220753]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9751332149200711
# Specificity : 0.02949597709423037
# Accuracy: 0.07797253205857804
# ROC 0.502314596007
# TP 3294 FP 60673 TN 1844 FN 84
#
#
#
# None
# x ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9682976402934761
# Specificity : 0.6513263960134839
# Accuracy: 0.8086538224945252
# ROC 0.809812018153
# TP 39065 FP 14274 TN 26664 FN 1279
#
#
#
# None
# Cross: Validation: [ 0.96380547  0.97161733  0.97294571  0.97278577  0.97287189]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9757252812314979
# Specificity : 0.022953756578210728
# Accuracy: 0.07179603915319827
# ROC 0.499339518905
# TP 3296 FP 61082 TN 1435 FN 82
#
#
#
# None
# y SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323848
# Test Data Points: 80963
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9698669579030977
# Specificity : 0.9980086047940996
# Accuracy: 0.9840050393389573
# ROC 0.983937781349
# TP 39074 FP 81 TN 40594 FN 1214
#
#
#
# None
# Cross: Validation: [ 0.97080148  0.98606754  0.98706801  0.98631457  0.9865616 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.26376554174067496
# Specificity : 0.7951277252587297
# Accuracy: 0.7678883071553229
# ROC 0.5294466335
# TP 891 FP 12808 TN 49709 FN 2487
#
#
#
# None
# x SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574181
# Test Data Points: 80932
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9617621365281418
# Specificity : 0.9971859935889593
# Accuracy: 0.9796495823654426
# ROC 0.979474065059
# TP 38533 FP 115 TN 40752 FN 1532
#
#
#
# None
# Cross: Validation: [ 0.97153201  0.98495033  0.98660604  0.98723604  0.98653174]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.10094730609828301
# Specificity : 0.9219412319849001
# Accuracy: 0.8798543136808559
# ROC 0.511444269042
# TP 341 FP 4880 TN 57637 FN 3037
#
#
#
# None
# y SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323804
# Test Data Points: 80951
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9933961323763956
# Specificity : 0.4458271072679617
# Accuracy: 0.7172610591592444
# ROC 0.719611619822
# TP 39863 FP 22623 TN 18200 FN 265
#
#
#
# None
# Cross: Validation: [ 0.97114339  0.98578152  0.98643624  0.98657212  0.98735022]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6429840142095915
# Specificity : 0.2988787049922421
# Accuracy: 0.31651870399878596
# ROC 0.470931359601
# TP 2172 FP 43832 TN 18685 FN 1206
#
#
#
# None
# x SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574119
# Test Data Points: 80917
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7699875466998755
# Specificity : 0.8761743567100841
# Accuracy: 0.8234857940852973
# ROC 0.823080951705
# TP 30915 FP 5048 TN 35719 FN 9235
#
#
#
# None
# Cross: Validation: [ 0.97137843  0.98584952  0.98733254  0.98661575  0.98701122]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.4792776791000592
# Specificity : 0.6651950669417919
# Accuracy: 0.6556643144396388
# ROC 0.572236373021
# TP 1619 FP 20931 TN 41586 FN 1759
#
#
#
# None
# y SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323656
# Test Data Points: 80914
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9698122653316645
# Specificity : 0.8674445854896983
# Accuracy: 0.9179869985416615
# ROC 0.918628425411
# TP 38744 FP 5430 TN 35534 FN 1206
#
#
#
# None
# Cross: Validation: [ 0.97136501  0.98514472  0.98712213  0.9865907   0.98596023]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8327412670219064
# Specificity : 0.23623974278996113
# Accuracy: 0.2668184232491084
# ROC 0.534490504906
# TP 2813 FP 47748 TN 14769 FN 565
#
#
#
# None
# x SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574239
# Test Data Points: 80947
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6145724127602217
# Specificity : 0.8261465084994497
# Accuracy: 0.7214350130332192
# ROC 0.72035946063
# TP 24621 FP 7108 TN 33777 FN 15441
#
#
#
# None
# Cross: Validation: [ 0.97192025  0.9839152   0.9856324   0.98600301  0.98589183]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.4638839550029603
# Specificity : 0.47379112881296287
# Accuracy: 0.47328325366112756
# ROC 0.468837541908
# TP 1567 FP 32897 TN 29620 FN 1811
#
#
#
# None
# y SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323677
# Test Data Points: 80920
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9689688691707584
# Specificity : 0.989583078016618
# Accuracy: 0.9793623331685616
# ROC 0.979275973594
# TP 38876 FP 425 TN 40374 FN 1245
#
#
#
# None
# Cross: Validation: [ 0.97141657  0.98523215  0.98656681  0.98631965  0.98607249]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.23712255772646537
# Specificity : 0.7786362109506214
# Accuracy: 0.7508763942636012
# ROC 0.507879384339
# TP 801 FP 13839 TN 48678 FN 2577
#
#
#
# None
# x SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 548074
# Test Data Points: 74406
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9563713949381989
# Specificity : 0.9820398453761523
# Accuracy: 0.9679730129290649
# ROC 0.969205620157
# TP 38997 FP 604 TN 33026 FN 1779
#
#
#
# None
# Cross: Validation: [ 0.9624627   0.98258182  0.98626436  0.98643908  0.98574021]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.20071047957371227
# Specificity : 0.8549354575555449
# Accuracy: 0.8213976781242887
# ROC 0.527822968565
# TP 678 FP 9069 TN 53448 FN 2700
#
#
#
# None
# y SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323793
# Test Data Points: 80949
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9601546906187625
# Specificity : 0.9970393207565637
# Accuracy: 0.9787767606764753
# ROC 0.978597005688
# TP 38483 FP 121 TN 40748 FN 1597
#
#
#
# None
# Cross: Validation: [ 0.97119209  0.98542274  0.97733113  0.97886297  0.98102486]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574121
# Test Data Points: 80917
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9661067636943628
# Specificity : 0.9515089112794489
# Accuracy: 0.9587478527379908
# ROC 0.958807837487
# TP 38766 FP 1978 TN 38813 FN 1360
#
#
#
# None
# Cross: Validation: [ 0.97156381  0.98598564  0.98687544  0.98673933  0.98697415]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.08851391355831853
# Specificity : 0.9179903066365949
# Accuracy: 0.8754685484482889
# ROC 0.503252110097
# TP 299 FP 5127 TN 57390 FN 3079
#
#
#
# None
# y random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9311082584510055
# Specificity : 0.9979130052724078
# Accuracy: 0.9640689356167353
# ROC 0.964510631862
# TP 8704 FP 19 TN 9085 FN 644
#
#
#
# None
# Cross: Validation: [ 0.96396055  0.96509863  0.9643941   0.96417344  0.96260163]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9986243741702256
# Accuracy: 0.9474466955004174
# ROC 0.499460203663
# TP 1 FP 86 TN 62431 FN 3377
#
#
#
# None
# x random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9317501069747539
# Specificity : 0.9972539543057997
# Accuracy: 0.9640689356167353
# ROC 0.96450203064
# TP 8710 FP 25 TN 9079 FN 638
#
#
#
# None
# Cross: Validation: [ 0.96412313  0.96634511  0.96450249  0.96276423  0.96471545]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9317501069747539
# Specificity : 0.9980228471001757
# Accuracy: 0.9644482982874485
# ROC 0.964886477037
# TP 8710 FP 18 TN 9086 FN 638
#
#
#
# None
# Cross: Validation: [ 0.96499024  0.96477347  0.9643941   0.96471545  0.96292683]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.04322084073416223
# Specificity : 0.9471983620455237
# Accuracy: 0.900857424690796
# ROC 0.49520960139
# TP 146 FP 3301 TN 59216 FN 3232
#
#
#
# None
# x random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5722079589216945
# Specificity : 0.960896309314587
# Accuracy: 0.7639822241491437
# ROC 0.766552134118
# TP 5349 FP 356 TN 8748 FN 3999
#
#
#
# None
# Cross: Validation: [ 0.96569478  0.96493605  0.96157598  0.96525745  0.96428184]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.03285968028419183
# Specificity : 0.9009069533087001
# Accuracy: 0.8564079216936035
# ROC 0.466883316796
# TP 111 FP 6195 TN 56322 FN 3267
#
#
#
# None
# y random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9331407787762088
# Specificity : 0.9968145869947276
# Accuracy: 0.964556687621938
# ROC 0.964977682885
# TP 8723 FP 29 TN 9075 FN 625
#
#
#
# None
# Cross: Validation: [ 0.96331021  0.96482766  0.96515283  0.96319783  0.96574526]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.3401420959147424
# Specificity : 0.6799910424364572
# Accuracy: 0.662569238940739
# ROC 0.510066569176
# TP 1149 FP 20006 TN 42511 FN 2229
#
#
#
# None
# x random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1295464270432178
# Specificity : 0.9991212653778558
# Accuracy: 0.5585844352915673
# ROC 0.564333846211
# TP 1211 FP 8 TN 9096 FN 8137
#
#
#
# None
# Cross: Validation: [ 0.96482766  0.96412313  0.9644483   0.96449864  0.96542005]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9963849832845466
# Accuracy: 0.9453221033462327
# ROC 0.49834050822
# TP 1 FP 226 TN 62291 FN 3377
#
#
#
# None
# y random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9312152332049636
# Specificity : 0.9978031634446397
# Accuracy: 0.9640689356167353
# ROC 0.964509198325
# TP 8705 FP 20 TN 9084 FN 643
#
#
#
# None
# Cross: Validation: [ 0.96558639  0.96493605  0.96363538  0.96379404  0.96379404]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.013025458851391355
# Specificity : 0.9951053313498728
# Accuracy: 0.9447606039911981
# ROC 0.504065395101
# TP 44 FP 306 TN 62211 FN 3334
#
#
#
# None
# x random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9312152332049636
# Specificity : 0.9962653778558875
# Accuracy: 0.9633102102753089
# ROC 0.96374030553
# TP 8705 FP 34 TN 9070 FN 643
#
#
#
# None
# Cross: Validation: [ 0.96455669  0.96509863  0.96374377  0.96330623  0.96476965]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9293966623876765
# Specificity : 0.9970342706502636
# Accuracy: 0.9627682636028615
# ROC 0.963215466519
# TP 8688 FP 27 TN 9077 FN 660
#
#
#
# None
# Cross: Validation: [ 0.96347279  0.96287665  0.96564058  0.96493225  0.96514905]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.036708111308466546
# Specificity : 0.9773661564054578
# Accuracy: 0.9291448516579407
# ROC 0.507037133857
# TP 124 FP 1415 TN 61102 FN 3254
#
#
#
# None
# x random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9324989302524604
# Specificity : 0.9962653778558875
# Accuracy: 0.9639605462822458
# ROC 0.964382154054
# TP 8717 FP 34 TN 9070 FN 631
#
#
#
# None
# Cross: Validation: [ 0.96417732  0.96428571  0.96331021  0.96466125  0.96455285]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9993121870851128
# Accuracy: 0.9480992488049169
# ROC 0.49980411012
# TP 1 FP 43 TN 62474 FN 3377
#
#
#
# None
# y ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187444
# Test Data Points: 46861
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9305973356252686
# Specificity : 0.9996005645354565
# Accuracy: 0.9858944538102047
# ROC 0.96509895008
# TP 8662 FP 15 TN 37538 FN 646
#
#
#
# None
# Cross: Validation: [ 0.98623618  0.98561734  0.98574508  0.98617157  0.98629962]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437876
# Test Data Points: 46856
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9310344827586207
# Specificity : 0.9996271339920633
# Accuracy: 0.9859996585282568
# ROC 0.965330808375
# TP 8667 FP 14 TN 37533 FN 642
#
#
#
# None
# Cross: Validation: [ 0.98678931  0.98570087  0.98599966  0.98510298  0.98638352]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187448
# Test Data Points: 46863
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.928663515255694
# Specificity : 0.9996005858074823
# Accuracy: 0.9855109574717794
# ROC 0.964132050532
# TP 8644 FP 15 TN 37540 FN 664
#
#
#
# None
# Cross: Validation: [ 0.98593773  0.98538292  0.9861938   0.98649197  0.98597981]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.07992895204262877
# Specificity : 0.9257961834381049
# Accuracy: 0.8824341755823659
# ROC 0.50286256774
# TP 270 FP 4639 TN 57878 FN 3108
#
#
#
# None
# x ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437891
# Test Data Points: 46860
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6853980874610508
# Specificity : 0.9018453918461907
# Accuracy: 0.8588561673068715
# ROC 0.793621739654
# TP 6379 FP 3686 TN 33867 FN 2928
#
#
#
# None
# Cross: Validation: [ 0.98563807  0.98597951  0.98608621  0.98600055  0.98632037]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.24067495559502664
# Specificity : 0.8162259865316633
# Accuracy: 0.7867212990363457
# ROC 0.528450471063
# TP 813 FP 11489 TN 51028 FN 2565
#
#
#
# None
# y ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187411
# Test Data Points: 46853
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9278040395358831
# Specificity : 0.9994140364895459
# Accuracy: 0.9851877147674643
# ROC 0.963609038013
# TP 8636 FP 22 TN 37523 FN 672
#
#
#
# None
# Cross: Validation: [ 0.98623383  0.98627623  0.98561458  0.98565696  0.9862119 ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.08052101835405566
# Specificity : 0.9033063006862133
# Accuracy: 0.8611275514075423
# ROC 0.49191365952
# TP 272 FP 6045 TN 56472 FN 3106
#
#
#
# None
# x ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437882
# Test Data Points: 46858
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3406038465671
# Specificity : 0.9975499986684775
# Accuracy: 0.8670664561014128
# ROC 0.669076922618
# TP 3170 FP 92 TN 37459 FN 6137
#
#
#
# None
# Cross: Validation: [ 0.98642708  0.98593623  0.98629903  0.98529537  0.98604234]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9948973879104883
# Accuracy: 0.9439107671295243
# ROC 0.497596710533
# TP 1 FP 319 TN 62198 FN 3377
#
#
#
# None
# y ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187423
# Test Data Points: 46856
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9289934472016328
# Specificity : 0.9995738674195009
# Accuracy: 0.9855514768652894
# ROC 0.964283657311
# TP 8648 FP 16 TN 37531 FN 661
#
#
#
# None
# Cross: Validation: [ 0.98672557  0.9857649   0.98587161  0.98523103  0.98640487]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.049437537004144466
# Specificity : 0.9884671369387527
# Accuracy: 0.9403293117838987
# ROC 0.518952336971
# TP 167 FP 721 TN 61796 FN 3211
#
#
#
# None
# x ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437902
# Test Data Points: 46862
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9315495379325166
# Specificity : 0.999573969538822
# Accuracy: 0.9860654688233537
# ROC 0.965561753736
# TP 8669 FP 16 TN 37540 FN 637
#
#
#
# None
# Cross: Validation: [ 0.98583104  0.98642853  0.98610815  0.98617187  0.98546766]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 92 TN 62425 FN 3378
#
#
#
# None
# y ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187412
# Test Data Points: 46854
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9287709497206704
# Specificity : 0.9995472220742556
# Accuracy: 0.9854868314338157
# ROC 0.964159085897
# TP 8645 FP 17 TN 37529 FN 663
#
#
#
# None
# Cross: Validation: [ 0.98625518  0.98499594  0.98687412  0.98546487  0.986404  ]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437894
# Test Data Points: 46861
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9293081220455522
# Specificity : 0.9996005645354565
# Accuracy: 0.9856383773286955
# ROC 0.964454343291
# TP 8650 FP 15 TN 37538 FN 658
#
#
#
# None
# Cross: Validation: [ 0.98655598  0.98593713  0.98687608  0.98538168  0.98525363]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9425545571245186
# Specificity : 0.9973637961335676
# Accuracy: 0.9695967916756991
# ROC 0.969959176629
# TP 8811 FP 24 TN 9080 FN 537
#
#
#
# None
# Cross: Validation: [ 0.96612833  0.97366139  0.96780837  0.97230352  0.96119241]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.1246299585553582
# Specificity : 0.8941727850024793
# Accuracy: 0.8547234236284998
# ROC 0.509401371779
# TP 421 FP 6616 TN 55901 FN 2957
#
#
#
# None
# x near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9407359863072315
# Specificity : 0.9980228471001757
# Accuracy: 0.9690006503360069
# ROC 0.969379416704
# TP 8794 FP 18 TN 9086 FN 554
#
#
#
# None
# Cross: Validation: [ 0.96910904  0.9685129   0.97013874  0.97170732  0.96195122]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.09621077560686797
# Specificity : 0.9207895452436937
# Accuracy: 0.8785188557553684
# ROC 0.508500160425
# TP 325 FP 4952 TN 57565 FN 3053
#
#
#
# None
# y near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9433033804022251
# Specificity : 0.9974736379613357
# Accuracy: 0.970030349013657
# ROC 0.970388509182
# TP 8818 FP 23 TN 9081 FN 530
#
#
#
# None
# Cross: Validation: [ 0.96818773  0.96840451  0.96775417  0.97219512  0.96113821]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.07756068679692125
# Specificity : 0.9543004302829631
# Accuracy: 0.9093557933075347
# ROC 0.51593055854
# TP 262 FP 2857 TN 59660 FN 3116
#
#
#
# None
# x near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6959777492511767
# Specificity : 0.9939586994727593
# Accuracy: 0.8429980489919792
# ROC 0.844968224362
# TP 6506 FP 55 TN 9049 FN 2842
#
#
#
# None
# Cross: Validation: [ 0.97078907  0.96900065  0.96965099  0.9700813   0.96102981]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.002368265245707519
# Specificity : 0.9757665914871155
# Accuracy: 0.9258669094771985
# ROC 0.489067428366
# TP 8 FP 1515 TN 61002 FN 3370
#
#
#
# None
# y near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9429824561403509
# Specificity : 0.9976933216168717
# Accuracy: 0.9699761543464123
# ROC 0.970337888879
# TP 8815 FP 21 TN 9083 FN 533
#
#
#
# None
# Cross: Validation: [ 0.96683286  0.9705723   0.97122263  0.97192412  0.96146341]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.29573712255772644
# Specificity : 0.7080634067533631
# Accuracy: 0.686926170422642
# ROC 0.501900264656
# TP 999 FP 18251 TN 44266 FN 2379
#
#
#
# None
# x near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2702182284980745
# Specificity : 0.999670474516696
# Accuracy: 0.6301213960546282
# ROC 0.634944351507
# TP 2526 FP 3 TN 9101 FN 6822
#
#
#
# None
# Cross: Validation: [ 0.96824192  0.96889226  0.96905485  0.97143631  0.96184282]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0011841326228537595
# Specificity : 0.9873954284434634
# Accuracy: 0.936838910387738
# ROC 0.494289780533
# TP 4 FP 788 TN 61729 FN 3374
#
#
#
# None
# y near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.941591784338896
# Specificity : 0.9973637961335676
# Accuracy: 0.9691090396704964
# ROC 0.969477790236
# TP 8802 FP 24 TN 9080 FN 546
#
#
#
# None
# Cross: Validation: [ 0.96715803  0.96872968  0.96910904  0.97181572  0.96298103]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.19123741859088217
# Specificity : 0.8369723435225619
# Accuracy: 0.803869792852265
# ROC 0.514104881057
# TP 646 FP 10192 TN 52325 FN 2732
#
#
#
# None
# x near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9449080017115961
# Specificity : 0.9962653778558875
# Accuracy: 0.970247127682636
# ROC 0.970586689784
# TP 8833 FP 34 TN 9070 FN 515
#
#
#
# None
# Cross: Validation: [ 0.96623672  0.97040971  0.96959679  0.97311653  0.96308943]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.02427471876850207
# Specificity : 0.9901786714013788
# Accuracy: 0.9406631762652705
# ROC 0.507226695085
# TP 82 FP 614 TN 61903 FN 3296
#
#
#
# None
# y near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9434103551561831
# Specificity : 0.9975834797891037
# Accuracy: 0.9701387383481466
# ROC 0.970496917473
# TP 8819 FP 22 TN 9082 FN 529
#
#
#
# None
# Cross: Validation: [ 0.96818773  0.96981357  0.97203555  0.96937669  0.96146341]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.1921255180580225
# Specificity : 0.8402034646576131
# Accuracy: 0.8069808027923211
# ROC 0.516164491358
# TP 649 FP 9990 TN 52527 FN 2729
#
#
#
# None
# x near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9373127941805733
# Specificity : 0.9981326889279437
# Accuracy: 0.9673206156514199
# ROC 0.967722741554
# TP 8762 FP 17 TN 9087 FN 586
#
#
#
# None
# Cross: Validation: [ 0.96807934  0.9694884   0.96894646  0.9698103   0.96352304]
# Number of data points in benchmark 65895
# Scaling Data
# Benchmark Results
# Sensitivity: 0.11219656601539373
# Specificity : 0.8937089111761601
# Accuracy: 0.8536459518931634
# ROC 0.502952738596
# TP 379 FP 6645 TN 55872 FN 2999
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]

for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
        y.supervised_training("xgb", scale=j)
        y.benchmark("Data/Benchmarks/phos.csv", "Y")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
        x.supervised_training("xgb", scale=j)
        x.benchmark("Data/Benchmarks/phos.csv", "Y")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.929820725841714
# Specificity : 0.9996092128080503
# Accuracy: 0.9868639076880078
# ROC 0.964714969325
# TP 8506 FP 16 TN 40927 FN 642
#
#
#
# None
# Cross: Validation: [ 0.98726344  0.98702362  0.98662434  0.98662408  0.986664  ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9323127392017496
# Specificity : 0.9991207932398769
# Accuracy: 0.9869237986863908
# ROC 0.965716766221
# TP 8526 FP 36 TN 40910 FN 619
#
#
#
# None
# Cross: Validation: [ 0.98594586  0.98724322  0.98690384  0.98652426  0.9875025 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9315806486370003
# Specificity : 0.9994854202401372
# Accuracy: 0.9869038350202631
# ROC 0.965533034439
# TP 8646 FP 21 TN 40789 FN 635
#
#
#
# None
# Cross: Validation: [ 0.98702388  0.98696373  0.98696373  0.98656418  0.98654422]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 552 TN 22962 FN 41
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6983546617915904
# Specificity : 0.9560453030005883
# Accuracy: 0.9082070631450759
# ROC 0.827199982396
# TP 6494 FP 1793 TN 38999 FN 2805
#
#
#
# None
# Cross: Validation: [ 0.98648487  0.98630493  0.98612525  0.987223    0.9879417 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1682 TN 21832 FN 41
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9296264118158123
# Specificity : 0.9996086392877235
# Accuracy: 0.9867441256912419
# ROC 0.964617525552
# TP 8560 FP 16 TN 40867 FN 648
#
#
#
# None
# Cross: Validation: [ 0.98606564  0.98760256  0.98634485  0.98674386  0.98742264]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 802 TN 22712 FN 41
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.506675350048844
# Specificity : 0.9875483144967954
# Accuracy: 0.8991036313908686
# ROC 0.747111832273
# TP 4668 FP 509 TN 40369 FN 4545
#
#
#
# None
# Cross: Validation: [ 0.98716362  0.9869238   0.98642471  0.98682372  0.98684368]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 298 TN 23216 FN 41
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9281719486785832
# Specificity : 0.9996583032314752
# Accuracy: 0.9866443073606037
# ROC 0.963915125955
# TP 8464 FP 14 TN 40958 FN 655
#
#
#
# None
# Cross: Validation: [ 0.98554659  0.98752271  0.9869238   0.98688361  0.98714314]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 124 TN 23390 FN 41
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9300951755825402
# Specificity : 0.9993894993894994
# Accuracy: 0.9867441256912419
# ROC 0.964742337486
# TP 8502 FP 25 TN 40925 FN 639
#
#
#
# None
# Cross: Validation: [ 0.98702388  0.98666427  0.9864846   0.98686365  0.98710321]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 248 TN 23266 FN 41
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9302450558899398
# Specificity : 0.9996322357613946
# Accuracy: 0.9867441256912419
# ROC 0.964938645826
# TP 8655 FP 15 TN 40772 FN 649
#
#
#
# None
# Cross: Validation: [ 0.98672443  0.98660438  0.98654449  0.98720303  0.98708325]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9278475435117868
# Specificity : 0.9995123497427645
# Accuracy: 0.9865245253638378
# ROC 0.963679946627
# TP 8423 FP 20 TN 40993 FN 655
#
#
#
# None
# Cross: Validation: [ 0.98568634  0.98704358  0.98696373  0.98766221  0.98688361]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9449822962834575
# Specificity : 0.9956229367893386
# Accuracy: 0.9704608646440787
# ROC 0.970302616536
# TP 38165 FP 179 TN 40716 FN 2222
#
#
#
# None
# Cross: Validation: [ 0.9625629   0.97292143  0.97215831  0.97278577  0.9745574 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9435280130777233
# Specificity : 0.9938398357289527
# Accuracy: 0.96884919170296
# ROC 0.968683924403
# TP 38094 FP 252 TN 40656 FN 2280
#
#
#
# None
# Cross: Validation: [ 0.96309191  0.97128516  0.97233056  0.97186304  0.97383152]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9688815578916271
# Specificity : 0.4470157145316381
# Accuracy: 0.707807386629266
# ROC 0.707948636212
# TP 39355 FP 22486 TN 18177 FN 1264
#
#
#
# None
# Cross: Validation: [ 0.96376856  0.97127285  0.97052202  0.97177692  0.97445898]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.2794080122480225
# Accuracy: 0.2806622797707493
# ROC 0.639704006124
# TP 41 FP 16944 TN 6570 FN 0
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.952333738194978
# Specificity : 0.3708688536603239
# Accuracy: 0.6594695012425875
# ROC 0.661601295928
# TP 38420 FP 25756 TN 15183 FN 1923
#
#
#
# None
# Cross: Validation: [ 0.96285816  0.9701779   0.97327789  0.97317946  0.97358546]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.16441269031215447
# Accuracy: 0.16586711950753555
# ROC 0.582206345156
# TP 41 FP 19648 TN 3866 FN 0
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9287733042443475
# Specificity : 0.9808772529673229
# Accuracy: 0.9550207918112251
# ROC 0.954825278606
# TP 37463 FP 783 TN 40163 FN 2873
#
#
#
# None
# Cross: Validation: [ 0.9630427   0.97155582  0.95737011  0.96134398  0.96034744]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.2950582631623713
# Accuracy: 0.2962852897473997
# ROC 0.647529131581
# TP 41 FP 16576 TN 6938 FN 0
#
#
#
# None
# x ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9865572798260354
# Specificity : 0.14722889204684667
# Accuracy: 0.565106665682439
# ROC 0.566893085936
# TP 39924 FP 34805 TN 6009 FN 544
#
#
#
# None
# Cross: Validation: [ 0.96271053  0.97030093  0.97404067  0.97431134  0.97287189]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.0878625499702305
# Accuracy: 0.08945022288261516
# ROC 0.543931274985
# TP 41 FP 21448 TN 2066 FN 0
#
#
#
# None
# y ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9829591963289098
# Specificity : 0.2747577318329387
# Accuracy: 0.626018060579218
# ROC 0.628858464081
# TP 39628 FP 29711 TN 11256 FN 687
#
#
#
# None
# Cross: Validation: [ 0.96338718  0.97316749  0.97239207  0.97221983  0.97322868]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 41 FP 23514 TN 0 FN 0
#
#
#
# None
# x ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9558801720302535
# Specificity : 0.34947579854987265
# Accuracy: 0.6513127137619645
# ROC 0.65267798529
# TP 38673 FP 26557 TN 14267 FN 1785
#
#
#
# None
# Cross: Validation: [ 0.96331336  0.97044856  0.9749511   0.97295801  0.97304413]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 41 FP 23514 TN 0 FN 0
#
#
#
# None
# y ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9673593437276075
# Specificity : 0.6662909509691015
# Accuracy: 0.8161954676312099
# ROC 0.816825147348
# TP 39150 FP 13619 TN 27192 FN 1321
#
#
#
# None
# Cross: Validation: [ 0.96362093  0.9701779   0.97438516  0.97386843  0.97122329]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.0053585098239346774
# Accuracy: 0.0070897898535342814
# ROC 0.502679254912
# TP 41 FP 23388 TN 126 FN 0
#
#
#
# None
# x ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9614183764495986
# Specificity : 0.739725357963153
# Accuracy: 0.8497945424571246
# ROC 0.850571867206
# TP 38799 FP 10652 TN 30274 FN 1557
#
#
#
# None
# Cross: Validation: [ 0.9630427   0.969735    0.97203528  0.97306874  0.97519716]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.00705962405375521
# Accuracy: 0.008787943111865846
# ROC 0.503529812027
# TP 41 FP 23348 TN 166 FN 0
#
#
#
# None
# y SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323754
# Test Data Points: 80939
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9685724254810089
# Specificity : 0.9980889378904815
# Accuracy: 0.9834566772507691
# ROC 0.983330681686
# TP 38863 FP 78 TN 40737 FN 1261
#
#
#
# None
# Cross: Validation: [ 0.97089202  0.9852605   0.98543329  0.98538387  0.98548272]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.7116611380454197
# Accuracy: 0.7104648694544683
# ROC 0.368025690974
# TP 1 FP 6780 TN 16734 FN 40
#
#
#
# None
# x SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574223
# Test Data Points: 80943
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.964917967386426
# Specificity : 0.9969635379680192
# Accuracy: 0.981085455196867
# ROC 0.980940752677
# TP 38699 FP 124 TN 40713 FN 1407
#
#
#
# None
# Cross: Validation: [ 0.97102935  0.98412443  0.98503867  0.98512515  0.98638531]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 3500 TN 20014 FN 41
#
#
#
# None
# y SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323700
# Test Data Points: 80926
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9846919632807224
# Specificity : 0.4026668620411752
# Accuracy: 0.6901984529075946
# ROC 0.693679412661
# TP 39367 FP 24459 TN 16488 FN 612
#
#
#
# None
# Cross: Validation: [ 0.97109705  0.98531974  0.98700031  0.98729688  0.98648131]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.2897848090499277
# Accuracy: 0.2910210146465719
# ROC 0.644892404525
# TP 41 FP 16700 TN 6814 FN 0
#
#
#
# None
# x SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 548050
# Test Data Points: 74400
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7527410670582477
# Specificity : 0.7732259988073942
# Accuracy: 0.7619758064516129
# ROC 0.762983532933
# TP 30757 FP 7606 TN 25934 FN 10103
#
#
#
# None
# Cross: Validation: [ 0.96153226  0.98420678  0.98676057  0.98654552  0.98567185]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.546568002041337
# Accuracy: 0.5456590957333899
# ROC 0.285479122972
# TP 1 FP 10662 TN 12852 FN 40
#
#
#
# None
# y SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323684
# Test Data Points: 80922
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9698621914313583
# Specificity : 0.85559002418232
# Accuracy: 0.9120511109463434
# ROC 0.912726107807
# TP 38778 FP 5912 TN 35027 FN 1205
#
#
#
# None
# Cross: Validation: [ 0.97149107  0.98352714  0.98661658  0.98641885  0.98654243]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.2885089733775623
# Accuracy: 0.2880492464444916
# ROC 0.15644960864
# TP 1 FP 16730 TN 6784 FN 40
#
#
#
# None
# x SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574201
# Test Data Points: 80937
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.611061106110611
# Specificity : 0.7887203536796854
# Accuracy: 0.7009278821799672
# ROC 0.699890729895
# TP 24440 FP 8650 TN 32291 FN 15556
#
#
#
# None
# Cross: Validation: [ 0.97110134  0.983308    0.98685397  0.98480281  0.98593951]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.5283660797822574
# Accuracy: 0.5291870091275738
# ROC 0.764183039891
# TP 41 FP 11090 TN 12424 FN 0
#
#
#
# None
# y SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323799
# Test Data Points: 80950
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9735076209244893
# Specificity : 0.9726158138169003
# Accuracy: 0.9730574428659666
# ROC 0.973061717371
# TP 39025 FP 1119 TN 39744 FN 1062
#
#
#
# None
# Cross: Validation: [ 0.97082186  0.9842866   0.98621371  0.98564528  0.98736241]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 5626 TN 17888 FN 41
#
#
#
# None
# x SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574200
# Test Data Points: 80937
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9590995402758346
# Specificity : 0.9848458925036052
# Accuracy: 0.9721141134462606
# ROC 0.97197271639
# TP 38387 FP 620 TN 40293 FN 1637
#
#
#
# None
# Cross: Validation: [ 0.97118782  0.98535898  0.98612484  0.9863843   0.98577889]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 4184 TN 19330 FN 41
#
#
#
# None
# y SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323701
# Test Data Points: 80926
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9705669601656232
# Specificity : 0.991477898861271
# Accuracy: 0.9811185527518967
# ROC 0.981022429513
# TP 38911 FP 348 TN 40487 FN 1180
#
#
#
# None
# Cross: Validation: [ 0.97141869  0.98504788  0.98591288  0.98693852  0.9859376 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 258 TN 23256 FN 41
#
#
#
# None
# x SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574085
# Test Data Points: 80908
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9629472316610034
# Specificity : 0.9888464925154095
# Accuracy: 0.9760345083304494
# ROC 0.975896862088
# TP 38541 FP 456 TN 40428 FN 1483
#
#
#
# None
# Cross: Validation: [ 0.97161008  0.98541553  0.98712117  0.988357    0.9866637 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 258 TN 23256 FN 41
#
#
#
# None
# y random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9320710312366282
# Specificity : 0.9972539543057997
# Accuracy: 0.9642315196184695
# ROC 0.964662492771
# TP 8713 FP 25 TN 9079 FN 635
#
#
#
# None
# Cross: Validation: [ 0.96471927  0.9644483   0.96363538  0.96471545  0.96395664]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9307873341891314
# Specificity : 0.9963752196836555
# Accuracy: 0.9631476262735746
# ROC 0.963581276936
# TP 8701 FP 33 TN 9071 FN 647
#
#
#
# None
# Cross: Validation: [ 0.96374377  0.96379796  0.96629092  0.96379404  0.96449864]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9311082584510055
# Specificity : 0.9973637961335676
# Accuracy: 0.9637979622805116
# ROC 0.964236027292
# TP 8704 FP 24 TN 9080 FN 644
#
#
#
# None
# Cross: Validation: [ 0.96412313  0.96531541  0.96509863  0.96411924  0.96384824]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1262 TN 22252 FN 41
#
#
#
# None
# x random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5678219940094138
# Specificity : 0.9626537785588752
# Accuracy: 0.7626273574680251
# ROC 0.765237886284
# TP 5308 FP 340 TN 8764 FN 4040
#
#
#
# None
# Cross: Validation: [ 0.96558639  0.96455669  0.9674832   0.96124661  0.96249322]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2466 TN 21048 FN 41
#
#
#
# None
# y random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.933461703038083
# Specificity : 0.9023506151142355
# Accuracy: 0.9181118577931932
# ROC 0.917906159076
# TP 8726 FP 889 TN 8215 FN 622
#
#
#
# None
# Cross: Validation: [ 0.96428571  0.96385216  0.96325602  0.96439024  0.96482385]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 7324 TN 16190 FN 41
#
#
#
# None
# x random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.12740693196405647
# Specificity : 0.9995606326889279
# Accuracy: 0.5577173206156514
# ROC 0.563483782326
# TP 1191 FP 4 TN 9100 FN 8157
#
#
#
# None
# Cross: Validation: [ 0.96433991  0.96504444  0.96433991  0.96411924  0.96352304]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 82 TN 23432 FN 41
#
#
#
# None
# y random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9337826272999572
# Specificity : 0.9983523725834798
# Accuracy: 0.9656405809668329
# ROC 0.966067499942
# TP 8729 FP 15 TN 9089 FN 619
#
#
#
# None
# Cross: Validation: [ 0.96352699  0.96509863  0.96282246  0.96612466  0.96476965]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 166 TN 23348 FN 41
#
#
#
# None
# x random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9333547282841249
# Specificity : 0.9969244288224957
# Accuracy: 0.9647192716236722
# ROC 0.965139578553
# TP 8725 FP 28 TN 9076 FN 623
#
#
#
# None
# Cross: Validation: [ 0.96390635  0.96732062  0.96282246  0.96422764  0.96401084]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 344 TN 23170 FN 41
#
#
#
# None
# y random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9288617886178862
# Specificity : 0.9975834797891037
# Accuracy: 0.9627682636028615
# ROC 0.963222634203
# TP 8683 FP 22 TN 9082 FN 665
#
#
#
# None
# Cross: Validation: [ 0.96780837  0.96406894  0.96352699  0.96417344  0.96325203]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 40 TN 23474 FN 41
#
#
#
# None
# x random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9264013692768507
# Specificity : 0.9976933216168717
# Accuracy: 0.9615759809234772
# ROC 0.962047345447
# TP 8660 FP 21 TN 9083 FN 688
#
#
#
# None
# Cross: Validation: [ 0.96152179  0.96672447  0.96428571  0.96346883  0.96493225]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187453
# Test Data Points: 46864
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9320941227033416
# Specificity : 0.9994674761029901
# Accuracy: 0.9860874018436326
# ROC 0.965780799403
# TP 8675 FP 20 TN 37537 FN 632
#
#
#
# None
# Cross: Validation: [ 0.98610874  0.98583134  0.98587402  0.98604443  0.98615083]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437863
# Test Data Points: 46853
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9312419424151268
# Specificity : 0.9995205753096285
# Accuracy: 0.9859560753847139
# ROC 0.965381258862
# TP 8668 FP 18 TN 37527 FN 640
#
#
#
# None
# Cross: Validation: [ 0.98478219  0.98602011  0.98680981  0.98610518  0.98633967]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187428
# Test Data Points: 46857
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9324164607284839
# Specificity : 0.9995472703062583
# Accuracy: 0.9862133726017457
# ROC 0.965981865517
# TP 8678 FP 17 TN 37533 FN 629
#
#
#
# None
# Cross: Validation: [ 0.9869606   0.98508259  0.98599996  0.9857649   0.98617039]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1508 TN 22006 FN 41
#
#
#
# None
# x ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437885
# Test Data Points: 46858
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.695498012248845
# Specificity : 0.9417325770285745
# Accuracy: 0.8928251312475991
# ROC 0.818615294639
# TP 6473 FP 2188 TN 35363 FN 2834
#
#
#
# None
# Cross: Validation: [ 0.98531766  0.98670451  0.98608562  0.98587191  0.98599996]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2018 TN 21496 FN 41
#
#
#
# None
# y ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187445
# Test Data Points: 46862
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9297227595099935
# Specificity : 0.9995473426349984
# Accuracy: 0.9856813622978106
# ROC 0.964635051072
# TP 8652 FP 17 TN 37539 FN 654
#
#
#
# None
# Cross: Validation: [ 0.98527592  0.98572404  0.98653493  0.98608651  0.98638498]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2610 TN 20904 FN 41
#
#
#
# None
# x ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437880
# Test Data Points: 46857
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.49704523476952833
# Specificity : 0.9910252996005326
# Accuracy: 0.8929082100860064
# ROC 0.744035267185
# TP 4626 FP 337 TN 37213 FN 4681
#
#
#
# None
# Cross: Validation: [ 0.98629874  0.98585057  0.98636276  0.98593563  0.98557282]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 138 TN 23376 FN 41
#
#
#
# None
# y ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187431
# Test Data Points: 46858
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9312345546362952
# Specificity : 0.9995472823626534
# Accuracy: 0.9859789150198472
# ROC 0.965390918499
# TP 8667 FP 17 TN 37534 FN 640
#
#
#
# None
# Cross: Validation: [ 0.98572313  0.98600026  0.98561612  0.98655484  0.98610666]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 172 TN 23342 FN 41
#
#
#
# None
# x ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437878
# Test Data Points: 46856
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9318865492049849
# Specificity : 0.9994407158836689
# Accuracy: 0.9860210005122076
# ROC 0.965663632544
# TP 8674 FP 21 TN 37527 FN 634
#
#
#
# None
# Cross: Validation: [ 0.98570118  0.98649081  0.98589295  0.98640487  0.98552983]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 724 TN 22790 FN 41
#
#
#
# None
# y ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187440
# Test Data Points: 46860
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9348877189212421
# Specificity : 0.9997070806593348
# Accuracy: 0.9868331199317115
# ROC 0.96729739979
# TP 8701 FP 11 TN 37542 FN 606
#
#
#
# None
# Cross: Validation: [ 0.98615053  0.98597981  0.98578745  0.98531766  0.98676882]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437918
# Test Data Points: 46867
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9333763163550398
# Specificity : 0.9995740262506323
# Accuracy: 0.9864296839994026
# ROC 0.966475171303
# TP 8686 FP 16 TN 37545 FN 620
#
#
#
# None
# Cross: Validation: [ 0.98649369  0.98576824  0.98608829  0.9862584   0.98538355]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9453359007274283
# Specificity : 0.9974736379613357
# Accuracy: 0.9710600476913072
# ROC 0.971404769344
# TP 8837 FP 23 TN 9081 FN 511
#
#
#
# None
# Cross: Validation: [ 0.96818773  0.97019293  0.97111424  0.97100271  0.9603252 ]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.7975674066513566
# Accuracy: 0.7962216090002122
# ROC 0.410978825277
# TP 1 FP 4760 TN 18754 FN 40
#
#
#
# None
# x near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9444801026957638
# Specificity : 0.9975834797891037
# Accuracy: 0.970680685020594
# ROC 0.971031791242
# TP 8829 FP 22 TN 9082 FN 519
#
#
#
# None
# Cross: Validation: [ 0.97003035  0.97095166  0.97003035  0.97078591  0.96065041]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 4696 TN 18818 FN 41
#
#
#
# None
# y near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9445870774497218
# Specificity : 0.9975834797891037
# Accuracy: 0.9707348796878387
# ROC 0.971085278619
# TP 8830 FP 22 TN 9082 FN 518
#
#
#
# None
# Cross: Validation: [ 0.96704964  0.97024713  0.9685129   0.97235772  0.96205962]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 1184 TN 22330 FN 41
#
#
#
# None
# x near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.696405648267009
# Specificity : 0.9939586994727593
# Accuracy: 0.8432148276609581
# ROC 0.84518217387
# TP 6510 FP 55 TN 9049 FN 2838
#
#
#
# None
# Cross: Validation: [ 0.96802515  0.97046391  0.97030132  0.97241192  0.96308943]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 630 TN 22884 FN 41
#
#
#
# None
# y near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9404150620453573
# Specificity : 0.9974736379613357
# Accuracy: 0.968567092998049
# ROC 0.968944350003
# TP 8791 FP 23 TN 9081 FN 557
#
#
#
# None
# Cross: Validation: [ 0.96889226  0.97062649  0.97024713  0.9698645   0.96162602]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 6500 TN 17014 FN 41
#
#
#
# None
# x near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.27000427899015833
# Specificity : 0.999670474516696
# Accuracy: 0.6300130067201387
# ROC 0.634837376753
# TP 2524 FP 3 TN 9101 FN 6824
#
#
#
# None
# Cross: Validation: [ 0.96764578  0.96872968  0.96981357  0.97235772  0.96271003]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 330 TN 23184 FN 41
#
#
#
# None
# y near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9426615318784767
# Specificity : 0.9981326889279437
# Accuracy: 0.970030349013657
# ROC 0.970397110403
# TP 8812 FP 17 TN 9087 FN 536
#
#
#
# None
# Cross: Validation: [ 0.96732062  0.97106005  0.96872968  0.97230352  0.96070461]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.8725014884749511
# Accuracy: 0.8710252600297177
# ROC 0.448445866189
# TP 1 FP 2998 TN 20516 FN 40
#
#
#
# None
# x near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9492939666238768
# Specificity : 0.9930799648506151
# Accuracy: 0.970897463689573
# ROC 0.971186965737
# TP 8874 FP 63 TN 9041 FN 474
#
#
#
# None
# Cross: Validation: [ 0.96639931  0.96943421  0.97116844  0.97246612  0.96151762]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2888 TN 20626 FN 41
#
#
#
# None
# y near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9407359863072315
# Specificity : 0.9972539543057997
# Accuracy: 0.9686212876652938
# ROC 0.968994970307
# TP 8794 FP 25 TN 9079 FN 554
#
#
#
# None
# Cross: Validation: [ 0.96791676  0.9695426   0.97171038  0.97241192  0.9597832 ]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.8878965722548269
# Accuracy: 0.8863935470176183
# ROC 0.456143408079
# TP 1 FP 2636 TN 20878 FN 40
#
#
#
# None
# x near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9394522892597347
# Specificity : 0.9982425307557118
# Accuracy: 0.9684587036635595
# ROC 0.968847410008
# TP 8782 FP 16 TN 9088 FN 566
#
#
#
# None
# Cross: Validation: [ 0.96835031  0.96840451  0.97078907  0.9703523   0.96314363]
# Number of data points in benchmark 23555
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 2002 TN 21512 FN 41
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
scale = [-1, "standard", "robust", "minmax", "max"]
for i in par:
    for j in scale: 
        print("y", i, " ", j)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training("xgb", scale=j)
        y.benchmark("Data/Benchmarks/phos.csv", "T")
        del y
        print("x", i, " ", j)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training("xgb", scale=j)
        x.benchmark("Data/Benchmarks/phos.csv", "T")
        del x
# Out:
# y pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9295575606044135
# Specificity : 0.9996820894062408
# Accuracy: 0.9868040166896249
# ROC 0.964619825005
# TP 8551 FP 13 TN 40879 FN 648
#
#
#
# None
# Cross: Validation: [ 0.98696399  0.98664431  0.98744285  0.986664    0.98640447]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 1 TN 46496 FN 1233
#
#
#
# None
# x pass   -1
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9286407243721031
# Specificity : 0.9985054148086441
# Accuracy: 0.9855662693897107
# ROC 0.96357306959
# TP 8615 FP 61 TN 40753 FN 662
#
#
#
# None
# Cross: Validation: [ 0.98666454  0.98678405  0.98632489  0.98740268  0.98702336]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9340635738831615
# Specificity : 0.9994850290590745
# Accuracy: 0.9873230720089438
# ROC 0.966774301471
# TP 8698 FP 21 TN 40758 FN 614
#
#
#
# None
# Cross: Validation: [ 0.98724347  0.98616518  0.98660438  0.98692354  0.98718307]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0024330900243309003
# Specificity : 0.9793104931500957
# Accuracy: 0.954075005237796
# ROC 0.490871791587
# TP 3 FP 962 TN 45535 FN 1230
#
#
#
# None
# x pass   standard
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7020131338141888
# Specificity : 0.9322092054311063
# Accuracy: 0.8895210716495977
# ROC 0.817111169623
# TP 6521 FP 2766 TN 38036 FN 2768
#
#
#
# None
# Cross: Validation: [ 0.98594586  0.98658442  0.98756264  0.98680375  0.98724296]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.1792376317923763
# Specificity : 0.8567864593414629
# Accuracy: 0.8392834695160276
# ROC 0.518012045567
# TP 221 FP 6659 TN 39838 FN 1012
#
#
#
# None
# y pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9344968756733463
# Specificity : 0.9994854076306697
# Accuracy: 0.9874428540057096
# ROC 0.966991141652
# TP 8674 FP 21 TN 40788 FN 608
#
#
#
# None
# Cross: Validation: [ 0.98726344  0.98650456  0.9867042   0.98734278  0.98634458]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.035685320356853206
# Specificity : 0.9695894358775835
# Accuracy: 0.9454640687198826
# ROC 0.502637378117
# TP 44 FP 1414 TN 45083 FN 1189
#
#
#
# None
# x pass   robust
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5156809549647314
# Specificity : 0.985933065857716
# Accuracy: 0.899423050048911
# ROC 0.750807010411
# TP 4752 FP 575 TN 40301 FN 4463
#
#
#
# None
# Cross: Validation: [ 0.98712369  0.98696373  0.98676409  0.98588541  0.98742264]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0016220600162206002
# Specificity : 0.9786652902337786
# Accuracy: 0.9534255185417976
# ROC 0.490143675125
# TP 2 FP 992 TN 45505 FN 1231
#
#
#
# None
# y pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9243706597222222
# Specificity : 0.9995351681957186
# Accuracy: 0.9857060150526042
# ROC 0.961952913959
# TP 8519 FP 19 TN 40856 FN 697
#
#
#
# None
# Cross: Validation: [ 0.98638505  0.98702362  0.98632489  0.98724296  0.987223  ]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0032441200324412004
# Specificity : 0.9978708303761533
# Accuracy: 0.9721768279907815
# ROC 0.500557475204
# TP 4 FP 99 TN 46398 FN 1229
#
#
#
# None
# x pass   minmax
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9383050113648663
# Specificity : 0.9988250269264662
# Accuracy: 0.9876624543331137
# ROC 0.968565019146
# TP 8669 FP 48 TN 40804 FN 570
#
#
#
# None
# Cross: Validation: [ 0.98672443  0.98644467  0.98676409  0.98686365  0.98732282]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0040551500405515
# Specificity : 0.9939565993504957
# Accuracy: 0.968384663733501
# ROC 0.499005874696
# TP 5 FP 281 TN 46216 FN 1228
#
#
#
# None
# y pass   max
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 200363
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.93155276816609
# Specificity : 0.9996572240041133
# Accuracy: 0.987083508015412
# ROC 0.965604996085
# TP 8615 FP 14 TN 40829 FN 633
#
#
#
# None
# Cross: Validation: [ 0.98636509  0.98672416  0.98702362  0.987223    0.98680375]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass   max
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 450817
# Test Data Points: 50091
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9283051962288972
# Specificity : 0.9989016085332812
# Accuracy: 0.9860453973767743
# ROC 0.963603402381
# TP 8468 FP 45 TN 40924 FN 654
#
#
#
# None
# Cross: Validation: [ 0.98700391  0.98678405  0.98776227  0.98582551  0.98680375]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9468208951527011
# Specificity : 0.9954288787308416
# Accuracy: 0.9712851553849561
# ROC 0.971124886942
# TP 38226 FP 187 TN 40722 FN 2147
#
#
#
# None
# Cross: Validation: [ 0.96311652  0.97263847  0.97325328  0.97236747  0.97218292]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ADASYN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9426830476567918
# Specificity : 0.9952089953556588
# Accuracy: 0.9691198543342929
# ROC 0.968946021506
# TP 38058 FP 196 TN 40714 FN 2314
#
#
#
# None
# Cross: Validation: [ 0.96234145  0.95775202  0.97315486  0.96369385  0.96467809]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9603386809269162
# Specificity : 0.5937148447053069
# Accuracy: 0.7759036441032455
# ROC 0.777026762816
# TP 38790 FP 16613 TN 24277 FN 1602
#
#
#
# None
# Cross: Validation: [ 0.96357172  0.97164194  0.97237977  0.97470504  0.97199838]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5928629359286294
# Specificity : 0.2424672559519969
# Accuracy: 0.2515189608212864
# ROC 0.41766509594
# TP 731 FP 35223 TN 11274 FN 502
#
#
#
# None
# x ADASYN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9567637092186302
# Specificity : 0.35811323525812055
# Accuracy: 0.6558770699539873
# ROC 0.657438472238
# TP 38681 FP 26223 TN 14630 FN 1748
#
#
#
# None
# Cross: Validation: [ 0.96315343  0.97128516  0.97342552  0.97103874  0.97396686]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.8913219789132197
# Specificity : 0.14788050841989805
# Accuracy: 0.1670856903415043
# ROC 0.519601243667
# TP 1099 FP 39621 TN 6876 FN 134
#
#
#
# None
# y ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9500581582399089
# Specificity : 0.8381896024464832
# Accuracy: 0.8938018257424768
# ROC 0.894123880343
# TP 38389 FP 6614 TN 34261 FN 2018
#
#
#
# None
# Cross: Validation: [ 0.96305501  0.97267538  0.97297031  0.97408989  0.97260122]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.5579886455798865
# Specificity : 0.3357205841237069
# Accuracy: 0.3414623926251833
# ROC 0.446854614852
# TP 688 FP 30887 TN 15610 FN 545
#
#
#
# None
# x ADASYN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9913707842943329
# Specificity : 0.08347617415152554
# Accuracy: 0.5352230506139121
# ROC 0.537423479223
# TP 40095 FP 37429 TN 3409 FN 349
#
#
#
# None
# Cross: Validation: [ 0.96309191  0.97327822  0.97178923  0.97139553  0.97191226]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9318734793187348
# Specificity : 0.06181043938318601
# Accuracy: 0.08428661219358893
# ROC 0.496841959351
# TP 1149 FP 43623 TN 2874 FN 84
#
#
#
# None
# y ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9806614142112673
# Specificity : 0.24867011497070576
# Accuracy: 0.6132969169065722
# ROC 0.614665764591
# TP 39706 FP 30649 TN 10144 FN 783
#
#
#
# None
# Cross: Validation: [ 0.96252599  0.96988263  0.97484037  0.9733148   0.97183844]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 1233 FP 46497 TN 0 FN 0
#
#
#
# None
# x ADASYN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.980764957159436
# Specificity : 0.22251918691611702
# Accuracy: 0.6003174134494722
# ROC 0.601642072038
# TP 39720 FP 31708 TN 9075 FN 779
#
#
#
# None
# Cross: Validation: [ 0.96364553  0.96882459  0.97460661  0.9716662   0.9737331 ]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 1233 FP 46497 TN 0 FN 0
#
#
#
# None
# y ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 325126
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9711141337949796
# Specificity : 0.6095918916933925
# Accuracy: 0.78943677566989
# ROC 0.790353012744
# TP 39267 FP 15947 TN 24900 FN 1168
#
#
#
# None
# Cross: Validation: [ 0.96240296  0.96144288  0.96288185  0.96298028  0.97165389]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9967558799675588
# Specificity : 0.027442630707357463
# Accuracy: 0.05248271527341295
# ROC 0.512099255337
# TP 1229 FP 45221 TN 1276 FN 4
#
#
#
# None
# x ADASYN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 575580
# Test Data Points: 81282
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9755697899597795
# Specificity : 0.5751146229636133
# Accuracy: 0.7735538003494008
# ROC 0.775342206462
# TP 39294 FP 17422 TN 23582 FN 984
#
#
#
# None
# Cross: Validation: [ 0.96365784  0.97097758  0.9729334   0.97329019  0.97357316]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.9959448499594485
# Specificity : 0.017463492268318385
# Accuracy: 0.04274041483343809
# ROC 0.506704171114
# TP 1228 FP 45685 TN 812 FN 5
#
#
#
# None
# y SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323771
# Test Data Points: 80943
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9689106304785081
# Specificity : 0.9978363493312352
# Accuracy: 0.9834451404074472
# ROC 0.983373489905
# TP 39019 FP 88 TN 40584 FN 1252
#
#
#
# None
# Cross: Validation: [ 0.97051048  0.98511298  0.98465587  0.98555756  0.98586642]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.5312246553122466
# Specificity : 0.6573112243800675
# Accuracy: 0.654054054054054
# ROC 0.594267939846
# TP 655 FP 15934 TN 30563 FN 578
#
#
#
# None
# x SMOTEENN   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574143
# Test Data Points: 80923
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9636327454540932
# Specificity : 0.9962919306517362
# Accuracy: 0.9800674715470262
# ROC 0.979962338053
# TP 38739 FP 151 TN 40571 FN 1462
#
#
#
# None
# Cross: Validation: [ 0.97134348  0.98344084  0.98697511  0.98632016  0.98638195]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.18896999188969993
# Specificity : 0.9219089403617438
# Accuracy: 0.9029750680913472
# ROC 0.555439466126
# TP 233 FP 3631 TN 42866 FN 1000
#
#
#
# None
# y SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323763
# Test Data Points: 80941
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9874041621029573
# Specificity : 0.37837572665505653
# Accuracy: 0.6806439258225127
# ROC 0.682889944379
# TP 39666 FP 25343 TN 15426 FN 506
#
#
#
# None
# Cross: Validation: [ 0.97084332  0.98558209  0.985335    0.98658265  0.98439585]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.7534468775344688
# Specificity : 0.2616943028582489
# Accuracy: 0.2743976534674209
# ROC 0.507570590196
# TP 929 FP 34329 TN 12168 FN 304
#
#
#
# None
# x SMOTEENN   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574216
# Test Data Points: 80941
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.773111133320008
# Specificity : 0.8826160275680035
# Accuracy: 0.8284676492753982
# ROC 0.827863580444
# TP 30943 FP 4803 TN 36114 FN 9081
#
#
#
# None
# Cross: Validation: [ 0.97131279  0.98529793  0.98556956  0.98616259  0.98654559]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.4931062449310625
# Specificity : 0.631029958922081
# Accuracy: 0.6274670018856066
# ROC 0.562068101927
# TP 608 FP 17156 TN 29341 FN 625
#
#
#
# None
# y SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323786
# Test Data Points: 80947
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9680962343096234
# Specificity : 0.855472484373085
# Accuracy: 0.9113370476978764
# ROC 0.911784359341
# TP 38871 FP 5896 TN 34899 FN 1281
#
#
#
# None
# Cross: Validation: [ 0.97145081  0.98549668  0.98626245  0.98612655  0.98559534]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.6236820762368208
# Specificity : 0.30731014904187365
# Accuracy: 0.31548292478525036
# ROC 0.465496112639
# TP 769 FP 32208 TN 14289 FN 464
#
#
#
# None
# x SMOTEENN   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574253
# Test Data Points: 80950
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6165090927233268
# Specificity : 0.8223821060617185
# Accuracy: 0.7204323656578134
# ROC 0.719445599393
# TP 24714 FP 7258 TN 33605 FN 15373
#
#
#
# None
# Cross: Validation: [ 0.97092068  0.98518839  0.98622607  0.9864112   0.98638649]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.67558799675588
# Specificity : 0.47579413725616704
# Accuracy: 0.4809553739786298
# ROC 0.575691067006
# TP 833 FP 24374 TN 22123 FN 400
#
#
#
# None
# y SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323647
# Test Data Points: 80912
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9693684262997857
# Specificity : 0.9938710468252022
# Accuracy: 0.9817208819458176
# ROC 0.981619736562
# TP 38893 FP 250 TN 40540 FN 1229
#
#
#
# None
# Cross: Validation: [ 0.97131487  0.9852803   0.98671396  0.98586101  0.98657784]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.2984590429845904
# Specificity : 0.7883089231563327
# Accuracy: 0.7756547244919338
# ROC 0.54338398307
# TP 368 FP 9843 TN 36654 FN 865
#
#
#
# None
# x SMOTEENN   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 574160
# Test Data Points: 80927
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9619828923015357
# Specificity : 0.9494443766027598
# Accuracy: 0.9556390327084904
# ROC 0.955713634452
# TP 38462 FP 2070 TN 38875 FN 1520
#
#
#
# None
# Cross: Validation: [ 0.97123369  0.98446748  0.9857277   0.98676569  0.98599956]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.07948094079480941
# Specificity : 0.8549368776480203
# Accuracy: 0.8349046721139745
# ROC 0.467208909221
# TP 98 FP 6745 TN 39752 FN 1135
#
#
#
# None
# y SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 323698
# Test Data Points: 80925
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9788332086761407
# Specificity : 0.7599901996814896
# Accuracy: 0.8684584491813407
# ROC 0.869411704179
# TP 39261 FP 9796 TN 31019 FN 849
#
#
#
# None
# Cross: Validation: [ 0.97139362  0.98415817  0.98624635  0.98630814  0.98638228]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.1111111111111111
# Specificity : 0.9669871174484376
# Accuracy: 0.94487743557511
# ROC 0.53904911428
# TP 137 FP 1535 TN 44962 FN 1096
#
#
#
# None
# x SMOTEENN   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 548207
# Test Data Points: 74439
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9570844853318979
# Specificity : 0.9958591515729266
# Accuracy: 0.9745697819691291
# ROC 0.976471818452
# TP 39117 FP 139 TN 33429 FN 1754
#
#
#
# None
# Cross: Validation: [ 0.96211714  0.98305973  0.98682125  0.98713023  0.9852629 ]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.18085969180859693
# Specificity : 0.941157494031873
# Accuracy: 0.9215168657029122
# ROC 0.56100859292
# TP 223 FP 2736 TN 43761 FN 1010
#
#
#
# None
# y random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9332477535301669
# Specificity : 0.9973637961335676
# Accuracy: 0.9648818556254065
# ROC 0.965305774832
# TP 8724 FP 24 TN 9080 FN 624
#
#
#
# None
# Cross: Validation: [ 0.96585736  0.96325602  0.96499024  0.96390244  0.96368564]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0008110300081103001
# Specificity : 0.9963653569047466
# Accuracy: 0.9706473915776241
# ROC 0.498588193456
# TP 1 FP 169 TN 46328 FN 1232
#
#
#
# None
# x random_under_sample   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9315361574668378
# Specificity : 0.9976933216168717
# Accuracy: 0.9641773249512248
# ROC 0.964614739542
# TP 8708 FP 21 TN 9083 FN 640
#
#
#
# None
# Cross: Validation: [ 0.96282246  0.96358118  0.96580316  0.96504065  0.96395664]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 1 TN 46496 FN 1233
#
#
#
# None
# y random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9322849807445442
# Specificity : 0.9973637961335676
# Accuracy: 0.9643941036202037
# ROC 0.964824388439
# TP 8715 FP 24 TN 9080 FN 633
#
#
#
# None
# Cross: Validation: [ 0.96368957  0.96406894  0.96482766  0.96569106  0.96271003]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.047850770478507706
# Specificity : 0.9328343764113813
# Accuracy: 0.9099727634611355
# ROC 0.490342573445
# TP 59 FP 3123 TN 43374 FN 1174
#
#
#
# None
# x random_under_sample   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5572314933675653
# Specificity : 0.9625439367311072
# Accuracy: 0.7572078907435509
# ROC 0.759887715049
# TP 5209 FP 341 TN 8763 FN 4139
#
#
#
# None
# Cross: Validation: [ 0.96466508  0.96661608  0.96580316  0.96140921  0.96341463]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.11354420113544202
# Specificity : 0.881411703980902
# Accuracy: 0.8615755290173894
# ROC 0.497477952558
# TP 140 FP 5514 TN 40983 FN 1093
#
#
#
# None
# y random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9321780059905862
# Specificity : 0.9963752196836555
# Accuracy: 0.9638521569477564
# ROC 0.964276612837
# TP 8714 FP 33 TN 9071 FN 634
#
#
#
# None
# Cross: Validation: [ 0.96331021  0.96629092  0.96531541  0.96373984  0.96330623]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.3357664233576642
# Specificity : 0.632191324171452
# Accuracy: 0.6245338361617432
# ROC 0.483978873765
# TP 414 FP 17102 TN 29395 FN 819
#
#
#
# None
# x random_under_sample   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.1286906290115533
# Specificity : 0.999890158172232
# Accuracy: 0.5585302406243225
# ROC 0.564290393592
# TP 1203 FP 1 TN 9103 FN 8145
#
#
#
# None
# Cross: Validation: [ 0.96287665  0.96601994  0.9643941   0.96471545  0.96422764]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 51 TN 46446 FN 1233
#
#
#
# None
# y random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9295036371416345
# Specificity : 0.9978031634446397
# Accuracy: 0.9632018209408194
# ROC 0.963653400293
# TP 8689 FP 20 TN 9084 FN 659
#
#
#
# None
# Cross: Validation: [ 0.96612833  0.96618253  0.96271407  0.96357724  0.96303523]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.008921330089213302
# Specificity : 0.9856764952577586
# Accuracy: 0.9604441650953279
# ROC 0.497298912673
# TP 11 FP 666 TN 45831 FN 1222
#
#
#
# None
# x random_under_sample   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9266153187847668
# Specificity : 0.9980228471001757
# Accuracy: 0.9618469542597008
# ROC 0.962319082942
# TP 8662 FP 18 TN 9086 FN 686
#
#
#
# None
# Cross: Validation: [ 0.96531541  0.96455669  0.96368957  0.96406504  0.96422764]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.004866180048661801
# Specificity : 0.9873110093124288
# Accuracy: 0.9619316991410015
# ROC 0.496088594681
# TP 6 FP 590 TN 45907 FN 1227
#
#
#
# None
# y random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9264013692768507
# Specificity : 0.9970342706502636
# Accuracy: 0.9612508129200087
# ROC 0.961717819964
# TP 8660 FP 27 TN 9077 FN 688
#
#
#
# None
# Cross: Validation: [ 0.96488186  0.96466508  0.96417732  0.96498645  0.96341463]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.038929440389294405
# Specificity : 0.9944512549196722
# Accuracy: 0.9697674418604652
# ROC 0.516690347654
# TP 48 FP 258 TN 46239 FN 1185
#
#
#
# None
# x random_under_sample   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9316431322207959
# Specificity : 0.9980228471001757
# Accuracy: 0.9643941036202037
# ROC 0.96483298966
# TP 8709 FP 18 TN 9086 FN 639
#
#
#
# None
# Cross: Validation: [ 0.9634186   0.96488186  0.96455669  0.96574526  0.96314363]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187454
# Test Data Points: 46864
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9316569954867827
# Specificity : 0.9994674902816977
# Accuracy: 0.9860020484807102
# ROC 0.965562242884
# TP 8670 FP 20 TN 37538 FN 636
#
#
#
# None
# Cross: Validation: [ 0.9860874   0.98679157  0.98559662  0.98598041  0.98555364]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437858
# Test Data Points: 46851
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9338203695745595
# Specificity : 0.9995738220174201
# Accuracy: 0.9865104266717893
# ROC 0.966697095796
# TP 8692 FP 16 TN 37527 FN 616
#
#
#
# None
# Cross: Validation: [ 0.98529412  0.98599846  0.98668118  0.98569904  0.98629669]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187464
# Test Data Points: 46867
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9319793681495809
# Specificity : 0.9996006496099678
# Accuracy: 0.9861736403012781
# ROC 0.96579000888
# TP 8673 FP 15 TN 37546 FN 633
#
#
#
# None
# Cross: Validation: [ 0.98619498  0.9857469   0.98649369  0.98649312  0.98508482]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.039740470397404706
# Specificity : 0.9291782265522507
# Accuracy: 0.9062015503875969
# ROC 0.484459348475
# TP 49 FP 3293 TN 43204 FN 1184
#
#
#
# None
# x ncl   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437886
# Test Data Points: 46858
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.691952293972279
# Specificity : 0.9205880003195653
# Accuracy: 0.8751760638524905
# ROC 0.806270147146
# TP 6440 FP 2982 TN 34569 FN 2867
#
#
#
# None
# Cross: Validation: [ 0.9860219   0.98668345  0.98610696  0.98595727  0.98521032]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.14436334144363341
# Specificity : 0.8631094479213712
# Accuracy: 0.8445422166352399
# ROC 0.503736394683
# TP 178 FP 6365 TN 40132 FN 1055
#
#
#
# None
# y ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187452
# Test Data Points: 46864
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9283335124100139
# Specificity : 0.9996804856617941
# Accuracy: 0.9855112666439058
# ROC 0.964006999036
# TP 8640 FP 12 TN 37545 FN 667
#
#
#
# None
# Cross: Validation: [ 0.98642882  0.98572465  0.98570331  0.98595877  0.98617217]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.07542579075425791
# Specificity : 0.887519624922038
# Accuracy: 0.8665409595642154
# ROC 0.481472707838
# TP 93 FP 5230 TN 41267 FN 1140
#
#
#
# None
# x ncl   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437875
# Test Data Points: 46856
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.3519174991943281
# Specificity : 0.9980557701014728
# Accuracy: 0.8696858459962438
# ROC 0.674986634648
# TP 3276 FP 73 TN 37474 FN 6033
#
#
#
# None
# Cross: Validation: [ 0.98593563  0.98557282  0.98666126  0.98559385  0.98623383]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 62 TN 46435 FN 1233
#
#
#
# None
# y ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187442
# Test Data Points: 46861
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.929522990975505
# Specificity : 0.999573935504487
# Accuracy: 0.9856597170354879
# ROC 0.96454846324
# TP 8652 FP 16 TN 37537 FN 656
#
#
#
# None
# Cross: Validation: [ 0.98563838  0.98604383  0.98640661  0.98670508  0.98518993]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0040551500405515
# Specificity : 0.9921500311848076
# Accuracy: 0.9666247642991829
# ROC 0.498102590613
# TP 5 FP 365 TN 46132 FN 1228
#
#
#
# None
# x ncl   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437897
# Test Data Points: 46861
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9281263429308122
# Specificity : 0.9995473064735174
# Accuracy: 0.985360961140394
# ROC 0.963836824702
# TP 8639 FP 17 TN 37536 FN 669
#
#
#
# None
# Cross: Validation: [ 0.98636422  0.98461407  0.98670536  0.98557405  0.9867691 ]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0056772100567721
# Specificity : 0.9580187969116287
# Accuracy: 0.9334171380683008
# ROC 0.481848003484
# TP 7 FP 1952 TN 44545 FN 1226
#
#
#
# None
# y ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 187446
# Test Data Points: 46862
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9347732645604986
# Specificity : 0.9994408350197039
# Accuracy: 0.9865989501088301
# ROC 0.96710704979
# TP 8699 FP 21 TN 37535 FN 607
#
#
#
# None
# Cross: Validation: [ 0.98559601  0.98546797  0.98610815  0.98649197  0.98634259]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 437890
# Test Data Points: 46859
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9285484044267756
# Specificity : 0.9996804431188752
# Accuracy: 0.9855524018865106
# ROC 0.964114423773
# TP 8642 FP 12 TN 37540 FN 665
#
#
#
# None
# Cross: Validation: [ 0.98602219  0.98580879  0.98597921  0.98559478  0.98659781]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9424475823705606
# Specificity : 0.9974736379613357
# Accuracy: 0.9695967916756991
# ROC 0.969960610166
# TP 8810 FP 23 TN 9081 FN 538
#
#
#
# None
# Cross: Validation: [ 0.96786256  0.96780837  0.97181877  0.97078591  0.96357724]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.32522303325223034
# Specificity : 0.799298879497602
# Accuracy: 0.7870521684475172
# ROC 0.562260956375
# TP 401 FP 9332 TN 37165 FN 832
#
#
#
# None
# x near_miss   -1
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9409499358151476
# Specificity : 0.9976933216168717
# Accuracy: 0.9689464556687621
# ROC 0.969321628716
# TP 8796 FP 21 TN 9083 FN 552
#
#
#
# None
# Cross: Validation: [ 0.96878387  0.9674832   0.96921743  0.97311653  0.96130081]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.19059205190592052
# Specificity : 0.8441404821816462
# Accuracy: 0.8272574900481877
# ROC 0.517366267044
# TP 235 FP 7247 TN 39250 FN 998
#
#
#
# None
# y near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9423406076166024
# Specificity : 0.9973637961335676
# Accuracy: 0.9694884023412096
# ROC 0.969852201875
# TP 8809 FP 24 TN 9080 FN 539
#
#
#
# None
# Cross: Validation: [ 0.9694884   0.96699545  0.97106005  0.9697561   0.96341463]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.1111111111111111
# Specificity : 0.9303610985654989
# Accuracy: 0.909197569662686
# ROC 0.520736104838
# TP 137 FP 3238 TN 43259 FN 1096
#
#
#
# None
# x near_miss   standard
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6845314505776636
# Specificity : 0.9935193321616872
# Accuracy: 0.8369824409278127
# ROC 0.83902539137
# TP 6399 FP 59 TN 9045 FN 2949
#
#
#
# None
# Cross: Validation: [ 0.96829612  0.9685129   0.96992196  0.97121951  0.96173442]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.0024330900243309003
# Specificity : 0.9642987719637827
# Accuracy: 0.9394510789859627
# ROC 0.483365930994
# TP 3 FP 1660 TN 44837 FN 1230
#
#
#
# None
# y near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9452289259734703
# Specificity : 0.9967047451669596
# Accuracy: 0.9706264903533492
# ROC 0.97096683557
# TP 8836 FP 30 TN 9074 FN 512
#
#
#
# None
# Cross: Validation: [ 0.96699545  0.97040971  0.96981357  0.97100271  0.96303523]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.38929440389294406
# Specificity : 0.7037228208271501
# Accuracy: 0.6956002514142049
# ROC 0.54650861236
# TP 480 FP 13776 TN 32721 FN 753
#
#
#
# None
# x near_miss   robust
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2734274711168164
# Specificity : 0.999670474516696
# Accuracy: 0.6317472360719705
# ROC 0.636548972817
# TP 2556 FP 3 TN 9101 FN 6792
#
#
#
# None
# Cross: Validation: [ 0.96938001  0.96867548  0.96970518  0.97192412  0.96092141]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Failed
# TP 0 FP 777 TN 45720 FN 1233
#
#
#
# None
# y near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9427685066324347
# Specificity : 0.9973637961335676
# Accuracy: 0.9697051810101885
# ROC 0.970066151383
# TP 8813 FP 24 TN 9080 FN 535
#
#
#
# None
# Cross: Validation: [ 0.96965099  0.96878387  0.97008454  0.9699187   0.96189702]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.24898621248986214
# Specificity : 0.8993483450545197
# Accuracy: 0.8825476639430128
# ROC 0.574167278772
# TP 307 FP 4680 TN 41817 FN 926
#
#
#
# None
# x near_miss   minmax
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9456568249893025
# Specificity : 0.9928602811950791
# Accuracy: 0.9689464556687621
# ROC 0.969258553092
# TP 8840 FP 65 TN 9039 FN 508
#
#
#
# None
# Cross: Validation: [ 0.96672447  0.9705723   0.9705181   0.97186992  0.9604336 ]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.15328467153284672
# Specificity : 0.8727229713744973
# Accuracy: 0.8541378587890216
# ROC 0.513003821454
# TP 189 FP 5918 TN 40579 FN 1044
#
#
#
# None
# y near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 73804
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9425545571245186
# Specificity : 0.9979130052724078
# Accuracy: 0.9698677650119228
# ROC 0.970233781198
# TP 8811 FP 19 TN 9085 FN 537
#
#
#
# None
# Cross: Validation: [ 0.96764578  0.96639931  0.97133102  0.97289973  0.96184282]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.18572587185725872
# Specificity : 0.8745940598318171
# Accuracy: 0.8567986591242405
# ROC 0.530159965845
# TP 229 FP 5831 TN 40666 FN 1004
#
#
#
# None
# x near_miss   max
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 324258
# Test Data Points: 18452
# Scaling Data
# Finished Scaling Data
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9409499358151476
# Specificity : 0.9980228471001757
# Accuracy: 0.9691090396704964
# ROC 0.969486391458
# TP 8796 FP 18 TN 9086 FN 552
#
#
#
# None
# Cross: Validation: [ 0.96932582  0.96797095  0.97084327  0.97149051  0.96146341]
# Number of data points in benchmark 47730
# Scaling Data
# Benchmark Results
# Sensitivity: 0.17680454176804541
# Specificity : 0.9079295438415381
# Accuracy: 0.889042530902996
# ROC 0.542367042805
# TP 218 FP 4281 TN 42216 FN 1015
#
#
#
# None
