# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.
#
# Note: SMOTEEN seems to preform best

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    try:
        print("y", i)
        y = Predictor()
        y.load_data(file="Data/Training/clean_s_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
        y.supervised_training("isolation_forest")
        y.benchmark("Data/Benchmarks/phos.csv", "S")
        del y
    except:
        print("failed")
    try:
        print("x", i)
        x = Predictor()
        x.load_data(file="Data/Training/clean_s_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
        x.supervised_training("isolation_forest")
        x.benchmark("Data/Benchmarks/phos.csv", "S")
        del x
    except:
        print("failed")
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Failed
# TP 13362 FP 54283 TN 0 FN 7492
#
#
#
# None
# failed
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 175317
# Test Data Points: 75137
# Starting Training
# Done training
# Test Results
# Failed
# TP 13548 FP 53934 TN 0 FN 7655
#
#
#
# None
# failed
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Failed
# TP 52684 FP 56989 TN 0 FN 12250
#
#
#
# None
# failed
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 284485
# Test Data Points: 121923
# Starting Training
# Done training
# Test Results
# Failed
# TP 53006 FP 56928 TN 0 FN 11989
#
#
#
# None
# failed
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283229
# Test Data Points: 121385
# Starting Training
# Done training
# Test Results
# Failed
# TP 59768 FP 49418 TN 0 FN 12199
#
#
#
# None
# failed
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 283184
# Test Data Points: 121366
# Starting Training
# Done training
# Test Results
# Failed
# TP 59694 FP 49547 TN 0 FN 12125
#
#
#
# None
# failed
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Failed
# TP 13635 FP 11301 TN 0 FN 2741
#
#
#
# None
# failed
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Failed
# TP 13611 FP 11234 TN 0 FN 2832
#
#
#
# None
# failed
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164012
# Test Data Points: 70292
# Starting Training
# Done training
# Test Results
# Failed
# TP 13538 FP 49565 TN 0 FN 7189
#
#
#
# None
# failed
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 164009
# Test Data Points: 70290
# Starting Training
# Done training
# Test Results
# Failed
# TP 13470 FP 49687 TN 0 FN 7133
#
#
#
# None
# failed
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Failed
# TP 13181 FP 11786 TN 0 FN 2710
#
#
#
# None
# failed
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 64579
# Test Data Points: 27677
# Starting Training
# Done training
# Test Results
# Failed
# TP 13105 FP 11806 TN 0 FN 2766
#
#
#
# None
# failed

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    try:
        print("y", i)
        y = Predictor()
        y.load_data(file="Data/Training/clean_Y_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
        y.supervised_training("isolation_forest")
        y.benchmark("Data/Benchmarks/phos.csv", "Y")
        del y
    except:
        print("failed")
    try:
        print("x", i)
        x = Predictor()
        x.load_data(file="Data/Training/clean_Y_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
        x.supervised_training("isolation_forest")
        x.benchmark("Data/Benchmarks/phos.csv", "Y")
        del x
    except:
        print("failed")
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Failed
# TP 162 FP 3225 TN 0 FN 401
#
#
#
# None
# failed
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 8836
# Test Data Points: 3788
# Starting Training
# Done training
# Test Results
# Failed
# TP 164 FP 3249 TN 0 FN 375
#
#
#
# None
# failed
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Failed
# TP 2841 FP 3672 TN 0 FN 753
#
#
#
# None
# failed
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16953
# Test Data Points: 7266
# Starting Training
# Done training
# Test Results
# Failed
# TP 2958 FP 3647 TN 0 FN 661
#
#
#
# None
# failed
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16840
# Test Data Points: 7218
# Starting Training
# Done training
# Test Results
# Failed
# TP 3376 FP 3126 TN 0 FN 716
#
#
#
# None
# failed
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 16841
# Test Data Points: 7218
# Starting Training
# Done training
# Test Results
# Failed
# TP 3380 FP 3103 TN 0 FN 735
#
#
#
# None
# failed
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Failed
# TP 143 FP 168 TN 0 FN 44
#
#
#
# None
# failed
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Failed
# TP 149 FP 157 TN 0 FN 49
#
#
#
# None
# failed
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8074
# Test Data Points: 3461
# Starting Training
# Done training
# Test Results
# Failed
# TP 137 FP 2974 TN 0 FN 350
#
#
#
# None
# failed
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 8077
# Test Data Points: 3463
# Starting Training
# Done training
# Test Results
# Failed
# TP 140 FP 2971 TN 0 FN 352
#
#
#
# None
# failed
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Failed
# TP 135 FP 174 TN 0 FN 46
#
#
#
# None
# failed
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 827
# Test Data Points: 355
# Starting Training
# Done training
# Test Results
# Failed
# TP 145 FP 176 TN 0 FN 34
#
#
#
# None
# failed

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    try:
        print("y", i)
        y = Predictor()
        y.load_data(file="Data/Training/clean_t_filtered.csv")
        y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
        y.supervised_training("isolation_forest")
        y.benchmark("Data/Benchmarks/phos.csv", "T")
        del y
    except:
        print("failed")
    try:
        
        print("x", i)
        x = Predictor()
        x.load_data(file="Data/Training/clean_t_filtered.csv")
        x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
        x.supervised_training("isolation_forest")
        x.benchmark("Data/Benchmarks/phos.csv", "T")
        del x
    except:
        print("failed")
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Failed
# TP 4349 FP 18024 TN 0 FN 2499
#
#
#
# None
# failed
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 58032
# Test Data Points: 24872
# Starting Training
# Done training
# Test Results
# Failed
# TP 4299 FP 18126 TN 0 FN 2447
#
#
#
# None
# failed
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Failed
# TP 17050 FP 19918 TN 0 FN 4109
#
#
#
# None
# failed
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 95846
# Test Data Points: 41077
# Starting Training
# Done training
# Test Results
# Failed
# TP 16930 FP 20032 TN 0 FN 4115
#
#
#
# None
# failed
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 94212
# Test Data Points: 40378
# Starting Training
# Done training
# Test Results
# Failed
# TP 19944 FP 16423 TN 0 FN 4011
#
#
#
# None
# failed
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 85411
# Test Data Points: 36605
# Starting Training
# Done training
# Test Results
# Failed
# TP 20165 FP 12804 TN 0 FN 3636
#
#
#
# None
# failed
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Failed
# TP 4483 FP 3635 TN 0 FN 905
#
#
#
# None
# failed
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Failed
# TP 4462 FP 3652 TN 0 FN 909
#
#
#
# None
# failed
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54642
# Test Data Points: 23419
# Starting Training
# Done training
# Test Results
# Failed
# TP 4079 FP 16921 TN 0 FN 2419
#
#
#
# None
# failed
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 54655
# Test Data Points: 23424
# Starting Training
# Done training
# Test Results
# Failed
# TP 4234 FP 16848 TN 0 FN 2342
#
#
#
# None
# failed
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Failed
# TP 4290 FP 3805 TN 0 FN 928
#
#
#
# None
# failed
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21051
# Test Data Points: 9023
# Starting Training
# Done training
# Test Results
# Failed
# TP 4293 FP 3782 TN 0 FN 948
#
#
#
# None
# failed
