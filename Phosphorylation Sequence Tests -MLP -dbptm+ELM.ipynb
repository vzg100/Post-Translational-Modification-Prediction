# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector
# Out:
# /Users/mark/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 225408
# Test Data Points: 25046
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9305495456512333
# Specificity : 0.9983352918135526
# Accuracy: 0.9858260800127765
# ROC 0.964442418732
# TP 4301 FP 34 TN 20390 FN 321
#
#
#
# None
# Cross: Validation: [ 0.98614549  0.98586572  0.9844483   0.98480735  0.98640447]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0002960331557134399
# Specificity : 0.9999840043508166
# Accuracy: 0.9487366264511723
# ROC 0.500140018753
# TP 1 FP 1 TN 62516 FN 3377
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 475862
# Test Data Points: 25046
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9319520174482007
# Specificity : 0.9977518205366307
# Accuracy: 0.9857063004072507
# ROC 0.964851918992
# TP 4273 FP 46 TN 20415 FN 312
#
#
#
# None
# Cross: Validation: [ 0.98367005  0.98614522  0.98492743  0.98578559  0.98588541]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 365767
# Test Data Points: 40641
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9224590976698066
# Specificity : 0.9919886668946314
# Accuracy: 0.9574813611869787
# ROC 0.957223882282
# TP 18606 FP 164 TN 20307 FN 1564
#
#
#
# None
# Cross: Validation: [ 0.95764182  0.94066337  0.94672802  0.94044119  0.9367995 ]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.02634695085849615
# Specificity : 0.9968648527600492
# Accuracy: 0.9471128310190454
# ROC 0.511605901809
# TP 89 FP 196 TN 62321 FN 3289
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 616221
# Test Data Points: 40641
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9250332692592045
# Specificity : 0.9869791666666666
# Accuracy: 0.9560542309490416
# ROC 0.956006217963
# TP 18768 FP 265 TN 20087 FN 1521
#
#
#
# None
# Cross: Validation: [ 0.95895821  0.9464334   0.94034276  0.94985298  0.92668643]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.0038484310242747188
# Specificity : 0.9937297055200985
# Accuracy: 0.9429850519766295
# ROC 0.498789068272
# TP 13 FP 392 TN 62125 FN 3365
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 364235
# Test Data Points: 40471
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9414779795969147
# Specificity : 0.995975657636435
# Accuracy: 0.9689160139359048
# ROC 0.968726818617
# TP 18919 FP 82 TN 20294 FN 1176
#
#
#
# None
# Cross: Validation: [ 0.96755702  0.96730952  0.96826083  0.96684004  0.96895269]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.013025458851391355
# Specificity : 0.9965929267239311
# Accuracy: 0.9461719402079065
# ROC 0.504809192788
# TP 44 FP 213 TN 62304 FN 3334
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 614502
# Test Data Points: 40450
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9418470346005122
# Specificity : 0.9967375955592346
# Accuracy: 0.9697156983930779
# ROC 0.96929231508
# TP 18755 FP 67 TN 20470 FN 1158
#
#
#
# None
# Cross: Validation: [ 0.97133534  0.96798517  0.96908491  0.96793533  0.96737908]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.023682652457075192
# Specificity : 0.9984644176783914
# Accuracy: 0.9484938159192655
# ROC 0.511073535068
# TP 80 FP 96 TN 62421 FN 3298
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 83030
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9251016477637491
# Specificity : 0.9956072918954535
# Accuracy: 0.9598959462388901
# ROC 0.96035446983
# TP 4323 FP 20 TN 4533 FN 350
#
#
#
# None
# Cross: Validation: [ 0.96200954  0.9613592   0.96482766  0.96097561  0.96590786]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 4 TN 62513 FN 3378
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 333484
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9334474641557886
# Specificity : 0.9953876564902262
# Accuracy: 0.9640147409494906
# ROC 0.964417560323
# TP 4362 FP 21 TN 4532 FN 311
#
#
#
# None
# Cross: Validation: [ 0.96222632  0.965478    0.96276826  0.95485095  0.96352304]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.012433392539964476
# Specificity : 0.9958411312123102
# Accuracy: 0.9454283329539419
# ROC 0.504137261876
# TP 42 FP 260 TN 62257 FN 3336
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 210856
# Test Data Points: 23429
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9294830196841878
# Specificity : 0.9994150802935233
# Accuracy: 0.9856161167783516
# ROC 0.964449049989
# TP 4297 FP 11 TN 18795 FN 326
#
#
#
# None
# Cross: Validation: [ 0.98580819  0.98533868  0.98623471  0.98678931  0.98465511]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 2 TN 62515 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 461332
# Test Data Points: 23431
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9287416071041802
# Specificity : 0.999468480918465
# Accuracy: 0.9855319875378772
# ROC 0.964105044011
# TP 4288 FP 10 TN 18804 FN 329
#
#
#
# None
# Cross: Validation: [ 0.98559631  0.98538261  0.98598011  0.98621455  0.98572374]
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 1 TN 62516 FN 3378
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 83030
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9494971110635566
# Specificity : 0.9866022402811333
# Accuracy: 0.9678083676566226
# ROC 0.968049675672
# TP 4437 FP 61 TN 4492 FN 236
#
#
#
# None
# Cross: Validation: [ 0.96786256  0.97414914  0.96694125  0.96780488  0.82314363]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.2912966252220249
# Specificity : 0.6920037749732073
# Accuracy: 0.6714621746718263
# ROC 0.491650200098
# TP 984 FP 19255 TN 43262 FN 2394
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 333484
# Test Data Points: 9226
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.93772736999786
# Specificity : 0.9923127608170437
# Accuracy: 0.9646650769564274
# ROC 0.965020065407
# TP 4382 FP 35 TN 4518 FN 291
#
#
#
# None
# Cross: Validation: [ 0.97393237  0.97528723  0.96482766  0.93658537  0.93246612]
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.19390171699230313
# Specificity : 0.8144664651214869
# Accuracy: 0.7826542226269064
# ROC 0.504184091057
# TP 655 FP 11599 TN 50918 FN 2723
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 11361
# Test Data Points: 1263
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.0196078431372549
# Specificity : 0.9975247524752475
# Accuracy: 0.9580364212193191
# ROC 0.508566297806
# TP 1 FP 3 TN 1209 FN 50
#
#
#
# None
# Cross: Validation: [ 0.95209818  0.95128713  0.95089109  0.95285261  0.94968304]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 42 TN 23472 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 23985
# Test Data Points: 1263
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1200 FN 63
#
#
#
# None
# Cross: Validation: [ 0.9517023   0.95366337  0.95247525  0.95324881  0.95206022]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21797
# Test Data Points: 2422
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8436988543371522
# Specificity : 0.8975
# Accuracy: 0.870355078447564
# ROC 0.870599427169
# TP 1031 FP 123 TN 1077 FN 191
#
#
#
# None
# Cross: Validation: [ 0.67905057  0.72254335  0.75557391  0.71649804  0.71422672]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.9255762524453517
# Accuracy: 0.9257057949479941
# ROC 0.962788126223
# TP 41 FP 1750 TN 21764 FN 0
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 34421
# Test Data Points: 2422
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9654320987654321
# Specificity : 0.7696768848384424
# Accuracy: 0.8678777869529315
# ROC 0.867554491802
# TP 1173 FP 278 TN 929 FN 42
#
#
#
# None
# Cross: Validation: [ 0.71661507  0.72295623  0.72749794  0.72537683  0.73301673]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.8282725184996172
# Accuracy: 0.8285714285714286
# ROC 0.91413625925
# TP 41 FP 4038 TN 19476 FN 0
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21653
# Test Data Points: 2406
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9711033274956217
# Specificity : 0.8093354430379747
# Accuracy: 0.8861180382377389
# ROC 0.890219385267
# TP 1109 FP 241 TN 1023 FN 33
#
#
#
# None
# Cross: Validation: [ 0.87014336  0.88902743  0.86616791  0.8559551   0.88921222]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.85914774177086
# Accuracy: 0.8593504563786881
# ROC 0.917378748934
# TP 40 FP 3312 TN 20202 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 34279
# Test Data Points: 2407
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8454391891891891
# Specificity : 0.910874897792314
# Accuracy: 0.8786871624428749
# ROC 0.878157043491
# TP 1001 FP 109 TN 1114 FN 183
#
#
#
# None
# Cross: Validation: [ 0.86391024  0.90442551  0.85580719  0.85910224  0.89253793]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.9164752913158118
# Accuracy: 0.9165782211844619
# ROC 0.946042523707
# TP 40 FP 1964 TN 21550 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1063
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8688524590163934
# Specificity : 0.29310344827586204
# Accuracy: 0.5882352941176471
# ROC 0.580977953646
# TP 53 FP 41 TN 17 FN 8
#
#
#
# None
# Cross: Validation: [ 0.54201681  0.48305085  0.53389831  0.51694915  0.52118644]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.4111593093476227
# Accuracy: 0.41218424962852895
# ROC 0.705579654674
# TP 41 FP 13846 TN 9668 FN 0
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13687
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5737704918032787
# Specificity : 0.6379310344827587
# Accuracy: 0.6050420168067226
# ROC 0.605850763143
# TP 35 FP 21 TN 37 FN 26
#
#
#
# None
# Cross: Validation: [ 0.53781513  0.58050847  0.6059322   0.58050847  0.58474576]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.5998128774347198
# Accuracy: 0.5988112927191679
# ROC 0.312101560669
# TP 1 FP 9410 TN 14104 FN 40
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 10379
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 1 TN 1091 FN 62
#
#
#
# None
# Cross: Validation: [ 0.94454073  0.94841786  0.94796184  0.9501301   0.94882914]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 40 TN 23474 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 23008
# Test Data Points: 1154
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.015873015873015872
# Specificity : 0.998166819431714
# Accuracy: 0.9445407279029463
# ROC 0.507019917652
# TP 1 FP 2 TN 1089 FN 62
#
#
#
# None
# Cross: Validation: [ 0.94802945  0.94887348  0.9479844   0.9479844   0.94668401]
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1063
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7049180327868853
# Specificity : 0.6379310344827587
# Accuracy: 0.6722689075630253
# ROC 0.671424533635
# TP 43 FP 21 TN 37 FN 18
#
#
#
# None
# Cross: Validation: [ 0.62605042  0.63559322  0.64830508  0.6059322   0.68220339]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.37832780471208644
# Accuracy: 0.3793674379112715
# ROC 0.676968780405
# TP 40 FP 14618 TN 8896 FN 1
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13687
# Test Data Points: 119
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.639344262295082
# Specificity : 0.6551724137931034
# Accuracy: 0.6470588235294118
# ROC 0.647258338044
# TP 39 FP 20 TN 38 FN 22
#
#
#
# None
# Cross: Validation: [ 0.63865546  0.72457627  0.56779661  0.67372881  0.58474576]
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.4130305350004253
# Accuracy: 0.4140097643812354
# ROC 0.694320145549
# TP 40 FP 13802 TN 9712 FN 1
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t_filtered.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t_filtered.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 74613
# Test Data Points: 8291
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8815520762423418
# Specificity : 0.9986807387862797
# Accuracy: 0.9779278735978773
# ROC 0.940116407514
# TP 1295 FP 9 TN 6813 FN 174
#
#
#
# None
# Cross: Validation: [ 0.98021952  0.97931492  0.98112183  0.98021713  0.98148372]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 4 TN 46493 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 157517
# Test Data Points: 8291
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9087837837837838
# Specificity : 0.9982381441785347
# Accuracy: 0.9822699312507538
# ROC 0.953510963981
# TP 1345 FP 12 TN 6799 FN 135
#
#
#
# None
# Cross: Validation: [ 0.98178748  0.98052105  0.97931242  0.98039807  0.98166466]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 123230
# Test Data Points: 13693
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8898453457834841
# Specificity : 0.9416581371545547
# Accuracy: 0.9157233623019061
# ROC 0.915751741469
# TP 6099 FP 399 TN 6440 FN 755
#
#
#
# None
# Cross: Validation: [ 0.93799752  0.84031404  0.86806164  0.83063103  0.87547473]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.14274128142741282
# Specificity : 0.9463191173624105
# Accuracy: 0.9255604441650953
# ROC 0.544530199395
# TP 176 FP 2496 TN 44001 FN 1057
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 206134
# Test Data Points: 13693
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8514808362369338
# Specificity : 0.9656135194709772
# Accuracy: 0.9082012707222669
# ROC 0.908547177854
# TP 5865 FP 234 TN 6571 FN 1023
#
#
#
# None
# Cross: Validation: [ 0.93482071  0.8520723   0.86477505  0.83150745  0.83088665]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.1362530413625304
# Specificity : 0.9726433963481514
# Accuracy: 0.9510370835952231
# ROC 0.554448218855
# TP 168 FP 1272 TN 45225 FN 1065
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 121167
# Test Data Points: 13464
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9200240529164161
# Specificity : 0.9914856136230182
# Accuracy: 0.9561794414735592
# ROC 0.95575483327
# TP 6120 FP 58 TN 6754 FN 532
#
#
#
# None
# Cross: Validation: [ 0.95498942  0.95970587  0.95565624  0.95528485  0.95873723]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.0024330900243309003
# Specificity : 0.9966234380712734
# Accuracy: 0.9709407081500104
# ROC 0.499528264048
# TP 3 FP 157 TN 46340 FN 1230
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 204065
# Test Data Points: 13463
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9433531292827775
# Specificity : 0.9696925754060325
# Accuracy: 0.9568446854341529
# ROC 0.956522852344
# TP 6195 FP 209 TN 6687 FN 372
#
#
#
# None
# Cross: Validation: [ 0.95610191  0.95413355  0.9573986   0.9596271   0.95375873]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.040551500405515
# Specificity : 0.9726218895842742
# Accuracy: 0.9485438927299392
# ROC 0.506586694995
# TP 50 FP 1273 TN 45224 FN 1183
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 27066
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8930654569021387
# Specificity : 0.9959044368600682
# Accuracy: 0.9431515957446809
# ROC 0.944484946881
# TP 1378 FP 6 TN 1459 FN 165
#
#
#
# None
# Cross: Validation: [ 0.95046543  0.94630984  0.94911872  0.94163618  0.94978384]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 47 TN 46450 FN 1233
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 109970
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9066753078418665
# Specificity : 0.9802047781569966
# Accuracy: 0.9424867021276596
# ROC 0.943440042999
# TP 1399 FP 29 TN 1436 FN 144
#
#
#
# None
# Cross: Validation: [ 0.94830452  0.94099069  0.92534087  0.93182574  0.93864317]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.004866180048661801
# Specificity : 0.9878916919371142
# Accuracy: 0.9624973811020323
# ROC 0.496378935993
# TP 6 FP 563 TN 45934 FN 1227
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 70255
# Test Data Points: 7807
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.89
# Specificity : 0.9995243380371016
# Accuracy: 0.9784808505187652
# ROC 0.944762169019
# TP 1335 FP 3 TN 6304 FN 165
#
#
#
# None
# Cross: Validation: [ 0.97976046  0.9803369   0.98084807  0.98039969  0.98033564]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 41 TN 46456 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 153150
# Test Data Points: 7806
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8995983935742972
# Specificity : 0.9969898605830165
# Accuracy: 0.9783499871893415
# ROC 0.948294127079
# TP 1344 FP 19 TN 6293 FN 150
#
#
#
# None
# Cross: Validation: [ 0.98039844  0.98007815  0.97950032  0.97834721  0.98033312]
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 47 TN 46450 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 27066
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9176928062216462
# Specificity : 0.9843003412969283
# Accuracy: 0.9501329787234043
# ROC 0.950996573759
# TP 1416 FP 23 TN 1442 FN 127
#
#
#
# None
# Cross: Validation: [ 0.79704122  0.94730718  0.95194546  0.94113735  0.92733622]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.24249797242497972
# Specificity : 0.7911693227520055
# Accuracy: 0.7769956002514142
# ROC 0.516833647588
# TP 299 FP 9710 TN 36787 FN 934
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 109970
# Test Data Points: 3008
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9338950097213221
# Specificity : 0.9638225255972697
# Accuracy: 0.948470744680851
# ROC 0.948858767659
# TP 1441 FP 53 TN 1412 FN 102
#
#
#
# None
# Cross: Validation: [ 0.75132979  0.94830452  0.95809777  0.94512803  0.93182574]
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.45093268450932683
# Specificity : 0.7097877282405316
# Accuracy: 0.7031007751937984
# ROC 0.580360206375
# TP 556 FP 13494 TN 33003 FN 677
#
#
#
# None
