# %% [markdown]
# Template for test

# %%
from pred import Predictor
from pred import sequence_vector
from pred import chemical_vector

# %% [markdown]
# Controlling for Random Negatve vs Sans Random in Imbalanced Techniques using S, T, and Y Phosphorylation.
#
# Included is N Phosphorylation however no benchmarks are available, yet.
#
#
# Training data is from phospho.elm and benchmarks are from dbptm.

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_s.csv")
    y.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "S")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_s.csv")
    x.process_data(vector_function="sequence", amino_acid="S", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "S")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 225408
# Test Data Points: 25046
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.002976190476190476
# Specificity : 0.9996762444354512
# Accuracy: 0.9863051984348798
# ROC 0.501326217456
# TP 1 FP 8 TN 24702 FN 335
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.011841326228537596
# Specificity : 0.9999840043508166
# Accuracy: 0.9493284771226952
# ROC 0.50591266529
# TP 40 FP 1 TN 62516 FN 3338
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 475862
# Test Data Points: 25046
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 2 TN 24720 FN 324
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 446261
# Test Data Points: 49585
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9088780330251524
# Specificity : 0.8497743391360413
# Accuracy: 0.8792981748512655
# ROC 0.879326186081
# TP 22512 FP 3728 TN 21088 FN 2257
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.3037300177619893
# Specificity : 0.81560215621351
# Accuracy: 0.7893618635708324
# ROC 0.559666086988
# TP 1026 FP 11528 TN 50989 FN 2352
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 696715
# Test Data Points: 49585
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8476898823719633
# Specificity : 0.953272156483941
# Accuracy: 0.9005949379852778
# ROC 0.900481019428
# TP 20971 FP 1161 TN 23685 FN 3768
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.18146832445233865
# Specificity : 0.9453428667402467
# Accuracy: 0.9061840807345019
# ROC 0.563405595596
# TP 613 FP 3417 TN 59100 FN 2765
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 445034
# Test Data Points: 49449
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8296976810069205
# Specificity : 0.8464834276475344
# Accuracy: 0.8380958158911201
# ROC 0.838090554327
# TP 20501 FP 3798 TN 20942 FN 4208
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.2673179396092362
# Specificity : 0.7935761472879377
# Accuracy: 0.7665983762045678
# ROC 0.530447043449
# TP 903 FP 12905 TN 49612 FN 2475
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 695489
# Test Data Points: 49449
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.850337933546481
# Specificity : 0.8425626515763945
# Accuracy: 0.8464478553661348
# ROC 0.846450292561
# TP 21011 FP 3895 TN 20845 FN 3698
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.2664298401420959
# Specificity : 0.7877217396868051
# Accuracy: 0.7609985583124668
# ROC 0.527075789914
# TP 900 FP 13271 TN 49246 FN 2478
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5779
# Test Data Points: 643
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8220064724919094
# Specificity : 0.4311377245508982
# Accuracy: 0.6189735614307932
# ROC 0.626572098521
# TP 254 FP 190 TN 144 FN 55
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.9363528715216104
# Specificity : 0.19314746388982196
# Accuracy: 0.2312466803247591
# ROC 0.564750167706
# TP 3163 FP 50442 TN 12075 FN 215
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 256233
# Test Data Points: 643
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7540453074433657
# Specificity : 0.5568862275449101
# Accuracy: 0.6516329704510109
# ROC 0.655465767494
# TP 233 FP 148 TN 186 FN 76
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.7782711663706335
# Specificity : 0.43877665275045186
# Accuracy: 0.45618028681994083
# ROC 0.608523909561
# TP 2629 FP 35086 TN 27431 FN 749
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 220652
# Test Data Points: 24517
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 24186 FN 331
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 471098
# Test Data Points: 24516
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 24185 FN 331
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Failed
# TP 0 FP 0 TN 62517 FN 3378
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 5779
# Test Data Points: 643
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9288025889967637
# Specificity : 0.9401197604790419
# Accuracy: 0.9346811819595645
# ROC 0.934461174738
# TP 287 FP 20 TN 314 FN 22
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.9751332149200711
# Specificity : 0.009453428667402466
# Accuracy: 0.058957432278625085
# ROC 0.492293321794
# TP 3294 FP 61926 TN 591 FN 84
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 250454
# Filtering Random Data
# Random Data Added: 250454
# Finished with Random Data
# Training Data Points: 256233
# Test Data Points: 643
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9579288025889967
# Specificity : 0.9311377245508982
# Accuracy: 0.9440124416796267
# ROC 0.94453326357
# TP 296 FP 23 TN 311 FN 13
#
#
#
# None
# Number of data points in benchmark 65895
# Benchmark Results
# Sensitivity: 0.9994079336885732
# Specificity : 0.002783242957915447
# Accuracy: 0.053873586766826013
# ROC 0.501095588323
# TP 3376 FP 62343 TN 174 FN 2
#
#
#
# None

# %% [markdown]
# Y Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_Y.csv")
    y.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "Y")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_Y.csv")
    x.process_data(vector_function="sequence", amino_acid="Y", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "Y")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 11361
# Test Data Points: 1263
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1203 FN 60
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 23985
# Test Data Points: 1263
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.029850746268656716
# Specificity : 0.9983277591973244
# Accuracy: 0.9469517022961204
# ROC 0.514089252733
# TP 2 FP 2 TN 1194 FN 65
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21832
# Test Data Points: 2426
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.897497982243745
# Specificity : 0.8803706823925863
# Accuracy: 0.8891178895300906
# ROC 0.888934332318
# TP 1112 FP 142 TN 1045 FN 127
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8815173938929999
# Accuracy: 0.8816811717257482
# ROC 0.928563574995
# TP 40 FP 2786 TN 20728 FN 1
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 34456
# Test Data Points: 2426
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8738884397736459
# Specificity : 0.8940285954583683
# Accuracy: 0.8837592745259687
# ROC 0.883958517616
# TP 1081 FP 126 TN 1063 FN 156
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.9102662243769669
# Accuracy: 0.9087242623646784
# ROC 0.46732823414
# TP 1 FP 2110 TN 21404 FN 40
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 21706
# Test Data Points: 2412
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9101497504159733
# Specificity : 0.8099173553719008
# Accuracy: 0.8598673300165838
# ROC 0.860033552894
# TP 1094 FP 230 TN 980 FN 108
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8542995662158714
# Accuracy: 0.8545107195924432
# ROC 0.914954661157
# TP 40 FP 3426 TN 20088 FN 1
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 34332
# Test Data Points: 2413
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8887966804979253
# Specificity : 0.8998344370860927
# Accuracy: 0.8943224202237878
# ROC 0.894315558792
# TP 1071 FP 121 TN 1087 FN 134
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.9217487454282555
# Accuracy: 0.9218424962852897
# ROC 0.948679250763
# TP 40 FP 1840 TN 21674 FN 1
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2463768115942029
# Specificity : 0.7954545454545454
# Accuracy: 0.46017699115044247
# ROC 0.520915678524
# TP 17 FP 9 TN 35 FN 52
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.024390243902439025
# Specificity : 0.7557199965977716
# Accuracy: 0.7544470388452558
# ROC 0.39005512025
# TP 1 FP 5744 TN 17770 FN 40
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13633
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.18840579710144928
# Specificity : 0.7727272727272727
# Accuracy: 0.415929203539823
# ROC 0.480566534914
# TP 13 FP 10 TN 34 FN 56
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 0.975609756097561
# Specificity : 0.8036914178787106
# Accuracy: 0.8039906601570792
# ROC 0.889650586988
# TP 40 FP 4616 TN 18898 FN 1
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 10413
# Test Data Points: 1158
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1102 FN 56
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 23047
# Test Data Points: 1159
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 1103 FN 56
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 0 TN 23514 FN 41
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 1009
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.2753623188405797
# Specificity : 0.9090909090909091
# Accuracy: 0.5221238938053098
# ROC 0.592226613966
# TP 19 FP 4 TN 40 FN 50
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Failed
# TP 0 FP 6138 TN 17376 FN 41
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 12624
# Filtering Random Data
# Random Data Added: 12624
# Finished with Random Data
# Training Data Points: 13633
# Test Data Points: 113
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8840579710144928
# Specificity : 0.5909090909090909
# Accuracy: 0.7699115044247787
# ROC 0.737483530962
# TP 61 FP 18 TN 26 FN 8
#
#
#
# None
# Number of data points in benchmark 23555
# Benchmark Results
# Sensitivity: 1.0
# Specificity : 0.27268861104023134
# Accuracy: 0.27395457440033966
# ROC 0.63634430552
# TP 41 FP 17102 TN 6412 FN 0
#
#
#
# None

# %% [markdown]
# T Phosphorylation

# %%
par = ["pass", "ADASYN", "SMOTEENN", "random_under_sample", "ncl", "near_miss"]
for i in par:
    print("y", i)
    y = Predictor()
    y.load_data(file="Data/Training/clean_t.csv")
    y.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=0)
    y.supervised_training("mlp_adam")
    y.benchmark("Data/Benchmarks/phos.csv", "T")
    del y
    print("x", i)
    x = Predictor()
    x.load_data(file="Data/Training/clean_t.csv")
    x.process_data(vector_function="sequence", amino_acid="T", imbalance_function=i, random_data=1)
    x.supervised_training("mlp_adam")
    x.benchmark("Data/Benchmarks/phos.csv", "T")
    del x
# Out:
# y pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Training Data Points: 74613
# Test Data Points: 8291
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 8135 FN 156
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x pass
# Loading Data
# Loaded Data
# Working on Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 157517
# Test Data Points: 8291
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 8145 FN 146
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 3 TN 46494 FN 1233
#
#
#
# None
# y ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 146495
# Test Data Points: 16278
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.879730236043462
# Specificity : 0.9026719864587112
# Accuracy: 0.8913871482983168
# ROC 0.891201111251
# TP 7044 FP 805 TN 7466 FN 963
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.2197891321978913
# Specificity : 0.905757360689937
# Accuracy: 0.8880368740833857
# ROC 0.562773246444
# TP 271 FP 4382 TN 42115 FN 962
#
#
#
# None
# x ADASYN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 229399
# Test Data Points: 16278
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9054087736789631
# Specificity : 0.8887811969953961
# Accuracy: 0.8969775156653151
# ROC 0.897094985337
# TP 7265 FP 918 TN 7336 FN 759
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.21654501216545013
# Specificity : 0.880788007828462
# Accuracy: 0.8636287450240938
# ROC 0.548666509997
# TP 267 FP 5543 TN 40954 FN 966
#
#
#
# None
# y SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 146461
# Test Data Points: 16274
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.8954483442887263
# Specificity : 0.8786993058092802
# Accuracy: 0.886997664987096
# ROC 0.887073825049
# TP 7220 FP 996 TN 7215 FN 843
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.12489862124898621
# Specificity : 0.860206034797944
# Accuracy: 0.8412109784202807
# ROC 0.492552328023
# TP 154 FP 6500 TN 39997 FN 1079
#
#
#
# None
# x SMOTEENN
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 229366
# Test Data Points: 16274
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.9167694204685574
# Specificity : 0.8596276335129839
# Accuracy: 0.8881037237311048
# ROC 0.888198526991
# TP 7435 FP 1146 TN 7018 FN 675
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.22384428223844283
# Specificity : 0.8536679785792631
# Accuracy: 0.8373978629792583
# ROC 0.538756130409
# TP 276 FP 6804 TN 39693 FN 957
#
#
#
# None
# y random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2757
# Test Data Points: 307
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7469135802469136
# Specificity : 0.5241379310344828
# Accuracy: 0.6416938110749185
# ROC 0.635525755641
# TP 121 FP 69 TN 76 FN 41
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.8491484184914841
# Specificity : 0.42323160634019397
# Accuracy: 0.43423423423423424
# ROC 0.636190012416
# TP 1047 FP 26818 TN 19679 FN 186
#
#
#
# None
# x random_under_sample
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 85661
# Test Data Points: 307
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.5246913580246914
# Specificity : 0.7586206896551724
# Accuracy: 0.6351791530944625
# ROC 0.64165602384
# TP 85 FP 35 TN 110 FN 77
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.5344687753446877
# Specificity : 0.7344559864077252
# Accuracy: 0.7292897548711502
# ROC 0.634462380876
# TP 659 FP 12347 TN 34150 FN 574
#
#
#
# None
# y ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 72030
# Test Data Points: 8004
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 7849 FN 155
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# x ncl
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 154931
# Test Data Points: 8003
# Starting Training
# Done training
# Test Results
# Failed
# TP 0 FP 0 TN 7849 FN 154
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Failed
# TP 0 FP 0 TN 46497 FN 1233
#
#
#
# None
# y near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Training Data Points: 2757
# Test Data Points: 307
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.7777777777777778
# Specificity : 0.8413793103448276
# Accuracy: 0.8078175895765473
# ROC 0.809578544061
# TP 126 FP 23 TN 122 FN 36
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.786699107866991
# Specificity : 0.17734477493171602
# Accuracy: 0.19308610936517914
# ROC 0.482021941399
# TP 970 FP 38251 TN 8246 FN 263
#
#
#
# None
# x near_miss
# Loading Data
# Loaded Data
# Working on Data
# Balancing Data
# Balanced Data
# Finished working with Data
# Random Sequences Generated 82904
# Filtering Random Data
# Random Data Added: 82904
# Finished with Random Data
# Training Data Points: 85661
# Test Data Points: 307
# Starting Training
# Done training
# Test Results
# Sensitivity: 0.6728395061728395
# Specificity : 0.8344827586206897
# Accuracy: 0.749185667752443
# ROC 0.753661132397
# TP 109 FP 24 TN 121 FN 53
#
#
#
# None
# Number of data points in benchmark 47730
# Benchmark Results
# Sensitivity: 0.8767234387672344
# Specificity : 0.17267780717035508
# Accuracy: 0.1908652838885397
# ROC 0.524700622969
# TP 1081 FP 38468 TN 8029 FN 152
#
#
#
# None
